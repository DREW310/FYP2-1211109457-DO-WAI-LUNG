# %% [markdown]
# # 14 Train GAN Make Images Dataset 2
#
# This notebook trains one StyleGAN2-ADA model per training fold, selects the lowest-KID snapshot in each fold, and generates the exact minority top-up needed for the GAN-balanced CNN runs.

# %% [markdown]
# ## Important Notes
#
# - Open Jupyter from `x64 Native Tools Command Prompt for VS 2022`.
# - Run the notebook itself in the main `fyp2` kernel so the normal notebook packages stay available.
# - Keep the `fyp2_stylegan2ada` environment available on the school Windows PC.
# - This notebook launches StyleGAN with the dedicated Windows Python path set in the config cell below.
# - This notebook keeps the GAN native resolution at `256x256`.
# - Every generated image is resized deterministically to `224x224` before the CNN notebooks use it.

# %%
from pathlib import Path
import csv
import json
import math
import os
import shutil
import subprocess
import sys
import time

import matplotlib.pyplot as plt

import pandas as pd

from IPython.display import display
from PIL import Image

# This helper keeps the notebook easy to run from the repo root or from notebooks/.
def find_repo_root(start_path: Path) -> Path:
    if (start_path / "raw_data").exists():
        return start_path
    if start_path.name == "notebooks" and (start_path.parent / "raw_data").exists():
        return start_path.parent
    raise FileNotFoundError("Could not find the FYP2 repo root.")

REPO_ROOT = find_repo_root(Path.cwd())
MANIFESTS_DIR = REPO_ROOT / "manifests"
RESULTS_DIR = REPO_ROOT / "results"
CHECKPOINTS_DIR = REPO_ROOT / "checkpoints"
GAN_PATCHES_DIR = REPO_ROOT / "gan_patches_256" / "dataset2"
GAN_IMAGES_256_DIR = REPO_ROOT / "gan_images_256" / "dataset2"
GAN_IMAGES_224_DIR = REPO_ROOT / "gan_images_224" / "dataset2"
THIRD_PARTY_DIR = REPO_ROOT / "third_party"
STYLEGAN_DIR = THIRD_PARTY_DIR / "stylegan2-ada-pytorch"
NOTEBOOK_TAG = "14_train_gan_make_images_dataset2"
NOTEBOOK_RESULTS_DIR = RESULTS_DIR / NOTEBOOK_TAG
NOTEBOOK_CHECKPOINTS_DIR = CHECKPOINTS_DIR / NOTEBOOK_TAG
NOTEBOOK_RESULTS_DIR.mkdir(parents=True, exist_ok=True)
NOTEBOOK_CHECKPOINTS_DIR.mkdir(parents=True, exist_ok=True)
GAN_IMAGES_256_DIR.mkdir(parents=True, exist_ok=True)
GAN_IMAGES_224_DIR.mkdir(parents=True, exist_ok=True)

SEED = 2026
FOLDS_TO_RUN = [1, 2, 3, 4, 5]
GAN_PATCH_SIZE = 256
CNN_PATCH_SIZE = 224
GAN_BATCH_SIZE = 8
GAN_WORKERS = 3
GAN_KIMG = 200
SNAP_TICKS = 2
GAN_MIRROR = True
ADA_TARGET = 0.6
GAN_CFG = "auto"
GAN_AUG = "ada"
GAN_AUGPIPE = "color"
KID_METRIC_NAME = "kid50k_full"
GENERATE_START_SEED = 10000
GENERATE_NOISE_MODE = "random"
LONG_COMMAND_NOTEBOOK_MODE = "smart"
KID_OPENMP_DUPLICATE_OK = True
STYLEGAN_WINDOWS_PYTHON = Path(r"C:\Users\FYP2610\anaconda3\envs\fyp2_stylegan2ada\python.exe")
STYLEGAN_TORCH_CUDA_ARCH_LIST = "8.0+PTX"
STYLEGAN_EXTENSIONS_DIR = CHECKPOINTS_DIR / "torch_extensions_sm80ptx"
STYLEGAN_EXTENSIONS_DIR.mkdir(parents=True, exist_ok=True)

if os.name == "nt":
    PYTHON_EXE = STYLEGAN_WINDOWS_PYTHON
    if not PYTHON_EXE.exists():
        raise FileNotFoundError(
            f"Could not find the StyleGAN Python executable on the Windows machine: {PYTHON_EXE}"
        )
    STYLEGAN_ENV_ROOT = PYTHON_EXE.parent
    CONDA_EXE = STYLEGAN_ENV_ROOT.parent.parent / "Scripts" / "conda.exe"
    if not CONDA_EXE.exists():
        raise FileNotFoundError(
            f"Could not find conda.exe on the Windows machine: {CONDA_EXE}"
        )
else:
    PYTHON_EXE = Path(sys.executable)
    STYLEGAN_ENV_ROOT = None
    CONDA_EXE = None

STYLEGAN_EXTRA_ENV = {
    "TORCH_CUDA_ARCH_LIST": STYLEGAN_TORCH_CUDA_ARCH_LIST,
    "TORCH_EXTENSIONS_DIR": str(STYLEGAN_EXTENSIONS_DIR),
}
if KID_OPENMP_DUPLICATE_OK:
    STYLEGAN_EXTRA_ENV["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# This helper ensures Windows subprocesses really run inside the StyleGAN conda env.
def build_stylegan_command(script_name: str, *script_args: str):
    if os.name == "nt":
        return [
            str(CONDA_EXE),
            "run",
            "--no-capture-output",
            "-p",
            str(STYLEGAN_ENV_ROOT),
            "python",
            script_name,
            *script_args,
        ]
    return [str(PYTHON_EXE), script_name, *script_args]

# %%
# This helper reads a CSV file into a plain list of rows.
def read_csv_rows(csv_path: Path):
    with csv_path.open("r", newline="", encoding="utf-8") as handle:
        return list(csv.DictReader(handle))

# This helper writes a CSV file with a stable header.
def write_csv_rows(csv_path: Path, rows, fieldnames):
    if not rows:
        raise ValueError(f"No rows were provided for {csv_path.name}.")
    csv_path.parent.mkdir(parents=True, exist_ok=True)
    with csv_path.open("w", newline="", encoding="utf-8") as handle:
        writer = csv.DictWriter(handle, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

# This helper writes one small JSON file with clean formatting.
def write_json(json_path: Path, data):
    json_path.parent.mkdir(parents=True, exist_ok=True)
    json_path.write_text(json.dumps(data, indent=2), encoding="utf-8")

# This helper stores paths in repo-relative form so the outputs stay portable.
def as_repo_relative(repo_root: Path, path_value: Path) -> str:
    return path_value.relative_to(repo_root).as_posix()

# This helper decides which command lines matter enough to echo in the notebook.
def should_echo_command_line(line_text: str, line_index: int, notebook_mode: str) -> bool:
    if notebook_mode == "all":
        return True
    if notebook_mode == "quiet":
        return False
    if line_index <= 20:
        return True
    lowered = line_text.lower()
    important_markers = [
        "training for",
        "tick ",
        "sec/kimg",
        "snapshot",
        "saved",
        "kid50k_full",
        "generating image for seed",
        "traceback",
        "runtimeerror",
        "error:",
    ]
    return any(marker in lowered for marker in important_markers)

# This helper runs a subprocess, streams useful lines to the notebook, and saves a log to disk.
def run_command(command_parts, workdir: Path, live_log_path: Path, notebook_mode: str = "smart", extra_env=None):
    live_log_path.parent.mkdir(parents=True, exist_ok=True)
    command_env = os.environ.copy()
    if extra_env is not None:
        command_env.update(extra_env)

    process = subprocess.Popen(
        command_parts,
        cwd=workdir,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        encoding="utf-8",
        errors="replace",
        env=command_env,
    )

    start_time = time.time()
    output_tail = []
    printed_line_count = 0
    suppressed_line_count = 0
    total_line_count = 0

    with live_log_path.open("w", encoding="utf-8") as log_handle:
        for line in process.stdout:
            total_line_count += 1
            output_tail.append(line)
            output_tail = output_tail[-200:]
            log_handle.write(line)
            log_handle.flush()

            line_text = line.rstrip()
            if should_echo_command_line(line_text, total_line_count, notebook_mode):
                print(line_text)
                printed_line_count += 1
            else:
                suppressed_line_count += 1

    returncode = process.wait()
    duration_seconds = round(time.time() - start_time, 2)
    report = {
        "command": " ".join(str(item) for item in command_parts),
        "returncode": returncode,
        "duration_seconds": duration_seconds,
        "printed_line_count": printed_line_count,
        "suppressed_line_count": suppressed_line_count,
        "total_line_count": total_line_count,
        "log_path": as_repo_relative(REPO_ROOT, live_log_path),
        "output_tail": "".join(output_tail),
    }
    return report

# %%
# We load the real patch manifest and compute the exact top-up target for each training fold.
real_patch_rows = read_csv_rows(MANIFESTS_DIR / "dataset2_patch_manifest_224.csv")
gan_source_rows = read_csv_rows(MANIFESTS_DIR / "dataset2_gan_patch_manifest_256.csv")
fold_manifest_rows = read_csv_rows(MANIFESTS_DIR / "dataset2_fold_manifest.csv")

for row in real_patch_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])
for row in gan_source_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])
for row in fold_manifest_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])

fold_plan_rows = []
for fold_id in FOLDS_TO_RUN:
    train_rows = [row for row in real_patch_rows if int(row["fold_id"]) == fold_id]
    gan_rows = [row for row in gan_source_rows if int(row["fold_id"]) == fold_id]
    train_cocci_count = sum(1 for row in train_rows if int(row["binary_label"]) == 0)
    train_bacilli_count = sum(1 for row in train_rows if int(row["binary_label"]) == 1)
    test_fold_ids = [value for value in FOLDS_TO_RUN if value != fold_id]
    test_fold_text = ",".join(str(value) for value in test_fold_ids)
    if train_cocci_count >= train_bacilli_count:
        raise AssertionError(
            f"Fold {fold_id} no longer has cocci as the minority class. "
            f"cocci={train_cocci_count}, bacilli={train_bacilli_count}"
        )
    needed_gan_count_224 = train_bacilli_count - train_cocci_count
    fold_plan_rows.append({
        "round_id": fold_id,
        "train_fold_id": fold_id,
        "test_fold_ids": test_fold_text,
        "real_train_patch_count_224": len(train_rows),
        "real_cocci_count_224": train_cocci_count,
        "real_bacilli_count_224": train_bacilli_count,
        "needed_gan_count_224": needed_gan_count_224,
        "real_cocci_patch_count_256_for_gan": len(gan_rows),
        "train_raw_sample_count": sum(1 for row in fold_manifest_rows if int(row["fold_id"]) == fold_id),
        "dataset_zip_path": as_repo_relative(REPO_ROOT, NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}" / f"fold_{fold_id}_minority_256.zip"),
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "fold_plan.csv", fold_plan_rows, list(fold_plan_rows[0].keys()))
display(pd.DataFrame(fold_plan_rows))
# Out:
#    round_id  train_fold_id test_fold_ids  real_train_patch_count_224  \
# 0         1              1       2,3,4,5                         870
# 1         2              2       1,3,4,5                         837
# 2         3              3       1,2,4,5                         806
# 3         4              4       1,2,3,5                         821
# 4         5              5       1,2,3,4                         845
#
#    real_cocci_count_224  real_bacilli_count_224  needed_gan_count_224  \
# 0                   380                     490                   110
# 1                   344                     493                   149
# 2                   358                     448                    90
# 3                   351                     470                   119
# 4                   354                     491                   137
#
#    real_cocci_patch_count_256_for_gan  train_raw_sample_count  \
# 0                                 260                      86
# 1                                 239                      86
# 2                                 229                      85
# 3                                 243                      85
# 4                                 240                      85
#
#                                     dataset_zip_path
# 0  results/14_train_gan_make_images_dataset2/fold...
# 1  results/14_train_gan_make_images_dataset2/fold...
# 2  results/14_train_gan_make_images_dataset2/fold...
# 3  results/14_train_gan_make_images_dataset2/fold...
# 4  results/14_train_gan_make_images_dataset2/fold...

# %%
# We create one StyleGAN zip file per training fold so each GAN only sees same-fold minority data.
dataset_zip_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    source_dir = GAN_PATCHES_DIR / f"fold_{fold_id}"
    if not source_dir.exists():
        raise FileNotFoundError(f"Missing GAN source folder for fold {fold_id}: {source_dir}")

    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    fold_result_dir.mkdir(parents=True, exist_ok=True)
    dataset_zip_path = REPO_ROOT / fold_plan["dataset_zip_path"]
    if dataset_zip_path.exists():
        dataset_zip_path.unlink()

    dataset_tool_log_path = fold_result_dir / "dataset_tool.log"
    report = run_command(
        build_stylegan_command(
            "dataset_tool.py",
            f"--source={source_dir}",
            f"--dest={dataset_zip_path}",
        ),
        STYLEGAN_DIR,
        live_log_path=dataset_tool_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=STYLEGAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "dataset_tool_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"dataset_tool.py failed for fold {fold_id}")

    dataset_zip_rows.append({
        "fold_id": fold_id,
        "source_dir": as_repo_relative(REPO_ROOT, source_dir),
        "dataset_zip_path": as_repo_relative(REPO_ROOT, dataset_zip_path),
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "dataset_zip_manifest.csv", dataset_zip_rows, list(dataset_zip_rows[0].keys()))
display(pd.DataFrame(dataset_zip_rows))
# Out:
# dataset_tool.py:205: DeprecationWarning: BOX is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BOX instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
# dataset_tool.py:205: DeprecationWarning: LANCZOS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
#
#   0%|          | 0/260 [00:00<?, ?it/s]
#   9%|▉         | 23/260 [00:00<00:01, 223.85it/s]
#  18%|█▊        | 47/260 [00:00<00:00, 229.04it/s]
#  27%|██▋       | 70/260 [00:00<00:00, 220.43it/s]
#  36%|███▌      | 94/260 [00:00<00:00, 224.67it/s]
#  45%|████▌     | 118/260 [00:00<00:00, 228.90it/s]
#  55%|█████▌    | 143/260 [00:00<00:00, 232.76it/s]
#  64%|██████▍   | 167/260 [00:00<00:00, 234.71it/s]
#  74%|███████▍  | 192/260 [00:00<00:00, 237.00it/s]
#  83%|████████▎ | 216/260 [00:00<00:00, 237.45it/s]
#  93%|█████████▎| 241/260 [00:01<00:00, 238.50it/s]
# 100%|██████████| 260/260 [00:01<00:00, 233.90it/s]
# dataset_tool.py:205: DeprecationWarning: BOX is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BOX instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
# dataset_tool.py:205: DeprecationWarning: LANCZOS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
#
#   0%|          | 0/239 [00:00<?, ?it/s]
#  10%|█         | 25/239 [00:00<00:00, 243.92it/s]
#  21%|██        | 50/239 [00:00<00:00, 245.28it/s]
#  31%|███▏      | 75/239 [00:00<00:00, 244.27it/s]
#  42%|████▏     | 100/239 [00:00<00:00, 245.53it/s]
#  52%|█████▏    | 125/239 [00:00<00:00, 244.76it/s]
#  63%|██████▎   | 150/239 [00:00<00:00, 244.82it/s]
#  73%|███████▎  | 175/239 [00:00<00:00, 239.75it/s]
#  84%|████████▎ | 200/239 [00:00<00:00, 241.36it/s]
#  94%|█████████▍| 225/239 [00:00<00:00, 243.36it/s]
# 100%|██████████| 239/239 [00:00<00:00, 243.51it/s]
# dataset_tool.py:205: DeprecationWarning: BOX is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BOX instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
# dataset_tool.py:205: DeprecationWarning: LANCZOS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
#
#   0%|          | 0/229 [00:00<?, ?it/s]
#  10%|█         | 23/229 [00:00<00:00, 229.86it/s]
#  21%|██        | 47/229 [00:00<00:00, 230.44it/s]
#  31%|███       | 71/229 [00:00<00:00, 228.66it/s]
#  41%|████▏     | 95/229 [00:00<00:00, 231.26it/s]
#  52%|█████▏    | 120/229 [00:00<00:00, 236.92it/s]
#  63%|██████▎   | 144/229 [00:00<00:00, 236.14it/s]
#  73%|███████▎  | 168/229 [00:00<00:00, 233.00it/s]
#  84%|████████▍ | 192/229 [00:00<00:00, 232.31it/s]
#  94%|█████████▍| 216/229 [00:00<00:00, 233.35it/s]
# 100%|██████████| 229/229 [00:00<00:00, 233.02it/s]
# dataset_tool.py:205: DeprecationWarning: BOX is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BOX instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
# dataset_tool.py:205: DeprecationWarning: LANCZOS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
#
#   0%|          | 0/243 [00:00<?, ?it/s]
#  10%|▉         | 24/243 [00:00<00:00, 236.10it/s]
#  20%|█▉        | 48/243 [00:00<00:00, 235.65it/s]
#  30%|██▉       | 72/243 [00:00<00:00, 235.28it/s]
#  40%|███▉      | 96/243 [00:00<00:00, 233.83it/s]
#  49%|████▉     | 120/243 [00:00<00:00, 233.36it/s]
#  59%|█████▉    | 144/243 [00:00<00:00, 231.44it/s]
#  69%|██████▉   | 168/243 [00:00<00:00, 232.16it/s]
#  79%|███████▉  | 192/243 [00:00<00:00, 233.64it/s]
#  89%|████████▉ | 216/243 [00:00<00:00, 233.99it/s]
#  99%|█████████▉| 240/243 [00:01<00:00, 234.30it/s]
# 100%|██████████| 243/243 [00:01<00:00, 234.02it/s]
# dataset_tool.py:205: DeprecationWarning: BOX is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BOX instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
# dataset_tool.py:205: DeprecationWarning: LANCZOS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   resample = { 'box': PIL.Image.BOX, 'lanczos': PIL.Image.LANCZOS }[resize_filter]
#
#   0%|          | 0/240 [00:00<?, ?it/s]
#  10%|▉         | 23/240 [00:00<00:00, 224.48it/s]
#  20%|█▉        | 47/240 [00:00<00:00, 228.90it/s]
#  30%|██▉       | 71/240 [00:00<00:00, 231.22it/s]
#  40%|███▉      | 95/240 [00:00<00:00, 231.85it/s]
#  50%|████▉     | 119/240 [00:00<00:00, 232.58it/s]
#  60%|█████▉    | 143/240 [00:00<00:00, 233.53it/s]
#  70%|██████▉   | 167/240 [00:00<00:00, 233.61it/s]
#  80%|███████▉  | 191/240 [00:00<00:00, 234.48it/s]
#  90%|█████████ | 216/240 [00:00<00:00, 238.30it/s]
# 100%|██████████| 240/240 [00:01<00:00, 236.90it/s]
# 100%|██████████| 240/240 [00:01<00:00, 234.30it/s]
#    fold_id                       source_dir  \
# 0        1  gan_patches_256/dataset2/fold_1
# 1        2  gan_patches_256/dataset2/fold_2
# 2        3  gan_patches_256/dataset2/fold_3
# 3        4  gan_patches_256/dataset2/fold_4
# 4        5  gan_patches_256/dataset2/fold_5
#
#                                     dataset_zip_path
# 0  results/14_train_gan_make_images_dataset2/fold...
# 1  results/14_train_gan_make_images_dataset2/fold...
# 2  results/14_train_gan_make_images_dataset2/fold...
# 3  results/14_train_gan_make_images_dataset2/fold...
# 4  results/14_train_gan_make_images_dataset2/fold...

# %%
# We train one StyleGAN2-ADA run per training fold and keep the logs on disk.
training_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    dataset_zip_path = REPO_ROOT / fold_plan["dataset_zip_path"]
    run_parent = NOTEBOOK_CHECKPOINTS_DIR / f"fold_{fold_id}"
    run_parent.mkdir(parents=True, exist_ok=True)
    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    train_log_path = fold_result_dir / "train.log"

    report = run_command(
        build_stylegan_command(
            "train.py",
            f"--outdir={run_parent}",
            "--gpus=1",
            f"--data={dataset_zip_path}",
            f"--cfg={GAN_CFG}",
            f"--aug={GAN_AUG}",
            f"--augpipe={GAN_AUGPIPE}",
            f"--mirror={int(GAN_MIRROR)}",
            f"--batch={GAN_BATCH_SIZE}",
            f"--kimg={GAN_KIMG}",
            f"--snap={SNAP_TICKS}",
            f"--workers={GAN_WORKERS}",
            f"--target={ADA_TARGET}",
            f"--metrics={KID_METRIC_NAME}",
        ),
        STYLEGAN_DIR,
        live_log_path=train_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=STYLEGAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "train_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"StyleGAN training failed for fold {fold_id}")

    run_dirs = [path for path in run_parent.iterdir() if path.is_dir()]
    if not run_dirs:
        raise FileNotFoundError(f"No StyleGAN run directory was found for fold {fold_id}")
    run_dir = sorted(run_dirs, key=lambda item: item.name)[-1]
    snapshot_paths = sorted(run_dir.glob("network-snapshot-*.pkl"))
    if not snapshot_paths:
        raise FileNotFoundError(f"No snapshots were saved for fold {fold_id}")

    training_rows.append({
        "fold_id": fold_id,
        "run_dir": as_repo_relative(REPO_ROOT, run_dir),
        "latest_snapshot_path": as_repo_relative(REPO_ROOT, snapshot_paths[-1]),
        "train_duration_seconds": report["duration_seconds"],
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "training_run_manifest.csv", training_rows, list(training_rows[0].keys()))
display(pd.DataFrame(training_rows))
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 2,
#   "network_snapshot_ticks": 2,
#   "metrics": [
#     "kid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:\\Users\\FYP2610\\Downloads\\FYP2\\results\\14_train_gan_make_images_dataset2\\fold_1\\fold_1_minority_256.zip",
#     "use_labels": false,
#     "max_size": 260,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 49s          sec/tick 5.0     sec/kimg 624.72  maintenance 43.8   cpumem 3.67   gpumem 4.93   augment 0.000
# {"results": {"kid50k_full": 0.4193052192269139}, "metric": "kid50k_full", "total_time": 544.5292768478394, "total_time_str": "9m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777068231.1886988}
# tick 1     kimg 4.0      time 14m 22s      sec/tick 253.6   sec/kimg 63.40   maintenance 559.3  cpumem 3.61   gpumem 3.32   augment 0.006
# tick 2     kimg 8.0      time 18m 37s      sec/tick 255.2   sec/kimg 63.79   maintenance 0.1    cpumem 3.61   gpumem 2.89   augment 0.012
# {"results": {"kid50k_full": 0.6405785257808395}, "metric": "kid50k_full", "total_time": 544.4583270549774, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000008.pkl", "timestamp": 1777069301.7926629}
# tick 3     kimg 12.0     time 32m 14s      sec/tick 255.4   sec/kimg 63.86   maintenance 561.8  cpumem 3.65   gpumem 2.89   augment 0.017
# tick 4     kimg 16.0     time 36m 30s      sec/tick 255.4   sec/kimg 63.85   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.023
# {"results": {"kid50k_full": 0.4171537385537085}, "metric": "kid50k_full", "total_time": 544.0701234340668, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000016.pkl", "timestamp": 1777070380.2546337}
# tick 5     kimg 20.0     time 50m 12s      sec/tick 255.2   sec/kimg 63.80   maintenance 567.6  cpumem 3.65   gpumem 2.89   augment 0.029
# tick 6     kimg 24.0     time 54m 28s      sec/tick 255.3   sec/kimg 63.82   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.036
# {"results": {"kid50k_full": 0.41896556753651126}, "metric": "kid50k_full", "total_time": 545.0238480567932, "total_time_str": "9m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000024.pkl", "timestamp": 1777071448.644036}
# tick 7     kimg 28.0     time 1h 08m 01s   sec/tick 255.1   sec/kimg 63.77   maintenance 557.8  cpumem 3.66   gpumem 2.89   augment 0.043
# tick 8     kimg 32.0     time 1h 12m 16s   sec/tick 255.5   sec/kimg 63.87   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.050
# {"results": {"kid50k_full": 0.27496181466824504}, "metric": "kid50k_full", "total_time": 544.1852765083313, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000032.pkl", "timestamp": 1777072519.1147594}
# tick 9     kimg 36.0     time 1h 25m 51s   sec/tick 255.3   sec/kimg 63.81   maintenance 559.9  cpumem 3.66   gpumem 2.89   augment 0.057
# tick 10    kimg 40.0     time 1h 30m 07s   sec/tick 255.3   sec/kimg 63.82   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.064
# {"results": {"kid50k_full": 0.29735586051730883}, "metric": "kid50k_full", "total_time": 543.9956378936768, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777073596.1191757}
# tick 11    kimg 44.0     time 1h 43m 48s   sec/tick 255.1   sec/kimg 63.78   maintenance 566.4  cpumem 3.66   gpumem 2.89   augment 0.071
# tick 12    kimg 48.0     time 1h 48m 04s   sec/tick 255.6   sec/kimg 63.91   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.079
# {"results": {"kid50k_full": 0.47894217794208777}, "metric": "kid50k_full", "total_time": 543.2807986736298, "total_time_str": "9m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000048.pkl", "timestamp": 1777074671.8771627}
# tick 13    kimg 52.0     time 2h 01m 44s   sec/tick 255.3   sec/kimg 63.84   maintenance 564.9  cpumem 3.66   gpumem 2.89   augment 0.086
# tick 14    kimg 56.0     time 2h 06m 00s   sec/tick 255.8   sec/kimg 63.96   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.092
# {"results": {"kid50k_full": 0.37362281047954143}, "metric": "kid50k_full", "total_time": 544.4144380092621, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000056.pkl", "timestamp": 1777075750.0464222}
# tick 15    kimg 60.0     time 2h 19m 42s   sec/tick 255.4   sec/kimg 63.84   maintenance 566.9  cpumem 3.66   gpumem 2.89   augment 0.099
# tick 16    kimg 64.0     time 2h 23m 58s   sec/tick 255.4   sec/kimg 63.85   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.103
# {"results": {"kid50k_full": 0.3055659794102403}, "metric": "kid50k_full", "total_time": 544.2328124046326, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000064.pkl", "timestamp": 1777076819.2456632}
# tick 17    kimg 68.0     time 2h 37m 32s   sec/tick 255.4   sec/kimg 63.85   maintenance 558.3  cpumem 3.66   gpumem 2.89   augment 0.110
# tick 18    kimg 72.0     time 2h 41m 47s   sec/tick 255.2   sec/kimg 63.79   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.116
# {"results": {"kid50k_full": 0.2870528057693021}, "metric": "kid50k_full", "total_time": 544.18639087677, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000072.pkl", "timestamp": 1777077889.7495987}
# tick 19    kimg 76.0     time 2h 55m 22s   sec/tick 255.1   sec/kimg 63.76   maintenance 559.9  cpumem 3.66   gpumem 2.89   augment 0.121
# tick 20    kimg 80.0     time 2h 59m 38s   sec/tick 255.7   sec/kimg 63.93   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.127
# {"results": {"kid50k_full": 0.2131762133729383}, "metric": "kid50k_full", "total_time": 543.9322211742401, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777078963.0995972}
# tick 21    kimg 84.0     time 3h 13m 16s   sec/tick 255.5   sec/kimg 63.86   maintenance 562.5  cpumem 3.75   gpumem 2.89   augment 0.132
# tick 22    kimg 88.0     time 3h 17m 31s   sec/tick 255.5   sec/kimg 63.88   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.137
# {"results": {"kid50k_full": 0.2246100796082166}, "metric": "kid50k_full", "total_time": 543.7059788703918, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000088.pkl", "timestamp": 1777080036.9298742}
# tick 23    kimg 92.0     time 3h 31m 09s   sec/tick 255.1   sec/kimg 63.79   maintenance 562.8  cpumem 3.67   gpumem 2.89   augment 0.141
# tick 24    kimg 96.0     time 3h 35m 25s   sec/tick 255.7   sec/kimg 63.93   maintenance 0.1    cpumem 3.67   gpumem 2.89   augment 0.146
# {"results": {"kid50k_full": 0.24339147453865007}, "metric": "kid50k_full", "total_time": 543.4087963104248, "total_time_str": "9m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000096.pkl", "timestamp": 1777081112.683799}
# tick 25    kimg 100.0    time 3h 49m 05s   sec/tick 255.3   sec/kimg 63.83   maintenance 564.8  cpumem 3.63   gpumem 2.89   augment 0.149
# tick 26    kimg 104.0    time 3h 53m 20s   sec/tick 255.4   sec/kimg 63.86   maintenance 0.1    cpumem 3.63   gpumem 2.89   augment 0.154
# {"results": {"kid50k_full": 0.2546523850783767}, "metric": "kid50k_full", "total_time": 543.9756524562836, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000104.pkl", "timestamp": 1777082185.625806}
# tick 27    kimg 108.0    time 4h 06m 58s   sec/tick 255.3   sec/kimg 63.83   maintenance 562.1  cpumem 3.75   gpumem 2.89   augment 0.160
# tick 28    kimg 112.0    time 4h 11m 14s   sec/tick 255.6   sec/kimg 63.89   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.165
# {"results": {"kid50k_full": 0.2575085740451725}, "metric": "kid50k_full", "total_time": 543.9408819675446, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000112.pkl", "timestamp": 1777083252.0938303}
# tick 29    kimg 116.0    time 4h 24m 44s   sec/tick 255.3   sec/kimg 63.81   maintenance 555.5  cpumem 3.75   gpumem 2.89   augment 0.170
# tick 30    kimg 120.0    time 4h 29m 00s   sec/tick 255.3   sec/kimg 63.81   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.175
# {"results": {"kid50k_full": 0.22527945007824823}, "metric": "kid50k_full", "total_time": 543.9662499427795, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777084325.6140635}
# tick 31    kimg 124.0    time 4h 42m 38s   sec/tick 255.3   sec/kimg 63.82   maintenance 563.0  cpumem 3.75   gpumem 2.89   augment 0.181
# tick 32    kimg 128.0    time 4h 46m 53s   sec/tick 255.5   sec/kimg 63.86   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.186
# {"results": {"kid50k_full": 0.2264458430756808}, "metric": "kid50k_full", "total_time": 543.3795728683472, "total_time_str": "9m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000128.pkl", "timestamp": 1777085396.8669991}
# tick 33    kimg 132.0    time 5h 00m 29s   sec/tick 255.2   sec/kimg 63.80   maintenance 560.5  cpumem 3.75   gpumem 2.89   augment 0.190
# tick 34    kimg 136.0    time 5h 04m 44s   sec/tick 255.2   sec/kimg 63.79   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.196
# {"results": {"kid50k_full": 0.14630097627246078}, "metric": "kid50k_full", "total_time": 544.260059595108, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000136.pkl", "timestamp": 1777086473.3852642}
# tick 35    kimg 140.0    time 5h 18m 26s   sec/tick 255.2   sec/kimg 63.81   maintenance 566.1  cpumem 3.75   gpumem 2.89   augment 0.200
# tick 36    kimg 144.0    time 5h 22m 41s   sec/tick 255.8   sec/kimg 63.94   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.205
# {"results": {"kid50k_full": 0.1669740505271756}, "metric": "kid50k_full", "total_time": 543.5874719619751, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000144.pkl", "timestamp": 1777087549.533361}
# tick 37    kimg 148.0    time 5h 36m 22s   sec/tick 255.4   sec/kimg 63.84   maintenance 565.1  cpumem 3.58   gpumem 2.89   augment 0.210
# tick 38    kimg 152.0    time 5h 40m 37s   sec/tick 255.5   sec/kimg 63.87   maintenance 0.1    cpumem 3.58   gpumem 2.89   augment 0.215
# {"results": {"kid50k_full": 0.18290259829746006}, "metric": "kid50k_full", "total_time": 544.9329700469971, "total_time_str": "9m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000152.pkl", "timestamp": 1777088624.5636492}
# tick 39    kimg 156.0    time 5h 54m 17s   sec/tick 255.4   sec/kimg 63.85   maintenance 564.1  cpumem 3.75   gpumem 2.89   augment 0.219
# tick 40    kimg 160.0    time 5h 58m 33s   sec/tick 255.7   sec/kimg 63.92   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.223
# {"results": {"kid50k_full": 0.10644474083689826}, "metric": "kid50k_full", "total_time": 543.6309912204742, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777089700.2151818}
# tick 41    kimg 164.0    time 6h 12m 12s   sec/tick 255.1   sec/kimg 63.79   maintenance 564.5  cpumem 3.75   gpumem 2.89   augment 0.228
# tick 42    kimg 168.0    time 6h 16m 28s   sec/tick 255.3   sec/kimg 63.82   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.234
# {"results": {"kid50k_full": 0.08134166102056724}, "metric": "kid50k_full", "total_time": 544.7910587787628, "total_time_str": "9m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000168.pkl", "timestamp": 1777090777.8615885}
# tick 43    kimg 172.0    time 6h 30m 10s   sec/tick 255.5   sec/kimg 63.86   maintenance 567.2  cpumem 3.75   gpumem 2.89   augment 0.240
# tick 44    kimg 176.0    time 6h 34m 26s   sec/tick 255.3   sec/kimg 63.83   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.247
# {"results": {"kid50k_full": 0.09987709463743116}, "metric": "kid50k_full", "total_time": 543.9909610748291, "total_time_str": "9m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000176.pkl", "timestamp": 1777091850.141729}
# tick 45    kimg 180.0    time 6h 48m 03s   sec/tick 255.6   sec/kimg 63.89   maintenance 561.5  cpumem 3.75   gpumem 2.89   augment 0.254
# tick 46    kimg 184.0    time 6h 52m 18s   sec/tick 255.3   sec/kimg 63.81   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.261
# {"results": {"kid50k_full": 0.07979339921302057}, "metric": "kid50k_full", "total_time": 545.6506903171539, "total_time_str": "9m 06s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000184.pkl", "timestamp": 1777092921.8816867}
# tick 47    kimg 188.0    time 7h 05m 54s   sec/tick 255.2   sec/kimg 63.81   maintenance 560.8  cpumem 3.76   gpumem 2.89   augment 0.268
# tick 48    kimg 192.0    time 7h 10m 10s   sec/tick 255.6   sec/kimg 63.91   maintenance 0.1    cpumem 3.76   gpumem 2.89   augment 0.276
# {"results": {"kid50k_full": 0.09377085634609673}, "metric": "kid50k_full", "total_time": 544.8187155723572, "total_time_str": "9m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000192.pkl", "timestamp": 1777093989.7344353}
# tick 49    kimg 196.0    time 7h 23m 42s   sec/tick 255.4   sec/kimg 63.85   maintenance 556.9  cpumem 3.75   gpumem 2.89   augment 0.283
# tick 50    kimg 200.0    time 7h 27m 57s   sec/tick 254.7   sec/kimg 63.80   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.291
# {"results": {"kid50k_full": 0.07881698654288799}, "metric": "kid50k_full", "total_time": 543.4220087528229, "total_time_str": "9m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777095057.311541}
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 2,
#   "network_snapshot_ticks": 2,
#   "metrics": [
#     "kid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:\\Users\\FYP2610\\Downloads\\FYP2\\results\\14_train_gan_make_images_dataset2\\fold_2\\fold_2_minority_256.zip",
#     "use_labels": false,
#     "max_size": 239,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 1m 03s       sec/tick 4.8     sec/kimg 602.01  maintenance 58.7   cpumem 3.67   gpumem 4.93   augment 0.000
# {"results": {"kid50k_full": 0.4551931562811747}, "metric": "kid50k_full", "total_time": 486.92589807510376, "total_time_str": "8m 07s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777095625.3895388}
# tick 1     kimg 4.0      time 13m 35s      sec/tick 249.7   sec/kimg 62.41   maintenance 501.4  cpumem 3.75   gpumem 3.32   augment 0.006
# tick 2     kimg 8.0      time 17m 44s      sec/tick 249.7   sec/kimg 62.42   maintenance 0.0    cpumem 3.62   gpumem 2.89   augment 0.012
# {"results": {"kid50k_full": 0.5293397551424637}, "metric": "kid50k_full", "total_time": 484.93472123146057, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000008.pkl", "timestamp": 1777096620.3477378}
# tick 3     kimg 12.0     time 30m 10s      sec/tick 249.8   sec/kimg 62.45   maintenance 495.6  cpumem 3.63   gpumem 2.89   augment 0.017
# tick 4     kimg 16.0     time 34m 20s      sec/tick 249.9   sec/kimg 62.49   maintenance 0.1    cpumem 3.63   gpumem 2.89   augment 0.023
# {"results": {"kid50k_full": 0.4781939934741032}, "metric": "kid50k_full", "total_time": 485.4171335697174, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000016.pkl", "timestamp": 1777097618.9145882}
# tick 5     kimg 20.0     time 46m 48s      sec/tick 249.7   sec/kimg 62.42   maintenance 498.7  cpumem 3.65   gpumem 2.89   augment 0.030
# tick 6     kimg 24.0     time 50m 58s      sec/tick 249.8   sec/kimg 62.46   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.036
# {"results": {"kid50k_full": 0.47736079460549913}, "metric": "kid50k_full", "total_time": 486.5611774921417, "total_time_str": "8m 07s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000024.pkl", "timestamp": 1777098628.5262253}
# tick 7     kimg 28.0     time 1h 03m 38s   sec/tick 249.6   sec/kimg 62.40   maintenance 510.0  cpumem 3.65   gpumem 2.89   augment 0.043
# tick 8     kimg 32.0     time 1h 07m 48s   sec/tick 250.0   sec/kimg 62.50   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.050
# {"results": {"kid50k_full": 0.39882264867506656}, "metric": "kid50k_full", "total_time": 485.19171476364136, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000032.pkl", "timestamp": 1777099639.3750296}
# tick 9     kimg 36.0     time 1h 20m 33s   sec/tick 254.2   sec/kimg 63.56   maintenance 511.2  cpumem 3.65   gpumem 2.89   augment 0.057
# tick 10    kimg 40.0     time 1h 24m 45s   sec/tick 252.3   sec/kimg 63.06   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.065
# {"results": {"kid50k_full": 0.42878726077108703}, "metric": "kid50k_full", "total_time": 484.58659529685974, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777100653.0167496}
# tick 11    kimg 44.0     time 1h 37m 22s   sec/tick 249.5   sec/kimg 62.37   maintenance 507.1  cpumem 3.65   gpumem 2.89   augment 0.072
# tick 12    kimg 48.0     time 1h 41m 31s   sec/tick 249.3   sec/kimg 62.33   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.080
# {"results": {"kid50k_full": 0.2917718225405961}, "metric": "kid50k_full", "total_time": 484.7722587585449, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000048.pkl", "timestamp": 1777101663.1795883}
# tick 13    kimg 52.0     time 1h 54m 12s   sec/tick 249.7   sec/kimg 62.42   maintenance 511.3  cpumem 3.65   gpumem 2.89   augment 0.087
# tick 14    kimg 56.0     time 1h 58m 22s   sec/tick 249.5   sec/kimg 62.37   maintenance 0.0    cpumem 3.65   gpumem 2.89   augment 0.093
# {"results": {"kid50k_full": 0.3720401670596724}, "metric": "kid50k_full", "total_time": 484.6363482475281, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000056.pkl", "timestamp": 1777102664.0713549}
# tick 15    kimg 60.0     time 2h 10m 53s   sec/tick 249.4   sec/kimg 62.36   maintenance 501.7  cpumem 3.65   gpumem 2.89   augment 0.099
# tick 16    kimg 64.0     time 2h 15m 02s   sec/tick 249.3   sec/kimg 62.33   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.107
# {"results": {"kid50k_full": 0.30121961398626507}, "metric": "kid50k_full", "total_time": 485.3266396522522, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000064.pkl", "timestamp": 1777103673.0326934}
# tick 17    kimg 68.0     time 2h 27m 42s   sec/tick 249.2   sec/kimg 62.29   maintenance 510.1  cpumem 3.66   gpumem 2.89   augment 0.114
# tick 18    kimg 72.0     time 2h 31m 52s   sec/tick 249.8   sec/kimg 62.44   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.119
# {"results": {"kid50k_full": 0.2989260328311792}, "metric": "kid50k_full", "total_time": 484.7923364639282, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000072.pkl", "timestamp": 1777104677.7792811}
# tick 19    kimg 76.0     time 2h 44m 27s   sec/tick 249.6   sec/kimg 62.40   maintenance 505.8  cpumem 3.66   gpumem 2.89   augment 0.126
# tick 20    kimg 80.0     time 2h 48m 37s   sec/tick 250.0   sec/kimg 62.51   maintenance 0.0    cpumem 3.44   gpumem 2.89   augment 0.133
# {"results": {"kid50k_full": 0.31093687804794884}, "metric": "kid50k_full", "total_time": 484.9602200984955, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777105685.4799259}
# tick 21    kimg 84.0     time 3h 01m 15s   sec/tick 249.9   sec/kimg 62.47   maintenance 508.0  cpumem 3.44   gpumem 2.89   augment 0.140
# tick 22    kimg 88.0     time 3h 05m 24s   sec/tick 249.5   sec/kimg 62.36   maintenance 0.1    cpumem 3.44   gpumem 2.89   augment 0.147
# {"results": {"kid50k_full": 0.40350921278170143}, "metric": "kid50k_full", "total_time": 484.6105489730835, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000088.pkl", "timestamp": 1777106692.9727616}
# tick 23    kimg 92.0     time 3h 18m 02s   sec/tick 249.5   sec/kimg 62.38   maintenance 508.1  cpumem 3.42   gpumem 2.89   augment 0.153
# tick 24    kimg 96.0     time 3h 22m 12s   sec/tick 249.8   sec/kimg 62.45   maintenance 0.1    cpumem 3.42   gpumem 2.89   augment 0.158
# {"results": {"kid50k_full": 0.2950136322134025}, "metric": "kid50k_full", "total_time": 486.0398120880127, "total_time_str": "8m 06s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000096.pkl", "timestamp": 1777107693.4377859}
# tick 25    kimg 100.0    time 3h 34m 42s   sec/tick 249.5   sec/kimg 62.36   maintenance 501.1  cpumem 3.52   gpumem 2.89   augment 0.161
# tick 26    kimg 104.0    time 3h 38m 52s   sec/tick 249.5   sec/kimg 62.39   maintenance 0.1    cpumem 3.52   gpumem 2.89   augment 0.164
# {"results": {"kid50k_full": 0.2710767235195404}, "metric": "kid50k_full", "total_time": 486.12392687797546, "total_time_str": "8m 06s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000104.pkl", "timestamp": 1777108690.7725623}
# tick 27    kimg 108.0    time 3h 51m 20s   sec/tick 249.7   sec/kimg 62.43   maintenance 498.3  cpumem 3.44   gpumem 2.89   augment 0.167
# tick 28    kimg 112.0    time 3h 55m 29s   sec/tick 248.9   sec/kimg 62.21   maintenance 0.1    cpumem 1.14   gpumem 2.89   augment 0.173
# {"results": {"kid50k_full": 0.24992505876604412}, "metric": "kid50k_full", "total_time": 485.01036286354065, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000112.pkl", "timestamp": 1777109691.5439398}
# tick 29    kimg 116.0    time 4h 08m 00s   sec/tick 249.4   sec/kimg 62.35   maintenance 502.1  cpumem 1.22   gpumem 2.89   augment 0.177
# tick 30    kimg 120.0    time 4h 12m 11s   sec/tick 250.0   sec/kimg 62.50   maintenance 0.1    cpumem 1.22   gpumem 2.89   augment 0.183
# {"results": {"kid50k_full": 0.2899272549185726}, "metric": "kid50k_full", "total_time": 484.7993941307068, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777110691.393794}
# tick 31    kimg 124.0    time 4h 24m 41s   sec/tick 249.8   sec/kimg 62.45   maintenance 500.4  cpumem 1.23   gpumem 2.89   augment 0.187
# tick 32    kimg 128.0    time 4h 28m 50s   sec/tick 249.7   sec/kimg 62.43   maintenance 0.0    cpumem 1.23   gpumem 2.89   augment 0.194
# {"results": {"kid50k_full": 0.24774072993535834}, "metric": "kid50k_full", "total_time": 485.4696350097656, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000128.pkl", "timestamp": 1777111693.2911105}
# tick 33    kimg 132.0    time 4h 41m 22s   sec/tick 249.5   sec/kimg 62.38   maintenance 502.3  cpumem 1.23   gpumem 2.89   augment 0.201
# tick 34    kimg 136.0    time 4h 45m 32s   sec/tick 249.6   sec/kimg 62.40   maintenance 0.1    cpumem 1.23   gpumem 2.89   augment 0.208
# {"results": {"kid50k_full": 0.20482456830638454}, "metric": "kid50k_full", "total_time": 485.46213698387146, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000136.pkl", "timestamp": 1777112699.5298696}
# tick 35    kimg 140.0    time 4h 58m 09s   sec/tick 249.5   sec/kimg 62.38   maintenance 507.0  cpumem 1.23   gpumem 2.89   augment 0.215
# tick 36    kimg 144.0    time 5h 02m 19s   sec/tick 249.9   sec/kimg 62.47   maintenance 0.1    cpumem 1.23   gpumem 2.89   augment 0.223
# {"results": {"kid50k_full": 0.21954408584951018}, "metric": "kid50k_full", "total_time": 485.29898953437805, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000144.pkl", "timestamp": 1777113701.3036482}
# tick 37    kimg 148.0    time 5h 14m 50s   sec/tick 249.3   sec/kimg 62.33   maintenance 502.3  cpumem 1.23   gpumem 2.89   augment 0.231
# tick 38    kimg 152.0    time 5h 19m 00s   sec/tick 249.6   sec/kimg 62.40   maintenance 0.1    cpumem 1.23   gpumem 2.89   augment 0.239
# {"results": {"kid50k_full": 0.24079204761584175}, "metric": "kid50k_full", "total_time": 484.86247515678406, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000152.pkl", "timestamp": 1777114698.834631}
# tick 39    kimg 156.0    time 5h 31m 28s   sec/tick 249.9   sec/kimg 62.46   maintenance 498.5  cpumem 1.29   gpumem 2.89   augment 0.247
# tick 40    kimg 160.0    time 5h 35m 38s   sec/tick 249.8   sec/kimg 62.45   maintenance 0.0    cpumem 1.29   gpumem 2.89   augment 0.254
# {"results": {"kid50k_full": 0.2154501705128314}, "metric": "kid50k_full", "total_time": 484.7001864910126, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777115696.2580595}
# tick 41    kimg 164.0    time 5h 48m 05s   sec/tick 249.6   sec/kimg 62.40   maintenance 497.7  cpumem 1.29   gpumem 2.89   augment 0.262
# tick 42    kimg 168.0    time 5h 52m 15s   sec/tick 249.4   sec/kimg 62.36   maintenance 0.1    cpumem 1.29   gpumem 2.89   augment 0.270
# {"results": {"kid50k_full": 0.2010273780479305}, "metric": "kid50k_full", "total_time": 484.92566776275635, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000168.pkl", "timestamp": 1777116694.5394034}
# tick 43    kimg 172.0    time 6h 04m 43s   sec/tick 249.4   sec/kimg 62.36   maintenance 499.2  cpumem 1.29   gpumem 2.89   augment 0.278
# tick 44    kimg 176.0    time 6h 08m 53s   sec/tick 249.7   sec/kimg 62.41   maintenance 0.1    cpumem 1.29   gpumem 2.89   augment 0.286
# {"results": {"kid50k_full": 0.2069312205737629}, "metric": "kid50k_full", "total_time": 484.47364473342896, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000176.pkl", "timestamp": 1777117691.9664583}
# tick 45    kimg 180.0    time 6h 21m 21s   sec/tick 249.4   sec/kimg 62.36   maintenance 498.3  cpumem 1.29   gpumem 2.89   augment 0.294
# tick 46    kimg 184.0    time 6h 25m 31s   sec/tick 249.7   sec/kimg 62.42   maintenance 0.1    cpumem 1.29   gpumem 2.89   augment 0.302
# {"results": {"kid50k_full": 0.2127215144282577}, "metric": "kid50k_full", "total_time": 484.9402606487274, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000184.pkl", "timestamp": 1777118689.859704}
# tick 47    kimg 188.0    time 6h 37m 59s   sec/tick 249.5   sec/kimg 62.38   maintenance 498.7  cpumem 1.29   gpumem 2.89   augment 0.310
# tick 48    kimg 192.0    time 6h 42m 09s   sec/tick 249.7   sec/kimg 62.42   maintenance 0.0    cpumem 1.29   gpumem 2.89   augment 0.317
# {"results": {"kid50k_full": 0.3463211456530103}, "metric": "kid50k_full", "total_time": 486.20687794685364, "total_time_str": "8m 06s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000192.pkl", "timestamp": 1777119696.014965}
# tick 49    kimg 196.0    time 6h 54m 45s   sec/tick 249.5   sec/kimg 62.37   maintenance 506.9  cpumem 1.20   gpumem 2.89   augment 0.325
# tick 50    kimg 200.0    time 6h 58m 54s   sec/tick 248.7   sec/kimg 62.30   maintenance 0.1    cpumem 1.20   gpumem 2.89   augment 0.333
# {"results": {"kid50k_full": 0.34786013833885215}, "metric": "kid50k_full", "total_time": 485.56228494644165, "total_time_str": "8m 06s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777120698.2618008}
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 2,
#   "network_snapshot_ticks": 2,
#   "metrics": [
#     "kid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:\\Users\\FYP2610\\Downloads\\FYP2\\results\\14_train_gan_make_images_dataset2\\fold_3\\fold_3_minority_256.zip",
#     "use_labels": false,
#     "max_size": 229,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 48s          sec/tick 4.8     sec/kimg 596.28  maintenance 43.1   cpumem 3.67   gpumem 4.93   augment 0.000
# {"results": {"kid50k_full": 0.44529166924632}, "metric": "kid50k_full", "total_time": 485.4582509994507, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777121249.7374651}
# tick 1     kimg 4.0      time 13m 17s      sec/tick 248.5   sec/kimg 62.14   maintenance 500.1  cpumem 3.61   gpumem 3.32   augment 0.006
# tick 2     kimg 8.0      time 17m 26s      sec/tick 249.0   sec/kimg 62.25   maintenance 0.0    cpumem 3.61   gpumem 2.89   augment 0.012
# {"results": {"kid50k_full": 0.5251313887796044}, "metric": "kid50k_full", "total_time": 484.39093685150146, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000008.pkl", "timestamp": 1777122251.8941488}
# tick 3     kimg 12.0     time 29m 59s      sec/tick 249.1   sec/kimg 62.29   maintenance 504.6  cpumem 3.64   gpumem 2.89   augment 0.018
# tick 4     kimg 16.0     time 34m 08s      sec/tick 249.0   sec/kimg 62.25   maintenance 0.1    cpumem 3.64   gpumem 2.89   augment 0.024
# {"results": {"kid50k_full": 0.477949816859766}, "metric": "kid50k_full", "total_time": 483.3559293746948, "total_time_str": "8m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000016.pkl", "timestamp": 1777123250.866407}
# tick 5     kimg 20.0     time 46m 38s      sec/tick 248.4   sec/kimg 62.11   maintenance 500.8  cpumem 3.64   gpumem 2.89   augment 0.031
# tick 6     kimg 24.0     time 50m 47s      sec/tick 249.1   sec/kimg 62.28   maintenance 0.1    cpumem 3.64   gpumem 2.89   augment 0.038
# {"results": {"kid50k_full": 0.48865284468497927}, "metric": "kid50k_full", "total_time": 486.87468814849854, "total_time_str": "8m 07s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000024.pkl", "timestamp": 1777124260.5478477}
# tick 7     kimg 28.0     time 1h 03m 28s   sec/tick 249.1   sec/kimg 62.28   maintenance 512.1  cpumem 3.64   gpumem 2.89   augment 0.045
# tick 8     kimg 32.0     time 1h 07m 37s   sec/tick 249.3   sec/kimg 62.34   maintenance 0.1    cpumem 3.64   gpumem 2.89   augment 0.052
# {"results": {"kid50k_full": 0.3728287423160307}, "metric": "kid50k_full", "total_time": 485.972953081131, "total_time_str": "8m 06s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000032.pkl", "timestamp": 1777125270.1488848}
# tick 9     kimg 36.0     time 1h 20m 18s   sec/tick 249.4   sec/kimg 62.35   maintenance 511.0  cpumem 3.64   gpumem 2.89   augment 0.059
# tick 10    kimg 40.0     time 1h 24m 27s   sec/tick 249.4   sec/kimg 62.35   maintenance 0.0    cpumem 3.64   gpumem 2.89   augment 0.067
# {"results": {"kid50k_full": 0.41332177843314394}, "metric": "kid50k_full", "total_time": 486.97268319129944, "total_time_str": "8m 07s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777126279.0435927}
# tick 11    kimg 44.0     time 1h 37m 06s   sec/tick 249.2   sec/kimg 62.29   maintenance 510.0  cpumem 3.65   gpumem 2.89   augment 0.074
# tick 12    kimg 48.0     time 1h 41m 16s   sec/tick 249.6   sec/kimg 62.40   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.081
# {"results": {"kid50k_full": 0.3274233002127788}, "metric": "kid50k_full", "total_time": 483.636332988739, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000048.pkl", "timestamp": 1777127286.3901563}
# tick 13    kimg 52.0     time 1h 53m 54s   sec/tick 249.1   sec/kimg 62.28   maintenance 508.5  cpumem 3.66   gpumem 2.89   augment 0.089
# tick 14    kimg 56.0     time 1h 58m 03s   sec/tick 249.0   sec/kimg 62.24   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.097
# {"results": {"kid50k_full": 0.5348124887038885}, "metric": "kid50k_full", "total_time": 483.91307163238525, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000056.pkl", "timestamp": 1777128294.7371147}
# tick 15    kimg 60.0     time 2h 10m 42s   sec/tick 249.0   sec/kimg 62.24   maintenance 510.2  cpumem 3.65   gpumem 2.89   augment 0.105
# tick 16    kimg 64.0     time 2h 14m 51s   sec/tick 249.1   sec/kimg 62.27   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.113
# {"results": {"kid50k_full": 0.3993018412771605}, "metric": "kid50k_full", "total_time": 484.2064139842987, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000064.pkl", "timestamp": 1777129298.4899547}
# tick 17    kimg 68.0     time 2h 27m 26s   sec/tick 249.1   sec/kimg 62.28   maintenance 505.7  cpumem 3.64   gpumem 2.89   augment 0.118
# tick 18    kimg 72.0     time 2h 31m 37s   sec/tick 250.7   sec/kimg 62.66   maintenance 0.1    cpumem 3.64   gpumem 2.89   augment 0.125
# {"results": {"kid50k_full": 0.41190768721457055}, "metric": "kid50k_full", "total_time": 484.00988006591797, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000072.pkl", "timestamp": 1777130308.1972463}
# tick 19    kimg 76.0     time 2h 44m 14s   sec/tick 247.4   sec/kimg 61.85   maintenance 509.9  cpumem 3.58   gpumem 2.89   augment 0.132
# tick 20    kimg 80.0     time 2h 48m 23s   sec/tick 249.2   sec/kimg 62.30   maintenance 0.1    cpumem 3.58   gpumem 2.89   augment 0.139
# {"results": {"kid50k_full": 0.4341162176496301}, "metric": "kid50k_full", "total_time": 484.17827558517456, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777131312.8024714}
# tick 21    kimg 84.0     time 3h 01m 00s   sec/tick 248.6   sec/kimg 62.16   maintenance 508.0  cpumem 3.50   gpumem 2.89   augment 0.143
# tick 22    kimg 88.0     time 3h 05m 09s   sec/tick 249.2   sec/kimg 62.31   maintenance 0.1    cpumem 3.50   gpumem 2.89   augment 0.147
# {"results": {"kid50k_full": 0.4035765649212675}, "metric": "kid50k_full", "total_time": 484.22360014915466, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000088.pkl", "timestamp": 1777132315.0623398}
# tick 23    kimg 92.0     time 3h 17m 42s   sec/tick 249.1   sec/kimg 62.27   maintenance 504.3  cpumem 3.66   gpumem 2.89   augment 0.150
# tick 24    kimg 96.0     time 3h 21m 51s   sec/tick 249.0   sec/kimg 62.26   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.157
# {"results": {"kid50k_full": 0.24207188709483698}, "metric": "kid50k_full", "total_time": 484.16579365730286, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000096.pkl", "timestamp": 1777133321.118795}
# tick 25    kimg 100.0    time 3h 34m 28s   sec/tick 248.8   sec/kimg 62.20   maintenance 507.9  cpumem 3.58   gpumem 2.89   augment 0.163
# tick 26    kimg 104.0    time 3h 38m 37s   sec/tick 248.8   sec/kimg 62.21   maintenance 0.1    cpumem 3.58   gpumem 2.89   augment 0.169
# {"results": {"kid50k_full": 0.27584496018677385}, "metric": "kid50k_full", "total_time": 485.0825397968292, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000104.pkl", "timestamp": 1777134325.5124774}
# tick 27    kimg 108.0    time 3h 51m 12s   sec/tick 248.6   sec/kimg 62.15   maintenance 506.7  cpumem 3.67   gpumem 2.89   augment 0.169
# tick 28    kimg 112.0    time 3h 55m 21s   sec/tick 249.0   sec/kimg 62.26   maintenance 0.0    cpumem 3.67   gpumem 2.89   augment 0.171
# {"results": {"kid50k_full": 0.2629539610324818}, "metric": "kid50k_full", "total_time": 484.786657333374, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000112.pkl", "timestamp": 1777135321.9451385}
# tick 29    kimg 116.0    time 4h 07m 49s   sec/tick 248.8   sec/kimg 62.21   maintenance 498.8  cpumem 3.68   gpumem 2.89   augment 0.172
# tick 30    kimg 120.0    time 4h 11m 58s   sec/tick 249.0   sec/kimg 62.25   maintenance 0.0    cpumem 3.68   gpumem 2.89   augment 0.180
# {"results": {"kid50k_full": 0.24505992835473916}, "metric": "kid50k_full", "total_time": 484.11819314956665, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777136330.2916398}
# tick 31    kimg 124.0    time 4h 24m 38s   sec/tick 249.0   sec/kimg 62.26   maintenance 510.5  cpumem 3.68   gpumem 2.89   augment 0.186
# tick 32    kimg 128.0    time 4h 28m 47s   sec/tick 249.3   sec/kimg 62.33   maintenance 0.1    cpumem 3.68   gpumem 2.89   augment 0.190
# {"results": {"kid50k_full": 0.3057541429521506}, "metric": "kid50k_full", "total_time": 484.1089987754822, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000128.pkl", "timestamp": 1777137335.7666388}
# tick 33    kimg 132.0    time 4h 41m 23s   sec/tick 249.1   sec/kimg 62.29   maintenance 507.1  cpumem 3.68   gpumem 2.89   augment 0.191
# tick 34    kimg 136.0    time 4h 45m 32s   sec/tick 248.9   sec/kimg 62.23   maintenance 0.1    cpumem 3.68   gpumem 2.89   augment 0.193
# {"results": {"kid50k_full": 0.2509615857953943}, "metric": "kid50k_full", "total_time": 484.115375995636, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000136.pkl", "timestamp": 1777138332.863434}
# tick 35    kimg 140.0    time 4h 58m 00s   sec/tick 249.0   sec/kimg 62.26   maintenance 499.0  cpumem 3.68   gpumem 2.89   augment 0.195
# tick 36    kimg 144.0    time 5h 02m 09s   sec/tick 249.0   sec/kimg 62.25   maintenance 0.1    cpumem 3.68   gpumem 2.89   augment 0.198
# {"results": {"kid50k_full": 0.22100182628485243}, "metric": "kid50k_full", "total_time": 484.6976172924042, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000144.pkl", "timestamp": 1777139328.1413088}
# tick 37    kimg 148.0    time 5h 14m 35s   sec/tick 248.9   sec/kimg 62.23   maintenance 497.2  cpumem 3.68   gpumem 2.89   augment 0.200
# tick 38    kimg 152.0    time 5h 18m 44s   sec/tick 248.9   sec/kimg 62.22   maintenance 0.0    cpumem 3.68   gpumem 2.89   augment 0.204
# {"results": {"kid50k_full": 0.19921764325811275}, "metric": "kid50k_full", "total_time": 484.8460319042206, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000152.pkl", "timestamp": 1777140325.6995292}
# tick 39    kimg 156.0    time 5h 31m 13s   sec/tick 248.8   sec/kimg 62.21   maintenance 499.7  cpumem 3.68   gpumem 2.89   augment 0.208
# tick 40    kimg 160.0    time 5h 35m 22s   sec/tick 249.4   sec/kimg 62.34   maintenance 0.1    cpumem 3.68   gpumem 2.89   augment 0.213
# {"results": {"kid50k_full": 0.14279364538629805}, "metric": "kid50k_full", "total_time": 483.87174820899963, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777141327.472726}
# tick 41    kimg 164.0    time 5h 47m 55s   sec/tick 248.9   sec/kimg 62.23   maintenance 503.5  cpumem 3.68   gpumem 2.89   augment 0.218
# tick 42    kimg 168.0    time 5h 52m 04s   sec/tick 249.1   sec/kimg 62.27   maintenance 0.1    cpumem 3.68   gpumem 2.89   augment 0.225
# {"results": {"kid50k_full": 0.1302550630755842}, "metric": "kid50k_full", "total_time": 484.60484290122986, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000168.pkl", "timestamp": 1777142329.839215}
# tick 43    kimg 172.0    time 6h 04m 37s   sec/tick 248.9   sec/kimg 62.24   maintenance 504.3  cpumem 3.68   gpumem 2.89   augment 0.232
# tick 44    kimg 176.0    time 6h 08m 46s   sec/tick 249.1   sec/kimg 62.28   maintenance 0.1    cpumem 3.68   gpumem 2.89   augment 0.239
# {"results": {"kid50k_full": 0.15760362718716972}, "metric": "kid50k_full", "total_time": 484.9634304046631, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000176.pkl", "timestamp": 1777143331.113171}
# tick 45    kimg 180.0    time 6h 21m 18s   sec/tick 248.8   sec/kimg 62.20   maintenance 503.1  cpumem 3.60   gpumem 2.89   augment 0.247
# tick 46    kimg 184.0    time 6h 25m 32s   sec/tick 253.8   sec/kimg 63.45   maintenance 0.1    cpumem 3.60   gpumem 2.89   augment 0.254
# {"results": {"kid50k_full": 0.14020057618218904}, "metric": "kid50k_full", "total_time": 484.3320517539978, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000184.pkl", "timestamp": 1777144334.6929965}
# tick 47    kimg 188.0    time 6h 38m 02s   sec/tick 248.7   sec/kimg 62.17   maintenance 500.9  cpumem 1.57   gpumem 2.89   augment 0.262
# tick 48    kimg 192.0    time 6h 42m 11s   sec/tick 249.2   sec/kimg 62.30   maintenance 0.1    cpumem 1.57   gpumem 2.89   augment 0.270
# {"results": {"kid50k_full": 0.25769247735111334}, "metric": "kid50k_full", "total_time": 484.67581725120544, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000192.pkl", "timestamp": 1777145334.6971118}
# tick 49    kimg 196.0    time 6h 54m 42s   sec/tick 249.0   sec/kimg 62.24   maintenance 502.1  cpumem 1.58   gpumem 2.89   augment 0.278
# tick 50    kimg 200.0    time 6h 58m 51s   sec/tick 248.8   sec/kimg 62.31   maintenance 0.1    cpumem 1.58   gpumem 2.89   augment 0.286
# {"results": {"kid50k_full": 0.1881934014315837}, "metric": "kid50k_full", "total_time": 481.2705478668213, "total_time_str": "8m 01s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777146328.1971054}
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 2,
#   "network_snapshot_ticks": 2,
#   "metrics": [
#     "kid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:\\Users\\FYP2610\\Downloads\\FYP2\\results\\14_train_gan_make_images_dataset2\\fold_4\\fold_4_minority_256.zip",
#     "use_labels": false,
#     "max_size": 243,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 1m 05s       sec/tick 4.7     sec/kimg 586.69  maintenance 59.8   cpumem 3.67   gpumem 4.93   augment 0.000
# {"results": {"kid50k_full": 0.4418878424780357}, "metric": "kid50k_full", "total_time": 483.32113099098206, "total_time_str": "8m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777146893.899735}
# tick 1     kimg 4.0      time 13m 31s      sec/tick 249.0   sec/kimg 62.26   maintenance 497.9  cpumem 3.61   gpumem 3.32   augment 0.006
# tick 2     kimg 8.0      time 17m 41s      sec/tick 249.0   sec/kimg 62.26   maintenance 0.1    cpumem 3.61   gpumem 2.89   augment 0.012
# {"results": {"kid50k_full": 0.4237148570029525}, "metric": "kid50k_full", "total_time": 481.9326846599579, "total_time_str": "8m 02s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000008.pkl", "timestamp": 1777147884.3120892}
# tick 3     kimg 12.0     time 30m 02s      sec/tick 248.8   sec/kimg 62.21   maintenance 492.3  cpumem 3.64   gpumem 2.89   augment 0.018
# tick 4     kimg 16.0     time 34m 12s      sec/tick 250.1   sec/kimg 62.52   maintenance 0.0    cpumem 3.64   gpumem 2.89   augment 0.025
# {"results": {"kid50k_full": 0.5186186954237054}, "metric": "kid50k_full", "total_time": 481.42582726478577, "total_time_str": "8m 01s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000016.pkl", "timestamp": 1777148886.10904}
# tick 5     kimg 20.0     time 46m 44s      sec/tick 249.5   sec/kimg 62.38   maintenance 502.8  cpumem 3.64   gpumem 2.89   augment 0.032
# tick 6     kimg 24.0     time 50m 54s      sec/tick 249.4   sec/kimg 62.35   maintenance 0.1    cpumem 3.64   gpumem 2.89   augment 0.039
# {"results": {"kid50k_full": 0.4293724906372406}, "metric": "kid50k_full", "total_time": 481.5552568435669, "total_time_str": "8m 02s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000024.pkl", "timestamp": 1777149883.5016139}
# tick 7     kimg 28.0     time 1h 03m 21s   sec/tick 249.3   sec/kimg 62.31   maintenance 498.4  cpumem 3.64   gpumem 2.89   augment 0.047
# tick 8     kimg 32.0     time 1h 07m 30s   sec/tick 249.0   sec/kimg 62.26   maintenance 0.1    cpumem 3.64   gpumem 2.89   augment 0.053
# {"results": {"kid50k_full": 0.2854170762119365}, "metric": "kid50k_full", "total_time": 481.5666618347168, "total_time_str": "8m 02s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000032.pkl", "timestamp": 1777150885.5750933}
# tick 9     kimg 36.0     time 1h 20m 03s   sec/tick 249.4   sec/kimg 62.34   maintenance 503.7  cpumem 3.65   gpumem 2.89   augment 0.060
# tick 10    kimg 40.0     time 1h 24m 13s   sec/tick 249.0   sec/kimg 62.25   maintenance 0.0    cpumem 3.65   gpumem 2.89   augment 0.068
# {"results": {"kid50k_full": 0.39675195990619705}, "metric": "kid50k_full", "total_time": 481.555123090744, "total_time_str": "8m 02s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777151888.6199179}
# tick 11    kimg 44.0     time 1h 36m 46s   sec/tick 248.9   sec/kimg 62.22   maintenance 504.6  cpumem 3.65   gpumem 2.89   augment 0.075
# tick 12    kimg 48.0     time 1h 40m 56s   sec/tick 249.6   sec/kimg 62.41   maintenance 0.0    cpumem 3.65   gpumem 2.89   augment 0.083
# {"results": {"kid50k_full": 0.39154185265303193}, "metric": "kid50k_full", "total_time": 481.44122672080994, "total_time_str": "8m 01s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000048.pkl", "timestamp": 1777152890.6385076}
# tick 13    kimg 52.0     time 1h 53m 28s   sec/tick 249.3   sec/kimg 62.32   maintenance 503.5  cpumem 3.65   gpumem 2.89   augment 0.091
# tick 14    kimg 56.0     time 1h 57m 38s   sec/tick 249.3   sec/kimg 62.32   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.098
# {"results": {"kid50k_full": 0.4048772467245651}, "metric": "kid50k_full", "total_time": 481.2261061668396, "total_time_str": "8m 01s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000056.pkl", "timestamp": 1777153892.4762151}
# tick 15    kimg 60.0     time 2h 10m 10s   sec/tick 249.3   sec/kimg 62.33   maintenance 503.2  cpumem 3.65   gpumem 2.89   augment 0.106
# tick 16    kimg 64.0     time 2h 14m 20s   sec/tick 249.6   sec/kimg 62.39   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.113
# {"results": {"kid50k_full": 0.5385062758540009}, "metric": "kid50k_full", "total_time": 481.5051097869873, "total_time_str": "8m 02s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000064.pkl", "timestamp": 1777154889.4172127}
# tick 17    kimg 68.0     time 2h 26m 47s   sec/tick 249.1   sec/kimg 62.28   maintenance 498.0  cpumem 3.65   gpumem 2.89   augment 0.118
# tick 18    kimg 72.0     time 2h 30m 56s   sec/tick 249.2   sec/kimg 62.29   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.123
# {"results": {"kid50k_full": 0.3861095489345486}, "metric": "kid50k_full", "total_time": 482.0048804283142, "total_time_str": "8m 02s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000072.pkl", "timestamp": 1777155882.6325157}
# tick 19    kimg 76.0     time 2h 43m 20s   sec/tick 249.1   sec/kimg 62.26   maintenance 494.9  cpumem 3.65   gpumem 2.89   augment 0.129
# tick 20    kimg 80.0     time 2h 47m 30s   sec/tick 249.5   sec/kimg 62.38   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.135
# {"results": {"kid50k_full": 0.2639928761232267}, "metric": "kid50k_full", "total_time": 481.41450452804565, "total_time_str": "8m 01s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777156883.9621131}
# tick 21    kimg 84.0     time 3h 00m 01s   sec/tick 248.3   sec/kimg 62.06   maintenance 502.7  cpumem 3.65   gpumem 2.89   augment 0.138
# tick 22    kimg 88.0     time 3h 04m 10s   sec/tick 249.7   sec/kimg 62.41   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.143
# {"results": {"kid50k_full": 0.292260820620121}, "metric": "kid50k_full", "total_time": 481.4651381969452, "total_time_str": "8m 01s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000088.pkl", "timestamp": 1777157884.4298213}
# tick 23    kimg 92.0     time 3h 16m 43s   sec/tick 249.6   sec/kimg 62.40   maintenance 502.5  cpumem 3.74   gpumem 2.89   augment 0.145
# tick 24    kimg 96.0     time 3h 20m 52s   sec/tick 249.5   sec/kimg 62.38   maintenance 0.1    cpumem 3.74   gpumem 2.89   augment 0.149
# {"results": {"kid50k_full": 0.29779504718267674}, "metric": "kid50k_full", "total_time": 481.9072644710541, "total_time_str": "8m 02s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000096.pkl", "timestamp": 1777158878.712565}
# tick 25    kimg 100.0    time 3h 33m 17s   sec/tick 249.5   sec/kimg 62.37   maintenance 495.1  cpumem 3.64   gpumem 2.89   augment 0.152
# tick 26    kimg 104.0    time 3h 37m 26s   sec/tick 249.1   sec/kimg 62.28   maintenance 0.1    cpumem 3.64   gpumem 2.89   augment 0.155
# ...
# tick 45    kimg 180.0    time 6h 19m 39s   sec/tick 249.2   sec/kimg 62.30   maintenance 497.7  cpumem 3.75   gpumem 2.89   augment 0.276
# tick 46    kimg 184.0    time 6h 23m 49s   sec/tick 249.6   sec/kimg 62.41   maintenance 0.0    cpumem 3.75   gpumem 2.89   augment 0.284
# {"results": {"kid50k_full": 0.1575744802493839}, "metric": "kid50k_full", "total_time": 483.4187397956848, "total_time_str": "8m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000184.pkl", "timestamp": 1777169859.8683991}
# tick 47    kimg 188.0    time 6h 36m 17s   sec/tick 249.0   sec/kimg 62.26   maintenance 499.6  cpumem 3.75   gpumem 2.89   augment 0.292
# tick 48    kimg 192.0    time 6h 40m 27s   sec/tick 250.0   sec/kimg 62.49   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.300
# {"results": {"kid50k_full": 0.14610846572530667}, "metric": "kid50k_full", "total_time": 481.540976524353, "total_time_str": "8m 02s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000192.pkl", "timestamp": 1777170862.875646}
# tick 49    kimg 196.0    time 6h 53m 01s   sec/tick 249.4   sec/kimg 62.34   maintenance 503.9  cpumem 3.75   gpumem 2.89   augment 0.308
# tick 50    kimg 200.0    time 6h 57m 10s   sec/tick 248.8   sec/kimg 62.32   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.316
# {"results": {"kid50k_full": 0.15193709626960605}, "metric": "kid50k_full", "total_time": 480.8099772930145, "total_time_str": "8m 01s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777171863.3401542}
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 2,
#   "network_snapshot_ticks": 2,
#   "metrics": [
#     "kid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:\\Users\\FYP2610\\Downloads\\FYP2\\results\\14_train_gan_make_images_dataset2\\fold_5\\fold_5_minority_256.zip",
#     "use_labels": false,
#     "max_size": 240,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 1m 02s       sec/tick 4.7     sec/kimg 588.57  maintenance 57.5   cpumem 3.67   gpumem 4.93   augment 0.000
# {"results": {"kid50k_full": 0.4382811069547049}, "metric": "kid50k_full", "total_time": 485.0893051624298, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777172428.5147924}
# tick 1     kimg 4.0      time 13m 30s      sec/tick 247.9   sec/kimg 61.98   maintenance 499.9  cpumem 3.61   gpumem 3.32   augment 0.005
# tick 2     kimg 8.0      time 17m 38s      sec/tick 248.3   sec/kimg 62.08   maintenance 0.1    cpumem 3.61   gpumem 2.89   augment 0.012
# {"results": {"kid50k_full": 0.6989876022757401}, "metric": "kid50k_full", "total_time": 483.5625274181366, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000008.pkl", "timestamp": 1777173421.1015499}
# tick 3     kimg 12.0     time 30m 03s      sec/tick 248.0   sec/kimg 62.01   maintenance 496.3  cpumem 3.64   gpumem 2.89   augment 0.018
# tick 4     kimg 16.0     time 34m 11s      sec/tick 248.4   sec/kimg 62.10   maintenance 0.1    cpumem 3.64   gpumem 2.89   augment 0.023
# {"results": {"kid50k_full": 0.36044316029426715}, "metric": "kid50k_full", "total_time": 483.29249691963196, "total_time_str": "8m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000016.pkl", "timestamp": 1777174421.6163676}
# tick 5     kimg 20.0     time 46m 44s      sec/tick 248.6   sec/kimg 62.16   maintenance 504.0  cpumem 3.64   gpumem 2.89   augment 0.029
# tick 6     kimg 24.0     time 50m 52s      sec/tick 248.3   sec/kimg 62.07   maintenance 0.1    cpumem 3.64   gpumem 2.89   augment 0.036
# {"results": {"kid50k_full": 0.49408851829681333}, "metric": "kid50k_full", "total_time": 484.39437890052795, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000024.pkl", "timestamp": 1777175414.5204268}
# tick 7     kimg 28.0     time 1h 03m 16s   sec/tick 248.3   sec/kimg 62.06   maintenance 495.9  cpumem 3.65   gpumem 2.89   augment 0.043
# tick 8     kimg 32.0     time 1h 07m 25s   sec/tick 248.2   sec/kimg 62.06   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.051
# {"results": {"kid50k_full": 0.4418565909342674}, "metric": "kid50k_full", "total_time": 484.5843710899353, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000032.pkl", "timestamp": 1777176409.0541034}
# tick 9     kimg 36.0     time 1h 19m 51s   sec/tick 248.3   sec/kimg 62.08   maintenance 498.0  cpumem 3.65   gpumem 2.89   augment 0.057
# tick 10    kimg 40.0     time 1h 23m 59s   sec/tick 248.3   sec/kimg 62.07   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.064
# {"results": {"kid50k_full": 0.303088215635079}, "metric": "kid50k_full", "total_time": 484.4912543296814, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777177414.147838}
# tick 11    kimg 44.0     time 1h 36m 35s   sec/tick 247.8   sec/kimg 61.95   maintenance 508.4  cpumem 3.65   gpumem 2.89   augment 0.071
# tick 12    kimg 48.0     time 1h 40m 44s   sec/tick 248.6   sec/kimg 62.15   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.079
# {"results": {"kid50k_full": 0.31264903079236406}, "metric": "kid50k_full", "total_time": 483.4314172267914, "total_time_str": "8m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000048.pkl", "timestamp": 1777178417.0476077}
# tick 13    kimg 52.0     time 1h 53m 19s   sec/tick 248.3   sec/kimg 62.09   maintenance 506.5  cpumem 3.65   gpumem 2.89   augment 0.086
# tick 14    kimg 56.0     time 1h 57m 27s   sec/tick 248.3   sec/kimg 62.08   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.093
# {"results": {"kid50k_full": 0.280295505962434}, "metric": "kid50k_full", "total_time": 483.1591603755951, "total_time_str": "8m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000056.pkl", "timestamp": 1777179420.0824394}
# tick 15    kimg 60.0     time 2h 10m 02s   sec/tick 248.3   sec/kimg 62.08   maintenance 506.3  cpumem 3.65   gpumem 2.89   augment 0.100
# tick 16    kimg 64.0     time 2h 14m 10s   sec/tick 248.5   sec/kimg 62.13   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.108
# {"results": {"kid50k_full": 0.32312285530803264}, "metric": "kid50k_full", "total_time": 483.66945600509644, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000064.pkl", "timestamp": 1777180423.3702273}
# tick 17    kimg 68.0     time 2h 26m 45s   sec/tick 248.2   sec/kimg 62.06   maintenance 506.4  cpumem 3.65   gpumem 2.89   augment 0.116
# tick 18    kimg 72.0     time 2h 30m 53s   sec/tick 247.9   sec/kimg 61.98   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.123
# {"results": {"kid50k_full": 0.3990794212720828}, "metric": "kid50k_full", "total_time": 484.3968770503998, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000072.pkl", "timestamp": 1777181421.6615748}
# tick 19    kimg 76.0     time 2h 43m 23s   sec/tick 248.1   sec/kimg 62.03   maintenance 502.1  cpumem 3.65   gpumem 2.89   augment 0.131
# tick 20    kimg 80.0     time 2h 47m 32s   sec/tick 248.6   sec/kimg 62.14   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.138
# {"results": {"kid50k_full": 0.35934774495102206}, "metric": "kid50k_full", "total_time": 483.5244300365448, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777182421.3854594}
# tick 21    kimg 84.0     time 3h 00m 03s   sec/tick 248.4   sec/kimg 62.10   maintenance 503.0  cpumem 3.65   gpumem 2.89   augment 0.143
# tick 22    kimg 88.0     time 3h 04m 12s   sec/tick 248.5   sec/kimg 62.13   maintenance 0.1    cpumem 3.65   gpumem 2.89   augment 0.150
# {"results": {"kid50k_full": 0.35015862692633876}, "metric": "kid50k_full", "total_time": 483.6616051197052, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000088.pkl", "timestamp": 1777183415.2424774}
# tick 23    kimg 92.0     time 3h 16m 37s   sec/tick 248.5   sec/kimg 62.11   maintenance 496.9  cpumem 3.74   gpumem 2.89   augment 0.154
# tick 24    kimg 96.0     time 3h 20m 46s   sec/tick 248.6   sec/kimg 62.14   maintenance 0.1    cpumem 3.74   gpumem 2.89   augment 0.160
# {"results": {"kid50k_full": 0.284036060898274}, "metric": "kid50k_full", "total_time": 484.1356985569, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000096.pkl", "timestamp": 1777184410.1818857}
# tick 25    kimg 100.0    time 3h 33m 12s   sec/tick 248.0   sec/kimg 62.01   maintenance 497.9  cpumem 3.66   gpumem 2.89   augment 0.165
# tick 26    kimg 104.0    time 3h 37m 20s   sec/tick 248.5   sec/kimg 62.13   maintenance 0.1    cpumem 3.66   gpumem 2.89   augment 0.170
# {"results": {"kid50k_full": 0.24686249827478499}, "metric": "kid50k_full", "total_time": 484.204918384552, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000104.pkl", "timestamp": 1777185403.3824358}
# tick 27    kimg 108.0    time 3h 49m 45s   sec/tick 248.1   sec/kimg 62.02   maintenance 496.6  cpumem 3.61   gpumem 2.89   augment 0.174
# tick 28    kimg 112.0    time 3h 53m 54s   sec/tick 248.8   sec/kimg 62.19   maintenance 0.1    cpumem 3.61   gpumem 2.89   augment 0.179
# {"results": {"kid50k_full": 0.23920545363166829}, "metric": "kid50k_full", "total_time": 484.3655791282654, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000112.pkl", "timestamp": 1777186397.4107559}
# tick 29    kimg 116.0    time 4h 06m 19s   sec/tick 248.1   sec/kimg 62.03   maintenance 497.1  cpumem 3.74   gpumem 2.89   augment 0.185
# tick 30    kimg 120.0    time 4h 10m 27s   sec/tick 248.4   sec/kimg 62.09   maintenance 0.0    cpumem 3.74   gpumem 2.89   augment 0.189
# {"results": {"kid50k_full": 0.22746909424849643}, "metric": "kid50k_full", "total_time": 484.7279691696167, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777187391.0035992}
# tick 31    kimg 124.0    time 4h 22m 53s   sec/tick 248.4   sec/kimg 62.10   maintenance 497.1  cpumem 3.75   gpumem 2.89   augment 0.194
# tick 32    kimg 128.0    time 4h 27m 02s   sec/tick 248.6   sec/kimg 62.14   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.198
# {"results": {"kid50k_full": 0.2465329256604851}, "metric": "kid50k_full", "total_time": 485.6294057369232, "total_time_str": "8m 06s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000128.pkl", "timestamp": 1777188384.2256827}
# tick 33    kimg 132.0    time 4h 39m 26s   sec/tick 248.4   sec/kimg 62.11   maintenance 496.2  cpumem 3.75   gpumem 2.89   augment 0.202
# tick 34    kimg 136.0    time 4h 43m 35s   sec/tick 248.5   sec/kimg 62.13   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.206
# {"results": {"kid50k_full": 0.19364077095092033}, "metric": "kid50k_full", "total_time": 486.9279592037201, "total_time_str": "8m 07s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000136.pkl", "timestamp": 1777189379.7867136}
# tick 35    kimg 140.0    time 4h 56m 01s   sec/tick 247.3   sec/kimg 61.83   maintenance 498.5  cpumem 3.75   gpumem 2.89   augment 0.211
# tick 36    kimg 144.0    time 5h 00m 09s   sec/tick 247.9   sec/kimg 61.98   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.217
# {"results": {"kid50k_full": 0.17474701898735318}, "metric": "kid50k_full", "total_time": 483.75761556625366, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000144.pkl", "timestamp": 1777190370.0701885}
# tick 37    kimg 148.0    time 5h 12m 32s   sec/tick 248.2   sec/kimg 62.05   maintenance 495.0  cpumem 3.75   gpumem 2.89   augment 0.223
# tick 38    kimg 152.0    time 5h 16m 40s   sec/tick 248.4   sec/kimg 62.09   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.231
# {"results": {"kid50k_full": 0.15453909295231508}, "metric": "kid50k_full", "total_time": 482.7266776561737, "total_time_str": "8m 03s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000152.pkl", "timestamp": 1777191360.7491515}
# tick 39    kimg 156.0    time 5h 29m 03s   sec/tick 248.5   sec/kimg 62.13   maintenance 494.1  cpumem 3.75   gpumem 2.89   augment 0.238
# tick 40    kimg 160.0    time 5h 33m 11s   sec/tick 248.4   sec/kimg 62.10   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.245
# {"results": {"kid50k_full": 0.16385719805105184}, "metric": "kid50k_full", "total_time": 484.5432059764862, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777192355.8185613}
# tick 41    kimg 164.0    time 5h 45m 38s   sec/tick 248.3   sec/kimg 62.07   maintenance 498.1  cpumem 3.75   gpumem 2.89   augment 0.253
# tick 42    kimg 168.0    time 5h 49m 46s   sec/tick 248.5   sec/kimg 62.12   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.261
# {"results": {"kid50k_full": 0.15938059949178793}, "metric": "kid50k_full", "total_time": 484.56836128234863, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000168.pkl", "timestamp": 1777193351.1378427}
# tick 43    kimg 172.0    time 6h 02m 13s   sec/tick 248.1   sec/kimg 62.02   maintenance 498.5  cpumem 3.75   gpumem 2.89   augment 0.269
# tick 44    kimg 176.0    time 6h 06m 21s   sec/tick 248.3   sec/kimg 62.08   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.276
# {"results": {"kid50k_full": 0.17690288252783953}, "metric": "kid50k_full", "total_time": 484.9820580482483, "total_time_str": "8m 05s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000176.pkl", "timestamp": 1777194346.0018992}
# tick 45    kimg 180.0    time 6h 18m 47s   sec/tick 247.8   sec/kimg 61.96   maintenance 498.4  cpumem 3.75   gpumem 2.89   augment 0.284
# tick 46    kimg 184.0    time 6h 22m 56s   sec/tick 248.3   sec/kimg 62.07   maintenance 0.0    cpumem 3.75   gpumem 2.89   augment 0.292
# {"results": {"kid50k_full": 0.21560304991909648}, "metric": "kid50k_full", "total_time": 484.3247151374817, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000184.pkl", "timestamp": 1777195345.6891649}
# tick 47    kimg 188.0    time 6h 35m 28s   sec/tick 248.5   sec/kimg 62.12   maintenance 503.5  cpumem 3.75   gpumem 2.89   augment 0.300
# tick 48    kimg 192.0    time 6h 39m 36s   sec/tick 248.5   sec/kimg 62.12   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.308
# {"results": {"kid50k_full": 0.22539168615478625}, "metric": "kid50k_full", "total_time": 483.81952118873596, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000192.pkl", "timestamp": 1777196342.6113024}
# tick 49    kimg 196.0    time 6h 52m 04s   sec/tick 248.2   sec/kimg 62.04   maintenance 499.9  cpumem 3.75   gpumem 2.89   augment 0.316
# tick 50    kimg 200.0    time 6h 56m 12s   sec/tick 247.6   sec/kimg 62.02   maintenance 0.1    cpumem 3.75   gpumem 2.89   augment 0.324
# {"results": {"kid50k_full": 0.19934339932734774}, "metric": "kid50k_full", "total_time": 483.8879246711731, "total_time_str": "8m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777197336.5088162}
#    fold_id                                            run_dir  \
# 0        1  checkpoints/14_train_gan_make_images_dataset2/...
# 1        2  checkpoints/14_train_gan_make_images_dataset2/...
# 2        3  checkpoints/14_train_gan_make_images_dataset2/...
# 3        4  checkpoints/14_train_gan_make_images_dataset2/...
# 4        5  checkpoints/14_train_gan_make_images_dataset2/...
#
#                                 latest_snapshot_path  train_duration_seconds
# 0  checkpoints/14_train_gan_make_images_dataset2/...                27437.03
# 1  checkpoints/14_train_gan_make_images_dataset2/...                25641.23
# 2  checkpoints/14_train_gan_make_images_dataset2/...                25629.76
# 3  checkpoints/14_train_gan_make_images_dataset2/...                25535.08
# 4  checkpoints/14_train_gan_make_images_dataset2/...                25473.00

# %%
# We read the online KID results from training and select the lowest-KID snapshot per fold.
kid_snapshot_rows = []
kid_rows = []
training_lookup = {int(row["fold_id"]): row for row in training_rows}

def parse_snapshot_kimg(snapshot_path: Path) -> int:
    return int(snapshot_path.stem.replace("network-snapshot-", ""))

def read_kid_values_by_snapshot(run_dir: Path):
    metric_file = run_dir / f"metric-{KID_METRIC_NAME}.jsonl"
    if not metric_file.exists():
        raise FileNotFoundError(f"Missing metric log: {metric_file}")

    kid_values = {}
    lines = [line for line in metric_file.read_text(encoding="utf-8").splitlines() if line.strip()]
    for line in lines:
        record = json.loads(line)
        if "results" not in record or "snapshot_pkl" not in record:
            continue
        kid_value = record["results"].get(KID_METRIC_NAME)
        if kid_value is None:
            continue
        kid_values[record["snapshot_pkl"]] = kid_value
    return kid_values

for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    run_dir = REPO_ROOT / training_lookup[fold_id]["run_dir"]
    snapshot_paths = [path for path in sorted(run_dir.glob("network-snapshot-*.pkl")) if parse_snapshot_kimg(path) > 0]
    if not snapshot_paths:
        raise FileNotFoundError(f"No trained snapshots were found for fold {fold_id}")
    kid_values = read_kid_values_by_snapshot(run_dir)

    fold_snapshot_rows = []
    for snapshot_path in snapshot_paths:
        kid_value = kid_values.get(snapshot_path.name)
        if kid_value is None:
            raise ValueError(
                f"No online KID value was found for fold {fold_id} at {snapshot_path.name}"
            )

        fold_snapshot_rows.append({
            "fold_id": fold_id,
            "snapshot_path": as_repo_relative(REPO_ROOT, snapshot_path),
            "snapshot_kimg": parse_snapshot_kimg(snapshot_path),
            "kid50k_full": kid_value,
        })

    kid_snapshot_rows.extend(fold_snapshot_rows)
    best_row = sorted(fold_snapshot_rows, key=lambda row: (row["kid50k_full"], row["snapshot_kimg"]))[0]
    kid_rows.append(best_row)

write_csv_rows(NOTEBOOK_RESULTS_DIR / "kid_snapshot_results.csv", kid_snapshot_rows, list(kid_snapshot_rows[0].keys()))
write_csv_rows(NOTEBOOK_RESULTS_DIR / "kid_results.csv", kid_rows, list(kid_rows[0].keys()))
kid_snapshot_df = pd.DataFrame(kid_snapshot_rows)
kid_df = pd.DataFrame(kid_rows)
display(kid_snapshot_df)
display(kid_df)

# This figure shows how KID moved across saved snapshots inside each fold.
fig, axis = plt.subplots(figsize=(9, 5))
for fold_id in sorted(kid_snapshot_df["fold_id"].unique()):
    current = kid_snapshot_df[kid_snapshot_df["fold_id"] == fold_id].sort_values("snapshot_kimg")
    axis.plot(current["snapshot_kimg"], current["kid50k_full"], marker="o", label=f"fold {fold_id}")
axis.set_xlabel("Snapshot kimg")
axis.set_ylabel("KID (lower is better)")
axis.set_title("KID progress by fold")
axis.legend()
fig.tight_layout()
fig.savefig(NOTEBOOK_RESULTS_DIR / "kid_progress_by_fold.png", dpi=200)
plt.show()
# Out:
#      fold_id                                      snapshot_path  \
# 0          1  checkpoints/14_train_gan_make_images_dataset2/...
# 1          1  checkpoints/14_train_gan_make_images_dataset2/...
# 2          1  checkpoints/14_train_gan_make_images_dataset2/...
# 3          1  checkpoints/14_train_gan_make_images_dataset2/...
# 4          1  checkpoints/14_train_gan_make_images_dataset2/...
# ..       ...                                                ...
# 120        5  checkpoints/14_train_gan_make_images_dataset2/...
# 121        5  checkpoints/14_train_gan_make_images_dataset2/...
# 122        5  checkpoints/14_train_gan_make_images_dataset2/...
# 123        5  checkpoints/14_train_gan_make_images_dataset2/...
# 124        5  checkpoints/14_train_gan_make_images_dataset2/...
#
#      snapshot_kimg  kid50k_full
# 0                8     0.640579
# 1               16     0.417154
# 2               24     0.418966
# 3               32     0.274962
# 4               40     0.297356
# ..             ...          ...
# 120            168     0.159381
# 121            176     0.176903
# 122            184     0.215603
# 123            192     0.225392
# 124            200     0.199343
#
# [125 rows x 4 columns]
#    fold_id                                      snapshot_path  snapshot_kimg  \
# 0        1  checkpoints/14_train_gan_make_images_dataset2/...            200
# 1        2  checkpoints/14_train_gan_make_images_dataset2/...            168
# 2        3  checkpoints/14_train_gan_make_images_dataset2/...            168
# 3        4  checkpoints/14_train_gan_make_images_dataset2/...            128
# 4        5  checkpoints/14_train_gan_make_images_dataset2/...            152
#
#    kid50k_full
# 0     0.078817
# 1     0.201027
# 2     0.130255
# 3     0.123767
# 4     0.154539

# %%
# We generate exactly the number of synthetic minority images needed to balance each training fold.
kid_lookup = {int(row["fold_id"]): row for row in kid_rows}
generated_rows_256 = []

for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    snapshot_path = REPO_ROOT / kid_lookup[fold_id]["snapshot_path"]
    generated_256_dir = GAN_IMAGES_256_DIR / f"fold_{fold_id}"
    if generated_256_dir.exists():
        shutil.rmtree(generated_256_dir)
    generated_256_dir.mkdir(parents=True, exist_ok=True)

    needed_count = int(fold_plan["needed_gan_count_224"])
    start_seed = GENERATE_START_SEED + (fold_id * 10000)
    end_seed = start_seed + needed_count - 1
    seed_text = f"{start_seed}-{end_seed}"
    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    generate_log_path = fold_result_dir / "generate.log"

    report = run_command(
        build_stylegan_command(
            "generate.py",
            f"--network={snapshot_path}",
            f"--outdir={generated_256_dir}",
            f"--seeds={seed_text}",
            f"--noise-mode={GENERATE_NOISE_MODE}",
            "--trunc=1",
        ),
        STYLEGAN_DIR,
        live_log_path=generate_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=STYLEGAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "generate_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"StyleGAN generation failed for fold {fold_id}")

    generated_files = sorted(generated_256_dir.glob("seed*.png"))
    if len(generated_files) != needed_count:
        raise AssertionError(
            f"Fold {fold_id} should have {needed_count} generated 256 images, but found {len(generated_files)}."
        )

    for generated_file in generated_files:
        seed_value = int(generated_file.stem.replace("seed", ""))
        test_fold_ids = [value for value in FOLDS_TO_RUN if value != fold_id]
        test_fold_text = ",".join(str(value) for value in test_fold_ids)
        generated_rows_256.append({
            "dataset_name": "dataset2",
            "gan_image_id": f"fold{fold_id}_seed{seed_value}_256",
            "fold_id": fold_id,
            "round_id": fold_id,
            "train_fold_id": fold_id,
            "test_fold_ids": test_fold_text,
            "binary_label": 0,
            "binary_group": "cocci",
            "seed": seed_value,
            "image_size": GAN_PATCH_SIZE,
            "file_path": as_repo_relative(REPO_ROOT, generated_file),
            "snapshot_path": as_repo_relative(REPO_ROOT, snapshot_path),
            "source_type": "gan_generated",
        })

write_csv_rows(MANIFESTS_DIR / "dataset2_gan_generated_manifest_256.csv", generated_rows_256, list(generated_rows_256[0].keys()))
display(pd.DataFrame(generated_rows_256[:10]))
# Out:
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\14_train_gan_make_images_dataset2\fold_1\00003-fold_1_minority_256-mirror-auto1-kimg200-batch8-ada-target0.6-color\network-snapshot-000200.pkl"...
# Generating image for seed 20000 (0/110) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 20001 (1/110) ...
# Generating image for seed 20002 (2/110) ...
# Generating image for seed 20003 (3/110) ...
# Generating image for seed 20004 (4/110) ...
# Generating image for seed 20005 (5/110) ...
# Generating image for seed 20006 (6/110) ...
# Generating image for seed 20007 (7/110) ...
# Generating image for seed 20008 (8/110) ...
# Generating image for seed 20009 (9/110) ...
# Generating image for seed 20010 (10/110) ...
# Generating image for seed 20011 (11/110) ...
# Generating image for seed 20012 (12/110) ...
# Generating image for seed 20013 (13/110) ...
# Generating image for seed 20014 (14/110) ...
# Generating image for seed 20015 (15/110) ...
# Generating image for seed 20016 (16/110) ...
# Generating image for seed 20017 (17/110) ...
# Generating image for seed 20018 (18/110) ...
# Generating image for seed 20019 (19/110) ...
# Generating image for seed 20020 (20/110) ...
# Generating image for seed 20021 (21/110) ...
# Generating image for seed 20022 (22/110) ...
# Generating image for seed 20023 (23/110) ...
# Generating image for seed 20024 (24/110) ...
# Generating image for seed 20025 (25/110) ...
# Generating image for seed 20026 (26/110) ...
# Generating image for seed 20027 (27/110) ...
# Generating image for seed 20028 (28/110) ...
# Generating image for seed 20029 (29/110) ...
# Generating image for seed 20030 (30/110) ...
# Generating image for seed 20031 (31/110) ...
# Generating image for seed 20032 (32/110) ...
# Generating image for seed 20033 (33/110) ...
# Generating image for seed 20034 (34/110) ...
# Generating image for seed 20035 (35/110) ...
# Generating image for seed 20036 (36/110) ...
# Generating image for seed 20037 (37/110) ...
# Generating image for seed 20038 (38/110) ...
# Generating image for seed 20039 (39/110) ...
# Generating image for seed 20040 (40/110) ...
# Generating image for seed 20041 (41/110) ...
# Generating image for seed 20042 (42/110) ...
# Generating image for seed 20043 (43/110) ...
# Generating image for seed 20044 (44/110) ...
# Generating image for seed 20045 (45/110) ...
# Generating image for seed 20046 (46/110) ...
# Generating image for seed 20047 (47/110) ...
# Generating image for seed 20048 (48/110) ...
# Generating image for seed 20049 (49/110) ...
# Generating image for seed 20050 (50/110) ...
# Generating image for seed 20051 (51/110) ...
# Generating image for seed 20052 (52/110) ...
# Generating image for seed 20053 (53/110) ...
# Generating image for seed 20054 (54/110) ...
# Generating image for seed 20055 (55/110) ...
# Generating image for seed 20056 (56/110) ...
# Generating image for seed 20057 (57/110) ...
# Generating image for seed 20058 (58/110) ...
# Generating image for seed 20059 (59/110) ...
# Generating image for seed 20060 (60/110) ...
# Generating image for seed 20061 (61/110) ...
# Generating image for seed 20062 (62/110) ...
# Generating image for seed 20063 (63/110) ...
# Generating image for seed 20064 (64/110) ...
# Generating image for seed 20065 (65/110) ...
# Generating image for seed 20066 (66/110) ...
# Generating image for seed 20067 (67/110) ...
# Generating image for seed 20068 (68/110) ...
# Generating image for seed 20069 (69/110) ...
# Generating image for seed 20070 (70/110) ...
# Generating image for seed 20071 (71/110) ...
# Generating image for seed 20072 (72/110) ...
# Generating image for seed 20073 (73/110) ...
# Generating image for seed 20074 (74/110) ...
# Generating image for seed 20075 (75/110) ...
# Generating image for seed 20076 (76/110) ...
# Generating image for seed 20077 (77/110) ...
# Generating image for seed 20078 (78/110) ...
# Generating image for seed 20079 (79/110) ...
# Generating image for seed 20080 (80/110) ...
# Generating image for seed 20081 (81/110) ...
# Generating image for seed 20082 (82/110) ...
# Generating image for seed 20083 (83/110) ...
# Generating image for seed 20084 (84/110) ...
# Generating image for seed 20085 (85/110) ...
# Generating image for seed 20086 (86/110) ...
# Generating image for seed 20087 (87/110) ...
# Generating image for seed 20088 (88/110) ...
# Generating image for seed 20089 (89/110) ...
# Generating image for seed 20090 (90/110) ...
# Generating image for seed 20091 (91/110) ...
# Generating image for seed 20092 (92/110) ...
# Generating image for seed 20093 (93/110) ...
# Generating image for seed 20094 (94/110) ...
# Generating image for seed 20095 (95/110) ...
# Generating image for seed 20096 (96/110) ...
# Generating image for seed 20097 (97/110) ...
# Generating image for seed 20098 (98/110) ...
# Generating image for seed 20099 (99/110) ...
# Generating image for seed 20100 (100/110) ...
# Generating image for seed 20101 (101/110) ...
# Generating image for seed 20102 (102/110) ...
# Generating image for seed 20103 (103/110) ...
# Generating image for seed 20104 (104/110) ...
# Generating image for seed 20105 (105/110) ...
# Generating image for seed 20106 (106/110) ...
# Generating image for seed 20107 (107/110) ...
# Generating image for seed 20108 (108/110) ...
# Generating image for seed 20109 (109/110) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\14_train_gan_make_images_dataset2\fold_2\00002-fold_2_minority_256-mirror-auto1-kimg200-batch8-ada-target0.6-color\network-snapshot-000168.pkl"...
# Generating image for seed 30000 (0/149) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 30001 (1/149) ...
# Generating image for seed 30002 (2/149) ...
# Generating image for seed 30003 (3/149) ...
# Generating image for seed 30004 (4/149) ...
# Generating image for seed 30005 (5/149) ...
# Generating image for seed 30006 (6/149) ...
# Generating image for seed 30007 (7/149) ...
# Generating image for seed 30008 (8/149) ...
# Generating image for seed 30009 (9/149) ...
# Generating image for seed 30010 (10/149) ...
# Generating image for seed 30011 (11/149) ...
# Generating image for seed 30012 (12/149) ...
# Generating image for seed 30013 (13/149) ...
# Generating image for seed 30014 (14/149) ...
# Generating image for seed 30015 (15/149) ...
# Generating image for seed 30016 (16/149) ...
# Generating image for seed 30017 (17/149) ...
# Generating image for seed 30018 (18/149) ...
# Generating image for seed 30019 (19/149) ...
# Generating image for seed 30020 (20/149) ...
# Generating image for seed 30021 (21/149) ...
# Generating image for seed 30022 (22/149) ...
# Generating image for seed 30023 (23/149) ...
# Generating image for seed 30024 (24/149) ...
# Generating image for seed 30025 (25/149) ...
# Generating image for seed 30026 (26/149) ...
# Generating image for seed 30027 (27/149) ...
# Generating image for seed 30028 (28/149) ...
# Generating image for seed 30029 (29/149) ...
# Generating image for seed 30030 (30/149) ...
# Generating image for seed 30031 (31/149) ...
# Generating image for seed 30032 (32/149) ...
# Generating image for seed 30033 (33/149) ...
# Generating image for seed 30034 (34/149) ...
# Generating image for seed 30035 (35/149) ...
# Generating image for seed 30036 (36/149) ...
# Generating image for seed 30037 (37/149) ...
# Generating image for seed 30038 (38/149) ...
# Generating image for seed 30039 (39/149) ...
# Generating image for seed 30040 (40/149) ...
# Generating image for seed 30041 (41/149) ...
# Generating image for seed 30042 (42/149) ...
# Generating image for seed 30043 (43/149) ...
# Generating image for seed 30044 (44/149) ...
# Generating image for seed 30045 (45/149) ...
# Generating image for seed 30046 (46/149) ...
# Generating image for seed 30047 (47/149) ...
# Generating image for seed 30048 (48/149) ...
# Generating image for seed 30049 (49/149) ...
# Generating image for seed 30050 (50/149) ...
# Generating image for seed 30051 (51/149) ...
# Generating image for seed 30052 (52/149) ...
# Generating image for seed 30053 (53/149) ...
# Generating image for seed 30054 (54/149) ...
# Generating image for seed 30055 (55/149) ...
# Generating image for seed 30056 (56/149) ...
# Generating image for seed 30057 (57/149) ...
# Generating image for seed 30058 (58/149) ...
# Generating image for seed 30059 (59/149) ...
# Generating image for seed 30060 (60/149) ...
# Generating image for seed 30061 (61/149) ...
# Generating image for seed 30062 (62/149) ...
# Generating image for seed 30063 (63/149) ...
# Generating image for seed 30064 (64/149) ...
# Generating image for seed 30065 (65/149) ...
# Generating image for seed 30066 (66/149) ...
# Generating image for seed 30067 (67/149) ...
# Generating image for seed 30068 (68/149) ...
# Generating image for seed 30069 (69/149) ...
# Generating image for seed 30070 (70/149) ...
# Generating image for seed 30071 (71/149) ...
# Generating image for seed 30072 (72/149) ...
# Generating image for seed 30073 (73/149) ...
# Generating image for seed 30074 (74/149) ...
# Generating image for seed 30075 (75/149) ...
# Generating image for seed 30076 (76/149) ...
# Generating image for seed 30077 (77/149) ...
# Generating image for seed 30078 (78/149) ...
# Generating image for seed 30079 (79/149) ...
# Generating image for seed 30080 (80/149) ...
# Generating image for seed 30081 (81/149) ...
# Generating image for seed 30082 (82/149) ...
# Generating image for seed 30083 (83/149) ...
# Generating image for seed 30084 (84/149) ...
# Generating image for seed 30085 (85/149) ...
# Generating image for seed 30086 (86/149) ...
# Generating image for seed 30087 (87/149) ...
# Generating image for seed 30088 (88/149) ...
# Generating image for seed 30089 (89/149) ...
# Generating image for seed 30090 (90/149) ...
# Generating image for seed 30091 (91/149) ...
# Generating image for seed 30092 (92/149) ...
# Generating image for seed 30093 (93/149) ...
# Generating image for seed 30094 (94/149) ...
# Generating image for seed 30095 (95/149) ...
# Generating image for seed 30096 (96/149) ...
# Generating image for seed 30097 (97/149) ...
# Generating image for seed 30098 (98/149) ...
# Generating image for seed 30099 (99/149) ...
# Generating image for seed 30100 (100/149) ...
# Generating image for seed 30101 (101/149) ...
# Generating image for seed 30102 (102/149) ...
# Generating image for seed 30103 (103/149) ...
# Generating image for seed 30104 (104/149) ...
# Generating image for seed 30105 (105/149) ...
# Generating image for seed 30106 (106/149) ...
# Generating image for seed 30107 (107/149) ...
# Generating image for seed 30108 (108/149) ...
# Generating image for seed 30109 (109/149) ...
# Generating image for seed 30110 (110/149) ...
# Generating image for seed 30111 (111/149) ...
# Generating image for seed 30112 (112/149) ...
# Generating image for seed 30113 (113/149) ...
# Generating image for seed 30114 (114/149) ...
# Generating image for seed 30115 (115/149) ...
# Generating image for seed 30116 (116/149) ...
# Generating image for seed 30117 (117/149) ...
# Generating image for seed 30118 (118/149) ...
# Generating image for seed 30119 (119/149) ...
# Generating image for seed 30120 (120/149) ...
# Generating image for seed 30121 (121/149) ...
# Generating image for seed 30122 (122/149) ...
# Generating image for seed 30123 (123/149) ...
# Generating image for seed 30124 (124/149) ...
# Generating image for seed 30125 (125/149) ...
# Generating image for seed 30126 (126/149) ...
# Generating image for seed 30127 (127/149) ...
# Generating image for seed 30128 (128/149) ...
# Generating image for seed 30129 (129/149) ...
# Generating image for seed 30130 (130/149) ...
# Generating image for seed 30131 (131/149) ...
# Generating image for seed 30132 (132/149) ...
# Generating image for seed 30133 (133/149) ...
# Generating image for seed 30134 (134/149) ...
# Generating image for seed 30135 (135/149) ...
# Generating image for seed 30136 (136/149) ...
# Generating image for seed 30137 (137/149) ...
# Generating image for seed 30138 (138/149) ...
# Generating image for seed 30139 (139/149) ...
# Generating image for seed 30140 (140/149) ...
# Generating image for seed 30141 (141/149) ...
# Generating image for seed 30142 (142/149) ...
# Generating image for seed 30143 (143/149) ...
# Generating image for seed 30144 (144/149) ...
# Generating image for seed 30145 (145/149) ...
# Generating image for seed 30146 (146/149) ...
# Generating image for seed 30147 (147/149) ...
# Generating image for seed 30148 (148/149) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\14_train_gan_make_images_dataset2\fold_3\00002-fold_3_minority_256-mirror-auto1-kimg200-batch8-ada-target0.6-color\network-snapshot-000168.pkl"...
# Generating image for seed 40000 (0/90) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 40001 (1/90) ...
# Generating image for seed 40002 (2/90) ...
# Generating image for seed 40003 (3/90) ...
# Generating image for seed 40004 (4/90) ...
# Generating image for seed 40005 (5/90) ...
# Generating image for seed 40006 (6/90) ...
# Generating image for seed 40007 (7/90) ...
# Generating image for seed 40008 (8/90) ...
# Generating image for seed 40009 (9/90) ...
# Generating image for seed 40010 (10/90) ...
# Generating image for seed 40011 (11/90) ...
# Generating image for seed 40012 (12/90) ...
# Generating image for seed 40013 (13/90) ...
# Generating image for seed 40014 (14/90) ...
# Generating image for seed 40015 (15/90) ...
# Generating image for seed 40016 (16/90) ...
# Generating image for seed 40017 (17/90) ...
# Generating image for seed 40018 (18/90) ...
# Generating image for seed 40019 (19/90) ...
# Generating image for seed 40020 (20/90) ...
# Generating image for seed 40021 (21/90) ...
# Generating image for seed 40022 (22/90) ...
# Generating image for seed 40023 (23/90) ...
# Generating image for seed 40024 (24/90) ...
# Generating image for seed 40025 (25/90) ...
# Generating image for seed 40026 (26/90) ...
# Generating image for seed 40027 (27/90) ...
# Generating image for seed 40028 (28/90) ...
# Generating image for seed 40029 (29/90) ...
# Generating image for seed 40030 (30/90) ...
# Generating image for seed 40031 (31/90) ...
# Generating image for seed 40032 (32/90) ...
# Generating image for seed 40033 (33/90) ...
# Generating image for seed 40034 (34/90) ...
# Generating image for seed 40035 (35/90) ...
# Generating image for seed 40036 (36/90) ...
# Generating image for seed 40037 (37/90) ...
# Generating image for seed 40038 (38/90) ...
# Generating image for seed 40039 (39/90) ...
# Generating image for seed 40040 (40/90) ...
# Generating image for seed 40041 (41/90) ...
# Generating image for seed 40042 (42/90) ...
# Generating image for seed 40043 (43/90) ...
# Generating image for seed 40044 (44/90) ...
# Generating image for seed 40045 (45/90) ...
# Generating image for seed 40046 (46/90) ...
# Generating image for seed 40047 (47/90) ...
# Generating image for seed 40048 (48/90) ...
# Generating image for seed 40049 (49/90) ...
# Generating image for seed 40050 (50/90) ...
# Generating image for seed 40051 (51/90) ...
# Generating image for seed 40052 (52/90) ...
# Generating image for seed 40053 (53/90) ...
# Generating image for seed 40054 (54/90) ...
# Generating image for seed 40055 (55/90) ...
# Generating image for seed 40056 (56/90) ...
# Generating image for seed 40057 (57/90) ...
# Generating image for seed 40058 (58/90) ...
# Generating image for seed 40059 (59/90) ...
# Generating image for seed 40060 (60/90) ...
# Generating image for seed 40061 (61/90) ...
# Generating image for seed 40062 (62/90) ...
# Generating image for seed 40063 (63/90) ...
# Generating image for seed 40064 (64/90) ...
# Generating image for seed 40065 (65/90) ...
# Generating image for seed 40066 (66/90) ...
# Generating image for seed 40067 (67/90) ...
# Generating image for seed 40068 (68/90) ...
# Generating image for seed 40069 (69/90) ...
# Generating image for seed 40070 (70/90) ...
# Generating image for seed 40071 (71/90) ...
# Generating image for seed 40072 (72/90) ...
# Generating image for seed 40073 (73/90) ...
# Generating image for seed 40074 (74/90) ...
# Generating image for seed 40075 (75/90) ...
# Generating image for seed 40076 (76/90) ...
# Generating image for seed 40077 (77/90) ...
# Generating image for seed 40078 (78/90) ...
# Generating image for seed 40079 (79/90) ...
# Generating image for seed 40080 (80/90) ...
# Generating image for seed 40081 (81/90) ...
# Generating image for seed 40082 (82/90) ...
# Generating image for seed 40083 (83/90) ...
# Generating image for seed 40084 (84/90) ...
# Generating image for seed 40085 (85/90) ...
# Generating image for seed 40086 (86/90) ...
# Generating image for seed 40087 (87/90) ...
# Generating image for seed 40088 (88/90) ...
# Generating image for seed 40089 (89/90) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\14_train_gan_make_images_dataset2\fold_4\00001-fold_4_minority_256-mirror-auto1-kimg200-batch8-ada-target0.6-color\network-snapshot-000128.pkl"...
# Generating image for seed 50000 (0/119) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 50001 (1/119) ...
# Generating image for seed 50002 (2/119) ...
# Generating image for seed 50003 (3/119) ...
# Generating image for seed 50004 (4/119) ...
# Generating image for seed 50005 (5/119) ...
# Generating image for seed 50006 (6/119) ...
# Generating image for seed 50007 (7/119) ...
# Generating image for seed 50008 (8/119) ...
# Generating image for seed 50009 (9/119) ...
# Generating image for seed 50010 (10/119) ...
# Generating image for seed 50011 (11/119) ...
# Generating image for seed 50012 (12/119) ...
# Generating image for seed 50013 (13/119) ...
# Generating image for seed 50014 (14/119) ...
# Generating image for seed 50015 (15/119) ...
# Generating image for seed 50016 (16/119) ...
# Generating image for seed 50017 (17/119) ...
# Generating image for seed 50018 (18/119) ...
# Generating image for seed 50019 (19/119) ...
# Generating image for seed 50020 (20/119) ...
# Generating image for seed 50021 (21/119) ...
# Generating image for seed 50022 (22/119) ...
# Generating image for seed 50023 (23/119) ...
# Generating image for seed 50024 (24/119) ...
# Generating image for seed 50025 (25/119) ...
# Generating image for seed 50026 (26/119) ...
# Generating image for seed 50027 (27/119) ...
# Generating image for seed 50028 (28/119) ...
# Generating image for seed 50029 (29/119) ...
# Generating image for seed 50030 (30/119) ...
# Generating image for seed 50031 (31/119) ...
# Generating image for seed 50032 (32/119) ...
# Generating image for seed 50033 (33/119) ...
# Generating image for seed 50034 (34/119) ...
# Generating image for seed 50035 (35/119) ...
# Generating image for seed 50036 (36/119) ...
# Generating image for seed 50037 (37/119) ...
# Generating image for seed 50038 (38/119) ...
# Generating image for seed 50039 (39/119) ...
# Generating image for seed 50040 (40/119) ...
# Generating image for seed 50041 (41/119) ...
# Generating image for seed 50042 (42/119) ...
# Generating image for seed 50043 (43/119) ...
# Generating image for seed 50044 (44/119) ...
# Generating image for seed 50045 (45/119) ...
# Generating image for seed 50046 (46/119) ...
# Generating image for seed 50047 (47/119) ...
# Generating image for seed 50048 (48/119) ...
# Generating image for seed 50049 (49/119) ...
# Generating image for seed 50050 (50/119) ...
# Generating image for seed 50051 (51/119) ...
# Generating image for seed 50052 (52/119) ...
# Generating image for seed 50053 (53/119) ...
# Generating image for seed 50054 (54/119) ...
# Generating image for seed 50055 (55/119) ...
# Generating image for seed 50056 (56/119) ...
# Generating image for seed 50057 (57/119) ...
# Generating image for seed 50058 (58/119) ...
# Generating image for seed 50059 (59/119) ...
# Generating image for seed 50060 (60/119) ...
# Generating image for seed 50061 (61/119) ...
# Generating image for seed 50062 (62/119) ...
# Generating image for seed 50063 (63/119) ...
# Generating image for seed 50064 (64/119) ...
# Generating image for seed 50065 (65/119) ...
# Generating image for seed 50066 (66/119) ...
# Generating image for seed 50067 (67/119) ...
# Generating image for seed 50068 (68/119) ...
# Generating image for seed 50069 (69/119) ...
# Generating image for seed 50070 (70/119) ...
# Generating image for seed 50071 (71/119) ...
# Generating image for seed 50072 (72/119) ...
# Generating image for seed 50073 (73/119) ...
# Generating image for seed 50074 (74/119) ...
# Generating image for seed 50075 (75/119) ...
# Generating image for seed 50076 (76/119) ...
# Generating image for seed 50077 (77/119) ...
# Generating image for seed 50078 (78/119) ...
# Generating image for seed 50079 (79/119) ...
# Generating image for seed 50080 (80/119) ...
# Generating image for seed 50081 (81/119) ...
# Generating image for seed 50082 (82/119) ...
# Generating image for seed 50083 (83/119) ...
# Generating image for seed 50084 (84/119) ...
# Generating image for seed 50085 (85/119) ...
# Generating image for seed 50086 (86/119) ...
# Generating image for seed 50087 (87/119) ...
# Generating image for seed 50088 (88/119) ...
# Generating image for seed 50089 (89/119) ...
# Generating image for seed 50090 (90/119) ...
# Generating image for seed 50091 (91/119) ...
# Generating image for seed 50092 (92/119) ...
# Generating image for seed 50093 (93/119) ...
# Generating image for seed 50094 (94/119) ...
# Generating image for seed 50095 (95/119) ...
# Generating image for seed 50096 (96/119) ...
# Generating image for seed 50097 (97/119) ...
# Generating image for seed 50098 (98/119) ...
# Generating image for seed 50099 (99/119) ...
# Generating image for seed 50100 (100/119) ...
# Generating image for seed 50101 (101/119) ...
# Generating image for seed 50102 (102/119) ...
# Generating image for seed 50103 (103/119) ...
# Generating image for seed 50104 (104/119) ...
# Generating image for seed 50105 (105/119) ...
# Generating image for seed 50106 (106/119) ...
# Generating image for seed 50107 (107/119) ...
# Generating image for seed 50108 (108/119) ...
# Generating image for seed 50109 (109/119) ...
# Generating image for seed 50110 (110/119) ...
# Generating image for seed 50111 (111/119) ...
# Generating image for seed 50112 (112/119) ...
# Generating image for seed 50113 (113/119) ...
# Generating image for seed 50114 (114/119) ...
# Generating image for seed 50115 (115/119) ...
# Generating image for seed 50116 (116/119) ...
# Generating image for seed 50117 (117/119) ...
# Generating image for seed 50118 (118/119) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\14_train_gan_make_images_dataset2\fold_5\00001-fold_5_minority_256-mirror-auto1-kimg200-batch8-ada-target0.6-color\network-snapshot-000152.pkl"...
# Generating image for seed 60000 (0/137) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 60001 (1/137) ...
# Generating image for seed 60002 (2/137) ...
# Generating image for seed 60003 (3/137) ...
# Generating image for seed 60004 (4/137) ...
# Generating image for seed 60005 (5/137) ...
# Generating image for seed 60006 (6/137) ...
# Generating image for seed 60007 (7/137) ...
# Generating image for seed 60008 (8/137) ...
# Generating image for seed 60009 (9/137) ...
# Generating image for seed 60010 (10/137) ...
# Generating image for seed 60011 (11/137) ...
# Generating image for seed 60012 (12/137) ...
# Generating image for seed 60013 (13/137) ...
# Generating image for seed 60014 (14/137) ...
# Generating image for seed 60015 (15/137) ...
# Generating image for seed 60016 (16/137) ...
# Generating image for seed 60017 (17/137) ...
# Generating image for seed 60018 (18/137) ...
# Generating image for seed 60019 (19/137) ...
# Generating image for seed 60020 (20/137) ...
# Generating image for seed 60021 (21/137) ...
# Generating image for seed 60022 (22/137) ...
# Generating image for seed 60023 (23/137) ...
# Generating image for seed 60024 (24/137) ...
# Generating image for seed 60025 (25/137) ...
# Generating image for seed 60026 (26/137) ...
# Generating image for seed 60027 (27/137) ...
# Generating image for seed 60028 (28/137) ...
# Generating image for seed 60029 (29/137) ...
# Generating image for seed 60030 (30/137) ...
# Generating image for seed 60031 (31/137) ...
# Generating image for seed 60032 (32/137) ...
# Generating image for seed 60033 (33/137) ...
# Generating image for seed 60034 (34/137) ...
# Generating image for seed 60035 (35/137) ...
# Generating image for seed 60036 (36/137) ...
# Generating image for seed 60037 (37/137) ...
# Generating image for seed 60038 (38/137) ...
# Generating image for seed 60039 (39/137) ...
# Generating image for seed 60040 (40/137) ...
# Generating image for seed 60041 (41/137) ...
# Generating image for seed 60042 (42/137) ...
# Generating image for seed 60043 (43/137) ...
# Generating image for seed 60044 (44/137) ...
# Generating image for seed 60045 (45/137) ...
# Generating image for seed 60046 (46/137) ...
# Generating image for seed 60047 (47/137) ...
# Generating image for seed 60048 (48/137) ...
# Generating image for seed 60049 (49/137) ...
# Generating image for seed 60050 (50/137) ...
# Generating image for seed 60051 (51/137) ...
# Generating image for seed 60052 (52/137) ...
# Generating image for seed 60053 (53/137) ...
# Generating image for seed 60054 (54/137) ...
# Generating image for seed 60055 (55/137) ...
# Generating image for seed 60056 (56/137) ...
# Generating image for seed 60057 (57/137) ...
# Generating image for seed 60058 (58/137) ...
# Generating image for seed 60059 (59/137) ...
# Generating image for seed 60060 (60/137) ...
# Generating image for seed 60061 (61/137) ...
# Generating image for seed 60062 (62/137) ...
# Generating image for seed 60063 (63/137) ...
# Generating image for seed 60064 (64/137) ...
# Generating image for seed 60065 (65/137) ...
# Generating image for seed 60066 (66/137) ...
# Generating image for seed 60067 (67/137) ...
# Generating image for seed 60068 (68/137) ...
# Generating image for seed 60069 (69/137) ...
# Generating image for seed 60070 (70/137) ...
# Generating image for seed 60071 (71/137) ...
# Generating image for seed 60072 (72/137) ...
# Generating image for seed 60073 (73/137) ...
# Generating image for seed 60074 (74/137) ...
# Generating image for seed 60075 (75/137) ...
# Generating image for seed 60076 (76/137) ...
# Generating image for seed 60077 (77/137) ...
# Generating image for seed 60078 (78/137) ...
# Generating image for seed 60079 (79/137) ...
# Generating image for seed 60080 (80/137) ...
# Generating image for seed 60081 (81/137) ...
# Generating image for seed 60082 (82/137) ...
# Generating image for seed 60083 (83/137) ...
# Generating image for seed 60084 (84/137) ...
# Generating image for seed 60085 (85/137) ...
# Generating image for seed 60086 (86/137) ...
# Generating image for seed 60087 (87/137) ...
# Generating image for seed 60088 (88/137) ...
# Generating image for seed 60089 (89/137) ...
# Generating image for seed 60090 (90/137) ...
# Generating image for seed 60091 (91/137) ...
# Generating image for seed 60092 (92/137) ...
# Generating image for seed 60093 (93/137) ...
# Generating image for seed 60094 (94/137) ...
# Generating image for seed 60095 (95/137) ...
# Generating image for seed 60096 (96/137) ...
# Generating image for seed 60097 (97/137) ...
# Generating image for seed 60098 (98/137) ...
# Generating image for seed 60099 (99/137) ...
# Generating image for seed 60100 (100/137) ...
# Generating image for seed 60101 (101/137) ...
# Generating image for seed 60102 (102/137) ...
# Generating image for seed 60103 (103/137) ...
# Generating image for seed 60104 (104/137) ...
# Generating image for seed 60105 (105/137) ...
# Generating image for seed 60106 (106/137) ...
# Generating image for seed 60107 (107/137) ...
# Generating image for seed 60108 (108/137) ...
# Generating image for seed 60109 (109/137) ...
# Generating image for seed 60110 (110/137) ...
# Generating image for seed 60111 (111/137) ...
# Generating image for seed 60112 (112/137) ...
# Generating image for seed 60113 (113/137) ...
# Generating image for seed 60114 (114/137) ...
# Generating image for seed 60115 (115/137) ...
# Generating image for seed 60116 (116/137) ...
# Generating image for seed 60117 (117/137) ...
# Generating image for seed 60118 (118/137) ...
# Generating image for seed 60119 (119/137) ...
# Generating image for seed 60120 (120/137) ...
# Generating image for seed 60121 (121/137) ...
# Generating image for seed 60122 (122/137) ...
# Generating image for seed 60123 (123/137) ...
# Generating image for seed 60124 (124/137) ...
# Generating image for seed 60125 (125/137) ...
# Generating image for seed 60126 (126/137) ...
# Generating image for seed 60127 (127/137) ...
# Generating image for seed 60128 (128/137) ...
# Generating image for seed 60129 (129/137) ...
# Generating image for seed 60130 (130/137) ...
# Generating image for seed 60131 (131/137) ...
# Generating image for seed 60132 (132/137) ...
# Generating image for seed 60133 (133/137) ...
# Generating image for seed 60134 (134/137) ...
# Generating image for seed 60135 (135/137) ...
# Generating image for seed 60136 (136/137) ...
#   dataset_name         gan_image_id  fold_id  round_id  train_fold_id  \
# 0     dataset2  fold1_seed20000_256        1         1              1
# 1     dataset2  fold1_seed20001_256        1         1              1
# 2     dataset2  fold1_seed20002_256        1         1              1
# 3     dataset2  fold1_seed20003_256        1         1              1
# 4     dataset2  fold1_seed20004_256        1         1              1
# 5     dataset2  fold1_seed20005_256        1         1              1
# 6     dataset2  fold1_seed20006_256        1         1              1
# 7     dataset2  fold1_seed20007_256        1         1              1
# 8     dataset2  fold1_seed20008_256        1         1              1
# 9     dataset2  fold1_seed20009_256        1         1              1
#
#   test_fold_ids  binary_label binary_group   seed  image_size  \
# 0       2,3,4,5             0        cocci  20000         256
# 1       2,3,4,5             0        cocci  20001         256
# 2       2,3,4,5             0        cocci  20002         256
# 3       2,3,4,5             0        cocci  20003         256
# 4       2,3,4,5             0        cocci  20004         256
# 5       2,3,4,5             0        cocci  20005         256
# 6       2,3,4,5             0        cocci  20006         256
# 7       2,3,4,5             0        cocci  20007         256
# 8       2,3,4,5             0        cocci  20008         256
# 9       2,3,4,5             0        cocci  20009         256
#
#                                       file_path  \
# 0  gan_images_256/dataset2/fold_1/seed20000.png
# 1  gan_images_256/dataset2/fold_1/seed20001.png
# 2  gan_images_256/dataset2/fold_1/seed20002.png
# 3  gan_images_256/dataset2/fold_1/seed20003.png
# 4  gan_images_256/dataset2/fold_1/seed20004.png
# 5  gan_images_256/dataset2/fold_1/seed20005.png
# 6  gan_images_256/dataset2/fold_1/seed20006.png
# 7  gan_images_256/dataset2/fold_1/seed20007.png
# 8  gan_images_256/dataset2/fold_1/seed20008.png
# 9  gan_images_256/dataset2/fold_1/seed20009.png
#
#                                        snapshot_path    source_type
# 0  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 1  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 2  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 3  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 4  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 5  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 6  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 7  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 8  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 9  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated

# %%
# We resize every generated image to the fixed 224x224 CNN input size.
generated_rows_224 = []
for row in generated_rows_256:
    fold_id = int(row["fold_id"])
    source_file = REPO_ROOT / row["file_path"]
    target_dir = GAN_IMAGES_224_DIR / f"fold_{fold_id}"
    target_dir.mkdir(parents=True, exist_ok=True)
    target_file = target_dir / source_file.name

    with Image.open(source_file) as image_handle:
        image = image_handle.convert("RGB")
        resized_image = image.resize((CNN_PATCH_SIZE, CNN_PATCH_SIZE), Image.Resampling.LANCZOS)
        resized_image.save(target_file)

    generated_rows_224.append({
        "dataset_name": row["dataset_name"],
        "gan_image_id": row["gan_image_id"].replace("_256", "_224"),
        "fold_id": row["fold_id"],
        "round_id": row["round_id"],
        "train_fold_id": row["train_fold_id"],
        "test_fold_ids": row["test_fold_ids"],
        "binary_label": row["binary_label"],
        "binary_group": row["binary_group"],
        "seed": row["seed"],
        "image_size": CNN_PATCH_SIZE,
        "file_path": as_repo_relative(REPO_ROOT, target_file),
        "source_file_256": row["file_path"],
        "snapshot_path": row["snapshot_path"],
        "source_type": row["source_type"],
    })

write_csv_rows(MANIFESTS_DIR / "dataset2_gan_generated_manifest_224.csv", generated_rows_224, list(generated_rows_224[0].keys()))

summary = {
    "notebook_tag": NOTEBOOK_TAG,
    "seed": SEED,
    "gan_patch_size": GAN_PATCH_SIZE,
    "cnn_patch_size": CNN_PATCH_SIZE,
    "gan_batch_size": GAN_BATCH_SIZE,
    "gan_workers": GAN_WORKERS,
    "gan_kimg": GAN_KIMG,
    "gan_mirror": GAN_MIRROR,
    "snap_ticks": SNAP_TICKS,
    "ada_target": ADA_TARGET,
    "gan_cfg": GAN_CFG,
    "gan_aug": GAN_AUG,
    "gan_augpipe": GAN_AUGPIPE,
    "kid_metric_name": KID_METRIC_NAME,
    "generated_manifest_256": as_repo_relative(REPO_ROOT, MANIFESTS_DIR / "dataset2_gan_generated_manifest_256.csv"),
    "generated_manifest_224": as_repo_relative(REPO_ROOT, MANIFESTS_DIR / "dataset2_gan_generated_manifest_224.csv"),
}
write_json(NOTEBOOK_RESULTS_DIR / "summary.json", summary)

fold_result_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    generated_count = sum(1 for row in generated_rows_224 if int(row["fold_id"]) == fold_id)
    fold_result_rows.append({
        "fold_id": fold_id,
        "needed_gan_count_224": int(fold_plan["needed_gan_count_224"]),
        "generated_count_224": generated_count,
        "selected_snapshot_kimg": int(kid_lookup[fold_id]["snapshot_kimg"]),
        "selected_kid50k_full": kid_lookup[fold_id]["kid50k_full"],
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "gan_summary_by_fold.csv", fold_result_rows, list(fold_result_rows[0].keys()))
display(pd.DataFrame(fold_result_rows))
display(pd.DataFrame(generated_rows_224[:10]))

# This preview helps us audit that the resized synthetic patches look sensible.
preview_rows = generated_rows_224[:8]
if preview_rows:
    figure_columns = min(4, len(preview_rows))
    figure_rows = math.ceil(len(preview_rows) / figure_columns)
    fig, axes = plt.subplots(figure_rows, figure_columns, figsize=(4 * figure_columns, 4 * figure_rows))
    if not isinstance(axes, (list, tuple)):
        axes = [axes]
    flat_axes = []
    for item in axes:
        if isinstance(item, (list, tuple)):
            flat_axes.extend(item)
        else:
            try:
                flat_axes.extend(item.flatten().tolist())
            except AttributeError:
                flat_axes.append(item)
    for axis, row in zip(flat_axes, preview_rows):
        image_path = REPO_ROOT / row["file_path"]
        with Image.open(image_path) as image_handle:
            axis.imshow(image_handle.convert("RGB"))
        axis.set_title(f"fold {row['fold_id']} | seed {row['seed']}")
        axis.axis("off")
    for axis in flat_axes[len(preview_rows):]:
        axis.axis("off")
    fig.tight_layout()
    fig.savefig(NOTEBOOK_RESULTS_DIR / "generated_preview_224.png", dpi=200)
    plt.show()
print(f"Saved generated 224 manifest to: {MANIFESTS_DIR / 'dataset2_gan_generated_manifest_224.csv'}")
# Out:
#    fold_id  needed_gan_count_224  generated_count_224  selected_snapshot_kimg  \
# 0        1                   110                  110                     200
# 1        2                   149                  149                     168
# 2        3                    90                   90                     168
# 3        4                   119                  119                     128
# 4        5                   137                  137                     152
#
#    selected_kid50k_full
# 0              0.078817
# 1              0.201027
# 2              0.130255
# 3              0.123767
# 4              0.154539
#   dataset_name         gan_image_id  fold_id  round_id  train_fold_id  \
# 0     dataset2  fold1_seed20000_224        1         1              1
# 1     dataset2  fold1_seed20001_224        1         1              1
# 2     dataset2  fold1_seed20002_224        1         1              1
# 3     dataset2  fold1_seed20003_224        1         1              1
# 4     dataset2  fold1_seed20004_224        1         1              1
# 5     dataset2  fold1_seed20005_224        1         1              1
# 6     dataset2  fold1_seed20006_224        1         1              1
# 7     dataset2  fold1_seed20007_224        1         1              1
# 8     dataset2  fold1_seed20008_224        1         1              1
# 9     dataset2  fold1_seed20009_224        1         1              1
#
#   test_fold_ids  binary_label binary_group   seed  image_size  \
# 0       2,3,4,5             0        cocci  20000         224
# 1       2,3,4,5             0        cocci  20001         224
# 2       2,3,4,5             0        cocci  20002         224
# 3       2,3,4,5             0        cocci  20003         224
# 4       2,3,4,5             0        cocci  20004         224
# 5       2,3,4,5             0        cocci  20005         224
# 6       2,3,4,5             0        cocci  20006         224
# 7       2,3,4,5             0        cocci  20007         224
# 8       2,3,4,5             0        cocci  20008         224
# 9       2,3,4,5             0        cocci  20009         224
#
#                                       file_path  \
# 0  gan_images_224/dataset2/fold_1/seed20000.png
# 1  gan_images_224/dataset2/fold_1/seed20001.png
# 2  gan_images_224/dataset2/fold_1/seed20002.png
# 3  gan_images_224/dataset2/fold_1/seed20003.png
# 4  gan_images_224/dataset2/fold_1/seed20004.png
# 5  gan_images_224/dataset2/fold_1/seed20005.png
# 6  gan_images_224/dataset2/fold_1/seed20006.png
# 7  gan_images_224/dataset2/fold_1/seed20007.png
# 8  gan_images_224/dataset2/fold_1/seed20008.png
# 9  gan_images_224/dataset2/fold_1/seed20009.png
#
#                                 source_file_256  \
# 0  gan_images_256/dataset2/fold_1/seed20000.png
# 1  gan_images_256/dataset2/fold_1/seed20001.png
# 2  gan_images_256/dataset2/fold_1/seed20002.png
# 3  gan_images_256/dataset2/fold_1/seed20003.png
# 4  gan_images_256/dataset2/fold_1/seed20004.png
# 5  gan_images_256/dataset2/fold_1/seed20005.png
# 6  gan_images_256/dataset2/fold_1/seed20006.png
# 7  gan_images_256/dataset2/fold_1/seed20007.png
# 8  gan_images_256/dataset2/fold_1/seed20008.png
# 9  gan_images_256/dataset2/fold_1/seed20009.png
#
#                                        snapshot_path    source_type
# 0  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 1  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 2  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 3  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 4  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 5  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 6  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 7  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 8  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# 9  checkpoints/14_train_gan_make_images_dataset2/...  gan_generated
# Saved generated 224 manifest to: C:\Users\FYP2610\Downloads\FYP2\manifests\dataset2_gan_generated_manifest_224.csv
