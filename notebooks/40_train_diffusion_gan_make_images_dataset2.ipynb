# %% [markdown]
# # 40 Train Diffusion-GAN and Make Images - Dataset-Bacteria
#
# This notebook trains Diffusion-GAN only for the minority cocci balancing arm. It does not overwrite StyleGAN2-ADA, StyleGAN3-T, or R3GAN outputs.

# %% [markdown]
# ## Locked Protocol
#
# - Binary task stays fixed: cocci = 0 and bacilli = 1.
# - One GAN is trained per training fold.
# - Each GAN sees only the same-fold real minority cocci 256x256 patches.
# - The generated count exactly matches the minority top-up needed to balance the CNN train fold.
# - Snapshot selection uses the same sparse KID rule as the other GAN arms: 40, 80, 120, 160, and 200 kimg.
# - Diffusion-GAN-specific diffusion noise settings are recorded as architecture-specific settings.
# - Outputs are saved under separate diffusion_gan folders and manifests.

# %%
from pathlib import Path
import csv
import json
import math
import os
import re
import shutil
import subprocess
import sys
import time

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display
from PIL import Image

# This helper keeps the notebook runnable from the repo root or from notebooks/.
def find_repo_root(start_path: Path) -> Path:
    current_path = start_path.resolve()
    for candidate in [current_path, *current_path.parents]:
        if (candidate / "notebooks").exists() and (candidate / "manifests").exists():
            return candidate
    raise RuntimeError("Could not find the FYP2 repository root.")

REPO_ROOT = find_repo_root(Path.cwd())
MANIFESTS_DIR = REPO_ROOT / "manifests"
RESULTS_DIR = REPO_ROOT / "results"
CHECKPOINTS_DIR = REPO_ROOT / "checkpoints"
GAN_PATCHES_DIR = REPO_ROOT / "gan_patches_256" / "dataset2"
GAN_IMAGES_256_DIR = REPO_ROOT / "gan_images_256" / "diffusion_gan" / "dataset2"
GAN_IMAGES_224_DIR = REPO_ROOT / "gan_images_224" / "diffusion_gan" / "dataset2"
THIRD_PARTY_DIR = REPO_ROOT / "third_party"
DIFFUSION_GAN_ROOT_CANDIDATES = [THIRD_PARTY_DIR / "Diffusion-GAN", THIRD_PARTY_DIR / "diffusion-gan"]
DIFFUSION_GAN_ROOT = next((path for path in DIFFUSION_GAN_ROOT_CANDIDATES if path.exists()), None)
if DIFFUSION_GAN_ROOT is None:
    raise FileNotFoundError(
        "Missing Diffusion-GAN folder. Clone the official repo into third_party/Diffusion-GAN before running this notebook."
    )

DIFFUSION_GAN_DIR = DIFFUSION_GAN_ROOT / "diffusion-stylegan2"
if not DIFFUSION_GAN_DIR.exists():
    raise FileNotFoundError(f"Missing diffusion-stylegan2 folder: {DIFFUSION_GAN_DIR}")

NOTEBOOK_TAG = "40_train_diffusion_gan_make_images_dataset2"
NOTEBOOK_RESULTS_DIR = RESULTS_DIR / NOTEBOOK_TAG
NOTEBOOK_CHECKPOINTS_DIR = CHECKPOINTS_DIR / NOTEBOOK_TAG
NOTEBOOK_RESULTS_DIR.mkdir(parents=True, exist_ok=True)
NOTEBOOK_CHECKPOINTS_DIR.mkdir(parents=True, exist_ok=True)
GAN_IMAGES_256_DIR.mkdir(parents=True, exist_ok=True)
GAN_IMAGES_224_DIR.mkdir(parents=True, exist_ok=True)

DATASET_NAME = "dataset2"
SEED = 2026
DIFFUSION_GAN_RANDOM_SEED = 0
FOLDS_TO_RUN = [1, 2, 3, 4, 5]
GAN_PATCH_SIZE = 256
CNN_PATCH_SIZE = 224
GAN_BATCH_SIZE = 8
GAN_WORKERS = 3
GAN_KIMG = 200
# Diffusion-GAN train.py does not expose --tick. The inherited StyleGAN2 training loop uses 4 kimg per tick.
# With snap=10, the saved sparse snapshots should be 40, 80, 120, 160, and 200 kimg.
TICK_KIMG = 4
SNAP_TICKS = 10
SNAPSHOT_SELECTION_KIMG = [40, 80, 120, 160, 200]
GAN_MIRROR = True
DIFFUSION_GAN_CFG = "auto"
DIFFUSION_GAN_AUG = "no"
DIFFUSION_GAN_TARGET = 0.6
DIFFUSION_GAN_NOISE_SD = 0.05
DIFFUSION_GAN_TS_DIST = "priority"
DIFFUSION_GAN_ADA_KIMG = 100
KID_METRIC_NAME = "kid50k_full"
GENERATE_START_SEED = 10000
LONG_COMMAND_NOTEBOOK_MODE = "smart"
KID_OPENMP_DUPLICATE_OK = True
ALLOW_OVERWRITE_DIFFUSION_GAN_OUTPUTS = True

# Diffusion-GAN is run in the same Windows fyp2 environment used for StyleGAN3/R3GAN on RTX 4060.
DIFFUSION_GAN_WINDOWS_PYTHON = Path("C:/Users/FYP2610/anaconda3/envs/fyp2/python.exe")
DIFFUSION_GAN_TORCH_CUDA_ARCH_LIST = "8.0+PTX"
DIFFUSION_GAN_EXTENSIONS_DIR = CHECKPOINTS_DIR / "torch_extensions_diffusion_gan_sm80ptx"
DIFFUSION_GAN_EXTENSIONS_DIR.mkdir(parents=True, exist_ok=True)

if os.name == "nt":
    PYTHON_EXE = DIFFUSION_GAN_WINDOWS_PYTHON
    if not PYTHON_EXE.exists():
        raise FileNotFoundError(f"Could not find the Diffusion-GAN Python executable: {PYTHON_EXE}")
    DIFFUSION_GAN_ENV_ROOT = PYTHON_EXE.parent
    CONDA_EXE = DIFFUSION_GAN_ENV_ROOT.parent.parent / "Scripts" / "conda.exe"
    if not CONDA_EXE.exists():
        raise FileNotFoundError(f"Could not find conda.exe: {CONDA_EXE}")
    if shutil.which("cl") is None:
        raise EnvironmentError(
            "cl.exe was not found. Start Jupyter from the Visual Studio 2022 Developer Command Prompt, "
            "then open this notebook again."
        )
else:
    PYTHON_EXE = Path(sys.executable)
    DIFFUSION_GAN_ENV_ROOT = None
    CONDA_EXE = None

DIFFUSION_GAN_EXTRA_ENV = {
    "TORCH_CUDA_ARCH_LIST": DIFFUSION_GAN_TORCH_CUDA_ARCH_LIST,
    "TORCH_EXTENSIONS_DIR": str(DIFFUSION_GAN_EXTENSIONS_DIR),
}
if KID_OPENMP_DUPLICATE_OK:
    DIFFUSION_GAN_EXTRA_ENV["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# This helper ensures Windows subprocesses really run inside the selected conda environment.
def build_python_command(*python_args: str):
    if os.name == "nt":
        return [
            str(CONDA_EXE),
            "run",
            "--no-capture-output",
            "-p",
            str(DIFFUSION_GAN_ENV_ROOT),
            "python",
            *python_args,
        ]
    return [str(PYTHON_EXE), *python_args]

def build_diffusion_gan_command(script_name: str, *script_args: str):
    return build_python_command(script_name, *script_args)

# %%
# This helper reads a CSV file into a plain list of rows.
def read_csv_rows(csv_path: Path):
    if not csv_path.exists():
        raise FileNotFoundError(f"Missing CSV file: {csv_path}")
    with csv_path.open("r", newline="", encoding="utf-8") as handle:
        return list(csv.DictReader(handle))

# This helper writes a CSV file with a stable header.
def write_csv_rows(csv_path: Path, rows, fieldnames, allow_existing=True):
    if not rows:
        raise ValueError(f"No rows were provided for {csv_path.name}.")
    if csv_path.exists() and not allow_existing:
        raise FileExistsError(f"Refusing to overwrite existing CSV file: {csv_path}")
    csv_path.parent.mkdir(parents=True, exist_ok=True)
    with csv_path.open("w", newline="", encoding="utf-8") as handle:
        writer = csv.DictWriter(handle, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

# This helper writes one small JSON file with clean formatting.
def write_json(json_path: Path, data):
    json_path.parent.mkdir(parents=True, exist_ok=True)
    json_path.write_text(json.dumps(data, indent=2), encoding="utf-8")

# This helper stores paths in repo-relative form so the outputs stay portable.
def as_repo_relative(repo_root: Path, path_value: Path) -> str:
    return str(path_value.resolve().relative_to(repo_root.resolve())).replace(chr(92), "/")

# This helper refuses to overwrite generated image folders unless we explicitly allow it.
def safe_prepare_output_dir(output_dir: Path):
    if output_dir.exists() and any(output_dir.iterdir()):
        if not ALLOW_OVERWRITE_DIFFUSION_GAN_OUTPUTS:
            raise FileExistsError(
                f"Refusing to overwrite existing Diffusion-GAN output folder: {output_dir}. "
                "Set ALLOW_OVERWRITE_DIFFUSION_GAN_OUTPUTS=True only if you intentionally want to rerun this notebook."
            )
        shutil.rmtree(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

# This helper refuses to continue from an old training run unless we explicitly allow it.
def safe_prepare_checkpoint_parent(output_dir: Path):
    if output_dir.exists() and any(path.is_dir() for path in output_dir.iterdir()):
        if not ALLOW_OVERWRITE_DIFFUSION_GAN_OUTPUTS:
            raise FileExistsError(
                f"Refusing to reuse existing Diffusion-GAN checkpoint folder: {output_dir}. "
                "Move the old folder or set ALLOW_OVERWRITE_DIFFUSION_GAN_OUTPUTS=True only if this is intentional."
            )
        shutil.rmtree(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

# This helper decides which command lines matter enough to echo in the notebook.
def should_echo_command_line(line_text: str, line_index: int, notebook_mode: str) -> bool:
    if notebook_mode == "all":
        return True
    if notebook_mode == "quiet":
        return False
    if line_index <= 25:
        return True
    lowered = line_text.lower()
    important_markers = [
        "training for",
        "tick ",
        "sec/kimg",
        "snapshot",
        "saved",
        "kid50k_full",
        "generating image for seed",
        "traceback",
        "runtimeerror",
        "error:",
        "done",
    ]
    return any(marker in lowered for marker in important_markers)

# This helper runs a subprocess, streams useful lines to the notebook, and saves a full log to disk.
def run_command(command_parts, workdir: Path, live_log_path: Path, notebook_mode: str = "smart", extra_env=None):
    live_log_path.parent.mkdir(parents=True, exist_ok=True)
    command_env = os.environ.copy()
    if extra_env is not None:
        command_env.update(extra_env)

    process = subprocess.Popen(
        command_parts,
        cwd=workdir,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        encoding="utf-8",
        errors="replace",
        env=command_env,
    )

    start_time = time.time()
    output_tail = []
    printed_line_count = 0
    suppressed_line_count = 0
    total_line_count = 0

    with live_log_path.open("w", encoding="utf-8") as log_handle:
        for line in process.stdout:
            total_line_count += 1
            output_tail.append(line)
            output_tail = output_tail[-200:]
            log_handle.write(line)
            log_handle.flush()

            line_text = line.rstrip()
            if should_echo_command_line(line_text, total_line_count, notebook_mode):
                print(line_text)
                printed_line_count += 1
            else:
                suppressed_line_count += 1

    returncode = process.wait()
    duration_seconds = round(time.time() - start_time, 2)
    return {
        "command": " ".join(str(item) for item in command_parts),
        "returncode": returncode,
        "duration_seconds": duration_seconds,
        "printed_line_count": printed_line_count,
        "suppressed_line_count": suppressed_line_count,
        "total_line_count": total_line_count,
        "log_path": as_repo_relative(REPO_ROOT, live_log_path),
        "output_tail": "".join(output_tail),
    }

# %%
# We record small compatibility fixes for PyTorch 2.11 without changing the Diffusion-GAN method.
def patch_text_file_once(file_path: Path, replacements):
    if not file_path.exists():
        raise FileNotFoundError(f"Missing file to patch: {file_path}")

    original_text = file_path.read_text(encoding="utf-8")
    updated_text = original_text
    applied = []

    for old_text, new_text, reason in replacements:
        if old_text in updated_text:
            updated_text = updated_text.replace(old_text, new_text)
            applied.append({"old_text": old_text, "new_text": new_text, "reason": reason})

    if updated_text != original_text:
        backup_path = file_path.with_name(file_path.name + ".fyp2_backup")
        if not backup_path.exists():
            backup_path.write_text(original_text, encoding="utf-8")
        file_path.write_text(updated_text, encoding="utf-8")
        status = "patched"
    else:
        backup_path = None
        status = "already_ok_or_pattern_not_present"

    return {
        "file_path": as_repo_relative(REPO_ROOT, file_path),
        "status": status,
        "backup_path": as_repo_relative(REPO_ROOT, backup_path) if backup_path else None,
        "applied_replacements": applied,
    }

def patch_numpy_removed_aliases(root_dir: Path):
    # NumPy 2.x removed old aliases such as np.int. This only updates compatibility names.
    alias_replacements = [
        (r"\bnp\.int\b", "int", "NumPy 2.x removed np.int; use the built-in int."),
        (r"\bnp\.float\b", "float", "NumPy 2.x removed np.float; use the built-in float."),
        (r"\bnp\.bool\b", "bool", "NumPy 2.x removed np.bool; use the built-in bool."),
    ]
    patch_rows = []
    for file_path in sorted(root_dir.rglob("*.py")):
        original_text = file_path.read_text(encoding="utf-8")
        updated_text = original_text
        applied = []
        for old_pattern, new_text, reason in alias_replacements:
            if re.search(old_pattern, updated_text):
                updated_text = re.sub(old_pattern, new_text, updated_text)
                applied.append({"old_text": old_pattern, "new_text": new_text, "reason": reason})
        if updated_text != original_text:
            backup_path = file_path.with_name(file_path.name + ".fyp2_numpy_backup")
            if not backup_path.exists():
                backup_path.write_text(original_text, encoding="utf-8")
            file_path.write_text(updated_text, encoding="utf-8")
            patch_rows.append({
                "file_path": as_repo_relative(REPO_ROOT, file_path),
                "status": "patched",
                "backup_path": as_repo_relative(REPO_ROOT, backup_path),
                "applied_replacements": applied,
            })
    if not patch_rows:
        patch_rows.append({
            "file_path": as_repo_relative(REPO_ROOT, root_dir),
            "status": "already_ok_or_pattern_not_present",
            "backup_path": None,
            "applied_replacements": [],
        })
    return patch_rows

def patch_custom_ops_loader(file_path: Path):
    # PyTorch 2.x returns the compiled extension module directly from cpp_extension.load.
    # Older StyleGAN2-derived code imports the module by name afterwards, which can fail on Windows.
    if not file_path.exists():
        raise FileNotFoundError(f"Missing file to patch: {file_path}")
    original_text = file_path.read_text(encoding="utf-8")
    updated_lines = []
    applied = []
    for line in original_text.splitlines(True):
        stripped_line = line.lstrip()
        indent = line[:len(line) - len(stripped_line)]
        if "module = module = torch.utils.cpp_extension.load(" in line:
            line = line.replace("module = module = torch.utils.cpp_extension.load(", "module = torch.utils.cpp_extension.load(")
            applied.append({"old_text": "module = module = torch.utils.cpp_extension.load(", "new_text": "module = torch.utils.cpp_extension.load(", "reason": "Remove accidental duplicate module assignment."})
        elif stripped_line.startswith("torch.utils.cpp_extension.load("):
            line = indent + "module = " + stripped_line
            applied.append({"old_text": "torch.utils.cpp_extension.load(", "new_text": "module = torch.utils.cpp_extension.load(", "reason": "Use the module object returned by PyTorch extension loader."})
        if "module = importlib.import_module(module_name)" in line:
            line = line.replace("module = importlib.import_module(module_name)", "# module is returned by torch.utils.cpp_extension.load above")
            applied.append({"old_text": "module = importlib.import_module(module_name)", "new_text": "# module is returned by torch.utils.cpp_extension.load above", "reason": "Avoid importing compiled extension by name from sys.path."})
        updated_lines.append(line)
    updated_text = "".join(updated_lines)
    if updated_text != original_text:
        backup_path = file_path.with_name(file_path.name + ".fyp2_custom_ops_backup")
        if not backup_path.exists():
            backup_path.write_text(original_text, encoding="utf-8")
        file_path.write_text(updated_text, encoding="utf-8")
        status = "patched"
    else:
        backup_path = None
        status = "already_ok_or_pattern_not_present"
    return {
        "file_path": as_repo_relative(REPO_ROOT, file_path),
        "status": status,
        "backup_path": as_repo_relative(REPO_ROOT, backup_path) if backup_path else None,
        "applied_replacements": applied,
    }

def patch_diffusion_gan_snapshot_names(file_path: Path):
    # Diffusion-GAN saves every network snapshot as network-snapshot.pkl by default.
    # We need kimg-specific snapshot files so KID-based snapshot selection is traceable.
    if not file_path.exists():
        raise FileNotFoundError(f"Missing file to patch: {file_path}")
    original_text = file_path.read_text(encoding="utf-8")
    replacement_text = "snapshot_pkl = os.path.join(run_dir, f'network-snapshot-{cur_nimg//1000:06d}.pkl')"
    replacement_candidates = [
        "snapshot_pkl = misc.get_ckpt_path(run_dir)",
        "snapshot_pkl = get_ckpt_path(run_dir)",
    ]
    applied = []
    updated_text = original_text
    if replacement_text not in updated_text:
        for old_text in replacement_candidates:
            if old_text in updated_text:
                updated_text = updated_text.replace(old_text, replacement_text)
                applied.append({"old_text": old_text, "new_text": replacement_text, "reason": "Save kimg-specific snapshots for fixed KID selection."})
                break
        if not applied:
            raise RuntimeError(
                "Could not find the Diffusion-GAN snapshot save line to patch. "
                "Open training/training_loop.py and check the snapshot_pkl assignment."
            )
    if updated_text != original_text:
        backup_path = file_path.with_name(file_path.name + ".fyp2_snapshot_backup")
        if not backup_path.exists():
            backup_path.write_text(original_text, encoding="utf-8")
        file_path.write_text(updated_text, encoding="utf-8")
        status = "patched"
    else:
        backup_path = None
        status = "already_ok_or_pattern_not_present"
    return {
        "file_path": as_repo_relative(REPO_ROOT, file_path),
        "status": status,
        "backup_path": as_repo_relative(REPO_ROOT, backup_path) if backup_path else None,
        "applied_replacements": applied,
    }

patch_report = {
    "notebook_tag": NOTEBOOK_TAG,
    "patch_date": time.strftime("%Y-%m-%d"),
    "reason": "Compatibility with the Windows fyp2 environment and traceable kimg-specific snapshot files. Network, loss, data, seeds, kimg, and selection protocol are unchanged.",
    "patches": [],
}

patch_report["patches"].append(patch_text_file_once(
    DIFFUSION_GAN_DIR / "train.py",
    [
        ("betas=[0,0.99]", "betas=[0.0,0.99]", "PyTorch 2.11 requires Adam betas to be floats, not ints."),
        ("betas=[0, 0.99]", "betas=[0.0, 0.99]", "PyTorch 2.11 requires Adam betas to be floats, not ints."),
    ],
))

patch_report["patches"].append(patch_text_file_once(
    DIFFUSION_GAN_DIR / "torch_utils" / "misc.py",
    [
        ("super().__init__(dataset)", "super().__init__()", "Newer PyTorch Sampler no longer accepts dataset in object.__init__."),
        ("super().__init__(None)", "super().__init__()", "Newer PyTorch Sampler no longer accepts a data_source argument in object.__init__."),
    ],
))

patch_report["patches"].append(patch_custom_ops_loader(DIFFUSION_GAN_DIR / "torch_utils" / "custom_ops.py"))

patch_report["patches"].append(patch_diffusion_gan_snapshot_names(DIFFUSION_GAN_DIR / "training" / "training_loop.py"))

patch_report["patches"].extend(patch_numpy_removed_aliases(DIFFUSION_GAN_DIR))

write_json(NOTEBOOK_RESULTS_DIR / "diffusion_gan_compatibility_patch_report.json", patch_report)
display(pd.DataFrame(patch_report["patches"]))

# This smoke check confirms that the selected Python environment can see CUDA before long training starts.
env_report = run_command(
    build_python_command(
        "-c",
        "import sys, numpy as np, torch; print(sys.version); print(np.__version__); print(torch.__version__); print(torch.cuda.is_available()); print(torch.cuda.get_device_name(0))",
    ),
    DIFFUSION_GAN_DIR,
    NOTEBOOK_RESULTS_DIR / "diffusion_gan_environment_check.log",
    notebook_mode="all",
    extra_env=DIFFUSION_GAN_EXTRA_ENV,
)
write_json(NOTEBOOK_RESULTS_DIR / "diffusion_gan_environment_check_report.json", env_report)
if env_report["returncode"] != 0:
    raise RuntimeError("Diffusion-GAN environment check failed. Read diffusion_gan_environment_check.log before continuing.")
# Out:
#                                            file_path  \
# 0  third_party/Diffusion-GAN/diffusion-stylegan2/...
# 1  third_party/Diffusion-GAN/diffusion-stylegan2/...
# 2  third_party/Diffusion-GAN/diffusion-stylegan2/...
# 3  third_party/Diffusion-GAN/diffusion-stylegan2/...
# 4      third_party/Diffusion-GAN/diffusion-stylegan2
#
#                               status backup_path applied_replacements
# 0  already_ok_or_pattern_not_present        None                   []
# 1  already_ok_or_pattern_not_present        None                   []
# 2  already_ok_or_pattern_not_present        None                   []
# 3  already_ok_or_pattern_not_present        None                   []
# 4  already_ok_or_pattern_not_present        None                   []
# 3.10.20 | packaged by Anaconda, Inc. | (main, Mar 11 2026, 17:42:35) [MSC v.1942 64 bit (AMD64)]
# 2.2.5
# 2.11.0+cu128
# True
# NVIDIA GeForce RTX 4060

# %%
# We load the real patch manifest and compute the exact top-up target for each training fold.
real_patch_rows = read_csv_rows(MANIFESTS_DIR / "dataset2_patch_manifest_224.csv")
gan_source_rows = read_csv_rows(MANIFESTS_DIR / "dataset2_gan_patch_manifest_256.csv")
fold_manifest_rows = read_csv_rows(MANIFESTS_DIR / "dataset2_fold_manifest.csv")

for row in real_patch_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])
for row in gan_source_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])
for row in fold_manifest_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])

fold_plan_rows = []
for fold_id in FOLDS_TO_RUN:
    train_rows = [row for row in real_patch_rows if int(row["fold_id"]) == fold_id]
    gan_rows = [row for row in gan_source_rows if int(row["fold_id"]) == fold_id]
    train_cocci_count = sum(1 for row in train_rows if int(row["binary_label"]) == 0)
    train_bacilli_count = sum(1 for row in train_rows if int(row["binary_label"]) == 1)
    test_fold_ids = [value for value in FOLDS_TO_RUN if value != fold_id]
    test_fold_text = ",".join(str(value) for value in test_fold_ids)
    if train_cocci_count >= train_bacilli_count:
        raise AssertionError(
            f"Fold {fold_id} no longer has cocci as the minority class. "
            f"cocci={train_cocci_count}, bacilli={train_bacilli_count}"
        )
    needed_gan_count_224 = train_bacilli_count - train_cocci_count
    fold_plan_rows.append({
        "round_id": fold_id,
        "train_fold_id": fold_id,
        "test_fold_ids": test_fold_text,
        "real_train_patch_count_224": len(train_rows),
        "real_cocci_count_224": train_cocci_count,
        "real_bacilli_count_224": train_bacilli_count,
        "needed_gan_count_224": needed_gan_count_224,
        "real_cocci_patch_count_256_for_gan": len(gan_rows),
        "train_raw_sample_count": sum(1 for row in fold_manifest_rows if int(row["fold_id"]) == fold_id),
        "dataset_zip_path": as_repo_relative(REPO_ROOT, NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}" / f"fold_{fold_id}_minority_256.zip"),
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "fold_plan.csv", fold_plan_rows, list(fold_plan_rows[0].keys()))
display(pd.DataFrame(fold_plan_rows))
# Out:
#    round_id  train_fold_id test_fold_ids  real_train_patch_count_224  \
# 0         1              1       2,3,4,5                         870
# 1         2              2       1,3,4,5                         837
# 2         3              3       1,2,4,5                         806
# 3         4              4       1,2,3,5                         821
# 4         5              5       1,2,3,4                         845
#
#    real_cocci_count_224  real_bacilli_count_224  needed_gan_count_224  \
# 0                   380                     490                   110
# 1                   344                     493                   149
# 2                   358                     448                    90
# 3                   351                     470                   119
# 4                   354                     491                   137
#
#    real_cocci_patch_count_256_for_gan  train_raw_sample_count  \
# 0                                 260                      86
# 1                                 239                      86
# 2                                 229                      85
# 3                                 243                      85
# 4                                 240                      85
#
#                                     dataset_zip_path
# 0  results/40_train_diffusion_gan_make_images_dat...
# 1  results/40_train_diffusion_gan_make_images_dat...
# 2  results/40_train_diffusion_gan_make_images_dat...
# 3  results/40_train_diffusion_gan_make_images_dat...
# 4  results/40_train_diffusion_gan_make_images_dat...

# %%
# We create one Diffusion-GAN zip file per training fold so each GAN only sees same-fold minority data.
dataset_zip_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    source_dir = GAN_PATCHES_DIR / f"fold_{fold_id}"
    if not source_dir.exists():
        raise FileNotFoundError(f"Missing GAN source folder for fold {fold_id}: {source_dir}")

    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    fold_result_dir.mkdir(parents=True, exist_ok=True)
    dataset_zip_path = REPO_ROOT / fold_plan["dataset_zip_path"]
    if dataset_zip_path.exists():
        if not ALLOW_OVERWRITE_DIFFUSION_GAN_OUTPUTS:
            raise FileExistsError(f"Refusing to overwrite existing dataset zip: {dataset_zip_path}")
        dataset_zip_path.unlink()

    dataset_tool_log_path = fold_result_dir / "dataset_tool.log"
    report = run_command(
        build_diffusion_gan_command(
            "dataset_tool.py",
            f"--source={source_dir}",
            f"--dest={dataset_zip_path}",
        ),
        DIFFUSION_GAN_DIR,
        live_log_path=dataset_tool_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=DIFFUSION_GAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "dataset_tool_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"Diffusion-GAN dataset_tool.py failed for fold {fold_id}")

    dataset_zip_rows.append({
        "fold_id": fold_id,
        "source_dir": as_repo_relative(REPO_ROOT, source_dir),
        "dataset_zip_path": as_repo_relative(REPO_ROOT, dataset_zip_path),
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "dataset_zip_manifest.csv", dataset_zip_rows, list(dataset_zip_rows[0].keys()))
display(pd.DataFrame(dataset_zip_rows))
# Out:
#   0%|          | 0/260 [00:00<?, ?it/s]
#  10%|█         | 27/260 [00:00<00:00, 266.52it/s]
#  21%|██        | 55/260 [00:00<00:00, 272.11it/s]
#  32%|███▏      | 83/260 [00:00<00:00, 270.73it/s]
#  43%|████▎     | 111/260 [00:00<00:00, 273.67it/s]
#  53%|█████▎    | 139/260 [00:00<00:00, 273.39it/s]
#  64%|██████▍   | 167/260 [00:00<00:00, 272.83it/s]
#  75%|███████▌  | 195/260 [00:00<00:00, 270.73it/s]
#  86%|████████▌ | 223/260 [00:00<00:00, 267.25it/s]
#  97%|█████████▋| 251/260 [00:00<00:00, 270.24it/s]
# 100%|██████████| 260/260 [00:00<00:00, 270.84it/s]
#
#   0%|          | 0/239 [00:00<?, ?it/s]
#  11%|█         | 26/239 [00:00<00:00, 254.90it/s]
#  22%|██▏       | 52/239 [00:00<00:00, 254.90it/s]
#  33%|███▎      | 78/239 [00:00<00:00, 255.99it/s]
#  44%|████▎     | 104/239 [00:00<00:00, 255.38it/s]
#  55%|█████▍    | 131/239 [00:00<00:00, 257.28it/s]
#  66%|██████▌   | 157/239 [00:00<00:00, 258.18it/s]
#  77%|███████▋  | 183/239 [00:00<00:00, 253.85it/s]
#  88%|████████▊ | 210/239 [00:00<00:00, 257.73it/s]
#  99%|█████████▉| 237/239 [00:00<00:00, 259.72it/s]
# 100%|██████████| 239/239 [00:00<00:00, 257.40it/s]
#
#   0%|          | 0/229 [00:00<?, ?it/s]
#  11%|█         | 25/229 [00:00<00:00, 245.09it/s]
#  23%|██▎       | 52/229 [00:00<00:00, 255.16it/s]
#  34%|███▍      | 79/229 [00:00<00:00, 258.85it/s]
#  46%|████▌     | 105/229 [00:00<00:00, 257.47it/s]
#  57%|█████▋    | 131/229 [00:00<00:00, 255.34it/s]
#  69%|██████▊   | 157/229 [00:00<00:00, 256.75it/s]
#  80%|████████  | 184/229 [00:00<00:00, 259.88it/s]
#  92%|█████████▏| 211/229 [00:00<00:00, 260.28it/s]
# 100%|██████████| 229/229 [00:00<00:00, 257.69it/s]
#
#   0%|          | 0/243 [00:00<?, ?it/s]
#  11%|█         | 27/243 [00:00<00:00, 268.07it/s]
#  23%|██▎       | 55/243 [00:00<00:00, 272.69it/s]
#  34%|███▍      | 83/243 [00:00<00:00, 268.25it/s]
#  46%|████▌     | 111/243 [00:00<00:00, 268.71it/s]
#  57%|█████▋    | 138/243 [00:00<00:00, 268.11it/s]
#  68%|██████▊   | 166/243 [00:00<00:00, 270.12it/s]
#  80%|███████▉  | 194/243 [00:00<00:00, 267.69it/s]
#  91%|█████████ | 221/243 [00:00<00:00, 263.37it/s]
# 100%|██████████| 243/243 [00:00<00:00, 266.20it/s]
#
#   0%|          | 0/240 [00:00<?, ?it/s]
#  11%|█▏        | 27/240 [00:00<00:00, 265.96it/s]
#  22%|██▎       | 54/240 [00:00<00:00, 267.46it/s]
#  34%|███▍      | 81/240 [00:00<00:00, 267.94it/s]
#  45%|████▌     | 109/240 [00:00<00:00, 270.03it/s]
#  57%|█████▋    | 137/240 [00:00<00:00, 272.00it/s]
#  69%|██████▉   | 165/240 [00:00<00:00, 270.21it/s]
#  80%|████████  | 193/240 [00:00<00:00, 269.14it/s]
#  92%|█████████▏| 220/240 [00:00<00:00, 267.89it/s]
# 100%|██████████| 240/240 [00:00<00:00, 267.92it/s]
#    fold_id                       source_dir  \
# 0        1  gan_patches_256/dataset2/fold_1
# 1        2  gan_patches_256/dataset2/fold_2
# 2        3  gan_patches_256/dataset2/fold_3
# 3        4  gan_patches_256/dataset2/fold_4
# 4        5  gan_patches_256/dataset2/fold_5
#
#                                     dataset_zip_path
# 0  results/40_train_diffusion_gan_make_images_dat...
# 1  results/40_train_diffusion_gan_make_images_dat...
# 2  results/40_train_diffusion_gan_make_images_dat...
# 3  results/40_train_diffusion_gan_make_images_dat...
# 4  results/40_train_diffusion_gan_make_images_dat...

# %%
# We train one Diffusion-GAN run per training fold and keep the full logs on disk.
training_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    dataset_zip_path = REPO_ROOT / fold_plan["dataset_zip_path"]
    run_parent = NOTEBOOK_CHECKPOINTS_DIR / f"fold_{fold_id}"
    safe_prepare_checkpoint_parent(run_parent)
    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    train_log_path = fold_result_dir / "train.log"

    report = run_command(
        build_diffusion_gan_command(
            "train.py",
            f"--outdir={run_parent}",
            "--gpus=1",
            f"--data={dataset_zip_path}",
            f"--cfg={DIFFUSION_GAN_CFG}",
            f"--aug={DIFFUSION_GAN_AUG}",
            f"--target={DIFFUSION_GAN_TARGET}",
            f"--noise_sd={DIFFUSION_GAN_NOISE_SD}",
            f"--ts_dist={DIFFUSION_GAN_TS_DIST}",
            f"--ada_kimg={DIFFUSION_GAN_ADA_KIMG}",
            f"--mirror={int(GAN_MIRROR)}",
            f"--batch={GAN_BATCH_SIZE}",
            f"--kimg={GAN_KIMG}",
            f"--snap={SNAP_TICKS}",
            f"--workers={GAN_WORKERS}",
            f"--metrics={KID_METRIC_NAME}",
            f"--seed={DIFFUSION_GAN_RANDOM_SEED}",
            f"--exp_id=dg_d2_f{fold_id}",
        ),
        DIFFUSION_GAN_DIR,
        live_log_path=train_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=DIFFUSION_GAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "train_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"Diffusion-GAN training failed for fold {fold_id}")

    run_dirs = [path for path in run_parent.iterdir() if path.is_dir()]
    if not run_dirs:
        raise FileNotFoundError(f"No Diffusion-GAN run directory was found for fold {fold_id}")
    run_dir = sorted(run_dirs, key=lambda item: item.name)[-1]
    snapshot_paths = sorted(run_dir.glob("network-snapshot-*.pkl"))
    if not snapshot_paths:
        raise FileNotFoundError(f"No Diffusion-GAN snapshots were saved for fold {fold_id}")

    training_rows.append({
        "fold_id": fold_id,
        "run_dir": as_repo_relative(REPO_ROOT, run_dir),
        "latest_snapshot_path": as_repo_relative(REPO_ROOT, snapshot_paths[-1]),
        "train_duration_seconds": report["duration_seconds"],
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "training_run_manifest.csv", training_rows, list(training_rows[0].keys()))
display(pd.DataFrame(training_rows))
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [
#     "kid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:\\Users\\FYP2610\\Downloads\\FYP2\\results\\40_train_diffusion_gan_make_images_dataset2\\fold_1\\fold_1_minority_256.zip",
#     "use_labels": false,
#     "max_size": 260,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Training for 200 kimg...
# tick 0     kimg 0.0      time 1m 32s       sec/tick 42.5    sec/kimg 5306.54 maintenance 49.4   cpumem 2.78   gpumem 4.94   augment 0.000 T 10.0
# {"results": {"kid50k_full": 0.4554867446422577}, "metric": "kid50k_full", "total_time": 403.06412839889526, "total_time_str": "6m 43s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1778605212.4212663}
# tick 1     kimg 4.0      time 12m 00s      sec/tick 210.5   sec/kimg 52.64   maintenance 418.1  cpumem 2.92   gpumem 5.39   augment 0.026 T 35.0
# tick 2     kimg 8.0      time 15m 31s      sec/tick 210.4   sec/kimg 52.60   maintenance 0.0    cpumem 2.92   gpumem 2.85   augment 0.058 T 67.0
# tick 3     kimg 12.0     time 19m 01s      sec/tick 209.8   sec/kimg 52.46   maintenance 0.0    cpumem 2.92   gpumem 2.85   augment 0.086 T 96.0
# tick 4     kimg 16.0     time 22m 31s      sec/tick 210.5   sec/kimg 52.62   maintenance 0.0    cpumem 2.92   gpumem 2.85   augment 0.114 T 122.0
# tick 5     kimg 20.0     time 26m 02s      sec/tick 210.7   sec/kimg 52.68   maintenance 0.1    cpumem 2.92   gpumem 2.85   augment 0.148 T 156.0
# tick 6     kimg 24.0     time 29m 33s      sec/tick 210.4   sec/kimg 52.61   maintenance 0.0    cpumem 2.92   gpumem 2.85   augment 0.185 T 193.0
# tick 7     kimg 28.0     time 33m 03s      sec/tick 210.6   sec/kimg 52.64   maintenance 0.0    cpumem 2.92   gpumem 2.85   augment 0.223 T 231.0
# tick 8     kimg 32.0     time 36m 34s      sec/tick 210.3   sec/kimg 52.58   maintenance 0.0    cpumem 2.92   gpumem 2.85   augment 0.258 T 265.0
# tick 9     kimg 36.0     time 40m 04s      sec/tick 210.7   sec/kimg 52.68   maintenance 0.1    cpumem 2.92   gpumem 2.85   augment 0.294 T 301.0
# tick 10    kimg 40.0     time 43m 35s      sec/tick 210.4   sec/kimg 52.60   maintenance 0.0    cpumem 2.92   gpumem 2.85   augment 0.330 T 337.0
# {"results": {"kid50k_full": 0.9040746688842773}, "metric": "kid50k_full", "total_time": 390.1370327472687, "total_time_str": "6m 30s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1778607720.3824916}
# tick 11    kimg 44.0     time 53m 48s      sec/tick 210.1   sec/kimg 52.52   maintenance 403.0  cpumem 2.97   gpumem 2.85   augment 0.367 T 373.0
# tick 12    kimg 48.0     time 57m 19s      sec/tick 210.7   sec/kimg 52.66   maintenance 0.0    cpumem 2.97   gpumem 2.85   augment 0.400 T 406.0
# tick 13    kimg 52.0     time 1h 00m 51s   sec/tick 212.0   sec/kimg 52.99   maintenance 0.1    cpumem 2.97   gpumem 2.85   augment 0.438 T 443.0
# tick 14    kimg 56.0     time 1h 04m 21s   sec/tick 210.5   sec/kimg 52.63   maintenance 0.0    cpumem 2.95   gpumem 2.85   augment 0.473 T 478.0
# tick 15    kimg 60.0     time 1h 07m 52s   sec/tick 210.3   sec/kimg 52.57   maintenance 0.0    cpumem 2.83   gpumem 2.85   augment 0.503 T 508.0
# tick 16    kimg 64.0     time 1h 11m 22s   sec/tick 210.2   sec/kimg 52.56   maintenance 0.0    cpumem 2.83   gpumem 2.85   augment 0.527 T 532.0
# tick 17    kimg 68.0     time 1h 14m 52s   sec/tick 210.5   sec/kimg 52.62   maintenance 0.1    cpumem 2.83   gpumem 2.85   augment 0.540 T 544.0
# tick 18    kimg 72.0     time 1h 18m 24s   sec/tick 211.2   sec/kimg 52.80   maintenance 0.0    cpumem 2.83   gpumem 2.85   augment 0.544 T 549.0
# tick 19    kimg 76.0     time 1h 21m 54s   sec/tick 210.5   sec/kimg 52.63   maintenance 0.0    cpumem 2.83   gpumem 2.85   augment 0.554 T 558.0
# tick 20    kimg 80.0     time 1h 25m 25s   sec/tick 210.5   sec/kimg 52.64   maintenance 0.0    cpumem 2.83   gpumem 2.85   augment 0.561 T 565.0
# {"results": {"kid50k_full": 0.31781768798828125}, "metric": "kid50k_full", "total_time": 391.55927753448486, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1778610229.3838298}
# tick 21    kimg 84.0     time 1h 35m 37s   sec/tick 210.2   sec/kimg 52.54   maintenance 402.0  cpumem 2.90   gpumem 2.85   augment 0.567 T 571.0
# tick 22    kimg 88.0     time 1h 39m 07s   sec/tick 210.4   sec/kimg 52.59   maintenance 0.0    cpumem 2.90   gpumem 2.85   augment 0.589 T 593.0
# tick 23    kimg 92.0     time 1h 42m 38s   sec/tick 210.2   sec/kimg 52.55   maintenance 0.0    cpumem 2.90   gpumem 2.85   augment 0.602 T 606.0
# tick 24    kimg 96.0     time 1h 46m 08s   sec/tick 210.6   sec/kimg 52.66   maintenance 0.1    cpumem 2.90   gpumem 2.85   augment 0.623 T 626.0
# tick 25    kimg 100.0    time 1h 49m 39s   sec/tick 210.3   sec/kimg 52.57   maintenance 0.1    cpumem 2.87   gpumem 2.85   augment 0.650 T 654.0
# tick 26    kimg 104.0    time 1h 53m 10s   sec/tick 210.8   sec/kimg 52.69   maintenance 0.0    cpumem 2.87   gpumem 2.85   augment 0.670 T 673.0
# tick 27    kimg 108.0    time 1h 56m 40s   sec/tick 210.6   sec/kimg 52.66   maintenance 0.0    cpumem 2.85   gpumem 2.85   augment 0.699 T 702.0
# tick 28    kimg 112.0    time 2h 00m 11s   sec/tick 210.3   sec/kimg 52.57   maintenance 0.0    cpumem 2.85   gpumem 2.85   augment 0.723 T 726.0
# tick 29    kimg 116.0    time 2h 03m 41s   sec/tick 210.3   sec/kimg 52.57   maintenance 0.1    cpumem 2.85   gpumem 2.85   augment 0.751 T 754.0
# tick 30    kimg 120.0    time 2h 07m 11s   sec/tick 210.2   sec/kimg 52.54   maintenance 0.0    cpumem 2.85   gpumem 2.85   augment 0.788 T 790.0
# {"results": {"kid50k_full": 0.21280823647975922}, "metric": "kid50k_full", "total_time": 391.00432872772217, "total_time_str": "6m 31s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1778612743.7885509}
# tick 31    kimg 124.0    time 2h 17m 32s   sec/tick 210.3   sec/kimg 52.58   maintenance 410.1  cpumem 2.93   gpumem 2.85   augment 0.818 T 820.0
# tick 32    kimg 128.0    time 2h 21m 02s   sec/tick 210.4   sec/kimg 52.60   maintenance 0.0    cpumem 2.85   gpumem 2.85   augment 0.856 T 857.0
# tick 33    kimg 132.0    time 2h 24m 32s   sec/tick 210.2   sec/kimg 52.55   maintenance 0.1    cpumem 2.85   gpumem 2.85   augment 0.883 T 884.0
# tick 34    kimg 136.0    time 2h 28m 03s   sec/tick 210.3   sec/kimg 52.57   maintenance 0.0    cpumem 2.83   gpumem 2.85   augment 0.906 T 907.0
# tick 35    kimg 140.0    time 2h 31m 33s   sec/tick 210.7   sec/kimg 52.68   maintenance 0.0    cpumem 2.81   gpumem 2.85   augment 0.931 T 932.0
# tick 36    kimg 144.0    time 2h 35m 04s   sec/tick 210.4   sec/kimg 52.60   maintenance 0.0    cpumem 2.81   gpumem 2.85   augment 0.966 T 967.0
# tick 37    kimg 148.0    time 2h 38m 34s   sec/tick 210.1   sec/kimg 52.53   maintenance 0.1    cpumem 2.81   gpumem 2.85   augment 0.991 T 991.0
# tick 38    kimg 152.0    time 2h 42m 05s   sec/tick 210.4   sec/kimg 52.60   maintenance 0.1    cpumem 2.81   gpumem 2.85   augment 1.000 T 1000.0
# tick 39    kimg 156.0    time 2h 45m 35s   sec/tick 210.6   sec/kimg 52.64   maintenance 0.0    cpumem 2.81   gpumem 2.85   augment 1.000 T 1000.0
# tick 40    kimg 160.0    time 2h 49m 06s   sec/tick 210.8   sec/kimg 52.70   maintenance 0.0    cpumem 2.81   gpumem 2.85   augment 1.000 T 1000.0
# {"results": {"kid50k_full": 0.2347525954246521}, "metric": "kid50k_full", "total_time": 392.3844361305237, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1778615251.4995909}
# tick 41    kimg 164.0    time 2h 59m 19s   sec/tick 210.4   sec/kimg 52.59   maintenance 402.9  cpumem 2.96   gpumem 2.85   augment 1.000 T 1000.0
# tick 42    kimg 168.0    time 3h 02m 50s   sec/tick 210.4   sec/kimg 52.60   maintenance 0.0    cpumem 2.84   gpumem 2.85   augment 1.000 T 1000.0
# tick 43    kimg 172.0    time 3h 06m 20s   sec/tick 210.0   sec/kimg 52.49   maintenance 0.0    cpumem 2.84   gpumem 2.85   augment 1.000 T 1000.0
# tick 44    kimg 176.0    time 3h 09m 51s   sec/tick 210.9   sec/kimg 52.72   maintenance 0.0    cpumem 2.84   gpumem 2.85   augment 1.000 T 1000.0
# tick 45    kimg 180.0    time 3h 13m 21s   sec/tick 210.4   sec/kimg 52.61   maintenance 0.1    cpumem 2.84   gpumem 2.85   augment 1.000 T 1000.0
# tick 46    kimg 184.0    time 3h 16m 52s   sec/tick 210.4   sec/kimg 52.61   maintenance 0.0    cpumem 2.84   gpumem 2.85   augment 1.000 T 1000.0
# tick 47    kimg 188.0    time 3h 20m 22s   sec/tick 210.1   sec/kimg 52.53   maintenance 0.0    cpumem 2.84   gpumem 2.85   augment 1.000 T 1000.0
# tick 48    kimg 192.0    time 3h 23m 52s   sec/tick 210.2   sec/kimg 52.56   maintenance 0.0    cpumem 2.84   gpumem 2.85   augment 1.000 T 1000.0
# tick 49    kimg 196.0    time 3h 27m 23s   sec/tick 210.8   sec/kimg 52.69   maintenance 0.1    cpumem 2.84   gpumem 2.85   augment 1.000 T 1000.0
# tick 50    kimg 200.0    time 3h 30m 53s   sec/tick 209.6   sec/kimg 52.51   maintenance 0.0    cpumem 2.84   gpumem 2.85   augment 1.000 T 1000.0
# {"results": {"kid50k_full": 0.12342972308397293}, "metric": "kid50k_full", "total_time": 392.5371356010437, "total_time_str": "6m 33s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1778617767.664848}
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [
#     "kid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:\\Users\\FYP2610\\Downloads\\FYP2\\results\\40_train_diffusion_gan_make_images_dataset2\\fold_2\\fold_2_minority_256.zip",
#     "use_labels": false,
#     "max_size": 239,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Training for 200 kimg...
# tick 0     kimg 0.0      time 1m 31s       sec/tick 42.1    sec/kimg 5257.76 maintenance 49.0   cpumem 2.79   gpumem 4.94   augment 0.000 T 10.0
# {"results": {"kid50k_full": 0.4876691997051239}, "metric": "kid50k_full", "total_time": 404.2203633785248, "total_time_str": "6m 44s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1778618283.9186442}
# tick 1     kimg 4.0      time 12m 02s      sec/tick 210.7   sec/kimg 52.67   maintenance 420.2  cpumem 3.18   gpumem 5.39   augment 0.023 T 32.0
# tick 2     kimg 8.0      time 15m 32s      sec/tick 210.5   sec/kimg 52.63   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 0.053 T 63.0
# tick 3     kimg 12.0     time 19m 03s      sec/tick 210.6   sec/kimg 52.64   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 0.085 T 94.0
# tick 4     kimg 16.0     time 22m 34s      sec/tick 210.7   sec/kimg 52.68   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 0.124 T 133.0
# tick 5     kimg 20.0     time 26m 04s      sec/tick 210.5   sec/kimg 52.63   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 0.161 T 170.0
# tick 6     kimg 24.0     time 29m 35s      sec/tick 210.7   sec/kimg 52.67   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 0.199 T 207.0
# tick 7     kimg 28.0     time 33m 06s      sec/tick 210.7   sec/kimg 52.67   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 0.236 T 243.0
# tick 8     kimg 32.0     time 36m 37s      sec/tick 210.9   sec/kimg 52.72   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 0.273 T 280.0
# tick 9     kimg 36.0     time 40m 08s      sec/tick 210.8   sec/kimg 52.69   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 0.308 T 314.0
# tick 10    kimg 40.0     time 43m 39s      sec/tick 210.8   sec/kimg 52.69   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 0.344 T 350.0
# {"results": {"kid50k_full": 0.7047183513641357}, "metric": "kid50k_full", "total_time": 392.46249508857727, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1778620793.4287548}
# tick 11    kimg 44.0     time 53m 51s      sec/tick 210.6   sec/kimg 52.64   maintenance 402.2  cpumem 2.97   gpumem 2.86   augment 0.372 T 378.0
# tick 12    kimg 48.0     time 57m 22s      sec/tick 210.9   sec/kimg 52.71   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.409 T 415.0
# tick 13    kimg 52.0     time 1h 00m 53s   sec/tick 210.9   sec/kimg 52.71   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.441 T 446.0
# tick 14    kimg 56.0     time 1h 04m 24s   sec/tick 210.8   sec/kimg 52.71   maintenance 0.1    cpumem 2.95   gpumem 2.86   augment 0.473 T 478.0
# tick 15    kimg 60.0     time 1h 07m 55s   sec/tick 210.9   sec/kimg 52.71   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 0.502 T 507.0
# tick 16    kimg 64.0     time 1h 11m 26s   sec/tick 210.8   sec/kimg 52.70   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 0.522 T 527.0
# tick 17    kimg 68.0     time 1h 14m 57s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.1    cpumem 2.95   gpumem 2.86   augment 0.534 T 539.0
# tick 18    kimg 72.0     time 1h 18m 28s   sec/tick 210.8   sec/kimg 52.69   maintenance 0.1    cpumem 2.95   gpumem 2.86   augment 0.539 T 543.0
# tick 19    kimg 76.0     time 1h 21m 59s   sec/tick 210.9   sec/kimg 52.72   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 0.547 T 552.0
# tick 20    kimg 80.0     time 1h 25m 29s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 0.547 T 552.0
# {"results": {"kid50k_full": 0.33401837944984436}, "metric": "kid50k_full", "total_time": 391.93651127815247, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1778623306.4151876}
# tick 21    kimg 84.0     time 1h 35m 44s   sec/tick 210.6   sec/kimg 52.64   maintenance 404.2  cpumem 2.97   gpumem 2.86   augment 0.540 T 544.0
# tick 22    kimg 88.0     time 1h 39m 15s   sec/tick 210.8   sec/kimg 52.70   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.539 T 543.0
# tick 23    kimg 92.0     time 1h 42m 46s   sec/tick 210.6   sec/kimg 52.65   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.532 T 536.0
# tick 24    kimg 96.0     time 1h 46m 17s   sec/tick 210.8   sec/kimg 52.70   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.538 T 542.0
# tick 25    kimg 100.0    time 1h 49m 47s   sec/tick 210.6   sec/kimg 52.64   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.543 T 547.0
# tick 26    kimg 104.0    time 1h 53m 19s   sec/tick 211.3   sec/kimg 52.82   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.581 T 585.0
# tick 27    kimg 108.0    time 1h 56m 50s   sec/tick 211.0   sec/kimg 52.75   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.588 T 592.0
# tick 28    kimg 112.0    time 2h 00m 21s   sec/tick 211.0   sec/kimg 52.74   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.590 T 594.0
# tick 29    kimg 116.0    time 2h 03m 52s   sec/tick 210.9   sec/kimg 52.72   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.608 T 612.0
# tick 30    kimg 120.0    time 2h 07m 23s   sec/tick 211.0   sec/kimg 52.76   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.613 T 617.0
# {"results": {"kid50k_full": 0.2275305688381195}, "metric": "kid50k_full", "total_time": 393.2730221748352, "total_time_str": "6m 33s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1778625826.3894029}
# tick 31    kimg 124.0    time 2h 17m 44s   sec/tick 210.6   sec/kimg 52.66   maintenance 411.0  cpumem 3.07   gpumem 2.86   augment 0.639 T 642.0
# tick 32    kimg 128.0    time 2h 21m 15s   sec/tick 210.9   sec/kimg 52.72   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.675 T 678.0
# tick 33    kimg 132.0    time 2h 24m 46s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.707 T 709.0
# tick 34    kimg 136.0    time 2h 28m 17s   sec/tick 210.8   sec/kimg 52.69   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.728 T 730.0
# tick 35    kimg 140.0    time 2h 31m 48s   sec/tick 210.7   sec/kimg 52.69   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.748 T 751.0
# tick 36    kimg 144.0    time 2h 35m 19s   sec/tick 211.0   sec/kimg 52.76   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.765 T 767.0
# tick 37    kimg 148.0    time 2h 38m 50s   sec/tick 210.9   sec/kimg 52.72   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.785 T 787.0
# tick 38    kimg 152.0    time 2h 42m 21s   sec/tick 210.8   sec/kimg 52.70   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.811 T 813.0
# tick 39    kimg 156.0    time 2h 45m 52s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.843 T 844.0
# tick 40    kimg 160.0    time 2h 49m 23s   sec/tick 211.1   sec/kimg 52.79   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.877 T 879.0
# {"results": {"kid50k_full": 0.13577361404895782}, "metric": "kid50k_full", "total_time": 392.13430070877075, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1778628341.8257828}
# tick 41    kimg 164.0    time 2h 59m 40s   sec/tick 210.5   sec/kimg 52.63   maintenance 406.2  cpumem 3.07   gpumem 2.86   augment 0.911 T 912.0
# tick 42    kimg 168.0    time 3h 03m 10s   sec/tick 210.6   sec/kimg 52.64   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 0.947 T 948.0
# tick 43    kimg 172.0    time 3h 06m 41s   sec/tick 211.0   sec/kimg 52.74   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 0.981 T 981.0
# tick 44    kimg 176.0    time 3h 10m 12s   sec/tick 210.7   sec/kimg 52.68   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 1.000 T 1000.0
# tick 45    kimg 180.0    time 3h 13m 43s   sec/tick 211.1   sec/kimg 52.77   maintenance 0.1    cpumem 2.95   gpumem 2.86   augment 1.000 T 1000.0
# tick 46    kimg 184.0    time 3h 17m 14s   sec/tick 210.6   sec/kimg 52.65   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 1.000 T 1000.0
# tick 47    kimg 188.0    time 3h 20m 45s   sec/tick 210.7   sec/kimg 52.68   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 1.000 T 1000.0
# tick 48    kimg 192.0    time 3h 24m 16s   sec/tick 211.0   sec/kimg 52.75   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 1.000 T 1000.0
# tick 49    kimg 196.0    time 3h 27m 47s   sec/tick 210.9   sec/kimg 52.72   maintenance 0.1    cpumem 2.95   gpumem 2.86   augment 1.000 T 1000.0
# tick 50    kimg 200.0    time 3h 31m 17s   sec/tick 210.3   sec/kimg 52.69   maintenance 0.0    cpumem 2.95   gpumem 2.86   augment 1.000 T 1000.0
# {"results": {"kid50k_full": 0.1668180674314499}, "metric": "kid50k_full", "total_time": 393.34535813331604, "total_time_str": "6m 33s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1778630862.3812928}
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [
#     "kid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:\\Users\\FYP2610\\Downloads\\FYP2\\results\\40_train_diffusion_gan_make_images_dataset2\\fold_3\\fold_3_minority_256.zip",
#     "use_labels": false,
#     "max_size": 229,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Training for 200 kimg...
# tick 0     kimg 0.0      time 1m 30s       sec/tick 41.7    sec/kimg 5215.02 maintenance 48.3   cpumem 2.78   gpumem 4.94   augment 0.000 T 10.0
# {"results": {"kid50k_full": 0.4975024163722992}, "metric": "kid50k_full", "total_time": 403.4354100227356, "total_time_str": "6m 43s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1778631374.1020467}
# tick 1     kimg 4.0      time 11m 59s      sec/tick 211.4   sec/kimg 52.85   maintenance 417.5  cpumem 2.94   gpumem 5.39   augment 0.029 T 39.0
# tick 2     kimg 8.0      time 15m 30s      sec/tick 211.0   sec/kimg 52.74   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 0.062 T 71.0
# tick 3     kimg 12.0     time 19m 01s      sec/tick 211.0   sec/kimg 52.74   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 0.096 T 105.0
# tick 4     kimg 16.0     time 22m 32s      sec/tick 210.7   sec/kimg 52.67   maintenance 0.1    cpumem 2.93   gpumem 2.86   augment 0.131 T 139.0
# tick 5     kimg 20.0     time 26m 02s      sec/tick 210.6   sec/kimg 52.66   maintenance 0.1    cpumem 2.93   gpumem 2.86   augment 0.158 T 167.0
# tick 6     kimg 24.0     time 29m 33s      sec/tick 210.8   sec/kimg 52.70   maintenance 0.0    cpumem 2.93   gpumem 2.86   augment 0.195 T 203.0
# tick 7     kimg 28.0     time 33m 04s      sec/tick 211.0   sec/kimg 52.75   maintenance 0.0    cpumem 2.93   gpumem 2.86   augment 0.219 T 226.0
# tick 8     kimg 32.0     time 36m 35s      sec/tick 211.1   sec/kimg 52.78   maintenance 0.0    cpumem 2.93   gpumem 2.86   augment 0.254 T 262.0
# tick 9     kimg 36.0     time 40m 07s      sec/tick 211.1   sec/kimg 52.76   maintenance 0.1    cpumem 2.93   gpumem 2.86   augment 0.290 T 297.0
# tick 10    kimg 40.0     time 43m 38s      sec/tick 211.0   sec/kimg 52.76   maintenance 0.0    cpumem 2.93   gpumem 2.86   augment 0.327 T 334.0
# {"results": {"kid50k_full": 0.5514646768569946}, "metric": "kid50k_full", "total_time": 392.32840609550476, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1778633889.343645}
# tick 11    kimg 44.0     time 53m 54s      sec/tick 211.4   sec/kimg 52.84   maintenance 405.1  cpumem 2.94   gpumem 2.86   augment 0.361 T 367.0
# tick 12    kimg 48.0     time 57m 25s      sec/tick 211.1   sec/kimg 52.79   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 0.397 T 403.0
# tick 13    kimg 52.0     time 1h 00m 57s   sec/tick 211.2   sec/kimg 52.81   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 0.417 T 423.0
# tick 14    kimg 56.0     time 1h 04m 28s   sec/tick 211.0   sec/kimg 52.74   maintenance 0.0    cpumem 2.92   gpumem 2.86   augment 0.434 T 440.0
# tick 15    kimg 60.0     time 1h 07m 59s   sec/tick 211.0   sec/kimg 52.75   maintenance 0.0    cpumem 2.92   gpumem 2.86   augment 0.443 T 448.0
# tick 16    kimg 64.0     time 1h 11m 30s   sec/tick 211.1   sec/kimg 52.78   maintenance 0.0    cpumem 2.92   gpumem 2.86   augment 0.463 T 468.0
# tick 17    kimg 68.0     time 1h 15m 01s   sec/tick 211.0   sec/kimg 52.74   maintenance 0.1    cpumem 2.92   gpumem 2.86   augment 0.462 T 468.0
# tick 18    kimg 72.0     time 1h 18m 32s   sec/tick 211.4   sec/kimg 52.86   maintenance 0.0    cpumem 2.92   gpumem 2.86   augment 0.468 T 473.0
# tick 19    kimg 76.0     time 1h 22m 03s   sec/tick 211.1   sec/kimg 52.76   maintenance 0.0    cpumem 2.92   gpumem 2.86   augment 0.480 T 485.0
# tick 20    kimg 80.0     time 1h 25m 35s   sec/tick 211.1   sec/kimg 52.78   maintenance 0.0    cpumem 2.92   gpumem 2.86   augment 0.492 T 497.0
# {"results": {"kid50k_full": 0.3223400413990021}, "metric": "kid50k_full", "total_time": 392.1445803642273, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1778636405.2154012}
# tick 21    kimg 84.0     time 1h 35m 50s   sec/tick 211.3   sec/kimg 52.81   maintenance 404.0  cpumem 2.97   gpumem 2.86   augment 0.508 T 513.0
# tick 22    kimg 88.0     time 1h 39m 21s   sec/tick 211.1   sec/kimg 52.77   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.528 T 533.0
# tick 23    kimg 92.0     time 1h 42m 52s   sec/tick 210.7   sec/kimg 52.67   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.550 T 555.0
# tick 24    kimg 96.0     time 1h 46m 23s   sec/tick 211.2   sec/kimg 52.80   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.576 T 580.0
# tick 25    kimg 100.0    time 1h 49m 54s   sec/tick 210.7   sec/kimg 52.68   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.613 T 617.0
# tick 26    kimg 104.0    time 1h 53m 25s   sec/tick 211.4   sec/kimg 52.86   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.642 T 645.0
# tick 27    kimg 108.0    time 1h 56m 56s   sec/tick 211.0   sec/kimg 52.75   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.671 T 674.0
# tick 28    kimg 112.0    time 2h 00m 28s   sec/tick 211.4   sec/kimg 52.86   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.696 T 699.0
# tick 29    kimg 116.0    time 2h 03m 59s   sec/tick 211.1   sec/kimg 52.78   maintenance 0.1    cpumem 2.97   gpumem 2.86   augment 0.720 T 723.0
# tick 30    kimg 120.0    time 2h 07m 30s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.0    cpumem 2.97   gpumem 2.86   augment 0.751 T 754.0
# {"results": {"kid50k_full": 0.2893388867378235}, "metric": "kid50k_full", "total_time": 392.23763704299927, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1778638923.3878443}
# tick 31    kimg 124.0    time 2h 17m 48s   sec/tick 211.4   sec/kimg 52.85   maintenance 406.8  cpumem 3.05   gpumem 2.86   augment 0.782 T 785.0
# tick 32    kimg 128.0    time 2h 21m 19s   sec/tick 211.0   sec/kimg 52.74   maintenance 0.0    cpumem 2.91   gpumem 2.86   augment 0.815 T 817.0
# tick 33    kimg 132.0    time 2h 24m 50s   sec/tick 210.7   sec/kimg 52.67   maintenance 0.1    cpumem 2.91   gpumem 2.86   augment 0.848 T 850.0
# tick 34    kimg 136.0    time 2h 28m 21s   sec/tick 211.2   sec/kimg 52.80   maintenance 0.0    cpumem 2.91   gpumem 2.86   augment 0.881 T 882.0
# tick 35    kimg 140.0    time 2h 31m 52s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.0    cpumem 2.91   gpumem 2.86   augment 0.916 T 916.0
# tick 36    kimg 144.0    time 2h 35m 24s   sec/tick 211.4   sec/kimg 52.85   maintenance 0.0    cpumem 2.91   gpumem 2.86   augment 0.952 T 953.0
# tick 37    kimg 148.0    time 2h 38m 55s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.1    cpumem 2.91   gpumem 2.86   augment 0.988 T 988.0
# tick 38    kimg 152.0    time 2h 42m 26s   sec/tick 211.2   sec/kimg 52.80   maintenance 0.0    cpumem 2.91   gpumem 2.86   augment 1.000 T 1000.0
# tick 39    kimg 156.0    time 2h 45m 57s   sec/tick 211.4   sec/kimg 52.85   maintenance 0.0    cpumem 2.91   gpumem 2.86   augment 1.000 T 1000.0
# tick 40    kimg 160.0    time 2h 49m 29s   sec/tick 211.4   sec/kimg 52.86   maintenance 0.1    cpumem 2.91   gpumem 2.86   augment 1.000 T 1000.0
# {"results": {"kid50k_full": 0.21294312179088593}, "metric": "kid50k_full", "total_time": 391.43455624580383, "total_time_str": "6m 31s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1778641443.82497}
# tick 41    kimg 164.0    time 2h 59m 49s   sec/tick 211.3   sec/kimg 52.83   maintenance 408.5  cpumem 3.05   gpumem 2.86   augment 1.000 T 1000.0
# tick 42    kimg 168.0    time 3h 03m 20s   sec/tick 211.0   sec/kimg 52.74   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 1.000 T 1000.0
# tick 43    kimg 172.0    time 3h 06m 51s   sec/tick 211.0   sec/kimg 52.76   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 1.000 T 1000.0
# tick 44    kimg 176.0    time 3h 10m 22s   sec/tick 211.3   sec/kimg 52.82   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 1.000 T 1000.0
# tick 45    kimg 180.0    time 3h 13m 53s   sec/tick 211.0   sec/kimg 52.75   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 1.000 T 1000.0
# tick 46    kimg 184.0    time 3h 17m 24s   sec/tick 211.2   sec/kimg 52.81   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 1.000 T 1000.0
# tick 47    kimg 188.0    time 3h 20m 55s   sec/tick 211.0   sec/kimg 52.75   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 1.000 T 1000.0
# tick 48    kimg 192.0    time 3h 24m 26s   sec/tick 211.0   sec/kimg 52.76   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 1.000 T 1000.0
# tick 49    kimg 196.0    time 3h 27m 58s   sec/tick 211.0   sec/kimg 52.76   maintenance 0.1    cpumem 2.94   gpumem 2.86   augment 1.000 T 1000.0
# tick 50    kimg 200.0    time 3h 31m 28s   sec/tick 210.5   sec/kimg 52.74   maintenance 0.0    cpumem 2.94   gpumem 2.86   augment 1.000 T 1000.0
# {"results": {"kid50k_full": 0.25087717175483704}, "metric": "kid50k_full", "total_time": 393.1778140068054, "total_time_str": "6m 33s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1778643964.9620147}
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [
#     "kid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:\\Users\\FYP2610\\Downloads\\FYP2\\results\\40_train_diffusion_gan_make_images_dataset2\\fold_4\\fold_4_minority_256.zip",
#     "use_labels": false,
#     "max_size": 243,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Training for 200 kimg...
# tick 0     kimg 0.0      time 1m 33s       sec/tick 42.5    sec/kimg 5315.22 maintenance 50.5   cpumem 2.79   gpumem 4.94   augment 0.000 T 10.0
# {"results": {"kid50k_full": 0.49124854803085327}, "metric": "kid50k_full", "total_time": 404.652907371521, "total_time_str": "6m 45s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1778644481.2301805}
# tick 1     kimg 4.0      time 12m 04s      sec/tick 212.0   sec/kimg 53.00   maintenance 418.8  cpumem 2.94   gpumem 5.39   augment 0.025 T 35.0
# tick 2     kimg 8.0      time 15m 36s      sec/tick 212.7   sec/kimg 53.17   maintenance 0.0    cpumem 2.94   gpumem 2.85   augment 0.056 T 66.0
# tick 3     kimg 12.0     time 19m 09s      sec/tick 212.2   sec/kimg 53.06   maintenance 0.1    cpumem 2.94   gpumem 2.85   augment 0.085 T 95.0
# tick 4     kimg 16.0     time 22m 41s      sec/tick 212.3   sec/kimg 53.08   maintenance 0.0    cpumem 2.94   gpumem 2.85   augment 0.123 T 132.0
# tick 5     kimg 20.0     time 26m 14s      sec/tick 212.5   sec/kimg 53.13   maintenance 0.1    cpumem 2.94   gpumem 2.85   augment 0.161 T 169.0
# tick 6     kimg 24.0     time 29m 46s      sec/tick 212.0   sec/kimg 53.01   maintenance 0.1    cpumem 2.94   gpumem 2.85   augment 0.198 T 206.0
# tick 7     kimg 28.0     time 33m 18s      sec/tick 212.1   sec/kimg 53.02   maintenance 0.0    cpumem 2.94   gpumem 2.85   augment 0.236 T 244.0
# tick 8     kimg 32.0     time 36m 50s      sec/tick 212.3   sec/kimg 53.08   maintenance 0.0    cpumem 2.94   gpumem 2.85   augment 0.273 T 281.0
# tick 9     kimg 36.0     time 40m 23s      sec/tick 212.1   sec/kimg 53.02   maintenance 0.1    cpumem 2.94   gpumem 2.85   augment 0.313 T 320.0
# tick 10    kimg 40.0     time 43m 54s      sec/tick 211.9   sec/kimg 52.98   maintenance 0.0    cpumem 2.94   gpumem 2.85   augment 0.337 T 343.0
# {"results": {"kid50k_full": 0.7005668878555298}, "metric": "kid50k_full", "total_time": 392.3144142627716, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1778647011.8491702}
# tick 11    kimg 44.0     time 54m 15s      sec/tick 212.3   sec/kimg 53.08   maintenance 407.9  cpumem 2.95   gpumem 2.85   augment 0.366 T 372.0
# tick 12    kimg 48.0     time 57m 47s      sec/tick 212.7   sec/kimg 53.18   maintenance 0.0    cpumem 2.95   gpumem 2.85   augment 0.397 T 403.0
# tick 13    kimg 52.0     time 1h 01m 20s   sec/tick 212.7   sec/kimg 53.18   maintenance 0.1    cpumem 2.95   gpumem 2.85   augment 0.416 T 422.0
# tick 14    kimg 56.0     time 1h 04m 52s   sec/tick 212.0   sec/kimg 53.01   maintenance 0.0    cpumem 2.93   gpumem 2.85   augment 0.434 T 439.0
# tick 15    kimg 60.0     time 1h 08m 25s   sec/tick 212.5   sec/kimg 53.12   maintenance 0.1    cpumem 2.93   gpumem 2.85   augment 0.440 T 446.0
# tick 16    kimg 64.0     time 1h 11m 57s   sec/tick 212.2   sec/kimg 53.04   maintenance 0.0    cpumem 2.93   gpumem 2.85   augment 0.447 T 453.0
# tick 17    kimg 68.0     time 1h 15m 30s   sec/tick 212.7   sec/kimg 53.17   maintenance 0.1    cpumem 2.93   gpumem 2.85   augment 0.447 T 452.0
# tick 18    kimg 72.0     time 1h 19m 03s   sec/tick 212.6   sec/kimg 53.15   maintenance 0.0    cpumem 2.93   gpumem 2.85   augment 0.449 T 455.0
# tick 19    kimg 76.0     time 1h 22m 35s   sec/tick 212.9   sec/kimg 53.22   maintenance 0.0    cpumem 2.93   gpumem 2.85   augment 0.460 T 466.0
# tick 20    kimg 80.0     time 1h 26m 08s   sec/tick 212.5   sec/kimg 53.13   maintenance 0.1    cpumem 2.93   gpumem 2.85   augment 0.481 T 486.0
# {"results": {"kid50k_full": 0.33977001905441284}, "metric": "kid50k_full", "total_time": 393.16520833969116, "total_time_str": "6m 33s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1778649540.9333687}
# tick 21    kimg 84.0     time 1h 36m 25s   sec/tick 213.1   sec/kimg 53.28   maintenance 403.4  cpumem 2.97   gpumem 2.85   augment 0.491 T 496.0
# tick 22    kimg 88.0     time 1h 39m 58s   sec/tick 213.0   sec/kimg 53.25   maintenance 0.0    cpumem 2.97   gpumem 2.85   augment 0.515 T 519.0
# tick 23    kimg 92.0     time 1h 43m 30s   sec/tick 212.6   sec/kimg 53.15   maintenance 0.0    cpumem 2.97   gpumem 2.85   augment 0.545 T 550.0
# tick 24    kimg 96.0     time 1h 47m 03s   sec/tick 213.1   sec/kimg 53.26   maintenance 0.0    cpumem 2.95   gpumem 2.85   augment 0.573 T 577.0
# tick 25    kimg 100.0    time 1h 50m 36s   sec/tick 212.4   sec/kimg 53.11   maintenance 0.1    cpumem 2.95   gpumem 2.85   augment 0.605 T 609.0
# tick 26    kimg 104.0    time 1h 54m 08s   sec/tick 212.3   sec/kimg 53.07   maintenance 0.0    cpumem 2.95   gpumem 2.85   augment 0.632 T 636.0
# tick 27    kimg 108.0    time 1h 57m 41s   sec/tick 212.5   sec/kimg 53.14   maintenance 0.1    cpumem 2.95   gpumem 2.85   augment 0.661 T 665.0
# tick 28    kimg 112.0    time 2h 01m 13s   sec/tick 212.3   sec/kimg 53.08   maintenance 0.0    cpumem 2.95   gpumem 2.85   augment 0.695 T 698.0
# tick 29    kimg 116.0    time 2h 04m 46s   sec/tick 212.4   sec/kimg 53.10   maintenance 0.1    cpumem 2.95   gpumem 2.85   augment 0.730 T 732.0
# tick 30    kimg 120.0    time 2h 08m 18s   sec/tick 212.5   sec/kimg 53.12   maintenance 0.1    cpumem 2.95   gpumem 2.85   augment 0.763 T 765.0
# {"results": {"kid50k_full": 0.2511865198612213}, "metric": "kid50k_full", "total_time": 392.3410794734955, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1778652071.9296234}
# tick 31    kimg 124.0    time 2h 18m 35s   sec/tick 212.2   sec/kimg 53.05   maintenance 404.2  cpumem 2.97   gpumem 2.85   augment 0.799 T 801.0
# tick 32    kimg 128.0    time 2h 22m 07s   sec/tick 212.6   sec/kimg 53.15   maintenance 0.0    cpumem 1.93   gpumem 2.85   augment 0.836 T 837.0
# tick 33    kimg 132.0    time 2h 25m 40s   sec/tick 212.3   sec/kimg 53.06   maintenance 0.1    cpumem 1.93   gpumem 2.85   augment 0.872 T 874.0
# tick 34    kimg 136.0    time 2h 29m 13s   sec/tick 212.8   sec/kimg 53.21   maintenance 0.0    cpumem 1.93   gpumem 2.85   augment 0.909 T 910.0
# tick 35    kimg 140.0    time 2h 32m 45s   sec/tick 212.7   sec/kimg 53.17   maintenance 0.0    cpumem 1.93   gpumem 2.85   augment 0.949 T 949.0
# tick 36    kimg 144.0    time 2h 36m 18s   sec/tick 212.3   sec/kimg 53.06   maintenance 0.0    cpumem 1.93   gpumem 2.85   augment 0.984 T 984.0
# tick 37    kimg 148.0    time 2h 39m 51s   sec/tick 212.9   sec/kimg 53.21   maintenance 0.1    cpumem 1.93   gpumem 2.85   augment 1.000 T 1000.0
# tick 38    kimg 152.0    time 2h 43m 23s   sec/tick 212.6   sec/kimg 53.15   maintenance 0.0    cpumem 1.93   gpumem 2.85   augment 1.000 T 1000.0
# tick 39    kimg 156.0    time 2h 46m 56s   sec/tick 212.5   sec/kimg 53.12   maintenance 0.1    cpumem 1.93   gpumem 2.85   augment 1.000 T 1000.0
# tick 40    kimg 160.0    time 2h 50m 28s   sec/tick 212.5   sec/kimg 53.13   maintenance 0.0    cpumem 1.93   gpumem 2.85   augment 1.000 T 1000.0
# {"results": {"kid50k_full": 0.21209605038166046}, "metric": "kid50k_full", "total_time": 392.1991741657257, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1778654608.6104524}
# tick 41    kimg 164.0    time 3h 00m 52s   sec/tick 212.4   sec/kimg 53.10   maintenance 410.8  cpumem 1.88   gpumem 2.85   augment 1.000 T 1000.0
# tick 42    kimg 168.0    time 3h 04m 24s   sec/tick 212.6   sec/kimg 53.14   maintenance 0.1    cpumem 1.77   gpumem 2.85   augment 1.000 T 1000.0
# tick 43    kimg 172.0    time 3h 07m 57s   sec/tick 212.5   sec/kimg 53.13   maintenance 0.0    cpumem 1.77   gpumem 2.85   augment 1.000 T 1000.0
# tick 44    kimg 176.0    time 3h 11m 29s   sec/tick 212.4   sec/kimg 53.10   maintenance 0.1    cpumem 1.77   gpumem 2.85   augment 1.000 T 1000.0
# tick 45    kimg 180.0    time 3h 15m 02s   sec/tick 212.4   sec/kimg 53.10   maintenance 0.1    cpumem 1.77   gpumem 2.85   augment 1.000 T 1000.0
# tick 46    kimg 184.0    time 3h 18m 34s   sec/tick 212.3   sec/kimg 53.07   maintenance 0.0    cpumem 1.77   gpumem 2.85   augment 1.000 T 1000.0
# tick 47    kimg 188.0    time 3h 22m 07s   sec/tick 212.6   sec/kimg 53.14   maintenance 0.1    cpumem 1.77   gpumem 2.85   augment 1.000 T 1000.0
# tick 48    kimg 192.0    time 3h 25m 39s   sec/tick 212.2   sec/kimg 53.04   maintenance 0.0    cpumem 1.77   gpumem 2.85   augment 1.000 T 1000.0
# tick 49    kimg 196.0    time 3h 29m 12s   sec/tick 212.6   sec/kimg 53.14   maintenance 0.1    cpumem 1.77   gpumem 2.85   augment 1.000 T 1000.0
# tick 50    kimg 200.0    time 3h 32m 43s   sec/tick 211.9   sec/kimg 53.08   maintenance 0.1    cpumem 1.77   gpumem 2.85   augment 1.000 T 1000.0
# {"results": {"kid50k_full": 0.25472262501716614}, "metric": "kid50k_full", "total_time": 391.3580400943756, "total_time_str": "6m 31s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1778657136.6514723}
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [
#     "kid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:\\Users\\FYP2610\\Downloads\\FYP2\\results\\40_train_diffusion_gan_make_images_dataset2\\fold_5\\fold_5_minority_256.zip",
#     "use_labels": false,
#     "max_size": 240,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Training for 200 kimg...
# tick 0     kimg 0.0      time 1m 30s       sec/tick 40.9    sec/kimg 5117.94 maintenance 49.4   cpumem 2.79   gpumem 4.94   augment 0.000 T 10.0
# {"results": {"kid50k_full": 0.4843830466270447}, "metric": "kid50k_full", "total_time": 405.93762016296387, "total_time_str": "6m 46s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1778657653.0237033}
# tick 1     kimg 4.0      time 12m 03s      sec/tick 211.3   sec/kimg 52.82   maintenance 421.4  cpumem 2.91   gpumem 5.39   augment 0.028 T 38.0
# tick 2     kimg 8.0      time 15m 34s      sec/tick 210.7   sec/kimg 52.69   maintenance 0.0    cpumem 2.91   gpumem 2.85   augment 0.062 T 71.0
# tick 3     kimg 12.0     time 19m 05s      sec/tick 210.9   sec/kimg 52.72   maintenance 0.0    cpumem 2.91   gpumem 2.85   augment 0.102 T 111.0
# tick 4     kimg 16.0     time 22m 36s      sec/tick 211.0   sec/kimg 52.74   maintenance 0.0    cpumem 2.91   gpumem 2.85   augment 0.139 T 147.0
# tick 5     kimg 20.0     time 26m 06s      sec/tick 210.5   sec/kimg 52.64   maintenance 0.1    cpumem 2.91   gpumem 2.85   augment 0.172 T 181.0
# tick 6     kimg 24.0     time 29m 37s      sec/tick 211.0   sec/kimg 52.74   maintenance 0.0    cpumem 2.82   gpumem 2.85   augment 0.211 T 219.0
# tick 7     kimg 28.0     time 33m 08s      sec/tick 210.7   sec/kimg 52.67   maintenance 0.0    cpumem 2.40   gpumem 2.85   augment 0.251 T 258.0
# tick 8     kimg 32.0     time 36m 39s      sec/tick 211.0   sec/kimg 52.76   maintenance 0.0    cpumem 2.39   gpumem 2.85   augment 0.272 T 279.0
# tick 9     kimg 36.0     time 40m 10s      sec/tick 211.2   sec/kimg 52.80   maintenance 0.1    cpumem 1.70   gpumem 2.85   augment 0.302 T 309.0
# tick 10    kimg 40.0     time 43m 42s      sec/tick 211.0   sec/kimg 52.76   maintenance 0.0    cpumem 1.70   gpumem 2.85   augment 0.332 T 339.0
# {"results": {"kid50k_full": 0.287121444940567}, "metric": "kid50k_full", "total_time": 392.29221415519714, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1778660170.5799122}
# tick 11    kimg 44.0     time 54m 01s      sec/tick 211.3   sec/kimg 52.84   maintenance 407.8  cpumem 2.01   gpumem 2.85   augment 0.363 T 370.0
# tick 12    kimg 48.0     time 57m 33s      sec/tick 212.6   sec/kimg 53.14   maintenance 0.0    cpumem 2.01   gpumem 2.85   augment 0.387 T 393.0
# tick 13    kimg 52.0     time 1h 01m 04s   sec/tick 211.1   sec/kimg 52.77   maintenance 0.1    cpumem 2.01   gpumem 2.85   augment 0.393 T 399.0
# tick 14    kimg 56.0     time 1h 04m 35s   sec/tick 210.9   sec/kimg 52.74   maintenance 0.0    cpumem 1.83   gpumem 2.85   augment 0.396 T 402.0
# tick 15    kimg 60.0     time 1h 08m 06s   sec/tick 210.6   sec/kimg 52.66   maintenance 0.0    cpumem 1.83   gpumem 2.85   augment 0.399 T 405.0
# tick 16    kimg 64.0     time 1h 11m 38s   sec/tick 211.3   sec/kimg 52.82   maintenance 0.0    cpumem 1.83   gpumem 2.85   augment 0.402 T 408.0
# tick 17    kimg 68.0     time 1h 15m 08s   sec/tick 210.8   sec/kimg 52.70   maintenance 0.1    cpumem 1.83   gpumem 2.85   augment 0.406 T 412.0
# tick 18    kimg 72.0     time 1h 18m 39s   sec/tick 210.8   sec/kimg 52.69   maintenance 0.0    cpumem 1.83   gpumem 2.85   augment 0.419 T 425.0
# tick 19    kimg 76.0     time 1h 22m 10s   sec/tick 210.8   sec/kimg 52.70   maintenance 0.0    cpumem 1.83   gpumem 2.85   augment 0.441 T 447.0
# tick 20    kimg 80.0     time 1h 25m 41s   sec/tick 211.2   sec/kimg 52.81   maintenance 0.0    cpumem 1.83   gpumem 2.85   augment 0.471 T 476.0
# {"results": {"kid50k_full": 0.23393726348876953}, "metric": "kid50k_full", "total_time": 392.743447303772, "total_time_str": "6m 33s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1778662688.007666}
# tick 21    kimg 84.0     time 1h 35m 58s   sec/tick 211.5   sec/kimg 52.88   maintenance 405.5  cpumem 1.89   gpumem 2.85   augment 0.495 T 500.0
# tick 22    kimg 88.0     time 1h 39m 30s   sec/tick 211.7   sec/kimg 52.92   maintenance 0.0    cpumem 1.81   gpumem 2.85   augment 0.525 T 530.0
# tick 23    kimg 92.0     time 1h 43m 02s   sec/tick 212.3   sec/kimg 53.07   maintenance 0.0    cpumem 1.81   gpumem 2.85   augment 0.556 T 561.0
# tick 24    kimg 96.0     time 1h 46m 34s   sec/tick 211.6   sec/kimg 52.91   maintenance 0.0    cpumem 1.79   gpumem 2.85   augment 0.587 T 591.0
# tick 25    kimg 100.0    time 1h 50m 05s   sec/tick 211.4   sec/kimg 52.84   maintenance 0.1    cpumem 1.79   gpumem 2.85   augment 0.617 T 621.0
# tick 26    kimg 104.0    time 1h 53m 37s   sec/tick 211.9   sec/kimg 52.98   maintenance 0.0    cpumem 1.76   gpumem 2.85   augment 0.651 T 654.0
# tick 27    kimg 108.0    time 1h 57m 09s   sec/tick 211.6   sec/kimg 52.90   maintenance 0.0    cpumem 1.76   gpumem 2.85   augment 0.685 T 688.0
# tick 28    kimg 112.0    time 2h 00m 41s   sec/tick 211.6   sec/kimg 52.91   maintenance 0.0    cpumem 1.76   gpumem 2.85   augment 0.723 T 725.0
# tick 29    kimg 116.0    time 2h 04m 12s   sec/tick 211.7   sec/kimg 52.91   maintenance 0.1    cpumem 1.76   gpumem 2.85   augment 0.759 T 761.0
# tick 30    kimg 120.0    time 2h 07m 44s   sec/tick 211.4   sec/kimg 52.84   maintenance 0.0    cpumem 1.76   gpumem 2.85   augment 0.793 T 795.0
# {"results": {"kid50k_full": 0.20985959470272064}, "metric": "kid50k_full", "total_time": 392.02293825149536, "total_time_str": "6m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1778665214.2378862}
# tick 31    kimg 124.0    time 2h 18m 04s   sec/tick 211.2   sec/kimg 52.81   maintenance 409.2  cpumem 1.82   gpumem 2.85   augment 0.828 T 830.0
# tick 32    kimg 128.0    time 2h 21m 35s   sec/tick 210.7   sec/kimg 52.67   maintenance 0.0    cpumem 1.73   gpumem 2.85   augment 0.867 T 869.0
# tick 33    kimg 132.0    time 2h 25m 06s   sec/tick 210.9   sec/kimg 52.74   maintenance 0.1    cpumem 1.70   gpumem 2.85   augment 0.901 T 902.0
# tick 34    kimg 136.0    time 2h 28m 37s   sec/tick 210.9   sec/kimg 52.71   maintenance 0.0    cpumem 1.70   gpumem 2.85   augment 0.938 T 939.0
# tick 35    kimg 140.0    time 2h 32m 07s   sec/tick 210.3   sec/kimg 52.57   maintenance 0.0    cpumem 1.68   gpumem 2.85   augment 0.976 T 976.0
# tick 36    kimg 144.0    time 2h 35m 39s   sec/tick 211.2   sec/kimg 52.81   maintenance 0.1    cpumem 1.68   gpumem 2.85   augment 1.000 T 1000.0
# tick 37    kimg 148.0    time 2h 39m 10s   sec/tick 210.9   sec/kimg 52.74   maintenance 0.1    cpumem 1.68   gpumem 2.85   augment 1.000 T 1000.0
# tick 38    kimg 152.0    time 2h 42m 41s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.0    cpumem 1.68   gpumem 2.85   augment 1.000 T 1000.0
# tick 39    kimg 156.0    time 2h 46m 12s   sec/tick 211.4   sec/kimg 52.86   maintenance 0.1    cpumem 1.68   gpumem 2.85   augment 1.000 T 1000.0
# tick 40    kimg 160.0    time 2h 49m 43s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.1    cpumem 1.68   gpumem 2.85   augment 1.000 T 1000.0
# {"results": {"kid50k_full": 0.24387402832508087}, "metric": "kid50k_full", "total_time": 392.7253432273865, "total_time_str": "6m 33s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1778667737.3564024}
# tick 41    kimg 164.0    time 3h 00m 07s   sec/tick 211.2   sec/kimg 52.79   maintenance 413.1  cpumem 1.78   gpumem 2.85   augment 1.000 T 1000.0
# tick 42    kimg 168.0    time 3h 03m 38s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.0    cpumem 1.67   gpumem 2.85   augment 1.000 T 1000.0
# tick 43    kimg 172.0    time 3h 07m 09s   sec/tick 211.2   sec/kimg 52.79   maintenance 0.1    cpumem 1.67   gpumem 2.85   augment 1.000 T 1000.0
# tick 44    kimg 176.0    time 3h 10m 40s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.0    cpumem 1.67   gpumem 2.85   augment 1.000 T 1000.0
# tick 45    kimg 180.0    time 3h 14m 11s   sec/tick 210.8   sec/kimg 52.70   maintenance 0.1    cpumem 1.67   gpumem 2.85   augment 1.000 T 1000.0
# tick 46    kimg 184.0    time 3h 17m 43s   sec/tick 211.1   sec/kimg 52.78   maintenance 0.0    cpumem 1.67   gpumem 2.85   augment 1.000 T 1000.0
# tick 47    kimg 188.0    time 3h 21m 13s   sec/tick 210.8   sec/kimg 52.70   maintenance 0.0    cpumem 1.67   gpumem 2.85   augment 1.000 T 1000.0
# tick 48    kimg 192.0    time 3h 24m 44s   sec/tick 210.6   sec/kimg 52.65   maintenance 0.0    cpumem 1.67   gpumem 2.85   augment 1.000 T 1000.0
# tick 49    kimg 196.0    time 3h 28m 15s   sec/tick 210.9   sec/kimg 52.73   maintenance 0.1    cpumem 1.67   gpumem 2.85   augment 1.000 T 1000.0
# tick 50    kimg 200.0    time 3h 31m 45s   sec/tick 210.1   sec/kimg 52.63   maintenance 0.0    cpumem 1.67   gpumem 2.85   augment 1.000 T 1000.0
# {"results": {"kid50k_full": 0.20076781511306763}, "metric": "kid50k_full", "total_time": 392.8311734199524, "total_time_str": "6m 33s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1778670252.5380623}
#    fold_id                                            run_dir  \
# 0        1  checkpoints/40_train_diffusion_gan_make_images...
# 1        2  checkpoints/40_train_diffusion_gan_make_images...
# 2        3  checkpoints/40_train_diffusion_gan_make_images...
# 3        4  checkpoints/40_train_diffusion_gan_make_images...
# 4        5  checkpoints/40_train_diffusion_gan_make_images...
#
#                                 latest_snapshot_path  train_duration_seconds
# 0  checkpoints/40_train_diffusion_gan_make_images...                13069.47
# 1  checkpoints/40_train_diffusion_gan_make_images...                13094.45
# 2  checkpoints/40_train_diffusion_gan_make_images...                13102.58
# 3  checkpoints/40_train_diffusion_gan_make_images...                13172.05
# 4  checkpoints/40_train_diffusion_gan_make_images...                13116.05

# %%
# We read the online KID results from training and select the lowest-KID sparse snapshot per fold.
kid_snapshot_rows = []
kid_rows = []
training_lookup = {int(row["fold_id"]): row for row in training_rows}

def parse_snapshot_kimg(snapshot_path: Path) -> int:
    return int(snapshot_path.stem.replace("network-snapshot-", ""))

def read_kid_values_by_snapshot(run_dir: Path):
    metric_file = run_dir / f"metric-{KID_METRIC_NAME}.jsonl"
    if not metric_file.exists():
        raise FileNotFoundError(f"Missing metric log: {metric_file}")

    kid_values = {}
    lines = [line for line in metric_file.read_text(encoding="utf-8").splitlines() if line.strip()]
    for line in lines:
        record = json.loads(line)
        if "results" not in record or "snapshot_pkl" not in record:
            continue
        kid_value = record["results"].get(KID_METRIC_NAME)
        if kid_value is None:
            continue
        kid_values[record["snapshot_pkl"]] = kid_value
    return kid_values

for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    run_dir = REPO_ROOT / training_lookup[fold_id]["run_dir"]
    candidate_snapshot_kimg = set(SNAPSHOT_SELECTION_KIMG)
    snapshot_paths = [
        path for path in sorted(run_dir.glob("network-snapshot-*.pkl"))
        if parse_snapshot_kimg(path) in candidate_snapshot_kimg
    ]
    if not snapshot_paths:
        raise FileNotFoundError(
            f"No snapshots from {SNAPSHOT_SELECTION_KIMG} kimg were found for fold {fold_id}"
        )
    kid_values = read_kid_values_by_snapshot(run_dir)

    fold_snapshot_rows = []
    for snapshot_path in snapshot_paths:
        kid_value = kid_values.get(snapshot_path.name)
        if kid_value is None:
            raise ValueError(f"No online KID value was found for fold {fold_id} at {snapshot_path.name}")

        fold_snapshot_rows.append({
            "fold_id": fold_id,
            "snapshot_path": as_repo_relative(REPO_ROOT, snapshot_path),
            "snapshot_kimg": parse_snapshot_kimg(snapshot_path),
            "kid50k_full": kid_value,
        })

    available_kimg = sorted(row["snapshot_kimg"] for row in fold_snapshot_rows)
    if available_kimg != SNAPSHOT_SELECTION_KIMG:
        raise RuntimeError(f"Fold {fold_id} Diffusion-GAN snapshots are {available_kimg}, expected {SNAPSHOT_SELECTION_KIMG}.")

    kid_snapshot_rows.extend(fold_snapshot_rows)
    best_row = sorted(fold_snapshot_rows, key=lambda row: (row["kid50k_full"], row["snapshot_kimg"]))[0]
    kid_rows.append(best_row)

write_csv_rows(NOTEBOOK_RESULTS_DIR / "kid_snapshot_results.csv", kid_snapshot_rows, list(kid_snapshot_rows[0].keys()))
write_csv_rows(NOTEBOOK_RESULTS_DIR / "kid_results.csv", kid_rows, list(kid_rows[0].keys()))
kid_snapshot_df = pd.DataFrame(kid_snapshot_rows)
kid_df = pd.DataFrame(kid_rows)
display(kid_snapshot_df)
display(kid_df)

# This figure shows how KID moved across the fixed sparse snapshots inside each fold.
fig, axis = plt.subplots(figsize=(9, 5))
for fold_id in sorted(kid_snapshot_df["fold_id"].unique()):
    current = kid_snapshot_df[kid_snapshot_df["fold_id"] == fold_id].sort_values("snapshot_kimg")
    axis.plot(current["snapshot_kimg"], current["kid50k_full"], marker="o", label=f"fold {fold_id}")
axis.set_xlabel("Snapshot kimg")
axis.set_ylabel("KID (lower is better)")
axis.set_title("Diffusion-GAN KID progress by fold")
axis.legend()
fig.tight_layout()
fig.savefig(NOTEBOOK_RESULTS_DIR / "kid_progress_by_fold.png", dpi=200)
plt.show()
# Out:
#     fold_id                                      snapshot_path  snapshot_kimg  \
# 0         1  checkpoints/40_train_diffusion_gan_make_images...             40
# 1         1  checkpoints/40_train_diffusion_gan_make_images...             80
# 2         1  checkpoints/40_train_diffusion_gan_make_images...            120
# 3         1  checkpoints/40_train_diffusion_gan_make_images...            160
# 4         1  checkpoints/40_train_diffusion_gan_make_images...            200
# 5         2  checkpoints/40_train_diffusion_gan_make_images...             40
# 6         2  checkpoints/40_train_diffusion_gan_make_images...             80
# 7         2  checkpoints/40_train_diffusion_gan_make_images...            120
# 8         2  checkpoints/40_train_diffusion_gan_make_images...            160
# 9         2  checkpoints/40_train_diffusion_gan_make_images...            200
# 10        3  checkpoints/40_train_diffusion_gan_make_images...             40
# 11        3  checkpoints/40_train_diffusion_gan_make_images...             80
# 12        3  checkpoints/40_train_diffusion_gan_make_images...            120
# 13        3  checkpoints/40_train_diffusion_gan_make_images...            160
# 14        3  checkpoints/40_train_diffusion_gan_make_images...            200
# 15        4  checkpoints/40_train_diffusion_gan_make_images...             40
# 16        4  checkpoints/40_train_diffusion_gan_make_images...             80
# 17        4  checkpoints/40_train_diffusion_gan_make_images...            120
# 18        4  checkpoints/40_train_diffusion_gan_make_images...            160
# 19        4  checkpoints/40_train_diffusion_gan_make_images...            200
# 20        5  checkpoints/40_train_diffusion_gan_make_images...             40
# 21        5  checkpoints/40_train_diffusion_gan_make_images...             80
# 22        5  checkpoints/40_train_diffusion_gan_make_images...            120
# 23        5  checkpoints/40_train_diffusion_gan_make_images...            160
# 24        5  checkpoints/40_train_diffusion_gan_make_images...            200
#
#     kid50k_full
# 0      0.904075
# 1      0.317818
# 2      0.212808
# 3      0.234753
# 4      0.123430
# 5      0.704718
# 6      0.334018
# 7      0.227531
# 8      0.135774
# 9      0.166818
# 10     0.551465
# 11     0.322340
# 12     0.289339
# 13     0.212943
# 14     0.250877
# 15     0.700567
# 16     0.339770
# 17     0.251187
# 18     0.212096
# 19     0.254723
# 20     0.287121
# 21     0.233937
# 22     0.209860
# 23     0.243874
# 24     0.200768
#    fold_id                                      snapshot_path  snapshot_kimg  \
# 0        1  checkpoints/40_train_diffusion_gan_make_images...            200
# 1        2  checkpoints/40_train_diffusion_gan_make_images...            160
# 2        3  checkpoints/40_train_diffusion_gan_make_images...            160
# 3        4  checkpoints/40_train_diffusion_gan_make_images...            160
# 4        5  checkpoints/40_train_diffusion_gan_make_images...            200
#
#    kid50k_full
# 0     0.123430
# 1     0.135774
# 2     0.212943
# 3     0.212096
# 4     0.200768

# %%
# We generate exactly the number of synthetic minority images needed to balance each training fold.
kid_lookup = {int(row["fold_id"]): row for row in kid_rows}
generated_rows_256 = []
generation_report_rows = []

for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    snapshot_path = REPO_ROOT / kid_lookup[fold_id]["snapshot_path"]
    generated_256_dir = GAN_IMAGES_256_DIR / f"fold_{fold_id}"
    safe_prepare_output_dir(generated_256_dir)

    needed_count = int(fold_plan["needed_gan_count_224"])
    start_seed = GENERATE_START_SEED + (fold_id * 10000)
    end_seed = start_seed + needed_count - 1
    seed_text = f"{start_seed}-{end_seed}"
    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    generate_log_path = fold_result_dir / "generate.log"

    report = run_command(
        build_diffusion_gan_command(
            "generate.py",
            f"--network={snapshot_path}",
            f"--outdir={generated_256_dir}",
            f"--seeds={seed_text}",
        ),
        DIFFUSION_GAN_DIR,
        live_log_path=generate_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=DIFFUSION_GAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "generate_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"Diffusion-GAN generation failed for fold {fold_id}")

    generated_files = sorted(generated_256_dir.glob("seed*.png"))
    if len(generated_files) != needed_count:
        raise AssertionError(
            f"Fold {fold_id} should have {needed_count} generated 256 images, but found {len(generated_files)}."
        )

    generation_report_rows.append({
        "fold_id": fold_id,
        "selected_snapshot_kimg": int(kid_lookup[fold_id]["snapshot_kimg"]),
        "selected_kid50k_full": float(kid_lookup[fold_id]["kid50k_full"]),
        "needed_gan_count_224": needed_count,
        "generated_count_256": len(generated_files),
        "generate_duration_seconds": report["duration_seconds"],
    })

    test_fold_ids = [value for value in FOLDS_TO_RUN if value != fold_id]
    test_fold_text = ",".join(str(value) for value in test_fold_ids)
    for generated_file in generated_files:
        seed_value = int(generated_file.stem.replace("seed", ""))
        generated_rows_256.append({
            "dataset_name": DATASET_NAME,
            "gan_image_id": f"diffusion_gan_dataset2_fold{fold_id}_seed{seed_value}_256",
            "fold_id": fold_id,
            "round_id": fold_id,
            "train_fold_id": fold_id,
            "test_fold_ids": test_fold_text,
            "binary_label": 0,
            "binary_group": "cocci",
            "seed": seed_value,
            "image_size": GAN_PATCH_SIZE,
            "file_path": as_repo_relative(REPO_ROOT, generated_file),
            "snapshot_path": as_repo_relative(REPO_ROOT, snapshot_path),
            "source_type": "diffusion_gan_generated",
        })

write_csv_rows(MANIFESTS_DIR / "dataset2_diffusion_gan_generated_manifest_256.csv", generated_rows_256, list(generated_rows_256[0].keys()), allow_existing=ALLOW_OVERWRITE_DIFFUSION_GAN_OUTPUTS)
write_csv_rows(NOTEBOOK_RESULTS_DIR / "generation_report.csv", generation_report_rows, list(generation_report_rows[0].keys()))
display(pd.DataFrame(generation_report_rows))
display(pd.DataFrame(generated_rows_256[:10]))
# Out:
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\40_train_diffusion_gan_make_images_dataset2\fold_1\00000-fold_1_minority_256-mirror-auto1-batch8-target0.6-ada_kimg100-ts_dist-priority-image_augno-noise_sd0.05-dg_d2_f1\network-snapshot-000200.pkl"...
# Generating image for seed 20000 (0/110) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 20001 (1/110) ...
# Generating image for seed 20002 (2/110) ...
# Generating image for seed 20003 (3/110) ...
# Generating image for seed 20004 (4/110) ...
# Generating image for seed 20005 (5/110) ...
# Generating image for seed 20006 (6/110) ...
# Generating image for seed 20007 (7/110) ...
# Generating image for seed 20008 (8/110) ...
# Generating image for seed 20009 (9/110) ...
# Generating image for seed 20010 (10/110) ...
# Generating image for seed 20011 (11/110) ...
# Generating image for seed 20012 (12/110) ...
# Generating image for seed 20013 (13/110) ...
# Generating image for seed 20014 (14/110) ...
# Generating image for seed 20015 (15/110) ...
# Generating image for seed 20016 (16/110) ...
# Generating image for seed 20017 (17/110) ...
# Generating image for seed 20018 (18/110) ...
# Generating image for seed 20019 (19/110) ...
# Generating image for seed 20020 (20/110) ...
# Generating image for seed 20021 (21/110) ...
# Generating image for seed 20022 (22/110) ...
# Generating image for seed 20023 (23/110) ...
# Generating image for seed 20024 (24/110) ...
# Generating image for seed 20025 (25/110) ...
# Generating image for seed 20026 (26/110) ...
# Generating image for seed 20027 (27/110) ...
# Generating image for seed 20028 (28/110) ...
# Generating image for seed 20029 (29/110) ...
# Generating image for seed 20030 (30/110) ...
# Generating image for seed 20031 (31/110) ...
# Generating image for seed 20032 (32/110) ...
# Generating image for seed 20033 (33/110) ...
# Generating image for seed 20034 (34/110) ...
# Generating image for seed 20035 (35/110) ...
# Generating image for seed 20036 (36/110) ...
# Generating image for seed 20037 (37/110) ...
# Generating image for seed 20038 (38/110) ...
# Generating image for seed 20039 (39/110) ...
# Generating image for seed 20040 (40/110) ...
# Generating image for seed 20041 (41/110) ...
# Generating image for seed 20042 (42/110) ...
# Generating image for seed 20043 (43/110) ...
# Generating image for seed 20044 (44/110) ...
# Generating image for seed 20045 (45/110) ...
# Generating image for seed 20046 (46/110) ...
# Generating image for seed 20047 (47/110) ...
# Generating image for seed 20048 (48/110) ...
# Generating image for seed 20049 (49/110) ...
# Generating image for seed 20050 (50/110) ...
# Generating image for seed 20051 (51/110) ...
# Generating image for seed 20052 (52/110) ...
# Generating image for seed 20053 (53/110) ...
# Generating image for seed 20054 (54/110) ...
# Generating image for seed 20055 (55/110) ...
# Generating image for seed 20056 (56/110) ...
# Generating image for seed 20057 (57/110) ...
# Generating image for seed 20058 (58/110) ...
# Generating image for seed 20059 (59/110) ...
# Generating image for seed 20060 (60/110) ...
# Generating image for seed 20061 (61/110) ...
# Generating image for seed 20062 (62/110) ...
# Generating image for seed 20063 (63/110) ...
# Generating image for seed 20064 (64/110) ...
# Generating image for seed 20065 (65/110) ...
# Generating image for seed 20066 (66/110) ...
# Generating image for seed 20067 (67/110) ...
# Generating image for seed 20068 (68/110) ...
# Generating image for seed 20069 (69/110) ...
# Generating image for seed 20070 (70/110) ...
# Generating image for seed 20071 (71/110) ...
# Generating image for seed 20072 (72/110) ...
# Generating image for seed 20073 (73/110) ...
# Generating image for seed 20074 (74/110) ...
# Generating image for seed 20075 (75/110) ...
# Generating image for seed 20076 (76/110) ...
# Generating image for seed 20077 (77/110) ...
# Generating image for seed 20078 (78/110) ...
# Generating image for seed 20079 (79/110) ...
# Generating image for seed 20080 (80/110) ...
# Generating image for seed 20081 (81/110) ...
# Generating image for seed 20082 (82/110) ...
# Generating image for seed 20083 (83/110) ...
# Generating image for seed 20084 (84/110) ...
# Generating image for seed 20085 (85/110) ...
# Generating image for seed 20086 (86/110) ...
# Generating image for seed 20087 (87/110) ...
# Generating image for seed 20088 (88/110) ...
# Generating image for seed 20089 (89/110) ...
# Generating image for seed 20090 (90/110) ...
# Generating image for seed 20091 (91/110) ...
# Generating image for seed 20092 (92/110) ...
# Generating image for seed 20093 (93/110) ...
# Generating image for seed 20094 (94/110) ...
# Generating image for seed 20095 (95/110) ...
# Generating image for seed 20096 (96/110) ...
# Generating image for seed 20097 (97/110) ...
# Generating image for seed 20098 (98/110) ...
# Generating image for seed 20099 (99/110) ...
# Generating image for seed 20100 (100/110) ...
# Generating image for seed 20101 (101/110) ...
# Generating image for seed 20102 (102/110) ...
# Generating image for seed 20103 (103/110) ...
# Generating image for seed 20104 (104/110) ...
# Generating image for seed 20105 (105/110) ...
# Generating image for seed 20106 (106/110) ...
# Generating image for seed 20107 (107/110) ...
# Generating image for seed 20108 (108/110) ...
# Generating image for seed 20109 (109/110) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\40_train_diffusion_gan_make_images_dataset2\fold_2\00000-fold_2_minority_256-mirror-auto1-batch8-target0.6-ada_kimg100-ts_dist-priority-image_augno-noise_sd0.05-dg_d2_f2\network-snapshot-000160.pkl"...
# Generating image for seed 30000 (0/149) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 30001 (1/149) ...
# Generating image for seed 30002 (2/149) ...
# Generating image for seed 30003 (3/149) ...
# Generating image for seed 30004 (4/149) ...
# Generating image for seed 30005 (5/149) ...
# Generating image for seed 30006 (6/149) ...
# Generating image for seed 30007 (7/149) ...
# Generating image for seed 30008 (8/149) ...
# Generating image for seed 30009 (9/149) ...
# Generating image for seed 30010 (10/149) ...
# Generating image for seed 30011 (11/149) ...
# Generating image for seed 30012 (12/149) ...
# Generating image for seed 30013 (13/149) ...
# Generating image for seed 30014 (14/149) ...
# Generating image for seed 30015 (15/149) ...
# Generating image for seed 30016 (16/149) ...
# Generating image for seed 30017 (17/149) ...
# Generating image for seed 30018 (18/149) ...
# Generating image for seed 30019 (19/149) ...
# Generating image for seed 30020 (20/149) ...
# Generating image for seed 30021 (21/149) ...
# Generating image for seed 30022 (22/149) ...
# Generating image for seed 30023 (23/149) ...
# Generating image for seed 30024 (24/149) ...
# Generating image for seed 30025 (25/149) ...
# Generating image for seed 30026 (26/149) ...
# Generating image for seed 30027 (27/149) ...
# Generating image for seed 30028 (28/149) ...
# Generating image for seed 30029 (29/149) ...
# Generating image for seed 30030 (30/149) ...
# Generating image for seed 30031 (31/149) ...
# Generating image for seed 30032 (32/149) ...
# Generating image for seed 30033 (33/149) ...
# Generating image for seed 30034 (34/149) ...
# Generating image for seed 30035 (35/149) ...
# Generating image for seed 30036 (36/149) ...
# Generating image for seed 30037 (37/149) ...
# Generating image for seed 30038 (38/149) ...
# Generating image for seed 30039 (39/149) ...
# Generating image for seed 30040 (40/149) ...
# Generating image for seed 30041 (41/149) ...
# Generating image for seed 30042 (42/149) ...
# Generating image for seed 30043 (43/149) ...
# Generating image for seed 30044 (44/149) ...
# Generating image for seed 30045 (45/149) ...
# Generating image for seed 30046 (46/149) ...
# Generating image for seed 30047 (47/149) ...
# Generating image for seed 30048 (48/149) ...
# Generating image for seed 30049 (49/149) ...
# Generating image for seed 30050 (50/149) ...
# Generating image for seed 30051 (51/149) ...
# Generating image for seed 30052 (52/149) ...
# Generating image for seed 30053 (53/149) ...
# Generating image for seed 30054 (54/149) ...
# Generating image for seed 30055 (55/149) ...
# Generating image for seed 30056 (56/149) ...
# Generating image for seed 30057 (57/149) ...
# Generating image for seed 30058 (58/149) ...
# Generating image for seed 30059 (59/149) ...
# Generating image for seed 30060 (60/149) ...
# Generating image for seed 30061 (61/149) ...
# Generating image for seed 30062 (62/149) ...
# Generating image for seed 30063 (63/149) ...
# Generating image for seed 30064 (64/149) ...
# Generating image for seed 30065 (65/149) ...
# Generating image for seed 30066 (66/149) ...
# Generating image for seed 30067 (67/149) ...
# Generating image for seed 30068 (68/149) ...
# Generating image for seed 30069 (69/149) ...
# Generating image for seed 30070 (70/149) ...
# Generating image for seed 30071 (71/149) ...
# Generating image for seed 30072 (72/149) ...
# Generating image for seed 30073 (73/149) ...
# Generating image for seed 30074 (74/149) ...
# Generating image for seed 30075 (75/149) ...
# Generating image for seed 30076 (76/149) ...
# Generating image for seed 30077 (77/149) ...
# Generating image for seed 30078 (78/149) ...
# Generating image for seed 30079 (79/149) ...
# Generating image for seed 30080 (80/149) ...
# Generating image for seed 30081 (81/149) ...
# Generating image for seed 30082 (82/149) ...
# Generating image for seed 30083 (83/149) ...
# Generating image for seed 30084 (84/149) ...
# Generating image for seed 30085 (85/149) ...
# Generating image for seed 30086 (86/149) ...
# Generating image for seed 30087 (87/149) ...
# Generating image for seed 30088 (88/149) ...
# Generating image for seed 30089 (89/149) ...
# Generating image for seed 30090 (90/149) ...
# Generating image for seed 30091 (91/149) ...
# Generating image for seed 30092 (92/149) ...
# Generating image for seed 30093 (93/149) ...
# Generating image for seed 30094 (94/149) ...
# Generating image for seed 30095 (95/149) ...
# Generating image for seed 30096 (96/149) ...
# Generating image for seed 30097 (97/149) ...
# Generating image for seed 30098 (98/149) ...
# Generating image for seed 30099 (99/149) ...
# Generating image for seed 30100 (100/149) ...
# Generating image for seed 30101 (101/149) ...
# Generating image for seed 30102 (102/149) ...
# Generating image for seed 30103 (103/149) ...
# Generating image for seed 30104 (104/149) ...
# Generating image for seed 30105 (105/149) ...
# Generating image for seed 30106 (106/149) ...
# Generating image for seed 30107 (107/149) ...
# Generating image for seed 30108 (108/149) ...
# Generating image for seed 30109 (109/149) ...
# Generating image for seed 30110 (110/149) ...
# Generating image for seed 30111 (111/149) ...
# Generating image for seed 30112 (112/149) ...
# Generating image for seed 30113 (113/149) ...
# Generating image for seed 30114 (114/149) ...
# Generating image for seed 30115 (115/149) ...
# Generating image for seed 30116 (116/149) ...
# Generating image for seed 30117 (117/149) ...
# Generating image for seed 30118 (118/149) ...
# Generating image for seed 30119 (119/149) ...
# Generating image for seed 30120 (120/149) ...
# Generating image for seed 30121 (121/149) ...
# Generating image for seed 30122 (122/149) ...
# Generating image for seed 30123 (123/149) ...
# Generating image for seed 30124 (124/149) ...
# Generating image for seed 30125 (125/149) ...
# Generating image for seed 30126 (126/149) ...
# Generating image for seed 30127 (127/149) ...
# Generating image for seed 30128 (128/149) ...
# Generating image for seed 30129 (129/149) ...
# Generating image for seed 30130 (130/149) ...
# Generating image for seed 30131 (131/149) ...
# Generating image for seed 30132 (132/149) ...
# Generating image for seed 30133 (133/149) ...
# Generating image for seed 30134 (134/149) ...
# Generating image for seed 30135 (135/149) ...
# Generating image for seed 30136 (136/149) ...
# Generating image for seed 30137 (137/149) ...
# Generating image for seed 30138 (138/149) ...
# Generating image for seed 30139 (139/149) ...
# Generating image for seed 30140 (140/149) ...
# Generating image for seed 30141 (141/149) ...
# Generating image for seed 30142 (142/149) ...
# Generating image for seed 30143 (143/149) ...
# Generating image for seed 30144 (144/149) ...
# Generating image for seed 30145 (145/149) ...
# Generating image for seed 30146 (146/149) ...
# Generating image for seed 30147 (147/149) ...
# Generating image for seed 30148 (148/149) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\40_train_diffusion_gan_make_images_dataset2\fold_3\00000-fold_3_minority_256-mirror-auto1-batch8-target0.6-ada_kimg100-ts_dist-priority-image_augno-noise_sd0.05-dg_d2_f3\network-snapshot-000160.pkl"...
# Generating image for seed 40000 (0/90) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 40001 (1/90) ...
# Generating image for seed 40002 (2/90) ...
# Generating image for seed 40003 (3/90) ...
# Generating image for seed 40004 (4/90) ...
# Generating image for seed 40005 (5/90) ...
# Generating image for seed 40006 (6/90) ...
# Generating image for seed 40007 (7/90) ...
# Generating image for seed 40008 (8/90) ...
# Generating image for seed 40009 (9/90) ...
# Generating image for seed 40010 (10/90) ...
# Generating image for seed 40011 (11/90) ...
# Generating image for seed 40012 (12/90) ...
# Generating image for seed 40013 (13/90) ...
# Generating image for seed 40014 (14/90) ...
# Generating image for seed 40015 (15/90) ...
# Generating image for seed 40016 (16/90) ...
# Generating image for seed 40017 (17/90) ...
# Generating image for seed 40018 (18/90) ...
# Generating image for seed 40019 (19/90) ...
# Generating image for seed 40020 (20/90) ...
# Generating image for seed 40021 (21/90) ...
# Generating image for seed 40022 (22/90) ...
# Generating image for seed 40023 (23/90) ...
# Generating image for seed 40024 (24/90) ...
# Generating image for seed 40025 (25/90) ...
# Generating image for seed 40026 (26/90) ...
# Generating image for seed 40027 (27/90) ...
# Generating image for seed 40028 (28/90) ...
# Generating image for seed 40029 (29/90) ...
# Generating image for seed 40030 (30/90) ...
# Generating image for seed 40031 (31/90) ...
# Generating image for seed 40032 (32/90) ...
# Generating image for seed 40033 (33/90) ...
# Generating image for seed 40034 (34/90) ...
# Generating image for seed 40035 (35/90) ...
# Generating image for seed 40036 (36/90) ...
# Generating image for seed 40037 (37/90) ...
# Generating image for seed 40038 (38/90) ...
# Generating image for seed 40039 (39/90) ...
# Generating image for seed 40040 (40/90) ...
# Generating image for seed 40041 (41/90) ...
# Generating image for seed 40042 (42/90) ...
# Generating image for seed 40043 (43/90) ...
# Generating image for seed 40044 (44/90) ...
# Generating image for seed 40045 (45/90) ...
# Generating image for seed 40046 (46/90) ...
# Generating image for seed 40047 (47/90) ...
# Generating image for seed 40048 (48/90) ...
# Generating image for seed 40049 (49/90) ...
# Generating image for seed 40050 (50/90) ...
# Generating image for seed 40051 (51/90) ...
# Generating image for seed 40052 (52/90) ...
# Generating image for seed 40053 (53/90) ...
# Generating image for seed 40054 (54/90) ...
# Generating image for seed 40055 (55/90) ...
# Generating image for seed 40056 (56/90) ...
# Generating image for seed 40057 (57/90) ...
# Generating image for seed 40058 (58/90) ...
# Generating image for seed 40059 (59/90) ...
# Generating image for seed 40060 (60/90) ...
# Generating image for seed 40061 (61/90) ...
# Generating image for seed 40062 (62/90) ...
# Generating image for seed 40063 (63/90) ...
# Generating image for seed 40064 (64/90) ...
# Generating image for seed 40065 (65/90) ...
# Generating image for seed 40066 (66/90) ...
# Generating image for seed 40067 (67/90) ...
# Generating image for seed 40068 (68/90) ...
# Generating image for seed 40069 (69/90) ...
# Generating image for seed 40070 (70/90) ...
# Generating image for seed 40071 (71/90) ...
# Generating image for seed 40072 (72/90) ...
# Generating image for seed 40073 (73/90) ...
# Generating image for seed 40074 (74/90) ...
# Generating image for seed 40075 (75/90) ...
# Generating image for seed 40076 (76/90) ...
# Generating image for seed 40077 (77/90) ...
# Generating image for seed 40078 (78/90) ...
# Generating image for seed 40079 (79/90) ...
# Generating image for seed 40080 (80/90) ...
# Generating image for seed 40081 (81/90) ...
# Generating image for seed 40082 (82/90) ...
# Generating image for seed 40083 (83/90) ...
# Generating image for seed 40084 (84/90) ...
# Generating image for seed 40085 (85/90) ...
# Generating image for seed 40086 (86/90) ...
# Generating image for seed 40087 (87/90) ...
# Generating image for seed 40088 (88/90) ...
# Generating image for seed 40089 (89/90) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\40_train_diffusion_gan_make_images_dataset2\fold_4\00000-fold_4_minority_256-mirror-auto1-batch8-target0.6-ada_kimg100-ts_dist-priority-image_augno-noise_sd0.05-dg_d2_f4\network-snapshot-000160.pkl"...
# Generating image for seed 50000 (0/119) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 50001 (1/119) ...
# Generating image for seed 50002 (2/119) ...
# Generating image for seed 50003 (3/119) ...
# Generating image for seed 50004 (4/119) ...
# Generating image for seed 50005 (5/119) ...
# Generating image for seed 50006 (6/119) ...
# Generating image for seed 50007 (7/119) ...
# Generating image for seed 50008 (8/119) ...
# Generating image for seed 50009 (9/119) ...
# Generating image for seed 50010 (10/119) ...
# Generating image for seed 50011 (11/119) ...
# Generating image for seed 50012 (12/119) ...
# Generating image for seed 50013 (13/119) ...
# Generating image for seed 50014 (14/119) ...
# Generating image for seed 50015 (15/119) ...
# Generating image for seed 50016 (16/119) ...
# Generating image for seed 50017 (17/119) ...
# Generating image for seed 50018 (18/119) ...
# Generating image for seed 50019 (19/119) ...
# Generating image for seed 50020 (20/119) ...
# Generating image for seed 50021 (21/119) ...
# Generating image for seed 50022 (22/119) ...
# Generating image for seed 50023 (23/119) ...
# Generating image for seed 50024 (24/119) ...
# Generating image for seed 50025 (25/119) ...
# Generating image for seed 50026 (26/119) ...
# Generating image for seed 50027 (27/119) ...
# Generating image for seed 50028 (28/119) ...
# Generating image for seed 50029 (29/119) ...
# Generating image for seed 50030 (30/119) ...
# Generating image for seed 50031 (31/119) ...
# Generating image for seed 50032 (32/119) ...
# Generating image for seed 50033 (33/119) ...
# Generating image for seed 50034 (34/119) ...
# Generating image for seed 50035 (35/119) ...
# Generating image for seed 50036 (36/119) ...
# Generating image for seed 50037 (37/119) ...
# Generating image for seed 50038 (38/119) ...
# Generating image for seed 50039 (39/119) ...
# Generating image for seed 50040 (40/119) ...
# Generating image for seed 50041 (41/119) ...
# Generating image for seed 50042 (42/119) ...
# Generating image for seed 50043 (43/119) ...
# Generating image for seed 50044 (44/119) ...
# Generating image for seed 50045 (45/119) ...
# Generating image for seed 50046 (46/119) ...
# Generating image for seed 50047 (47/119) ...
# Generating image for seed 50048 (48/119) ...
# Generating image for seed 50049 (49/119) ...
# Generating image for seed 50050 (50/119) ...
# Generating image for seed 50051 (51/119) ...
# Generating image for seed 50052 (52/119) ...
# Generating image for seed 50053 (53/119) ...
# Generating image for seed 50054 (54/119) ...
# Generating image for seed 50055 (55/119) ...
# Generating image for seed 50056 (56/119) ...
# Generating image for seed 50057 (57/119) ...
# Generating image for seed 50058 (58/119) ...
# Generating image for seed 50059 (59/119) ...
# Generating image for seed 50060 (60/119) ...
# Generating image for seed 50061 (61/119) ...
# Generating image for seed 50062 (62/119) ...
# Generating image for seed 50063 (63/119) ...
# Generating image for seed 50064 (64/119) ...
# Generating image for seed 50065 (65/119) ...
# Generating image for seed 50066 (66/119) ...
# Generating image for seed 50067 (67/119) ...
# Generating image for seed 50068 (68/119) ...
# Generating image for seed 50069 (69/119) ...
# Generating image for seed 50070 (70/119) ...
# Generating image for seed 50071 (71/119) ...
# Generating image for seed 50072 (72/119) ...
# Generating image for seed 50073 (73/119) ...
# Generating image for seed 50074 (74/119) ...
# Generating image for seed 50075 (75/119) ...
# Generating image for seed 50076 (76/119) ...
# Generating image for seed 50077 (77/119) ...
# Generating image for seed 50078 (78/119) ...
# Generating image for seed 50079 (79/119) ...
# Generating image for seed 50080 (80/119) ...
# Generating image for seed 50081 (81/119) ...
# Generating image for seed 50082 (82/119) ...
# Generating image for seed 50083 (83/119) ...
# Generating image for seed 50084 (84/119) ...
# Generating image for seed 50085 (85/119) ...
# Generating image for seed 50086 (86/119) ...
# Generating image for seed 50087 (87/119) ...
# Generating image for seed 50088 (88/119) ...
# Generating image for seed 50089 (89/119) ...
# Generating image for seed 50090 (90/119) ...
# Generating image for seed 50091 (91/119) ...
# Generating image for seed 50092 (92/119) ...
# Generating image for seed 50093 (93/119) ...
# Generating image for seed 50094 (94/119) ...
# Generating image for seed 50095 (95/119) ...
# Generating image for seed 50096 (96/119) ...
# Generating image for seed 50097 (97/119) ...
# Generating image for seed 50098 (98/119) ...
# Generating image for seed 50099 (99/119) ...
# Generating image for seed 50100 (100/119) ...
# Generating image for seed 50101 (101/119) ...
# Generating image for seed 50102 (102/119) ...
# Generating image for seed 50103 (103/119) ...
# Generating image for seed 50104 (104/119) ...
# Generating image for seed 50105 (105/119) ...
# Generating image for seed 50106 (106/119) ...
# Generating image for seed 50107 (107/119) ...
# Generating image for seed 50108 (108/119) ...
# Generating image for seed 50109 (109/119) ...
# Generating image for seed 50110 (110/119) ...
# Generating image for seed 50111 (111/119) ...
# Generating image for seed 50112 (112/119) ...
# Generating image for seed 50113 (113/119) ...
# Generating image for seed 50114 (114/119) ...
# Generating image for seed 50115 (115/119) ...
# Generating image for seed 50116 (116/119) ...
# Generating image for seed 50117 (117/119) ...
# Generating image for seed 50118 (118/119) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\40_train_diffusion_gan_make_images_dataset2\fold_5\00000-fold_5_minority_256-mirror-auto1-batch8-target0.6-ada_kimg100-ts_dist-priority-image_augno-noise_sd0.05-dg_d2_f5\network-snapshot-000200.pkl"...
# Generating image for seed 60000 (0/137) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 60001 (1/137) ...
# Generating image for seed 60002 (2/137) ...
# Generating image for seed 60003 (3/137) ...
# Generating image for seed 60004 (4/137) ...
# Generating image for seed 60005 (5/137) ...
# Generating image for seed 60006 (6/137) ...
# Generating image for seed 60007 (7/137) ...
# Generating image for seed 60008 (8/137) ...
# Generating image for seed 60009 (9/137) ...
# Generating image for seed 60010 (10/137) ...
# Generating image for seed 60011 (11/137) ...
# Generating image for seed 60012 (12/137) ...
# Generating image for seed 60013 (13/137) ...
# Generating image for seed 60014 (14/137) ...
# Generating image for seed 60015 (15/137) ...
# Generating image for seed 60016 (16/137) ...
# Generating image for seed 60017 (17/137) ...
# Generating image for seed 60018 (18/137) ...
# Generating image for seed 60019 (19/137) ...
# Generating image for seed 60020 (20/137) ...
# Generating image for seed 60021 (21/137) ...
# Generating image for seed 60022 (22/137) ...
# Generating image for seed 60023 (23/137) ...
# Generating image for seed 60024 (24/137) ...
# Generating image for seed 60025 (25/137) ...
# Generating image for seed 60026 (26/137) ...
# Generating image for seed 60027 (27/137) ...
# Generating image for seed 60028 (28/137) ...
# Generating image for seed 60029 (29/137) ...
# Generating image for seed 60030 (30/137) ...
# Generating image for seed 60031 (31/137) ...
# Generating image for seed 60032 (32/137) ...
# Generating image for seed 60033 (33/137) ...
# Generating image for seed 60034 (34/137) ...
# Generating image for seed 60035 (35/137) ...
# Generating image for seed 60036 (36/137) ...
# Generating image for seed 60037 (37/137) ...
# Generating image for seed 60038 (38/137) ...
# Generating image for seed 60039 (39/137) ...
# Generating image for seed 60040 (40/137) ...
# Generating image for seed 60041 (41/137) ...
# Generating image for seed 60042 (42/137) ...
# Generating image for seed 60043 (43/137) ...
# Generating image for seed 60044 (44/137) ...
# Generating image for seed 60045 (45/137) ...
# Generating image for seed 60046 (46/137) ...
# Generating image for seed 60047 (47/137) ...
# Generating image for seed 60048 (48/137) ...
# Generating image for seed 60049 (49/137) ...
# Generating image for seed 60050 (50/137) ...
# Generating image for seed 60051 (51/137) ...
# Generating image for seed 60052 (52/137) ...
# Generating image for seed 60053 (53/137) ...
# Generating image for seed 60054 (54/137) ...
# Generating image for seed 60055 (55/137) ...
# Generating image for seed 60056 (56/137) ...
# Generating image for seed 60057 (57/137) ...
# Generating image for seed 60058 (58/137) ...
# Generating image for seed 60059 (59/137) ...
# Generating image for seed 60060 (60/137) ...
# Generating image for seed 60061 (61/137) ...
# Generating image for seed 60062 (62/137) ...
# Generating image for seed 60063 (63/137) ...
# Generating image for seed 60064 (64/137) ...
# Generating image for seed 60065 (65/137) ...
# Generating image for seed 60066 (66/137) ...
# Generating image for seed 60067 (67/137) ...
# Generating image for seed 60068 (68/137) ...
# Generating image for seed 60069 (69/137) ...
# Generating image for seed 60070 (70/137) ...
# Generating image for seed 60071 (71/137) ...
# Generating image for seed 60072 (72/137) ...
# Generating image for seed 60073 (73/137) ...
# Generating image for seed 60074 (74/137) ...
# Generating image for seed 60075 (75/137) ...
# Generating image for seed 60076 (76/137) ...
# Generating image for seed 60077 (77/137) ...
# Generating image for seed 60078 (78/137) ...
# Generating image for seed 60079 (79/137) ...
# Generating image for seed 60080 (80/137) ...
# Generating image for seed 60081 (81/137) ...
# Generating image for seed 60082 (82/137) ...
# Generating image for seed 60083 (83/137) ...
# Generating image for seed 60084 (84/137) ...
# Generating image for seed 60085 (85/137) ...
# Generating image for seed 60086 (86/137) ...
# Generating image for seed 60087 (87/137) ...
# Generating image for seed 60088 (88/137) ...
# Generating image for seed 60089 (89/137) ...
# Generating image for seed 60090 (90/137) ...
# Generating image for seed 60091 (91/137) ...
# Generating image for seed 60092 (92/137) ...
# Generating image for seed 60093 (93/137) ...
# Generating image for seed 60094 (94/137) ...
# Generating image for seed 60095 (95/137) ...
# Generating image for seed 60096 (96/137) ...
# Generating image for seed 60097 (97/137) ...
# Generating image for seed 60098 (98/137) ...
# Generating image for seed 60099 (99/137) ...
# Generating image for seed 60100 (100/137) ...
# Generating image for seed 60101 (101/137) ...
# Generating image for seed 60102 (102/137) ...
# Generating image for seed 60103 (103/137) ...
# Generating image for seed 60104 (104/137) ...
# Generating image for seed 60105 (105/137) ...
# Generating image for seed 60106 (106/137) ...
# Generating image for seed 60107 (107/137) ...
# Generating image for seed 60108 (108/137) ...
# Generating image for seed 60109 (109/137) ...
# Generating image for seed 60110 (110/137) ...
# Generating image for seed 60111 (111/137) ...
# Generating image for seed 60112 (112/137) ...
# Generating image for seed 60113 (113/137) ...
# Generating image for seed 60114 (114/137) ...
# Generating image for seed 60115 (115/137) ...
# Generating image for seed 60116 (116/137) ...
# Generating image for seed 60117 (117/137) ...
# Generating image for seed 60118 (118/137) ...
# Generating image for seed 60119 (119/137) ...
# Generating image for seed 60120 (120/137) ...
# Generating image for seed 60121 (121/137) ...
# Generating image for seed 60122 (122/137) ...
# Generating image for seed 60123 (123/137) ...
# Generating image for seed 60124 (124/137) ...
# Generating image for seed 60125 (125/137) ...
# Generating image for seed 60126 (126/137) ...
# Generating image for seed 60127 (127/137) ...
# Generating image for seed 60128 (128/137) ...
# Generating image for seed 60129 (129/137) ...
# Generating image for seed 60130 (130/137) ...
# Generating image for seed 60131 (131/137) ...
# Generating image for seed 60132 (132/137) ...
# Generating image for seed 60133 (133/137) ...
# Generating image for seed 60134 (134/137) ...
# Generating image for seed 60135 (135/137) ...
# Generating image for seed 60136 (136/137) ...
#    fold_id  selected_snapshot_kimg  selected_kid50k_full  \
# 0        1                     200              0.123430
# 1        2                     160              0.135774
# 2        3                     160              0.212943
# 3        4                     160              0.212096
# 4        5                     200              0.200768
#
#    needed_gan_count_224  generated_count_256  generate_duration_seconds
# 0                   110                  110                      16.22
# 1                   149                  149                      10.14
# 2                    90                   90                       8.03
# 3                   119                  119                      10.35
# 4                   137                  137                       9.74
#   dataset_name                                gan_image_id  fold_id  round_id  \
# 0     dataset2  diffusion_gan_dataset2_fold1_seed20000_256        1         1
# 1     dataset2  diffusion_gan_dataset2_fold1_seed20001_256        1         1
# 2     dataset2  diffusion_gan_dataset2_fold1_seed20002_256        1         1
# 3     dataset2  diffusion_gan_dataset2_fold1_seed20003_256        1         1
# 4     dataset2  diffusion_gan_dataset2_fold1_seed20004_256        1         1
# 5     dataset2  diffusion_gan_dataset2_fold1_seed20005_256        1         1
# 6     dataset2  diffusion_gan_dataset2_fold1_seed20006_256        1         1
# 7     dataset2  diffusion_gan_dataset2_fold1_seed20007_256        1         1
# 8     dataset2  diffusion_gan_dataset2_fold1_seed20008_256        1         1
# 9     dataset2  diffusion_gan_dataset2_fold1_seed20009_256        1         1
#
#    train_fold_id test_fold_ids  binary_label binary_group   seed  image_size  \
# 0              1       2,3,4,5             0        cocci  20000         256
# 1              1       2,3,4,5             0        cocci  20001         256
# 2              1       2,3,4,5             0        cocci  20002         256
# 3              1       2,3,4,5             0        cocci  20003         256
# 4              1       2,3,4,5             0        cocci  20004         256
# 5              1       2,3,4,5             0        cocci  20005         256
# 6              1       2,3,4,5             0        cocci  20006         256
# 7              1       2,3,4,5             0        cocci  20007         256
# 8              1       2,3,4,5             0        cocci  20008         256
# 9              1       2,3,4,5             0        cocci  20009         256
#
#                                            file_path  \
# 0  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 1  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 2  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 3  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 4  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 5  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 6  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 7  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 8  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 9  gan_images_256/diffusion_gan/dataset2/fold_1/s...
#
#                                        snapshot_path              source_type
# 0  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 1  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 2  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 3  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 4  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 5  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 6  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 7  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 8  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 9  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated

# %%
# We resize every generated image to the fixed 224x224 CNN input size.
generated_rows_224 = []
for row in generated_rows_256:
    fold_id = int(row["fold_id"])
    source_file = REPO_ROOT / row["file_path"]
    target_dir = GAN_IMAGES_224_DIR / f"fold_{fold_id}"
    target_dir.mkdir(parents=True, exist_ok=True)
    target_file = target_dir / source_file.name
    if target_file.exists() and not ALLOW_OVERWRITE_DIFFUSION_GAN_OUTPUTS:
        raise FileExistsError(
            f"Refusing to overwrite existing Diffusion-GAN 224 image: {target_file}. "
            "Set ALLOW_OVERWRITE_DIFFUSION_GAN_OUTPUTS=True only if you intentionally rerun this notebook."
        )

    with Image.open(source_file) as image_handle:
        image = image_handle.convert("RGB")
        resized_image = image.resize((CNN_PATCH_SIZE, CNN_PATCH_SIZE), Image.Resampling.LANCZOS)
        resized_image.save(target_file)

    generated_rows_224.append({
        "dataset_name": row["dataset_name"],
        "gan_image_id": row["gan_image_id"].replace("_256", "_224"),
        "fold_id": row["fold_id"],
        "round_id": row["round_id"],
        "train_fold_id": row["train_fold_id"],
        "test_fold_ids": row["test_fold_ids"],
        "binary_label": row["binary_label"],
        "binary_group": row["binary_group"],
        "seed": row["seed"],
        "image_size": CNN_PATCH_SIZE,
        "file_path": as_repo_relative(REPO_ROOT, target_file),
        "source_file_256": row["file_path"],
        "snapshot_path": row["snapshot_path"],
        "source_type": row["source_type"],
    })

write_csv_rows(MANIFESTS_DIR / "dataset2_diffusion_gan_generated_manifest_224.csv", generated_rows_224, list(generated_rows_224[0].keys()), allow_existing=ALLOW_OVERWRITE_DIFFUSION_GAN_OUTPUTS)

summary = {
    "notebook_tag": NOTEBOOK_TAG,
    "dataset_name": DATASET_NAME,
    "seed": SEED,
    "diffusion_gan_random_seed": DIFFUSION_GAN_RANDOM_SEED,
    "gan_patch_size": GAN_PATCH_SIZE,
    "cnn_patch_size": CNN_PATCH_SIZE,
    "gan_batch_size": GAN_BATCH_SIZE,
    "gan_workers": GAN_WORKERS,
    "gan_kimg": GAN_KIMG,
    "tick_kimg_expected": TICK_KIMG,
    "snap_ticks": SNAP_TICKS,
    "snapshot_selection_kimg": SNAPSHOT_SELECTION_KIMG,
    "gan_mirror": GAN_MIRROR,
    "diffusion_gan_cfg": DIFFUSION_GAN_CFG,
    "diffusion_gan_aug": DIFFUSION_GAN_AUG,
    "diffusion_gan_target": DIFFUSION_GAN_TARGET,
    "diffusion_gan_noise_sd": DIFFUSION_GAN_NOISE_SD,
    "diffusion_gan_ts_dist": DIFFUSION_GAN_TS_DIST,
    "diffusion_gan_ada_kimg": DIFFUSION_GAN_ADA_KIMG,
    "kid_metric_name": KID_METRIC_NAME,
    "generated_manifest_256": as_repo_relative(REPO_ROOT, MANIFESTS_DIR / "dataset2_diffusion_gan_generated_manifest_256.csv"),
    "generated_manifest_224": as_repo_relative(REPO_ROOT, MANIFESTS_DIR / "dataset2_diffusion_gan_generated_manifest_224.csv"),
    "compatibility_patch_report": as_repo_relative(REPO_ROOT, NOTEBOOK_RESULTS_DIR / "diffusion_gan_compatibility_patch_report.json"),
}
write_json(NOTEBOOK_RESULTS_DIR / "summary.json", summary)

fold_result_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    generated_count = sum(1 for row in generated_rows_224 if int(row["fold_id"]) == fold_id)
    fold_result_rows.append({
        "fold_id": fold_id,
        "needed_gan_count_224": int(fold_plan["needed_gan_count_224"]),
        "generated_count_224": generated_count,
        "selected_snapshot_kimg": int(kid_lookup[fold_id]["snapshot_kimg"]),
        "selected_kid50k_full": float(kid_lookup[fold_id]["kid50k_full"]),
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "gan_summary_by_fold.csv", fold_result_rows, list(fold_result_rows[0].keys()))
display(pd.DataFrame(fold_result_rows))
display(pd.DataFrame(generated_rows_224[:10]))

# This preview helps us audit that the resized synthetic patches look sensible.
preview_rows = generated_rows_224[:8]
if preview_rows:
    figure_columns = min(4, len(preview_rows))
    figure_rows = math.ceil(len(preview_rows) / figure_columns)
    fig, axes = plt.subplots(figure_rows, figure_columns, figsize=(4 * figure_columns, 4 * figure_rows))
    try:
        flat_axes = axes.flatten().tolist()
    except AttributeError:
        flat_axes = [axes]
    for axis, row in zip(flat_axes, preview_rows):
        image_path = REPO_ROOT / row["file_path"]
        with Image.open(image_path) as image_handle:
            axis.imshow(image_handle.convert("RGB"))
        axis.set_title(f"fold {row['fold_id']} | seed {row['seed']}", fontsize=8)
        axis.axis("off")
    for axis in flat_axes[len(preview_rows):]:
        axis.axis("off")
    fig.tight_layout()
    fig.savefig(NOTEBOOK_RESULTS_DIR / "generated_preview_224.png", dpi=200)
    plt.show()
print(f"Saved generated 224 manifest to: {MANIFESTS_DIR / 'dataset2_diffusion_gan_generated_manifest_224.csv'}")
# Out:
#    fold_id  needed_gan_count_224  generated_count_224  selected_snapshot_kimg  \
# 0        1                   110                  110                     200
# 1        2                   149                  149                     160
# 2        3                    90                   90                     160
# 3        4                   119                  119                     160
# 4        5                   137                  137                     200
#
#    selected_kid50k_full
# 0              0.123430
# 1              0.135774
# 2              0.212943
# 3              0.212096
# 4              0.200768
#   dataset_name                                gan_image_id  fold_id  round_id  \
# 0     dataset2  diffusion_gan_dataset2_fold1_seed20000_224        1         1
# 1     dataset2  diffusion_gan_dataset2_fold1_seed20001_224        1         1
# 2     dataset2  diffusion_gan_dataset2_fold1_seed20002_224        1         1
# 3     dataset2  diffusion_gan_dataset2_fold1_seed20003_224        1         1
# 4     dataset2  diffusion_gan_dataset2_fold1_seed20004_224        1         1
# 5     dataset2  diffusion_gan_dataset2_fold1_seed20005_224        1         1
# 6     dataset2  diffusion_gan_dataset2_fold1_seed20006_224        1         1
# 7     dataset2  diffusion_gan_dataset2_fold1_seed20007_224        1         1
# 8     dataset2  diffusion_gan_dataset2_fold1_seed20008_224        1         1
# 9     dataset2  diffusion_gan_dataset2_fold1_seed20009_224        1         1
#
#    train_fold_id test_fold_ids  binary_label binary_group   seed  image_size  \
# 0              1       2,3,4,5             0        cocci  20000         224
# 1              1       2,3,4,5             0        cocci  20001         224
# 2              1       2,3,4,5             0        cocci  20002         224
# 3              1       2,3,4,5             0        cocci  20003         224
# 4              1       2,3,4,5             0        cocci  20004         224
# 5              1       2,3,4,5             0        cocci  20005         224
# 6              1       2,3,4,5             0        cocci  20006         224
# 7              1       2,3,4,5             0        cocci  20007         224
# 8              1       2,3,4,5             0        cocci  20008         224
# 9              1       2,3,4,5             0        cocci  20009         224
#
#                                            file_path  \
# 0  gan_images_224/diffusion_gan/dataset2/fold_1/s...
# 1  gan_images_224/diffusion_gan/dataset2/fold_1/s...
# 2  gan_images_224/diffusion_gan/dataset2/fold_1/s...
# 3  gan_images_224/diffusion_gan/dataset2/fold_1/s...
# 4  gan_images_224/diffusion_gan/dataset2/fold_1/s...
# 5  gan_images_224/diffusion_gan/dataset2/fold_1/s...
# 6  gan_images_224/diffusion_gan/dataset2/fold_1/s...
# 7  gan_images_224/diffusion_gan/dataset2/fold_1/s...
# 8  gan_images_224/diffusion_gan/dataset2/fold_1/s...
# 9  gan_images_224/diffusion_gan/dataset2/fold_1/s...
#
#                                      source_file_256  \
# 0  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 1  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 2  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 3  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 4  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 5  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 6  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 7  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 8  gan_images_256/diffusion_gan/dataset2/fold_1/s...
# 9  gan_images_256/diffusion_gan/dataset2/fold_1/s...
#
#                                        snapshot_path              source_type
# 0  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 1  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 2  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 3  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 4  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 5  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 6  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 7  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 8  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# 9  checkpoints/40_train_diffusion_gan_make_images...  diffusion_gan_generated
# Saved generated 224 manifest to: C:\Users\FYP2610\Downloads\FYP2\manifests\dataset2_diffusion_gan_generated_manifest_224.csv
