# %% [markdown]
# # 25 Train StyleGAN3 Make Images Dataset 2
#
# This notebook trains one StyleGAN3-T model per training fold, evaluates a fixed sparse set of snapshots, selects the lowest-KID trained snapshot in each fold, and generates the exact minority top-up needed for the second-GAN comparison.

# %% [markdown]
# ## Important Notes
#
# - Open Jupyter from `x64 Native Tools Command Prompt for VS 2022`.
# - Run the notebook itself in the main `fyp2` kernel so the normal notebook packages stay available.
# - Use the `fyp2` environment on the school Windows PC for StyleGAN3 because it matches the RTX 4060 CUDA setup.
# - Put the official NVIDIA StyleGAN3 repository in `third_party/stylegan3` before running this notebook.
# - This notebook keeps the GAN native resolution at `256x256`.
# - Every generated image is resized deterministically to `224x224` before any CNN notebooks use it.
# - Existing StyleGAN2-ADA outputs are not overwritten. StyleGAN3 images and manifests are saved with separate paths and names.
# - Snapshot comparison is fixed to `[40, 80, 120, 160, 200]` kimg so every fold uses the same candidate schedule.

# %%
from pathlib import Path
import csv
import json
import math
import os
import shutil
import subprocess
import sys
import time

import matplotlib.pyplot as plt

import pandas as pd

from IPython.display import display
from PIL import Image

# This helper keeps the notebook easy to run from the repo root or from notebooks/.
def find_repo_root(start_path: Path) -> Path:
    if (start_path / "raw_data").exists():
        return start_path
    if start_path.name == "notebooks" and (start_path.parent / "raw_data").exists():
        return start_path.parent
    raise FileNotFoundError("Could not find the FYP2 repo root.")

REPO_ROOT = find_repo_root(Path.cwd())
MANIFESTS_DIR = REPO_ROOT / "manifests"
RESULTS_DIR = REPO_ROOT / "results"
CHECKPOINTS_DIR = REPO_ROOT / "checkpoints"
GAN_PATCHES_DIR = REPO_ROOT / "gan_patches_256" / "dataset2"
GAN_IMAGES_256_DIR = REPO_ROOT / "gan_images_256" / "stylegan3" / "dataset2"
GAN_IMAGES_224_DIR = REPO_ROOT / "gan_images_224" / "stylegan3" / "dataset2"
THIRD_PARTY_DIR = REPO_ROOT / "third_party"
STYLEGAN_DIR = THIRD_PARTY_DIR / "stylegan3"
NOTEBOOK_TAG = "25_train_stylegan3_make_images_dataset2"
NOTEBOOK_RESULTS_DIR = RESULTS_DIR / NOTEBOOK_TAG
NOTEBOOK_CHECKPOINTS_DIR = CHECKPOINTS_DIR / NOTEBOOK_TAG
NOTEBOOK_RESULTS_DIR.mkdir(parents=True, exist_ok=True)
NOTEBOOK_CHECKPOINTS_DIR.mkdir(parents=True, exist_ok=True)
GAN_IMAGES_256_DIR.mkdir(parents=True, exist_ok=True)
GAN_IMAGES_224_DIR.mkdir(parents=True, exist_ok=True)

if not STYLEGAN_DIR.exists():
    raise FileNotFoundError(
        f"Missing StyleGAN3 folder: {STYLEGAN_DIR}. "
        "Clone the official NVIDIA StyleGAN3 repo into third_party/stylegan3 before running this notebook."
    )

SEED = 2026
STYLEGAN_RANDOM_SEED = 0
FOLDS_TO_RUN = [1, 2, 3, 4, 5]
GAN_PATCH_SIZE = 256
CNN_PATCH_SIZE = 224
GAN_BATCH_SIZE = 8
GAN_WORKERS = 3
GAN_KIMG = 200
# StyleGAN3 uses 4 kimg per tick, so snap=10 gives snapshots at 40, 80, 120, 160, and 200 kimg.
# We keep this sparse schedule fixed to reduce runtime and make the selection rule easy to audit.
SNAP_TICKS = 10
SNAPSHOT_SELECTION_KIMG = [40, 80, 120, 160, 200]
GAN_MIRROR = True
ADA_TARGET = 0.6
GAN_CFG = "stylegan3-t"
GAN_AUG = "ada"
GAN_AUGPIPE_REFERENCE = "color"
# StyleGAN3 official train.py does not expose --augpipe.
# The rest of the ADA setup stays aligned with the StyleGAN2-ADA runs.
GAN_GAMMA = 0.8192
KID_METRIC_NAME = "kid50k_full"
GENERATE_START_SEED = 10000
GENERATE_NOISE_MODE = "random"
LONG_COMMAND_NOTEBOOK_MODE = "smart"
KID_OPENMP_DUPLICATE_OK = True
STYLEGAN_WINDOWS_PYTHON = Path(r"C:\Users\FYP2610\anaconda3\envs\fyp2\python.exe")
STYLEGAN_TORCH_CUDA_ARCH_LIST = "8.0+PTX"
STYLEGAN_EXTENSIONS_DIR = CHECKPOINTS_DIR / "torch_extensions_stylegan3_sm80ptx"
STYLEGAN_EXTENSIONS_DIR.mkdir(parents=True, exist_ok=True)

if os.name == "nt":
    PYTHON_EXE = STYLEGAN_WINDOWS_PYTHON
    if not PYTHON_EXE.exists():
        raise FileNotFoundError(
            f"Could not find the StyleGAN Python executable on the Windows machine: {PYTHON_EXE}"
        )
    STYLEGAN_ENV_ROOT = PYTHON_EXE.parent
    CONDA_EXE = STYLEGAN_ENV_ROOT.parent.parent / "Scripts" / "conda.exe"
    if not CONDA_EXE.exists():
        raise FileNotFoundError(
            f"Could not find conda.exe on the Windows machine: {CONDA_EXE}"
        )
else:
    PYTHON_EXE = Path(sys.executable)
    STYLEGAN_ENV_ROOT = None
    CONDA_EXE = None

STYLEGAN_EXTRA_ENV = {
    "TORCH_CUDA_ARCH_LIST": STYLEGAN_TORCH_CUDA_ARCH_LIST,
    "TORCH_EXTENSIONS_DIR": str(STYLEGAN_EXTENSIONS_DIR),
}
if KID_OPENMP_DUPLICATE_OK:
    STYLEGAN_EXTRA_ENV["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# This helper ensures Windows subprocesses really run inside the StyleGAN conda env.
def build_stylegan_command(script_name: str, *script_args: str):
    if os.name == "nt":
        return [
            str(CONDA_EXE),
            "run",
            "--no-capture-output",
            "-p",
            str(STYLEGAN_ENV_ROOT),
            "python",
            script_name,
            *script_args,
        ]
    return [str(PYTHON_EXE), script_name, *script_args]

# %%
# This helper reads a CSV file into a plain list of rows.
def read_csv_rows(csv_path: Path):
    with csv_path.open("r", newline="", encoding="utf-8") as handle:
        return list(csv.DictReader(handle))

# This helper writes a CSV file with a stable header.
def write_csv_rows(csv_path: Path, rows, fieldnames):
    if not rows:
        raise ValueError(f"No rows were provided for {csv_path.name}.")
    csv_path.parent.mkdir(parents=True, exist_ok=True)
    with csv_path.open("w", newline="", encoding="utf-8") as handle:
        writer = csv.DictWriter(handle, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

# This helper writes one small JSON file with clean formatting.
def write_json(json_path: Path, data):
    json_path.parent.mkdir(parents=True, exist_ok=True)
    json_path.write_text(json.dumps(data, indent=2), encoding="utf-8")

# This helper stores paths in repo-relative form so the outputs stay portable.
def as_repo_relative(repo_root: Path, path_value: Path) -> str:
    return path_value.relative_to(repo_root).as_posix()

# This helper decides which command lines matter enough to echo in the notebook.
def should_echo_command_line(line_text: str, line_index: int, notebook_mode: str) -> bool:
    if notebook_mode == "all":
        return True
    if notebook_mode == "quiet":
        return False
    if line_index <= 20:
        return True
    lowered = line_text.lower()
    important_markers = [
        "training for",
        "tick ",
        "sec/kimg",
        "snapshot",
        "saved",
        "kid50k_full",
        "generating image for seed",
        "traceback",
        "runtimeerror",
        "error:",
    ]
    return any(marker in lowered for marker in important_markers)

# This helper runs a subprocess, streams useful lines to the notebook, and saves a log to disk.
def run_command(command_parts, workdir: Path, live_log_path: Path, notebook_mode: str = "smart", extra_env=None):
    live_log_path.parent.mkdir(parents=True, exist_ok=True)
    command_env = os.environ.copy()
    if extra_env is not None:
        command_env.update(extra_env)

    process = subprocess.Popen(
        command_parts,
        cwd=workdir,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        encoding="utf-8",
        errors="replace",
        env=command_env,
    )

    start_time = time.time()
    output_tail = []
    printed_line_count = 0
    suppressed_line_count = 0
    total_line_count = 0

    with live_log_path.open("w", encoding="utf-8") as log_handle:
        for line in process.stdout:
            total_line_count += 1
            output_tail.append(line)
            output_tail = output_tail[-200:]
            log_handle.write(line)
            log_handle.flush()

            line_text = line.rstrip()
            if should_echo_command_line(line_text, total_line_count, notebook_mode):
                print(line_text)
                printed_line_count += 1
            else:
                suppressed_line_count += 1

    returncode = process.wait()
    duration_seconds = round(time.time() - start_time, 2)
    report = {
        "command": " ".join(str(item) for item in command_parts),
        "returncode": returncode,
        "duration_seconds": duration_seconds,
        "printed_line_count": printed_line_count,
        "suppressed_line_count": suppressed_line_count,
        "total_line_count": total_line_count,
        "log_path": as_repo_relative(REPO_ROOT, live_log_path),
        "output_tail": "".join(output_tail),
    }
    return report

# %%
# We load the real patch manifest and compute the exact top-up target for each training fold.
real_patch_rows = read_csv_rows(MANIFESTS_DIR / "dataset2_patch_manifest_224.csv")
gan_source_rows = read_csv_rows(MANIFESTS_DIR / "dataset2_gan_patch_manifest_256.csv")
fold_manifest_rows = read_csv_rows(MANIFESTS_DIR / "dataset2_fold_manifest.csv")

for row in real_patch_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])
for row in gan_source_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])
for row in fold_manifest_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])

fold_plan_rows = []
for fold_id in FOLDS_TO_RUN:
    train_rows = [row for row in real_patch_rows if int(row["fold_id"]) == fold_id]
    gan_rows = [row for row in gan_source_rows if int(row["fold_id"]) == fold_id]
    train_cocci_count = sum(1 for row in train_rows if int(row["binary_label"]) == 0)
    train_bacilli_count = sum(1 for row in train_rows if int(row["binary_label"]) == 1)
    test_fold_ids = [value for value in FOLDS_TO_RUN if value != fold_id]
    test_fold_text = ",".join(str(value) for value in test_fold_ids)
    if train_cocci_count >= train_bacilli_count:
        raise AssertionError(
            f"Fold {fold_id} no longer has cocci as the minority class. "
            f"cocci={train_cocci_count}, bacilli={train_bacilli_count}"
        )
    needed_gan_count_224 = train_bacilli_count - train_cocci_count
    fold_plan_rows.append({
        "round_id": fold_id,
        "train_fold_id": fold_id,
        "test_fold_ids": test_fold_text,
        "real_train_patch_count_224": len(train_rows),
        "real_cocci_count_224": train_cocci_count,
        "real_bacilli_count_224": train_bacilli_count,
        "needed_gan_count_224": needed_gan_count_224,
        "real_cocci_patch_count_256_for_gan": len(gan_rows),
        "train_raw_sample_count": sum(1 for row in fold_manifest_rows if int(row["fold_id"]) == fold_id),
        "dataset_zip_path": as_repo_relative(REPO_ROOT, NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}" / f"fold_{fold_id}_minority_256.zip"),
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "fold_plan.csv", fold_plan_rows, list(fold_plan_rows[0].keys()))
display(pd.DataFrame(fold_plan_rows))
# Out:
#    round_id  train_fold_id test_fold_ids  real_train_patch_count_224  \
# 0         1              1       2,3,4,5                         870
# 1         2              2       1,3,4,5                         837
# 2         3              3       1,2,4,5                         806
# 3         4              4       1,2,3,5                         821
# 4         5              5       1,2,3,4                         845
#
#    real_cocci_count_224  real_bacilli_count_224  needed_gan_count_224  \
# 0                   380                     490                   110
# 1                   344                     493                   149
# 2                   358                     448                    90
# 3                   351                     470                   119
# 4                   354                     491                   137
#
#    real_cocci_patch_count_256_for_gan  train_raw_sample_count  \
# 0                                 260                      86
# 1                                 239                      86
# 2                                 229                      85
# 3                                 243                      85
# 4                                 240                      85
#
#                                     dataset_zip_path
# 0  results/25_train_stylegan3_make_images_dataset...
# 1  results/25_train_stylegan3_make_images_dataset...
# 2  results/25_train_stylegan3_make_images_dataset...
# 3  results/25_train_stylegan3_make_images_dataset...
# 4  results/25_train_stylegan3_make_images_dataset...

# %%
# We create one StyleGAN zip file per training fold so each GAN only sees same-fold minority data.
dataset_zip_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    source_dir = GAN_PATCHES_DIR / f"fold_{fold_id}"
    if not source_dir.exists():
        raise FileNotFoundError(f"Missing GAN source folder for fold {fold_id}: {source_dir}")

    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    fold_result_dir.mkdir(parents=True, exist_ok=True)
    dataset_zip_path = REPO_ROOT / fold_plan["dataset_zip_path"]
    if dataset_zip_path.exists():
        dataset_zip_path.unlink()

    dataset_tool_log_path = fold_result_dir / "dataset_tool.log"
    report = run_command(
        build_stylegan_command(
            "dataset_tool.py",
            f"--source={source_dir}",
            f"--dest={dataset_zip_path}",
        ),
        STYLEGAN_DIR,
        live_log_path=dataset_tool_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=STYLEGAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "dataset_tool_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"dataset_tool.py failed for fold {fold_id}")

    dataset_zip_rows.append({
        "fold_id": fold_id,
        "source_dir": as_repo_relative(REPO_ROOT, source_dir),
        "dataset_zip_path": as_repo_relative(REPO_ROOT, dataset_zip_path),
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "dataset_zip_manifest.csv", dataset_zip_rows, list(dataset_zip_rows[0].keys()))
display(pd.DataFrame(dataset_zip_rows))
# Out:
#   0%|          | 0/260 [00:00<?, ?it/s]
#  10%|▉         | 25/260 [00:00<00:00, 241.18it/s]
#  19%|█▉        | 50/260 [00:00<00:00, 243.71it/s]
#  29%|██▉       | 75/260 [00:00<00:00, 241.87it/s]
#  38%|███▊      | 100/260 [00:00<00:00, 243.98it/s]
#  48%|████▊     | 125/260 [00:00<00:00, 245.96it/s]
#  58%|█████▊    | 151/260 [00:00<00:00, 247.70it/s]
#  68%|██████▊   | 176/260 [00:00<00:00, 246.37it/s]
#  77%|███████▋  | 201/260 [00:00<00:00, 246.46it/s]
#  87%|████████▋ | 226/260 [00:00<00:00, 246.14it/s]
#  97%|█████████▋| 252/260 [00:01<00:00, 248.67it/s]
# 100%|██████████| 260/260 [00:01<00:00, 246.80it/s]
#
#   0%|          | 0/239 [00:00<?, ?it/s]
#  10%|█         | 24/239 [00:00<00:00, 238.61it/s]
#  21%|██        | 50/239 [00:00<00:00, 246.82it/s]
#  31%|███▏      | 75/239 [00:00<00:00, 226.52it/s]
#  42%|████▏     | 101/239 [00:00<00:00, 235.89it/s]
#  52%|█████▏    | 125/239 [00:00<00:00, 237.25it/s]
#  63%|██████▎   | 151/239 [00:00<00:00, 241.81it/s]
#  74%|███████▎  | 176/239 [00:00<00:00, 243.63it/s]
#  85%|████████▍ | 202/239 [00:00<00:00, 247.00it/s]
#  95%|█████████▌| 228/239 [00:00<00:00, 250.01it/s]
# 100%|██████████| 239/239 [00:00<00:00, 243.97it/s]
#
#   0%|          | 0/229 [00:00<?, ?it/s]
#  11%|█         | 25/229 [00:00<00:00, 249.39it/s]
#  22%|██▏       | 51/229 [00:00<00:00, 251.01it/s]
#  34%|███▎      | 77/229 [00:00<00:00, 248.86it/s]
#  45%|████▍     | 103/229 [00:00<00:00, 249.80it/s]
#  56%|█████▌    | 128/229 [00:00<00:00, 249.70it/s]
#  67%|██████▋   | 154/229 [00:00<00:00, 250.90it/s]
#  79%|███████▊  | 180/229 [00:00<00:00, 251.41it/s]
#  90%|████████▉ | 206/229 [00:00<00:00, 252.27it/s]
# 100%|██████████| 229/229 [00:00<00:00, 250.72it/s]
#
#   0%|          | 0/243 [00:00<?, ?it/s]
#  11%|█         | 26/243 [00:00<00:00, 252.80it/s]
#  21%|██▏       | 52/243 [00:00<00:00, 250.69it/s]
#  32%|███▏      | 78/243 [00:00<00:00, 252.14it/s]
#  43%|████▎     | 104/243 [00:00<00:00, 249.65it/s]
#  53%|█████▎    | 129/243 [00:00<00:00, 248.16it/s]
#  64%|██████▍   | 155/243 [00:00<00:00, 249.03it/s]
#  74%|███████▍  | 181/243 [00:00<00:00, 250.42it/s]
#  85%|████████▌ | 207/243 [00:00<00:00, 248.16it/s]
#  95%|█████████▌| 232/243 [00:00<00:00, 244.97it/s]
# 100%|██████████| 243/243 [00:00<00:00, 248.13it/s]
#
#   0%|          | 0/240 [00:00<?, ?it/s]
#  10%|█         | 25/240 [00:00<00:00, 245.38it/s]
#  21%|██        | 50/240 [00:00<00:00, 245.88it/s]
#  32%|███▏      | 76/240 [00:00<00:00, 248.95it/s]
#  42%|████▎     | 102/240 [00:00<00:00, 251.00it/s]
#  53%|█████▎    | 128/240 [00:00<00:00, 250.99it/s]
#  64%|██████▍   | 154/240 [00:00<00:00, 252.81it/s]
#  75%|███████▌  | 180/240 [00:00<00:00, 252.24it/s]
#  86%|████████▌ | 206/240 [00:00<00:00, 250.73it/s]
#  97%|█████████▋| 232/240 [00:00<00:00, 249.99it/s]
# 100%|██████████| 240/240 [00:00<00:00, 249.41it/s]
#    fold_id                       source_dir  \
# 0        1  gan_patches_256/dataset2/fold_1
# 1        2  gan_patches_256/dataset2/fold_2
# 2        3  gan_patches_256/dataset2/fold_3
# 3        4  gan_patches_256/dataset2/fold_4
# 4        5  gan_patches_256/dataset2/fold_5
#
#                                     dataset_zip_path
# 0  results/25_train_stylegan3_make_images_dataset...
# 1  results/25_train_stylegan3_make_images_dataset...
# 2  results/25_train_stylegan3_make_images_dataset...
# 3  results/25_train_stylegan3_make_images_dataset...
# 4  results/25_train_stylegan3_make_images_dataset...

# %%
# We train one StyleGAN3-T run per training fold and keep the logs on disk.
training_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    dataset_zip_path = REPO_ROOT / fold_plan["dataset_zip_path"]
    run_parent = NOTEBOOK_CHECKPOINTS_DIR / f"fold_{fold_id}"
    run_parent.mkdir(parents=True, exist_ok=True)
    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    train_log_path = fold_result_dir / "train.log"

    report = run_command(
        build_stylegan_command(
            "train.py",
            f"--outdir={run_parent}",
            "--gpus=1",
            f"--data={dataset_zip_path}",
            f"--cfg={GAN_CFG}",
            f"--gamma={GAN_GAMMA}",
            f"--aug={GAN_AUG}",
            f"--mirror={int(GAN_MIRROR)}",
            f"--batch={GAN_BATCH_SIZE}",
            f"--kimg={GAN_KIMG}",
            f"--snap={SNAP_TICKS}",
            f"--workers={GAN_WORKERS}",
            f"--target={ADA_TARGET}",
            f"--metrics={KID_METRIC_NAME}",
            f"--seed={STYLEGAN_RANDOM_SEED}",
        ),
        STYLEGAN_DIR,
        live_log_path=train_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=STYLEGAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "train_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"StyleGAN3 training failed for fold {fold_id}")

    run_dirs = [path for path in run_parent.iterdir() if path.is_dir()]
    if not run_dirs:
        raise FileNotFoundError(f"No StyleGAN3 run directory was found for fold {fold_id}")
    run_dir = sorted(run_dirs, key=lambda item: item.name)[-1]
    snapshot_paths = sorted(run_dir.glob("network-snapshot-*.pkl"))
    if not snapshot_paths:
        raise FileNotFoundError(f"No snapshots were saved for fold {fold_id}")

    training_rows.append({
        "fold_id": fold_id,
        "run_dir": as_repo_relative(REPO_ROOT, run_dir),
        "latest_snapshot_path": as_repo_relative(REPO_ROOT, snapshot_paths[-1]),
        "train_duration_seconds": report["duration_seconds"],
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "training_run_manifest.csv", training_rows, list(training_rows[0].keys()))
display(pd.DataFrame(training_rows))
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9997227795604651
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "kid50k_full"
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 2m 28s       sec/tick 45.1    sec/kimg 5635.86 maintenance 103.0  cpumem 2.87   gpumem 6.01   reserved 6.79   augment 0.000
# {"results": {"kid50k_full": 0.6548224091529846}, "metric": "kid50k_full", "total_time": 1726.2434105873108, "total_time_str": "28m 46s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777658466.997849}
# tick 1     kimg 4.0      time 45m 40s      sec/tick 842.8   sec/kimg 210.70  maintenance 1749.5 cpumem 3.49   gpumem 5.59   reserved 7.29   augment 0.006
# tick 2     kimg 8.0      time 59m 44s      sec/tick 843.5   sec/kimg 210.86  maintenance 0.1    cpumem 3.41   gpumem 5.60   reserved 7.29   augment 0.011
# tick 3     kimg 12.0     time 1h 13m 47s   sec/tick 843.2   sec/kimg 210.80  maintenance 0.1    cpumem 3.41   gpumem 5.60   reserved 7.29   augment 0.015
# tick 4     kimg 16.0     time 1h 27m 51s   sec/tick 843.3   sec/kimg 210.83  maintenance 0.1    cpumem 3.41   gpumem 5.61   reserved 7.29   augment 0.022
# tick 5     kimg 20.0     time 1h 41m 54s   sec/tick 843.5   sec/kimg 210.87  maintenance 0.3    cpumem 3.41   gpumem 5.61   reserved 7.29   augment 0.029
# tick 6     kimg 24.0     time 1h 55m 58s   sec/tick 843.2   sec/kimg 210.80  maintenance 0.1    cpumem 3.41   gpumem 5.60   reserved 7.29   augment 0.036
# tick 7     kimg 28.0     time 2h 10m 01s   sec/tick 843.4   sec/kimg 210.84  maintenance 0.1    cpumem 3.41   gpumem 5.60   reserved 7.29   augment 0.041
# tick 8     kimg 32.0     time 2h 24m 11s   sec/tick 849.4   sec/kimg 212.34  maintenance 0.1    cpumem 3.41   gpumem 5.61   reserved 7.29   augment 0.046
# tick 9     kimg 36.0     time 2h 38m 15s   sec/tick 843.5   sec/kimg 210.87  maintenance 0.3    cpumem 3.41   gpumem 5.61   reserved 7.29   augment 0.047
# tick 10    kimg 40.0     time 2h 52m 18s   sec/tick 843.2   sec/kimg 210.81  maintenance 0.1    cpumem 3.41   gpumem 5.61   reserved 7.29   augment 0.051
# {"results": {"kid50k_full": 0.4392305016517639}, "metric": "kid50k_full", "total_time": 1775.4366931915283, "total_time_str": "29m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777668709.2474256}
# tick 11    kimg 44.0     time 3h 36m 23s   sec/tick 843.4   sec/kimg 210.86  maintenance 1801.9 cpumem 3.53   gpumem 5.63   reserved 7.29   augment 0.052
# tick 12    kimg 48.0     time 3h 50m 27s   sec/tick 843.5   sec/kimg 210.88  maintenance 0.1    cpumem 3.43   gpumem 5.63   reserved 7.29   augment 0.049
# tick 13    kimg 52.0     time 4h 04m 31s   sec/tick 843.4   sec/kimg 210.85  maintenance 0.3    cpumem 3.43   gpumem 5.62   reserved 7.29   augment 0.045
# tick 14    kimg 56.0     time 4h 18m 34s   sec/tick 843.5   sec/kimg 210.89  maintenance 0.1    cpumem 3.43   gpumem 5.60   reserved 7.29   augment 0.042
# tick 15    kimg 60.0     time 4h 32m 38s   sec/tick 843.5   sec/kimg 210.88  maintenance 0.1    cpumem 3.43   gpumem 5.61   reserved 7.29   augment 0.040
# tick 16    kimg 64.0     time 4h 46m 42s   sec/tick 844.0   sec/kimg 211.01  maintenance 0.1    cpumem 3.43   gpumem 5.61   reserved 7.29   augment 0.038
# tick 17    kimg 68.0     time 5h 00m 46s   sec/tick 843.9   sec/kimg 210.98  maintenance 0.3    cpumem 3.43   gpumem 5.60   reserved 7.29   augment 0.038
# tick 18    kimg 72.0     time 5h 14m 50s   sec/tick 844.0   sec/kimg 211.01  maintenance 0.1    cpumem 3.43   gpumem 5.60   reserved 7.29   augment 0.037
# tick 19    kimg 76.0     time 5h 28m 54s   sec/tick 843.7   sec/kimg 210.92  maintenance 0.1    cpumem 3.43   gpumem 5.60   reserved 7.29   augment 0.037
# tick 20    kimg 80.0     time 5h 42m 58s   sec/tick 844.1   sec/kimg 211.01  maintenance 0.1    cpumem 3.43   gpumem 5.61   reserved 7.29   augment 0.034
# {"results": {"kid50k_full": 0.16709165275096893}, "metric": "kid50k_full", "total_time": 1775.385894536972, "total_time_str": "29m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777678952.420991}
# tick 21    kimg 84.0     time 6h 27m 07s   sec/tick 843.7   sec/kimg 210.92  maintenance 1804.5 cpumem 3.54   gpumem 5.63   reserved 7.29   augment 0.032
# tick 22    kimg 88.0     time 6h 41m 11s   sec/tick 844.1   sec/kimg 211.02  maintenance 0.1    cpumem 3.54   gpumem 5.60   reserved 7.29   augment 0.033
# tick 23    kimg 92.0     time 6h 55m 15s   sec/tick 843.7   sec/kimg 210.93  maintenance 0.1    cpumem 3.43   gpumem 5.61   reserved 7.29   augment 0.033
# tick 24    kimg 96.0     time 7h 09m 19s   sec/tick 843.7   sec/kimg 210.93  maintenance 0.1    cpumem 3.43   gpumem 5.60   reserved 7.29   augment 0.034
# tick 25    kimg 100.0    time 7h 23m 22s   sec/tick 843.7   sec/kimg 210.92  maintenance 0.3    cpumem 3.43   gpumem 5.61   reserved 7.29   augment 0.035
# tick 26    kimg 104.0    time 7h 37m 26s   sec/tick 843.5   sec/kimg 210.87  maintenance 0.1    cpumem 3.43   gpumem 5.61   reserved 7.29   augment 0.035
# tick 27    kimg 108.0    time 7h 51m 30s   sec/tick 843.8   sec/kimg 210.95  maintenance 0.1    cpumem 3.43   gpumem 5.62   reserved 7.29   augment 0.037
# tick 28    kimg 112.0    time 8h 05m 34s   sec/tick 843.6   sec/kimg 210.91  maintenance 0.1    cpumem 3.43   gpumem 5.61   reserved 7.29   augment 0.039
# tick 29    kimg 116.0    time 8h 19m 38s   sec/tick 843.7   sec/kimg 210.92  maintenance 0.3    cpumem 3.43   gpumem 5.60   reserved 7.29   augment 0.042
# tick 30    kimg 120.0    time 8h 33m 41s   sec/tick 843.5   sec/kimg 210.89  maintenance 0.1    cpumem 3.43   gpumem 5.63   reserved 7.29   augment 0.046
# {"results": {"kid50k_full": 0.15876908600330353}, "metric": "kid50k_full", "total_time": 1776.9124739170074, "total_time_str": "29m 37s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777689199.1711235}
# tick 31    kimg 124.0    time 9h 17m 54s   sec/tick 843.8   sec/kimg 210.95  maintenance 1808.3 cpumem 3.54   gpumem 5.62   reserved 7.29   augment 0.051
# tick 32    kimg 128.0    time 9h 31m 58s   sec/tick 843.9   sec/kimg 210.97  maintenance 0.1    cpumem 3.54   gpumem 5.60   reserved 7.29   augment 0.053
# tick 33    kimg 132.0    time 9h 46m 01s   sec/tick 843.7   sec/kimg 210.92  maintenance 0.3    cpumem 3.44   gpumem 5.62   reserved 7.29   augment 0.056
# tick 34    kimg 136.0    time 10h 00m 05s  sec/tick 843.8   sec/kimg 210.95  maintenance 0.1    cpumem 3.44   gpumem 5.61   reserved 7.29   augment 0.061
# tick 35    kimg 140.0    time 10h 14m 10s  sec/tick 844.1   sec/kimg 211.01  maintenance 0.1    cpumem 3.44   gpumem 5.67   reserved 7.29   augment 0.065
# tick 36    kimg 144.0    time 10h 28m 14s  sec/tick 844.5   sec/kimg 211.12  maintenance 0.1    cpumem 3.44   gpumem 5.63   reserved 7.29   augment 0.069
# tick 37    kimg 148.0    time 10h 42m 18s  sec/tick 843.7   sec/kimg 210.92  maintenance 0.3    cpumem 3.44   gpumem 5.61   reserved 7.29   augment 0.074
# tick 38    kimg 152.0    time 10h 56m 22s  sec/tick 843.8   sec/kimg 210.96  maintenance 0.1    cpumem 3.44   gpumem 5.63   reserved 7.29   augment 0.080
# tick 39    kimg 156.0    time 11h 10m 26s  sec/tick 843.7   sec/kimg 210.93  maintenance 0.1    cpumem 3.44   gpumem 5.63   reserved 7.29   augment 0.084
# tick 40    kimg 160.0    time 11h 24m 30s  sec/tick 843.7   sec/kimg 210.92  maintenance 0.1    cpumem 3.44   gpumem 5.63   reserved 7.29   augment 0.087
# {"results": {"kid50k_full": 0.13614408671855927}, "metric": "kid50k_full", "total_time": 1776.3384416103363, "total_time_str": "29m 36s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777699446.2794137}
# tick 41    kimg 164.0    time 12h 08m 40s  sec/tick 843.6   sec/kimg 210.90  maintenance 1807.0 cpumem 3.53   gpumem 5.62   reserved 7.29   augment 0.089
# tick 42    kimg 168.0    time 12h 22m 44s  sec/tick 843.9   sec/kimg 210.97  maintenance 0.1    cpumem 3.53   gpumem 5.64   reserved 7.29   augment 0.091
# tick 43    kimg 172.0    time 12h 36m 48s  sec/tick 843.5   sec/kimg 210.88  maintenance 0.1    cpumem 3.42   gpumem 5.63   reserved 7.29   augment 0.095
# tick 44    kimg 176.0    time 12h 50m 52s  sec/tick 843.8   sec/kimg 210.95  maintenance 0.1    cpumem 3.42   gpumem 5.62   reserved 7.29   augment 0.097
# tick 45    kimg 180.0    time 13h 04m 56s  sec/tick 843.9   sec/kimg 210.97  maintenance 0.3    cpumem 3.42   gpumem 5.62   reserved 7.29   augment 0.100
# tick 46    kimg 184.0    time 13h 19m 00s  sec/tick 843.7   sec/kimg 210.93  maintenance 0.1    cpumem 3.42   gpumem 5.63   reserved 7.29   augment 0.103
# tick 47    kimg 188.0    time 13h 33m 04s  sec/tick 843.8   sec/kimg 210.96  maintenance 0.1    cpumem 3.42   gpumem 5.62   reserved 7.29   augment 0.107
# tick 48    kimg 192.0    time 13h 47m 08s  sec/tick 844.1   sec/kimg 211.01  maintenance 0.1    cpumem 3.42   gpumem 5.62   reserved 7.29   augment 0.111
# tick 49    kimg 196.0    time 14h 01m 12s  sec/tick 843.8   sec/kimg 210.94  maintenance 0.3    cpumem 3.42   gpumem 5.63   reserved 7.29   augment 0.112
# tick 50    kimg 200.0    time 14h 15m 35s  sec/tick 862.8   sec/kimg 216.14  maintenance 0.1    cpumem 2.60   gpumem 5.62   reserved 7.29   augment 0.114
# {"results": {"kid50k_full": 0.12127359211444855}, "metric": "kid50k_full", "total_time": 1777.2920532226562, "total_time_str": "29m 37s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777709714.5897336}
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9997227795604651
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "kid50k_full"
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 2m 29s       sec/tick 45.0    sec/kimg 5620.71 maintenance 103.8  cpumem 2.85   gpumem 6.01   reserved 6.79   augment 0.000
# {"results": {"kid50k_full": 0.6947147250175476}, "metric": "kid50k_full", "total_time": 1726.107274055481, "total_time_str": "28m 46s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777711618.344653}
# tick 1     kimg 4.0      time 45m 09s      sec/tick 811.5   sec/kimg 202.86  maintenance 1749.3 cpumem 3.57   gpumem 5.59   reserved 7.29   augment 0.006
# tick 2     kimg 8.0      time 58m 41s      sec/tick 811.6   sec/kimg 202.91  maintenance 0.1    cpumem 3.49   gpumem 5.60   reserved 7.29   augment 0.012
# tick 3     kimg 12.0     time 1h 12m 13s   sec/tick 811.7   sec/kimg 202.94  maintenance 0.1    cpumem 3.49   gpumem 5.60   reserved 7.29   augment 0.019
# tick 4     kimg 16.0     time 1h 25m 45s   sec/tick 811.8   sec/kimg 202.95  maintenance 0.1    cpumem 3.49   gpumem 5.61   reserved 7.29   augment 0.025
# tick 5     kimg 20.0     time 1h 39m 17s   sec/tick 811.9   sec/kimg 202.96  maintenance 0.3    cpumem 3.49   gpumem 5.61   reserved 7.29   augment 0.033
# tick 6     kimg 24.0     time 1h 52m 49s   sec/tick 811.7   sec/kimg 202.93  maintenance 0.1    cpumem 3.49   gpumem 5.60   reserved 7.29   augment 0.040
# tick 7     kimg 28.0     time 2h 06m 21s   sec/tick 811.5   sec/kimg 202.87  maintenance 0.1    cpumem 3.49   gpumem 5.60   reserved 7.29   augment 0.045
# tick 8     kimg 32.0     time 2h 19m 53s   sec/tick 811.8   sec/kimg 202.95  maintenance 0.1    cpumem 3.49   gpumem 5.61   reserved 7.29   augment 0.048
# tick 9     kimg 36.0     time 2h 33m 25s   sec/tick 811.7   sec/kimg 202.92  maintenance 0.3    cpumem 3.49   gpumem 5.61   reserved 7.29   augment 0.053
# tick 10    kimg 40.0     time 2h 46m 56s   sec/tick 811.6   sec/kimg 202.91  maintenance 0.1    cpumem 3.49   gpumem 5.61   reserved 7.29   augment 0.055
# {"results": {"kid50k_full": 0.4295436143875122}, "metric": "kid50k_full", "total_time": 1712.4164204597473, "total_time_str": "28m 32s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777721476.9634814}
# tick 11    kimg 44.0     time 3h 29m 28s   sec/tick 811.8   sec/kimg 202.95  maintenance 1740.3 cpumem 3.56   gpumem 5.63   reserved 7.29   augment 0.054
# tick 12    kimg 48.0     time 3h 43m 00s   sec/tick 811.9   sec/kimg 202.97  maintenance 0.1    cpumem 3.46   gpumem 5.63   reserved 7.29   augment 0.053
# tick 13    kimg 52.0     time 3h 56m 33s   sec/tick 811.9   sec/kimg 202.97  maintenance 0.3    cpumem 3.46   gpumem 5.62   reserved 7.29   augment 0.051
# tick 14    kimg 56.0     time 4h 10m 05s   sec/tick 812.0   sec/kimg 203.00  maintenance 0.1    cpumem 3.46   gpumem 5.60   reserved 7.29   augment 0.048
# tick 15    kimg 60.0     time 4h 23m 37s   sec/tick 812.5   sec/kimg 203.13  maintenance 0.1    cpumem 3.46   gpumem 5.61   reserved 7.29   augment 0.046
# tick 16    kimg 64.0     time 4h 37m 10s   sec/tick 812.2   sec/kimg 203.06  maintenance 0.1    cpumem 3.46   gpumem 5.61   reserved 7.29   augment 0.044
# tick 17    kimg 68.0     time 4h 50m 42s   sec/tick 812.3   sec/kimg 203.07  maintenance 0.3    cpumem 3.46   gpumem 5.60   reserved 7.29   augment 0.042
# tick 18    kimg 72.0     time 5h 04m 15s   sec/tick 812.4   sec/kimg 203.11  maintenance 0.1    cpumem 3.46   gpumem 5.60   reserved 7.29   augment 0.039
# tick 19    kimg 76.0     time 5h 17m 47s   sec/tick 812.2   sec/kimg 203.06  maintenance 0.1    cpumem 3.46   gpumem 5.60   reserved 7.29   augment 0.038
# tick 20    kimg 80.0     time 5h 31m 20s   sec/tick 812.3   sec/kimg 203.08  maintenance 0.1    cpumem 3.46   gpumem 5.61   reserved 7.29   augment 0.038
# {"results": {"kid50k_full": 0.11839281767606735}, "metric": "kid50k_full", "total_time": 1714.7520298957825, "total_time_str": "28m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777731344.2493222}
# tick 21    kimg 84.0     time 6h 13m 56s   sec/tick 812.0   sec/kimg 203.00  maintenance 1744.2 cpumem 3.55   gpumem 5.63   reserved 7.29   augment 0.040
# tick 22    kimg 88.0     time 6h 27m 29s   sec/tick 812.5   sec/kimg 203.13  maintenance 0.1    cpumem 3.55   gpumem 5.60   reserved 7.29   augment 0.043
# tick 23    kimg 92.0     time 6h 41m 03s   sec/tick 814.3   sec/kimg 203.58  maintenance 0.1    cpumem 2.35   gpumem 5.62   reserved 7.29   augment 0.045
# tick 24    kimg 96.0     time 6h 54m 36s   sec/tick 812.4   sec/kimg 203.09  maintenance 0.1    cpumem 2.35   gpumem 5.61   reserved 7.29   augment 0.047
# tick 25    kimg 100.0    time 7h 08m 08s   sec/tick 812.5   sec/kimg 203.13  maintenance 0.3    cpumem 2.35   gpumem 5.61   reserved 7.29   augment 0.050
# tick 26    kimg 104.0    time 7h 21m 41s   sec/tick 812.2   sec/kimg 203.04  maintenance 0.1    cpumem 2.35   gpumem 5.62   reserved 7.29   augment 0.054
# tick 27    kimg 108.0    time 7h 35m 13s   sec/tick 812.6   sec/kimg 203.15  maintenance 0.1    cpumem 2.35   gpumem 5.63   reserved 7.29   augment 0.057
# tick 28    kimg 112.0    time 7h 48m 46s   sec/tick 812.8   sec/kimg 203.19  maintenance 0.1    cpumem 2.35   gpumem 5.61   reserved 7.29   augment 0.060
# tick 29    kimg 116.0    time 8h 02m 19s   sec/tick 812.7   sec/kimg 203.19  maintenance 0.3    cpumem 2.35   gpumem 5.62   reserved 7.29   augment 0.064
# tick 30    kimg 120.0    time 8h 15m 52s   sec/tick 812.5   sec/kimg 203.13  maintenance 0.1    cpumem 2.35   gpumem 5.63   reserved 7.29   augment 0.067
# {"results": {"kid50k_full": 0.10737501829862595}, "metric": "kid50k_full", "total_time": 1715.1588525772095, "total_time_str": "28m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777741218.8123863}
# tick 31    kimg 124.0    time 8h 58m 31s   sec/tick 812.5   sec/kimg 203.12  maintenance 1746.6 cpumem 2.47   gpumem 5.62   reserved 7.29   augment 0.071
# tick 32    kimg 128.0    time 9h 12m 04s   sec/tick 812.9   sec/kimg 203.23  maintenance 0.1    cpumem 2.47   gpumem 5.62   reserved 7.29   augment 0.075
# tick 33    kimg 132.0    time 9h 25m 37s   sec/tick 812.3   sec/kimg 203.08  maintenance 0.3    cpumem 2.36   gpumem 5.62   reserved 7.29   augment 0.078
# tick 34    kimg 136.0    time 9h 39m 09s   sec/tick 812.7   sec/kimg 203.17  maintenance 0.1    cpumem 2.36   gpumem 5.61   reserved 7.29   augment 0.081
# tick 35    kimg 140.0    time 9h 52m 42s   sec/tick 812.3   sec/kimg 203.07  maintenance 0.1    cpumem 2.36   gpumem 5.67   reserved 7.29   augment 0.085
# tick 36    kimg 144.0    time 10h 06m 14s  sec/tick 812.4   sec/kimg 203.09  maintenance 0.1    cpumem 2.36   gpumem 5.63   reserved 7.29   augment 0.087
# tick 37    kimg 148.0    time 10h 19m 47s  sec/tick 812.5   sec/kimg 203.13  maintenance 0.3    cpumem 2.36   gpumem 5.61   reserved 7.29   augment 0.090
# tick 38    kimg 152.0    time 10h 33m 20s  sec/tick 812.6   sec/kimg 203.15  maintenance 0.1    cpumem 2.36   gpumem 5.63   reserved 7.29   augment 0.094
# tick 39    kimg 156.0    time 10h 46m 52s  sec/tick 812.3   sec/kimg 203.08  maintenance 0.1    cpumem 2.36   gpumem 5.63   reserved 7.29   augment 0.098
# tick 40    kimg 160.0    time 11h 00m 25s  sec/tick 812.6   sec/kimg 203.15  maintenance 0.1    cpumem 2.36   gpumem 5.63   reserved 7.29   augment 0.101
# {"results": {"kid50k_full": 0.03460152819752693}, "metric": "kid50k_full", "total_time": 1714.8863945007324, "total_time_str": "28m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777751092.2159255}
# tick 41    kimg 164.0    time 11h 43m 05s  sec/tick 812.6   sec/kimg 203.15  maintenance 1746.9 cpumem 2.04   gpumem 5.62   reserved 7.29   augment 0.105
# tick 42    kimg 168.0    time 11h 56m 37s  sec/tick 812.3   sec/kimg 203.06  maintenance 0.1    cpumem 2.04   gpumem 5.64   reserved 7.29   augment 0.108
# tick 43    kimg 172.0    time 12h 10m 09s  sec/tick 812.3   sec/kimg 203.08  maintenance 0.1    cpumem 1.94   gpumem 5.63   reserved 7.29   augment 0.111
# tick 44    kimg 176.0    time 12h 23m 42s  sec/tick 812.4   sec/kimg 203.09  maintenance 0.1    cpumem 1.94   gpumem 5.62   reserved 7.29   augment 0.114
# tick 45    kimg 180.0    time 12h 37m 15s  sec/tick 812.8   sec/kimg 203.21  maintenance 0.3    cpumem 1.94   gpumem 5.62   reserved 7.29   augment 0.117
# tick 46    kimg 184.0    time 12h 50m 48s  sec/tick 812.6   sec/kimg 203.16  maintenance 0.1    cpumem 1.94   gpumem 5.63   reserved 7.29   augment 0.119
# tick 47    kimg 188.0    time 13h 04m 21s  sec/tick 812.7   sec/kimg 203.17  maintenance 0.1    cpumem 1.94   gpumem 5.63   reserved 7.29   augment 0.122
# tick 48    kimg 192.0    time 13h 17m 53s  sec/tick 812.6   sec/kimg 203.16  maintenance 0.1    cpumem 1.94   gpumem 5.62   reserved 7.29   augment 0.125
# tick 49    kimg 196.0    time 13h 31m 26s  sec/tick 812.5   sec/kimg 203.13  maintenance 0.3    cpumem 1.94   gpumem 5.63   reserved 7.29   augment 0.128
# tick 50    kimg 200.0    time 13h 44m 57s  sec/tick 811.0   sec/kimg 203.16  maintenance 0.1    cpumem 1.94   gpumem 5.64   reserved 7.29   augment 0.131
# {"results": {"kid50k_full": 0.03771182522177696}, "metric": "kid50k_full", "total_time": 1713.7012465000153, "total_time_str": "28m 34s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777760964.126477}
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9997227795604651
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "kid50k_full"
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 2m 26s       sec/tick 44.0    sec/kimg 5495.80 maintenance 101.7  cpumem 2.86   gpumem 6.01   reserved 6.79   augment 0.000
# {"results": {"kid50k_full": 0.6875383257865906}, "metric": "kid50k_full", "total_time": 1734.814048051834, "total_time_str": "28m 55s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777762872.9485602}
# tick 1     kimg 4.0      time 45m 31s      sec/tick 827.8   sec/kimg 206.94  maintenance 1758.0 cpumem 3.61   gpumem 5.59   reserved 7.58   augment 0.006
# tick 2     kimg 8.0      time 59m 19s      sec/tick 827.7   sec/kimg 206.93  maintenance 0.1    cpumem 3.52   gpumem 5.60   reserved 7.58   augment 0.011
# tick 3     kimg 12.0     time 1h 13m 07s   sec/tick 827.7   sec/kimg 206.94  maintenance 0.1    cpumem 3.52   gpumem 5.60   reserved 7.58   augment 0.017
# tick 4     kimg 16.0     time 1h 26m 55s   sec/tick 827.7   sec/kimg 206.94  maintenance 0.1    cpumem 3.52   gpumem 5.61   reserved 7.58   augment 0.023
# tick 5     kimg 20.0     time 1h 40m 43s   sec/tick 827.4   sec/kimg 206.85  maintenance 0.3    cpumem 3.52   gpumem 5.62   reserved 7.58   augment 0.028
# tick 6     kimg 24.0     time 1h 54m 30s   sec/tick 827.5   sec/kimg 206.87  maintenance 0.1    cpumem 3.52   gpumem 5.60   reserved 7.58   augment 0.035
# tick 7     kimg 28.0     time 2h 08m 18s   sec/tick 827.7   sec/kimg 206.92  maintenance 0.1    cpumem 3.52   gpumem 5.61   reserved 7.58   augment 0.038
# tick 8     kimg 32.0     time 2h 22m 06s   sec/tick 827.8   sec/kimg 206.95  maintenance 0.1    cpumem 3.52   gpumem 5.62   reserved 7.58   augment 0.040
# tick 9     kimg 36.0     time 2h 35m 54s   sec/tick 827.5   sec/kimg 206.88  maintenance 0.3    cpumem 3.52   gpumem 5.61   reserved 7.58   augment 0.044
# tick 10    kimg 40.0     time 2h 49m 41s   sec/tick 827.4   sec/kimg 206.86  maintenance 0.1    cpumem 3.52   gpumem 5.61   reserved 7.58   augment 0.049
# {"results": {"kid50k_full": 0.34325820207595825}, "metric": "kid50k_full", "total_time": 1782.828691959381, "total_time_str": "29m 43s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777772957.8718917}
# tick 11    kimg 44.0     time 3h 33m 36s   sec/tick 827.1   sec/kimg 206.79  maintenance 1807.1 cpumem 3.66   gpumem 5.60   reserved 7.58   augment 0.049
# tick 12    kimg 48.0     time 3h 47m 23s   sec/tick 827.5   sec/kimg 206.86  maintenance 0.1    cpumem 3.66   gpumem 5.63   reserved 7.58   augment 0.048
# tick 13    kimg 52.0     time 4h 01m 11s   sec/tick 827.7   sec/kimg 206.93  maintenance 0.3    cpumem 3.56   gpumem 5.62   reserved 7.58   augment 0.045
# tick 14    kimg 56.0     time 4h 14m 59s   sec/tick 828.0   sec/kimg 207.00  maintenance 0.1    cpumem 3.56   gpumem 5.60   reserved 7.58   augment 0.044
# tick 15    kimg 60.0     time 4h 28m 47s   sec/tick 827.7   sec/kimg 206.93  maintenance 0.1    cpumem 3.56   gpumem 5.62   reserved 7.58   augment 0.043
# tick 16    kimg 64.0     time 4h 42m 35s   sec/tick 828.0   sec/kimg 207.00  maintenance 0.1    cpumem 3.56   gpumem 5.61   reserved 7.58   augment 0.042
# tick 17    kimg 68.0     time 4h 56m 23s   sec/tick 827.8   sec/kimg 206.96  maintenance 0.3    cpumem 3.56   gpumem 5.60   reserved 7.58   augment 0.044
# tick 18    kimg 72.0     time 5h 10m 11s   sec/tick 827.7   sec/kimg 206.92  maintenance 0.1    cpumem 3.56   gpumem 5.60   reserved 7.58   augment 0.044
# tick 19    kimg 76.0     time 5h 23m 59s   sec/tick 827.8   sec/kimg 206.96  maintenance 0.1    cpumem 3.55   gpumem 5.61   reserved 7.58   augment 0.044
# tick 20    kimg 80.0     time 5h 37m 47s   sec/tick 828.0   sec/kimg 206.99  maintenance 0.1    cpumem 3.55   gpumem 5.61   reserved 7.58   augment 0.045
# {"results": {"kid50k_full": 0.20780907571315765}, "metric": "kid50k_full", "total_time": 1784.3880829811096, "total_time_str": "29m 44s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777783048.9735453}
# tick 21    kimg 84.0     time 6h 21m 48s   sec/tick 828.1   sec/kimg 207.02  maintenance 1812.2 cpumem 3.65   gpumem 5.63   reserved 7.59   augment 0.046
# tick 22    kimg 88.0     time 6h 35m 36s   sec/tick 828.2   sec/kimg 207.05  maintenance 0.1    cpumem 3.65   gpumem 5.61   reserved 7.59   augment 0.046
# tick 23    kimg 92.0     time 6h 49m 24s   sec/tick 827.8   sec/kimg 206.94  maintenance 0.1    cpumem 3.55   gpumem 5.62   reserved 7.59   augment 0.045
# tick 24    kimg 96.0     time 7h 03m 13s   sec/tick 828.4   sec/kimg 207.11  maintenance 0.1    cpumem 3.55   gpumem 5.61   reserved 7.59   augment 0.047
# tick 25    kimg 100.0    time 7h 17m 01s   sec/tick 828.1   sec/kimg 207.02  maintenance 0.3    cpumem 3.55   gpumem 5.62   reserved 7.59   augment 0.050
# tick 26    kimg 104.0    time 7h 30m 49s   sec/tick 827.8   sec/kimg 206.96  maintenance 0.1    cpumem 3.55   gpumem 5.62   reserved 7.59   augment 0.053
# tick 27    kimg 108.0    time 7h 44m 37s   sec/tick 828.1   sec/kimg 207.02  maintenance 0.1    cpumem 3.55   gpumem 5.62   reserved 7.59   augment 0.054
# tick 28    kimg 112.0    time 7h 58m 26s   sec/tick 828.4   sec/kimg 207.11  maintenance 0.1    cpumem 3.55   gpumem 5.62   reserved 7.59   augment 0.056
# tick 29    kimg 116.0    time 8h 12m 14s   sec/tick 828.2   sec/kimg 207.06  maintenance 0.3    cpumem 3.55   gpumem 5.62   reserved 7.59   augment 0.058
# tick 30    kimg 120.0    time 8h 26m 02s   sec/tick 828.1   sec/kimg 207.02  maintenance 0.1    cpumem 3.55   gpumem 5.63   reserved 7.59   augment 0.060
# {"results": {"kid50k_full": 0.11120691895484924}, "metric": "kid50k_full", "total_time": 1802.2608952522278, "total_time_str": "30m 02s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777793167.4973748}
# tick 31    kimg 124.0    time 9h 10m 33s   sec/tick 835.0   sec/kimg 208.76  maintenance 1835.8 cpumem 3.66   gpumem 5.62   reserved 7.59   augment 0.063
# tick 32    kimg 128.0    time 9h 24m 29s   sec/tick 835.6   sec/kimg 208.90  maintenance 0.1    cpumem 3.66   gpumem 5.62   reserved 7.59   augment 0.067
# tick 33    kimg 132.0    time 9h 38m 25s   sec/tick 835.3   sec/kimg 208.83  maintenance 0.3    cpumem 3.55   gpumem 5.62   reserved 7.59   augment 0.070
# tick 34    kimg 136.0    time 9h 52m 20s   sec/tick 835.4   sec/kimg 208.85  maintenance 0.1    cpumem 3.55   gpumem 5.61   reserved 7.59   augment 0.072
# tick 35    kimg 140.0    time 10h 06m 25s  sec/tick 844.9   sec/kimg 211.22  maintenance 0.1    cpumem 3.55   gpumem 5.67   reserved 7.59   augment 0.076
# tick 36    kimg 144.0    time 10h 20m 20s  sec/tick 834.6   sec/kimg 208.66  maintenance 0.1    cpumem 3.49   gpumem 5.63   reserved 7.59   augment 0.079
# tick 37    kimg 148.0    time 10h 34m 15s  sec/tick 834.3   sec/kimg 208.59  maintenance 0.3    cpumem 3.49   gpumem 5.61   reserved 7.59   augment 0.081
# tick 38    kimg 152.0    time 10h 48m 10s  sec/tick 835.3   sec/kimg 208.81  maintenance 0.1    cpumem 3.49   gpumem 5.63   reserved 7.59   augment 0.084
# tick 39    kimg 156.0    time 11h 02m 06s  sec/tick 835.6   sec/kimg 208.90  maintenance 0.1    cpumem 3.49   gpumem 5.63   reserved 7.59   augment 0.088
# tick 40    kimg 160.0    time 11h 16m 02s  sec/tick 835.8   sec/kimg 208.94  maintenance 0.1    cpumem 3.49   gpumem 5.63   reserved 7.59   augment 0.092
# {"results": {"kid50k_full": 0.05463935434818268}, "metric": "kid50k_full", "total_time": 1803.5426895618439, "total_time_str": "30m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777803368.0703974}
# tick 41    kimg 164.0    time 12h 00m 34s  sec/tick 835.8   sec/kimg 208.95  maintenance 1837.2 cpumem 3.58   gpumem 5.62   reserved 7.59   augment 0.096
# tick 42    kimg 168.0    time 12h 14m 30s  sec/tick 835.4   sec/kimg 208.84  maintenance 0.1    cpumem 3.58   gpumem 5.64   reserved 7.59   augment 0.100
# tick 43    kimg 172.0    time 12h 28m 26s  sec/tick 835.6   sec/kimg 208.91  maintenance 0.1    cpumem 3.47   gpumem 5.63   reserved 7.59   augment 0.103
# tick 44    kimg 176.0    time 12h 42m 22s  sec/tick 835.6   sec/kimg 208.90  maintenance 0.1    cpumem 3.47   gpumem 5.62   reserved 7.59   augment 0.107
# tick 45    kimg 180.0    time 12h 56m 17s  sec/tick 835.4   sec/kimg 208.85  maintenance 0.3    cpumem 3.47   gpumem 5.62   reserved 7.59   augment 0.111
# tick 46    kimg 184.0    time 13h 10m 13s  sec/tick 835.7   sec/kimg 208.92  maintenance 0.1    cpumem 3.47   gpumem 5.63   reserved 7.59   augment 0.114
# tick 47    kimg 188.0    time 13h 24m 09s  sec/tick 836.0   sec/kimg 209.01  maintenance 0.1    cpumem 3.47   gpumem 5.63   reserved 7.59   augment 0.117
# tick 48    kimg 192.0    time 13h 38m 05s  sec/tick 835.6   sec/kimg 208.91  maintenance 0.1    cpumem 3.47   gpumem 5.62   reserved 7.59   augment 0.120
# tick 49    kimg 196.0    time 13h 52m 01s  sec/tick 835.4   sec/kimg 208.85  maintenance 0.3    cpumem 3.47   gpumem 5.63   reserved 7.59   augment 0.123
# tick 50    kimg 200.0    time 14h 05m 55s  sec/tick 834.2   sec/kimg 208.97  maintenance 0.1    cpumem 3.47   gpumem 5.64   reserved 7.59   augment 0.127
# {"results": {"kid50k_full": 0.08946623653173447}, "metric": "kid50k_full", "total_time": 1803.8542304039001, "total_time_str": "30m 04s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777813563.664052}
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9997227795604651
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "kid50k_full"
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 2m 29s       sec/tick 45.3    sec/kimg 5664.88 maintenance 103.7  cpumem 2.86   gpumem 6.05   reserved 6.80   augment 0.000
# {"results": {"kid50k_full": 0.6807088255882263}, "metric": "kid50k_full", "total_time": 1733.0289511680603, "total_time_str": "28m 53s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777815474.347667}
# tick 1     kimg 4.0      time 45m 25s      sec/tick 819.8   sec/kimg 204.94  maintenance 1756.2 cpumem 3.54   gpumem 5.59   reserved 7.45   augment 0.006
# tick 2     kimg 8.0      time 59m 05s      sec/tick 820.2   sec/kimg 205.04  maintenance 0.1    cpumem 3.46   gpumem 5.60   reserved 7.45   augment 0.013
# tick 3     kimg 12.0     time 1h 12m 53s   sec/tick 827.4   sec/kimg 206.85  maintenance 0.1    cpumem 3.46   gpumem 5.60   reserved 7.45   augment 0.020
# tick 4     kimg 16.0     time 1h 26m 33s   sec/tick 820.4   sec/kimg 205.10  maintenance 0.1    cpumem 3.46   gpumem 5.61   reserved 7.45   augment 0.027
# tick 5     kimg 20.0     time 1h 40m 14s   sec/tick 820.4   sec/kimg 205.10  maintenance 0.3    cpumem 3.46   gpumem 5.61   reserved 7.45   augment 0.032
# tick 6     kimg 24.0     time 1h 53m 55s   sec/tick 820.6   sec/kimg 205.14  maintenance 0.1    cpumem 3.46   gpumem 5.60   reserved 7.45   augment 0.038
# tick 7     kimg 28.0     time 2h 07m 35s   sec/tick 820.4   sec/kimg 205.11  maintenance 0.1    cpumem 3.46   gpumem 5.60   reserved 7.45   augment 0.042
# tick 8     kimg 32.0     time 2h 21m 16s   sec/tick 820.3   sec/kimg 205.09  maintenance 0.1    cpumem 3.46   gpumem 5.61   reserved 7.45   augment 0.046
# tick 9     kimg 36.0     time 2h 34m 57s   sec/tick 820.5   sec/kimg 205.13  maintenance 0.3    cpumem 3.46   gpumem 5.61   reserved 7.45   augment 0.051
# tick 10    kimg 40.0     time 2h 48m 37s   sec/tick 820.3   sec/kimg 205.08  maintenance 0.1    cpumem 3.46   gpumem 5.61   reserved 7.45   augment 0.055
# {"results": {"kid50k_full": 0.3321989178657532}, "metric": "kid50k_full", "total_time": 1782.104646205902, "total_time_str": "29m 42s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777825492.1316745}
# tick 11    kimg 44.0     time 3h 32m 23s   sec/tick 820.2   sec/kimg 205.06  maintenance 1806.0 cpumem 3.59   gpumem 5.62   reserved 7.45   augment 0.055
# tick 12    kimg 48.0     time 3h 46m 04s   sec/tick 820.9   sec/kimg 205.22  maintenance 0.1    cpumem 3.59   gpumem 5.63   reserved 7.45   augment 0.053
# tick 13    kimg 52.0     time 3h 59m 45s   sec/tick 820.3   sec/kimg 205.07  maintenance 0.3    cpumem 3.49   gpumem 5.61   reserved 7.45   augment 0.050
# tick 14    kimg 56.0     time 4h 13m 25s   sec/tick 820.5   sec/kimg 205.11  maintenance 0.1    cpumem 3.49   gpumem 5.60   reserved 7.45   augment 0.049
# tick 15    kimg 60.0     time 4h 27m 06s   sec/tick 820.6   sec/kimg 205.15  maintenance 0.1    cpumem 3.49   gpumem 5.61   reserved 7.45   augment 0.049
# tick 16    kimg 64.0     time 4h 40m 47s   sec/tick 820.7   sec/kimg 205.18  maintenance 0.1    cpumem 3.49   gpumem 5.61   reserved 7.45   augment 0.049
# tick 17    kimg 68.0     time 4h 54m 28s   sec/tick 820.5   sec/kimg 205.12  maintenance 0.3    cpumem 3.49   gpumem 5.60   reserved 7.45   augment 0.051
# tick 18    kimg 72.0     time 5h 08m 09s   sec/tick 820.7   sec/kimg 205.18  maintenance 0.1    cpumem 3.49   gpumem 5.61   reserved 7.45   augment 0.051
# tick 19    kimg 76.0     time 5h 21m 50s   sec/tick 820.8   sec/kimg 205.20  maintenance 0.1    cpumem 3.49   gpumem 5.60   reserved 7.45   augment 0.051
# tick 20    kimg 80.0     time 5h 35m 34s   sec/tick 824.7   sec/kimg 206.18  maintenance 0.1    cpumem 3.49   gpumem 5.61   reserved 7.45   augment 0.050
# {"results": {"kid50k_full": 0.14088936150074005}, "metric": "kid50k_full", "total_time": 1781.936142206192, "total_time_str": "29m 42s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777835515.2689679}
# tick 21    kimg 84.0     time 6h 19m 27s   sec/tick 821.0   sec/kimg 205.24  maintenance 1811.7 cpumem 2.87   gpumem 5.62   reserved 7.45   augment 0.052
# tick 22    kimg 88.0     time 6h 33m 08s   sec/tick 820.8   sec/kimg 205.20  maintenance 0.1    cpumem 2.87   gpumem 5.62   reserved 7.45   augment 0.053
# tick 23    kimg 92.0     time 6h 46m 49s   sec/tick 820.5   sec/kimg 205.12  maintenance 0.1    cpumem 2.77   gpumem 5.61   reserved 7.45   augment 0.055
# tick 24    kimg 96.0     time 7h 00m 30s   sec/tick 821.0   sec/kimg 205.26  maintenance 0.1    cpumem 2.77   gpumem 5.62   reserved 7.45   augment 0.057
# tick 25    kimg 100.0    time 7h 14m 11s   sec/tick 820.9   sec/kimg 205.23  maintenance 0.3    cpumem 2.77   gpumem 5.61   reserved 7.45   augment 0.057
# tick 26    kimg 104.0    time 7h 27m 56s   sec/tick 825.3   sec/kimg 206.33  maintenance 0.1    cpumem 2.77   gpumem 5.62   reserved 7.45   augment 0.057
# tick 27    kimg 108.0    time 7h 41m 37s   sec/tick 820.7   sec/kimg 205.18  maintenance 0.1    cpumem 2.65   gpumem 5.62   reserved 7.45   augment 0.059
# tick 28    kimg 112.0    time 7h 55m 18s   sec/tick 820.7   sec/kimg 205.17  maintenance 0.1    cpumem 2.65   gpumem 5.61   reserved 7.45   augment 0.062
# tick 29    kimg 116.0    time 8h 08m 58s   sec/tick 819.7   sec/kimg 204.92  maintenance 0.3    cpumem 2.65   gpumem 5.62   reserved 7.45   augment 0.069
# tick 30    kimg 120.0    time 8h 22m 37s   sec/tick 819.3   sec/kimg 204.82  maintenance 0.1    cpumem 2.65   gpumem 5.63   reserved 7.45   augment 0.076
# {"results": {"kid50k_full": 0.46520760655403137}, "metric": "kid50k_full", "total_time": 1780.5069885253906, "total_time_str": "29m 41s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777845525.905777}
# tick 31    kimg 124.0    time 9h 06m 16s   sec/tick 819.6   sec/kimg 204.90  maintenance 1799.2 cpumem 2.75   gpumem 5.62   reserved 7.45   augment 0.084
# tick 32    kimg 128.0    time 9h 19m 56s   sec/tick 820.0   sec/kimg 204.99  maintenance 0.1    cpumem 2.75   gpumem 5.63   reserved 7.45   augment 0.091
# tick 33    kimg 132.0    time 9h 33m 36s   sec/tick 819.8   sec/kimg 204.94  maintenance 0.3    cpumem 2.64   gpumem 5.62   reserved 7.45   augment 0.098
# tick 34    kimg 136.0    time 9h 47m 17s   sec/tick 820.3   sec/kimg 205.09  maintenance 0.1    cpumem 2.64   gpumem 5.62   reserved 7.45   augment 0.104
# tick 35    kimg 140.0    time 10h 00m 57s  sec/tick 820.2   sec/kimg 205.05  maintenance 0.1    cpumem 2.64   gpumem 5.67   reserved 7.45   augment 0.110
# tick 36    kimg 144.0    time 10h 14m 38s  sec/tick 820.6   sec/kimg 205.16  maintenance 0.1    cpumem 2.64   gpumem 5.63   reserved 7.45   augment 0.116
# tick 37    kimg 148.0    time 10h 28m 19s  sec/tick 820.5   sec/kimg 205.13  maintenance 0.3    cpumem 2.64   gpumem 5.62   reserved 7.45   augment 0.122
# tick 38    kimg 152.0    time 10h 42m 00s  sec/tick 820.6   sec/kimg 205.14  maintenance 0.1    cpumem 2.64   gpumem 5.62   reserved 7.45   augment 0.128
# tick 39    kimg 156.0    time 10h 55m 40s  sec/tick 820.3   sec/kimg 205.07  maintenance 0.1    cpumem 2.64   gpumem 5.63   reserved 7.45   augment 0.133
# tick 40    kimg 160.0    time 11h 09m 21s  sec/tick 820.9   sec/kimg 205.22  maintenance 0.1    cpumem 2.64   gpumem 5.65   reserved 7.45   augment 0.139
# {"results": {"kid50k_full": 0.2973174452781677}, "metric": "kid50k_full", "total_time": 1780.3670110702515, "total_time_str": "29m 40s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777855536.8038886}
# tick 41    kimg 164.0    time 11h 53m 07s  sec/tick 819.4   sec/kimg 204.85  maintenance 1806.7 cpumem 1.96   gpumem 5.62   reserved 7.45   augment 0.144
# tick 42    kimg 168.0    time 12h 06m 47s  sec/tick 819.5   sec/kimg 204.88  maintenance 0.1    cpumem 1.91   gpumem 5.64   reserved 7.45   augment 0.150
# tick 43    kimg 172.0    time 12h 20m 28s  sec/tick 821.0   sec/kimg 205.24  maintenance 0.1    cpumem 1.81   gpumem 5.63   reserved 7.45   augment 0.156
# tick 44    kimg 176.0    time 12h 34m 08s  sec/tick 820.3   sec/kimg 205.08  maintenance 0.1    cpumem 1.81   gpumem 5.63   reserved 7.45   augment 0.161
# tick 45    kimg 180.0    time 12h 47m 49s  sec/tick 820.7   sec/kimg 205.17  maintenance 0.3    cpumem 1.81   gpumem 5.65   reserved 7.45   augment 0.166
# tick 46    kimg 184.0    time 13h 01m 30s  sec/tick 820.3   sec/kimg 205.08  maintenance 0.1    cpumem 1.81   gpumem 5.63   reserved 7.45   augment 0.170
# tick 47    kimg 188.0    time 13h 15m 11s  sec/tick 820.9   sec/kimg 205.23  maintenance 0.1    cpumem 1.81   gpumem 5.63   reserved 7.45   augment 0.174
# tick 48    kimg 192.0    time 13h 28m 52s  sec/tick 820.8   sec/kimg 205.19  maintenance 0.1    cpumem 1.86   gpumem 5.62   reserved 7.45   augment 0.179
# tick 49    kimg 196.0    time 13h 42m 32s  sec/tick 820.5   sec/kimg 205.12  maintenance 0.3    cpumem 1.86   gpumem 5.63   reserved 7.45   augment 0.184
# tick 50    kimg 200.0    time 13h 56m 12s  sec/tick 819.0   sec/kimg 205.16  maintenance 0.1    cpumem 1.86   gpumem 5.64   reserved 7.45   augment 0.189
# {"results": {"kid50k_full": 0.26182717084884644}, "metric": "kid50k_full", "total_time": 1780.2910482883453, "total_time_str": "29m 40s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777865549.0677395}
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9997227795604651
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "kid50k_full"
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 2m 27s       sec/tick 44.5    sec/kimg 5568.01 maintenance 102.3  cpumem 2.88   gpumem 6.05   reserved 6.86   augment 0.000
# {"results": {"kid50k_full": 0.6757429838180542}, "metric": "kid50k_full", "total_time": 1749.0538477897644, "total_time_str": "29m 09s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777867473.7234821}
# tick 1     kimg 4.0      time 45m 11s      sec/tick 792.3   sec/kimg 198.07  maintenance 1772.0 cpumem 3.17   gpumem 5.59   reserved 7.04   augment 0.006
# tick 2     kimg 8.0      time 58m 21s      sec/tick 789.8   sec/kimg 197.45  maintenance 0.1    cpumem 3.08   gpumem 5.59   reserved 7.04   augment 0.011
# tick 3     kimg 12.0     time 1h 11m 31s   sec/tick 790.0   sec/kimg 197.49  maintenance 0.1    cpumem 3.08   gpumem 5.60   reserved 7.04   augment 0.017
# tick 4     kimg 16.0     time 1h 24m 41s   sec/tick 790.1   sec/kimg 197.53  maintenance 0.1    cpumem 3.08   gpumem 5.60   reserved 7.04   augment 0.023
# tick 5     kimg 20.0     time 1h 37m 59s   sec/tick 797.5   sec/kimg 199.38  maintenance 0.3    cpumem 3.08   gpumem 5.61   reserved 7.04   augment 0.030
# tick 6     kimg 24.0     time 1h 51m 10s   sec/tick 790.3   sec/kimg 197.57  maintenance 0.1    cpumem 1.83   gpumem 5.60   reserved 7.04   augment 0.033
# tick 7     kimg 28.0     time 2h 04m 20s   sec/tick 789.9   sec/kimg 197.49  maintenance 0.1    cpumem 1.83   gpumem 5.60   reserved 7.04   augment 0.041
# tick 8     kimg 32.0     time 2h 17m 30s   sec/tick 790.2   sec/kimg 197.55  maintenance 0.1    cpumem 1.83   gpumem 5.61   reserved 7.04   augment 0.046
# tick 9     kimg 36.0     time 2h 30m 40s   sec/tick 790.1   sec/kimg 197.53  maintenance 0.3    cpumem 1.83   gpumem 5.61   reserved 7.04   augment 0.051
# tick 10    kimg 40.0     time 2h 43m 51s   sec/tick 790.0   sec/kimg 197.49  maintenance 0.1    cpumem 1.83   gpumem 5.61   reserved 7.04   augment 0.052
# {"results": {"kid50k_full": 0.5072435736656189}, "metric": "kid50k_full", "total_time": 1797.4174344539642, "total_time_str": "29m 57s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777877210.9922366}
# tick 11    kimg 44.0     time 3h 27m 27s   sec/tick 790.4   sec/kimg 197.60  maintenance 1825.5 cpumem 2.04   gpumem 5.60   reserved 7.04   augment 0.050
# tick 12    kimg 48.0     time 3h 40m 37s   sec/tick 790.5   sec/kimg 197.61  maintenance 0.1    cpumem 1.94   gpumem 5.63   reserved 7.04   augment 0.047
# tick 13    kimg 52.0     time 3h 53m 47s   sec/tick 789.9   sec/kimg 197.48  maintenance 0.1    cpumem 1.94   gpumem 5.61   reserved 7.04   augment 0.045
# tick 14    kimg 56.0     time 4h 07m 00s   sec/tick 792.4   sec/kimg 198.10  maintenance 0.1    cpumem 1.94   gpumem 5.60   reserved 7.04   augment 0.045
# tick 15    kimg 60.0     time 4h 20m 10s   sec/tick 790.3   sec/kimg 197.56  maintenance 0.1    cpumem 1.84   gpumem 5.61   reserved 7.04   augment 0.043
# tick 16    kimg 64.0     time 4h 33m 21s   sec/tick 790.9   sec/kimg 197.71  maintenance 0.1    cpumem 1.80   gpumem 5.61   reserved 7.04   augment 0.043
# tick 17    kimg 68.0     time 4h 46m 32s   sec/tick 790.4   sec/kimg 197.61  maintenance 0.3    cpumem 1.80   gpumem 5.60   reserved 7.04   augment 0.042
# tick 18    kimg 72.0     time 4h 59m 43s   sec/tick 791.0   sec/kimg 197.76  maintenance 0.1    cpumem 1.80   gpumem 5.60   reserved 7.04   augment 0.042
# tick 19    kimg 76.0     time 5h 12m 54s   sec/tick 790.5   sec/kimg 197.63  maintenance 0.1    cpumem 1.68   gpumem 5.60   reserved 7.04   augment 0.043
# tick 20    kimg 80.0     time 5h 26m 05s   sec/tick 791.0   sec/kimg 197.75  maintenance 0.1    cpumem 1.63   gpumem 5.61   reserved 7.04   augment 0.043
# {"results": {"kid50k_full": 0.18748599290847778}, "metric": "kid50k_full", "total_time": 1799.317917585373, "total_time_str": "29m 59s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777886946.446465}
# tick 21    kimg 84.0     time 6h 09m 42s   sec/tick 790.6   sec/kimg 197.64  maintenance 1826.8 cpumem 1.73   gpumem 5.62   reserved 7.04   augment 0.044
# tick 22    kimg 88.0     time 6h 22m 53s   sec/tick 790.7   sec/kimg 197.68  maintenance 0.1    cpumem 1.73   gpumem 5.60   reserved 7.04   augment 0.046
# tick 23    kimg 92.0     time 6h 36m 04s   sec/tick 790.8   sec/kimg 197.69  maintenance 0.1    cpumem 1.63   gpumem 5.61   reserved 7.04   augment 0.048
# tick 24    kimg 96.0     time 6h 49m 17s   sec/tick 793.4   sec/kimg 198.35  maintenance 0.1    cpumem 1.63   gpumem 5.61   reserved 7.04   augment 0.050
# tick 25    kimg 100.0    time 7h 02m 29s   sec/tick 791.0   sec/kimg 197.75  maintenance 0.3    cpumem 1.61   gpumem 5.61   reserved 7.04   augment 0.054
# tick 26    kimg 104.0    time 7h 15m 40s   sec/tick 791.2   sec/kimg 197.81  maintenance 0.1    cpumem 1.61   gpumem 5.62   reserved 7.04   augment 0.058
# tick 27    kimg 108.0    time 7h 28m 51s   sec/tick 791.1   sec/kimg 197.79  maintenance 0.1    cpumem 1.61   gpumem 5.62   reserved 7.04   augment 0.060
# tick 28    kimg 112.0    time 7h 42m 03s   sec/tick 791.3   sec/kimg 197.83  maintenance 0.1    cpumem 1.61   gpumem 5.61   reserved 7.04   augment 0.063
# tick 29    kimg 116.0    time 7h 55m 14s   sec/tick 791.1   sec/kimg 197.76  maintenance 0.3    cpumem 1.61   gpumem 5.62   reserved 7.04   augment 0.068
# tick 30    kimg 120.0    time 8h 08m 26s   sec/tick 791.2   sec/kimg 197.80  maintenance 0.1    cpumem 1.61   gpumem 5.62   reserved 7.04   augment 0.071
# {"results": {"kid50k_full": 0.16848880052566528}, "metric": "kid50k_full", "total_time": 1797.7848043441772, "total_time_str": "29m 58s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777896688.7466445}
# tick 31    kimg 124.0    time 8h 52m 04s   sec/tick 790.6   sec/kimg 197.65  maintenance 1828.3 cpumem 1.72   gpumem 5.62   reserved 7.04   augment 0.074
# tick 32    kimg 128.0    time 9h 05m 15s   sec/tick 790.5   sec/kimg 197.62  maintenance 0.1    cpumem 1.72   gpumem 5.62   reserved 7.04   augment 0.078
# tick 33    kimg 132.0    time 9h 18m 26s   sec/tick 790.6   sec/kimg 197.64  maintenance 0.3    cpumem 1.61   gpumem 5.62   reserved 7.04   augment 0.079
# tick 34    kimg 136.0    time 9h 31m 37s   sec/tick 790.5   sec/kimg 197.62  maintenance 0.1    cpumem 1.61   gpumem 5.61   reserved 7.04   augment 0.083
# tick 35    kimg 140.0    time 9h 44m 47s   sec/tick 790.8   sec/kimg 197.71  maintenance 0.1    cpumem 1.61   gpumem 5.67   reserved 7.04   augment 0.087
# tick 36    kimg 144.0    time 9h 57m 59s   sec/tick 791.0   sec/kimg 197.76  maintenance 0.1    cpumem 1.61   gpumem 5.63   reserved 7.04   augment 0.090
# tick 37    kimg 148.0    time 10h 11m 09s  sec/tick 790.5   sec/kimg 197.62  maintenance 0.1    cpumem 1.61   gpumem 5.61   reserved 7.04   augment 0.093
# tick 38    kimg 152.0    time 10h 24m 20s  sec/tick 790.9   sec/kimg 197.73  maintenance 0.1    cpumem 1.61   gpumem 5.62   reserved 7.04   augment 0.096
# tick 39    kimg 156.0    time 10h 37m 31s  sec/tick 790.5   sec/kimg 197.63  maintenance 0.1    cpumem 1.61   gpumem 5.63   reserved 7.04   augment 0.100
# tick 40    kimg 160.0    time 10h 50m 42s  sec/tick 791.2   sec/kimg 197.81  maintenance 0.1    cpumem 1.61   gpumem 5.63   reserved 7.04   augment 0.102
# {"results": {"kid50k_full": 0.11920690536499023}, "metric": "kid50k_full", "total_time": 1798.5372545719147, "total_time_str": "29m 59s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777906427.5523558}
# tick 41    kimg 164.0    time 11h 34m 28s  sec/tick 795.8   sec/kimg 198.94  maintenance 1830.3 cpumem 1.72   gpumem 5.62   reserved 7.04   augment 0.106
# tick 42    kimg 168.0    time 11h 47m 39s  sec/tick 790.5   sec/kimg 197.63  maintenance 0.1    cpumem 1.72   gpumem 5.64   reserved 7.04   augment 0.108
# tick 43    kimg 172.0    time 12h 00m 50s  sec/tick 790.4   sec/kimg 197.59  maintenance 0.1    cpumem 1.61   gpumem 5.63   reserved 7.04   augment 0.111
# tick 44    kimg 176.0    time 12h 14m 02s  sec/tick 792.2   sec/kimg 198.05  maintenance 0.1    cpumem 1.61   gpumem 5.62   reserved 7.04   augment 0.115
# tick 45    kimg 180.0    time 12h 27m 13s  sec/tick 790.5   sec/kimg 197.62  maintenance 0.3    cpumem 1.60   gpumem 5.62   reserved 7.04   augment 0.118
# tick 46    kimg 184.0    time 12h 40m 24s  sec/tick 791.5   sec/kimg 197.88  maintenance 0.1    cpumem 1.74   gpumem 5.63   reserved 7.04   augment 0.120
# tick 47    kimg 188.0    time 12h 53m 36s  sec/tick 791.2   sec/kimg 197.80  maintenance 0.1    cpumem 1.74   gpumem 5.62   reserved 7.04   augment 0.122
# tick 48    kimg 192.0    time 13h 06m 47s  sec/tick 791.3   sec/kimg 197.83  maintenance 0.1    cpumem 1.74   gpumem 5.62   reserved 7.04   augment 0.125
# tick 49    kimg 196.0    time 13h 19m 59s  sec/tick 791.7   sec/kimg 197.94  maintenance 0.3    cpumem 1.74   gpumem 5.63   reserved 7.04   augment 0.127
# tick 50    kimg 200.0    time 13h 33m 12s  sec/tick 792.2   sec/kimg 198.46  maintenance 0.1    cpumem 1.73   gpumem 5.64   reserved 7.04   augment 0.130
# {"results": {"kid50k_full": 0.1432780623435974}, "metric": "kid50k_full", "total_time": 1822.9270646572113, "total_time_str": "30m 23s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777916202.1292663}
#    fold_id                                            run_dir  \
# 0        1  checkpoints/25_train_stylegan3_make_images_dat...
# 1        2  checkpoints/25_train_stylegan3_make_images_dat...
# 2        3  checkpoints/25_train_stylegan3_make_images_dat...
# 3        4  checkpoints/25_train_stylegan3_make_images_dat...
# 4        5  checkpoints/25_train_stylegan3_make_images_dat...
#
#                                 latest_snapshot_path  train_duration_seconds
# 0  checkpoints/25_train_stylegan3_make_images_dat...                53150.28
# 1  checkpoints/25_train_stylegan3_make_images_dat...                51249.08
# 2  checkpoints/25_train_stylegan3_make_images_dat...                52599.79
# 3  checkpoints/25_train_stylegan3_make_images_dat...                51985.41
# 4  checkpoints/25_train_stylegan3_make_images_dat...                50652.78

# %%
# We read the online KID results from training and select the lowest-KID snapshot per fold.
kid_snapshot_rows = []
kid_rows = []
training_lookup = {int(row["fold_id"]): row for row in training_rows}

def parse_snapshot_kimg(snapshot_path: Path) -> int:
    return int(snapshot_path.stem.replace("network-snapshot-", ""))

def read_kid_values_by_snapshot(run_dir: Path):
    metric_file = run_dir / f"metric-{KID_METRIC_NAME}.jsonl"
    if not metric_file.exists():
        raise FileNotFoundError(f"Missing metric log: {metric_file}")

    kid_values = {}
    lines = [line for line in metric_file.read_text(encoding="utf-8").splitlines() if line.strip()]
    for line in lines:
        record = json.loads(line)
        if "results" not in record or "snapshot_pkl" not in record:
            continue
        kid_value = record["results"].get(KID_METRIC_NAME)
        if kid_value is None:
            continue
        kid_values[record["snapshot_pkl"]] = kid_value
    return kid_values

for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    run_dir = REPO_ROOT / training_lookup[fold_id]["run_dir"]
    candidate_snapshot_kimg = set(SNAPSHOT_SELECTION_KIMG)
    snapshot_paths = [
        path for path in sorted(run_dir.glob("network-snapshot-*.pkl"))
        if parse_snapshot_kimg(path) in candidate_snapshot_kimg
    ]
    if not snapshot_paths:
        raise FileNotFoundError(
            f"No snapshots from {SNAPSHOT_SELECTION_KIMG} kimg were found for fold {fold_id}"
        )
    kid_values = read_kid_values_by_snapshot(run_dir)

    fold_snapshot_rows = []
    for snapshot_path in snapshot_paths:
        kid_value = kid_values.get(snapshot_path.name)
        if kid_value is None:
            raise ValueError(
                f"No online KID value was found for fold {fold_id} at {snapshot_path.name}"
            )

        fold_snapshot_rows.append({
            "fold_id": fold_id,
            "snapshot_path": as_repo_relative(REPO_ROOT, snapshot_path),
            "snapshot_kimg": parse_snapshot_kimg(snapshot_path),
            "kid50k_full": kid_value,
        })

    kid_snapshot_rows.extend(fold_snapshot_rows)
    best_row = sorted(fold_snapshot_rows, key=lambda row: (row["kid50k_full"], row["snapshot_kimg"]))[0]
    kid_rows.append(best_row)

write_csv_rows(NOTEBOOK_RESULTS_DIR / "kid_snapshot_results.csv", kid_snapshot_rows, list(kid_snapshot_rows[0].keys()))
write_csv_rows(NOTEBOOK_RESULTS_DIR / "kid_results.csv", kid_rows, list(kid_rows[0].keys()))
kid_snapshot_df = pd.DataFrame(kid_snapshot_rows)
kid_df = pd.DataFrame(kid_rows)
display(kid_snapshot_df)
display(kid_df)

# This figure shows how KID moved across saved snapshots inside each fold.
fig, axis = plt.subplots(figsize=(9, 5))
for fold_id in sorted(kid_snapshot_df["fold_id"].unique()):
    current = kid_snapshot_df[kid_snapshot_df["fold_id"] == fold_id].sort_values("snapshot_kimg")
    axis.plot(current["snapshot_kimg"], current["kid50k_full"], marker="o", label=f"fold {fold_id}")
axis.set_xlabel("Snapshot kimg")
axis.set_ylabel("KID (lower is better)")
axis.set_title("KID progress by fold")
axis.legend()
fig.tight_layout()
fig.savefig(NOTEBOOK_RESULTS_DIR / "kid_progress_by_fold.png", dpi=200)
plt.show()
# Out:
#     fold_id                                      snapshot_path  snapshot_kimg  \
# 0         1  checkpoints/25_train_stylegan3_make_images_dat...             40
# 1         1  checkpoints/25_train_stylegan3_make_images_dat...             80
# 2         1  checkpoints/25_train_stylegan3_make_images_dat...            120
# 3         1  checkpoints/25_train_stylegan3_make_images_dat...            160
# 4         1  checkpoints/25_train_stylegan3_make_images_dat...            200
# 5         2  checkpoints/25_train_stylegan3_make_images_dat...             40
# 6         2  checkpoints/25_train_stylegan3_make_images_dat...             80
# 7         2  checkpoints/25_train_stylegan3_make_images_dat...            120
# 8         2  checkpoints/25_train_stylegan3_make_images_dat...            160
# 9         2  checkpoints/25_train_stylegan3_make_images_dat...            200
# 10        3  checkpoints/25_train_stylegan3_make_images_dat...             40
# 11        3  checkpoints/25_train_stylegan3_make_images_dat...             80
# 12        3  checkpoints/25_train_stylegan3_make_images_dat...            120
# 13        3  checkpoints/25_train_stylegan3_make_images_dat...            160
# 14        3  checkpoints/25_train_stylegan3_make_images_dat...            200
# 15        4  checkpoints/25_train_stylegan3_make_images_dat...             40
# 16        4  checkpoints/25_train_stylegan3_make_images_dat...             80
# 17        4  checkpoints/25_train_stylegan3_make_images_dat...            120
# 18        4  checkpoints/25_train_stylegan3_make_images_dat...            160
# 19        4  checkpoints/25_train_stylegan3_make_images_dat...            200
# 20        5  checkpoints/25_train_stylegan3_make_images_dat...             40
# 21        5  checkpoints/25_train_stylegan3_make_images_dat...             80
# 22        5  checkpoints/25_train_stylegan3_make_images_dat...            120
# 23        5  checkpoints/25_train_stylegan3_make_images_dat...            160
# 24        5  checkpoints/25_train_stylegan3_make_images_dat...            200
#
#     kid50k_full
# 0      0.439231
# 1      0.167092
# 2      0.158769
# 3      0.136144
# 4      0.121274
# 5      0.429544
# 6      0.118393
# 7      0.107375
# 8      0.034602
# 9      0.037712
# 10     0.343258
# 11     0.207809
# 12     0.111207
# 13     0.054639
# 14     0.089466
# 15     0.332199
# 16     0.140889
# 17     0.465208
# 18     0.297317
# 19     0.261827
# 20     0.507244
# 21     0.187486
# 22     0.168489
# 23     0.119207
# 24     0.143278
#    fold_id                                      snapshot_path  snapshot_kimg  \
# 0        1  checkpoints/25_train_stylegan3_make_images_dat...            200
# 1        2  checkpoints/25_train_stylegan3_make_images_dat...            160
# 2        3  checkpoints/25_train_stylegan3_make_images_dat...            160
# 3        4  checkpoints/25_train_stylegan3_make_images_dat...             80
# 4        5  checkpoints/25_train_stylegan3_make_images_dat...            160
#
#    kid50k_full
# 0     0.121274
# 1     0.034602
# 2     0.054639
# 3     0.140889
# 4     0.119207

# %%
# We generate exactly the number of synthetic minority images needed to balance each training fold.
kid_lookup = {int(row["fold_id"]): row for row in kid_rows}
generated_rows_256 = []

for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    snapshot_path = REPO_ROOT / kid_lookup[fold_id]["snapshot_path"]
    generated_256_dir = GAN_IMAGES_256_DIR / f"fold_{fold_id}"
    if generated_256_dir.exists():
        shutil.rmtree(generated_256_dir)
    generated_256_dir.mkdir(parents=True, exist_ok=True)

    needed_count = int(fold_plan["needed_gan_count_224"])
    start_seed = GENERATE_START_SEED + (fold_id * 10000)
    end_seed = start_seed + needed_count - 1
    seed_text = f"{start_seed}-{end_seed}"
    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    generate_log_path = fold_result_dir / "generate.log"

    report = run_command(
        build_stylegan_command(
            "gen_images.py",
            f"--network={snapshot_path}",
            f"--outdir={generated_256_dir}",
            f"--seeds={seed_text}",
            f"--noise-mode={GENERATE_NOISE_MODE}",
            "--trunc=1",
        ),
        STYLEGAN_DIR,
        live_log_path=generate_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=STYLEGAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "generate_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"StyleGAN3 generation failed for fold {fold_id}")

    generated_files = sorted(generated_256_dir.glob("seed*.png"))
    if len(generated_files) != needed_count:
        raise AssertionError(
            f"Fold {fold_id} should have {needed_count} generated 256 images, but found {len(generated_files)}."
        )

    for generated_file in generated_files:
        seed_value = int(generated_file.stem.replace("seed", ""))
        test_fold_ids = [value for value in FOLDS_TO_RUN if value != fold_id]
        test_fold_text = ",".join(str(value) for value in test_fold_ids)
        generated_rows_256.append({
            "dataset_name": "dataset2",
            "gan_image_id": f"fold{fold_id}_seed{seed_value}_256",
            "fold_id": fold_id,
            "round_id": fold_id,
            "train_fold_id": fold_id,
            "test_fold_ids": test_fold_text,
            "binary_label": 0,
            "binary_group": "cocci",
            "seed": seed_value,
            "image_size": GAN_PATCH_SIZE,
            "file_path": as_repo_relative(REPO_ROOT, generated_file),
            "snapshot_path": as_repo_relative(REPO_ROOT, snapshot_path),
            "source_type": "stylegan3_generated",
        })

write_csv_rows(MANIFESTS_DIR / "dataset2_stylegan3_generated_manifest_256.csv", generated_rows_256, list(generated_rows_256[0].keys()))
display(pd.DataFrame(generated_rows_256[:10]))
# Out:
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\25_train_stylegan3_make_images_dataset2\fold_1\00000-stylegan3-t-fold_1_minority_256-gpus1-batch8-gamma0.8192\network-snapshot-000200.pkl"...
# Generating image for seed 20000 (0/110) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 20001 (1/110) ...
# Generating image for seed 20002 (2/110) ...
# Generating image for seed 20003 (3/110) ...
# Generating image for seed 20004 (4/110) ...
# Generating image for seed 20005 (5/110) ...
# Generating image for seed 20006 (6/110) ...
# Generating image for seed 20007 (7/110) ...
# Generating image for seed 20008 (8/110) ...
# Generating image for seed 20009 (9/110) ...
# Generating image for seed 20010 (10/110) ...
# Generating image for seed 20011 (11/110) ...
# Generating image for seed 20012 (12/110) ...
# Generating image for seed 20013 (13/110) ...
# Generating image for seed 20014 (14/110) ...
# Generating image for seed 20015 (15/110) ...
# Generating image for seed 20016 (16/110) ...
# Generating image for seed 20017 (17/110) ...
# Generating image for seed 20018 (18/110) ...
# Generating image for seed 20019 (19/110) ...
# Generating image for seed 20020 (20/110) ...
# Generating image for seed 20021 (21/110) ...
# Generating image for seed 20022 (22/110) ...
# Generating image for seed 20023 (23/110) ...
# Generating image for seed 20024 (24/110) ...
# Generating image for seed 20025 (25/110) ...
# Generating image for seed 20026 (26/110) ...
# Generating image for seed 20027 (27/110) ...
# Generating image for seed 20028 (28/110) ...
# Generating image for seed 20029 (29/110) ...
# Generating image for seed 20030 (30/110) ...
# Generating image for seed 20031 (31/110) ...
# Generating image for seed 20032 (32/110) ...
# Generating image for seed 20033 (33/110) ...
# Generating image for seed 20034 (34/110) ...
# Generating image for seed 20035 (35/110) ...
# Generating image for seed 20036 (36/110) ...
# Generating image for seed 20037 (37/110) ...
# Generating image for seed 20038 (38/110) ...
# Generating image for seed 20039 (39/110) ...
# Generating image for seed 20040 (40/110) ...
# Generating image for seed 20041 (41/110) ...
# Generating image for seed 20042 (42/110) ...
# Generating image for seed 20043 (43/110) ...
# Generating image for seed 20044 (44/110) ...
# Generating image for seed 20045 (45/110) ...
# Generating image for seed 20046 (46/110) ...
# Generating image for seed 20047 (47/110) ...
# Generating image for seed 20048 (48/110) ...
# Generating image for seed 20049 (49/110) ...
# Generating image for seed 20050 (50/110) ...
# Generating image for seed 20051 (51/110) ...
# Generating image for seed 20052 (52/110) ...
# Generating image for seed 20053 (53/110) ...
# Generating image for seed 20054 (54/110) ...
# Generating image for seed 20055 (55/110) ...
# Generating image for seed 20056 (56/110) ...
# Generating image for seed 20057 (57/110) ...
# Generating image for seed 20058 (58/110) ...
# Generating image for seed 20059 (59/110) ...
# Generating image for seed 20060 (60/110) ...
# Generating image for seed 20061 (61/110) ...
# Generating image for seed 20062 (62/110) ...
# Generating image for seed 20063 (63/110) ...
# Generating image for seed 20064 (64/110) ...
# Generating image for seed 20065 (65/110) ...
# Generating image for seed 20066 (66/110) ...
# Generating image for seed 20067 (67/110) ...
# Generating image for seed 20068 (68/110) ...
# Generating image for seed 20069 (69/110) ...
# Generating image for seed 20070 (70/110) ...
# Generating image for seed 20071 (71/110) ...
# Generating image for seed 20072 (72/110) ...
# Generating image for seed 20073 (73/110) ...
# Generating image for seed 20074 (74/110) ...
# Generating image for seed 20075 (75/110) ...
# Generating image for seed 20076 (76/110) ...
# Generating image for seed 20077 (77/110) ...
# Generating image for seed 20078 (78/110) ...
# Generating image for seed 20079 (79/110) ...
# Generating image for seed 20080 (80/110) ...
# Generating image for seed 20081 (81/110) ...
# Generating image for seed 20082 (82/110) ...
# Generating image for seed 20083 (83/110) ...
# Generating image for seed 20084 (84/110) ...
# Generating image for seed 20085 (85/110) ...
# Generating image for seed 20086 (86/110) ...
# Generating image for seed 20087 (87/110) ...
# Generating image for seed 20088 (88/110) ...
# Generating image for seed 20089 (89/110) ...
# Generating image for seed 20090 (90/110) ...
# Generating image for seed 20091 (91/110) ...
# Generating image for seed 20092 (92/110) ...
# Generating image for seed 20093 (93/110) ...
# Generating image for seed 20094 (94/110) ...
# Generating image for seed 20095 (95/110) ...
# Generating image for seed 20096 (96/110) ...
# Generating image for seed 20097 (97/110) ...
# Generating image for seed 20098 (98/110) ...
# Generating image for seed 20099 (99/110) ...
# Generating image for seed 20100 (100/110) ...
# Generating image for seed 20101 (101/110) ...
# Generating image for seed 20102 (102/110) ...
# Generating image for seed 20103 (103/110) ...
# Generating image for seed 20104 (104/110) ...
# Generating image for seed 20105 (105/110) ...
# Generating image for seed 20106 (106/110) ...
# Generating image for seed 20107 (107/110) ...
# Generating image for seed 20108 (108/110) ...
# Generating image for seed 20109 (109/110) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\25_train_stylegan3_make_images_dataset2\fold_2\00000-stylegan3-t-fold_2_minority_256-gpus1-batch8-gamma0.8192\network-snapshot-000160.pkl"...
# Generating image for seed 30000 (0/149) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 30001 (1/149) ...
# Generating image for seed 30002 (2/149) ...
# Generating image for seed 30003 (3/149) ...
# Generating image for seed 30004 (4/149) ...
# Generating image for seed 30005 (5/149) ...
# Generating image for seed 30006 (6/149) ...
# Generating image for seed 30007 (7/149) ...
# Generating image for seed 30008 (8/149) ...
# Generating image for seed 30009 (9/149) ...
# Generating image for seed 30010 (10/149) ...
# Generating image for seed 30011 (11/149) ...
# Generating image for seed 30012 (12/149) ...
# Generating image for seed 30013 (13/149) ...
# Generating image for seed 30014 (14/149) ...
# Generating image for seed 30015 (15/149) ...
# Generating image for seed 30016 (16/149) ...
# Generating image for seed 30017 (17/149) ...
# Generating image for seed 30018 (18/149) ...
# Generating image for seed 30019 (19/149) ...
# Generating image for seed 30020 (20/149) ...
# Generating image for seed 30021 (21/149) ...
# Generating image for seed 30022 (22/149) ...
# Generating image for seed 30023 (23/149) ...
# Generating image for seed 30024 (24/149) ...
# Generating image for seed 30025 (25/149) ...
# Generating image for seed 30026 (26/149) ...
# Generating image for seed 30027 (27/149) ...
# Generating image for seed 30028 (28/149) ...
# Generating image for seed 30029 (29/149) ...
# Generating image for seed 30030 (30/149) ...
# Generating image for seed 30031 (31/149) ...
# Generating image for seed 30032 (32/149) ...
# Generating image for seed 30033 (33/149) ...
# Generating image for seed 30034 (34/149) ...
# Generating image for seed 30035 (35/149) ...
# Generating image for seed 30036 (36/149) ...
# Generating image for seed 30037 (37/149) ...
# Generating image for seed 30038 (38/149) ...
# Generating image for seed 30039 (39/149) ...
# Generating image for seed 30040 (40/149) ...
# Generating image for seed 30041 (41/149) ...
# Generating image for seed 30042 (42/149) ...
# Generating image for seed 30043 (43/149) ...
# Generating image for seed 30044 (44/149) ...
# Generating image for seed 30045 (45/149) ...
# Generating image for seed 30046 (46/149) ...
# Generating image for seed 30047 (47/149) ...
# Generating image for seed 30048 (48/149) ...
# Generating image for seed 30049 (49/149) ...
# Generating image for seed 30050 (50/149) ...
# Generating image for seed 30051 (51/149) ...
# Generating image for seed 30052 (52/149) ...
# Generating image for seed 30053 (53/149) ...
# Generating image for seed 30054 (54/149) ...
# Generating image for seed 30055 (55/149) ...
# Generating image for seed 30056 (56/149) ...
# Generating image for seed 30057 (57/149) ...
# Generating image for seed 30058 (58/149) ...
# Generating image for seed 30059 (59/149) ...
# Generating image for seed 30060 (60/149) ...
# Generating image for seed 30061 (61/149) ...
# Generating image for seed 30062 (62/149) ...
# Generating image for seed 30063 (63/149) ...
# Generating image for seed 30064 (64/149) ...
# Generating image for seed 30065 (65/149) ...
# Generating image for seed 30066 (66/149) ...
# Generating image for seed 30067 (67/149) ...
# Generating image for seed 30068 (68/149) ...
# Generating image for seed 30069 (69/149) ...
# Generating image for seed 30070 (70/149) ...
# Generating image for seed 30071 (71/149) ...
# Generating image for seed 30072 (72/149) ...
# Generating image for seed 30073 (73/149) ...
# Generating image for seed 30074 (74/149) ...
# Generating image for seed 30075 (75/149) ...
# Generating image for seed 30076 (76/149) ...
# Generating image for seed 30077 (77/149) ...
# Generating image for seed 30078 (78/149) ...
# Generating image for seed 30079 (79/149) ...
# Generating image for seed 30080 (80/149) ...
# Generating image for seed 30081 (81/149) ...
# Generating image for seed 30082 (82/149) ...
# Generating image for seed 30083 (83/149) ...
# Generating image for seed 30084 (84/149) ...
# Generating image for seed 30085 (85/149) ...
# Generating image for seed 30086 (86/149) ...
# Generating image for seed 30087 (87/149) ...
# Generating image for seed 30088 (88/149) ...
# Generating image for seed 30089 (89/149) ...
# Generating image for seed 30090 (90/149) ...
# Generating image for seed 30091 (91/149) ...
# Generating image for seed 30092 (92/149) ...
# Generating image for seed 30093 (93/149) ...
# Generating image for seed 30094 (94/149) ...
# Generating image for seed 30095 (95/149) ...
# Generating image for seed 30096 (96/149) ...
# Generating image for seed 30097 (97/149) ...
# Generating image for seed 30098 (98/149) ...
# Generating image for seed 30099 (99/149) ...
# Generating image for seed 30100 (100/149) ...
# Generating image for seed 30101 (101/149) ...
# Generating image for seed 30102 (102/149) ...
# Generating image for seed 30103 (103/149) ...
# Generating image for seed 30104 (104/149) ...
# Generating image for seed 30105 (105/149) ...
# Generating image for seed 30106 (106/149) ...
# Generating image for seed 30107 (107/149) ...
# Generating image for seed 30108 (108/149) ...
# Generating image for seed 30109 (109/149) ...
# Generating image for seed 30110 (110/149) ...
# Generating image for seed 30111 (111/149) ...
# Generating image for seed 30112 (112/149) ...
# Generating image for seed 30113 (113/149) ...
# Generating image for seed 30114 (114/149) ...
# Generating image for seed 30115 (115/149) ...
# Generating image for seed 30116 (116/149) ...
# Generating image for seed 30117 (117/149) ...
# Generating image for seed 30118 (118/149) ...
# Generating image for seed 30119 (119/149) ...
# Generating image for seed 30120 (120/149) ...
# Generating image for seed 30121 (121/149) ...
# Generating image for seed 30122 (122/149) ...
# Generating image for seed 30123 (123/149) ...
# Generating image for seed 30124 (124/149) ...
# Generating image for seed 30125 (125/149) ...
# Generating image for seed 30126 (126/149) ...
# Generating image for seed 30127 (127/149) ...
# Generating image for seed 30128 (128/149) ...
# Generating image for seed 30129 (129/149) ...
# Generating image for seed 30130 (130/149) ...
# Generating image for seed 30131 (131/149) ...
# Generating image for seed 30132 (132/149) ...
# Generating image for seed 30133 (133/149) ...
# Generating image for seed 30134 (134/149) ...
# Generating image for seed 30135 (135/149) ...
# Generating image for seed 30136 (136/149) ...
# Generating image for seed 30137 (137/149) ...
# Generating image for seed 30138 (138/149) ...
# Generating image for seed 30139 (139/149) ...
# Generating image for seed 30140 (140/149) ...
# Generating image for seed 30141 (141/149) ...
# Generating image for seed 30142 (142/149) ...
# Generating image for seed 30143 (143/149) ...
# Generating image for seed 30144 (144/149) ...
# Generating image for seed 30145 (145/149) ...
# Generating image for seed 30146 (146/149) ...
# Generating image for seed 30147 (147/149) ...
# Generating image for seed 30148 (148/149) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\25_train_stylegan3_make_images_dataset2\fold_3\00000-stylegan3-t-fold_3_minority_256-gpus1-batch8-gamma0.8192\network-snapshot-000160.pkl"...
# Generating image for seed 40000 (0/90) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 40001 (1/90) ...
# Generating image for seed 40002 (2/90) ...
# Generating image for seed 40003 (3/90) ...
# Generating image for seed 40004 (4/90) ...
# Generating image for seed 40005 (5/90) ...
# Generating image for seed 40006 (6/90) ...
# Generating image for seed 40007 (7/90) ...
# Generating image for seed 40008 (8/90) ...
# Generating image for seed 40009 (9/90) ...
# Generating image for seed 40010 (10/90) ...
# Generating image for seed 40011 (11/90) ...
# Generating image for seed 40012 (12/90) ...
# Generating image for seed 40013 (13/90) ...
# Generating image for seed 40014 (14/90) ...
# Generating image for seed 40015 (15/90) ...
# Generating image for seed 40016 (16/90) ...
# Generating image for seed 40017 (17/90) ...
# Generating image for seed 40018 (18/90) ...
# Generating image for seed 40019 (19/90) ...
# Generating image for seed 40020 (20/90) ...
# Generating image for seed 40021 (21/90) ...
# Generating image for seed 40022 (22/90) ...
# Generating image for seed 40023 (23/90) ...
# Generating image for seed 40024 (24/90) ...
# Generating image for seed 40025 (25/90) ...
# Generating image for seed 40026 (26/90) ...
# Generating image for seed 40027 (27/90) ...
# Generating image for seed 40028 (28/90) ...
# Generating image for seed 40029 (29/90) ...
# Generating image for seed 40030 (30/90) ...
# Generating image for seed 40031 (31/90) ...
# Generating image for seed 40032 (32/90) ...
# Generating image for seed 40033 (33/90) ...
# Generating image for seed 40034 (34/90) ...
# Generating image for seed 40035 (35/90) ...
# Generating image for seed 40036 (36/90) ...
# Generating image for seed 40037 (37/90) ...
# Generating image for seed 40038 (38/90) ...
# Generating image for seed 40039 (39/90) ...
# Generating image for seed 40040 (40/90) ...
# Generating image for seed 40041 (41/90) ...
# Generating image for seed 40042 (42/90) ...
# Generating image for seed 40043 (43/90) ...
# Generating image for seed 40044 (44/90) ...
# Generating image for seed 40045 (45/90) ...
# Generating image for seed 40046 (46/90) ...
# Generating image for seed 40047 (47/90) ...
# Generating image for seed 40048 (48/90) ...
# Generating image for seed 40049 (49/90) ...
# Generating image for seed 40050 (50/90) ...
# Generating image for seed 40051 (51/90) ...
# Generating image for seed 40052 (52/90) ...
# Generating image for seed 40053 (53/90) ...
# Generating image for seed 40054 (54/90) ...
# Generating image for seed 40055 (55/90) ...
# Generating image for seed 40056 (56/90) ...
# Generating image for seed 40057 (57/90) ...
# Generating image for seed 40058 (58/90) ...
# Generating image for seed 40059 (59/90) ...
# Generating image for seed 40060 (60/90) ...
# Generating image for seed 40061 (61/90) ...
# Generating image for seed 40062 (62/90) ...
# Generating image for seed 40063 (63/90) ...
# Generating image for seed 40064 (64/90) ...
# Generating image for seed 40065 (65/90) ...
# Generating image for seed 40066 (66/90) ...
# Generating image for seed 40067 (67/90) ...
# Generating image for seed 40068 (68/90) ...
# Generating image for seed 40069 (69/90) ...
# Generating image for seed 40070 (70/90) ...
# Generating image for seed 40071 (71/90) ...
# Generating image for seed 40072 (72/90) ...
# Generating image for seed 40073 (73/90) ...
# Generating image for seed 40074 (74/90) ...
# Generating image for seed 40075 (75/90) ...
# Generating image for seed 40076 (76/90) ...
# Generating image for seed 40077 (77/90) ...
# Generating image for seed 40078 (78/90) ...
# Generating image for seed 40079 (79/90) ...
# Generating image for seed 40080 (80/90) ...
# Generating image for seed 40081 (81/90) ...
# Generating image for seed 40082 (82/90) ...
# Generating image for seed 40083 (83/90) ...
# Generating image for seed 40084 (84/90) ...
# Generating image for seed 40085 (85/90) ...
# Generating image for seed 40086 (86/90) ...
# Generating image for seed 40087 (87/90) ...
# Generating image for seed 40088 (88/90) ...
# Generating image for seed 40089 (89/90) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\25_train_stylegan3_make_images_dataset2\fold_4\00000-stylegan3-t-fold_4_minority_256-gpus1-batch8-gamma0.8192\network-snapshot-000080.pkl"...
# Generating image for seed 50000 (0/119) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 50001 (1/119) ...
# Generating image for seed 50002 (2/119) ...
# Generating image for seed 50003 (3/119) ...
# Generating image for seed 50004 (4/119) ...
# Generating image for seed 50005 (5/119) ...
# Generating image for seed 50006 (6/119) ...
# Generating image for seed 50007 (7/119) ...
# Generating image for seed 50008 (8/119) ...
# Generating image for seed 50009 (9/119) ...
# Generating image for seed 50010 (10/119) ...
# Generating image for seed 50011 (11/119) ...
# Generating image for seed 50012 (12/119) ...
# Generating image for seed 50013 (13/119) ...
# Generating image for seed 50014 (14/119) ...
# Generating image for seed 50015 (15/119) ...
# Generating image for seed 50016 (16/119) ...
# Generating image for seed 50017 (17/119) ...
# Generating image for seed 50018 (18/119) ...
# Generating image for seed 50019 (19/119) ...
# Generating image for seed 50020 (20/119) ...
# Generating image for seed 50021 (21/119) ...
# Generating image for seed 50022 (22/119) ...
# Generating image for seed 50023 (23/119) ...
# Generating image for seed 50024 (24/119) ...
# Generating image for seed 50025 (25/119) ...
# Generating image for seed 50026 (26/119) ...
# Generating image for seed 50027 (27/119) ...
# Generating image for seed 50028 (28/119) ...
# Generating image for seed 50029 (29/119) ...
# Generating image for seed 50030 (30/119) ...
# Generating image for seed 50031 (31/119) ...
# Generating image for seed 50032 (32/119) ...
# Generating image for seed 50033 (33/119) ...
# Generating image for seed 50034 (34/119) ...
# Generating image for seed 50035 (35/119) ...
# Generating image for seed 50036 (36/119) ...
# Generating image for seed 50037 (37/119) ...
# Generating image for seed 50038 (38/119) ...
# Generating image for seed 50039 (39/119) ...
# Generating image for seed 50040 (40/119) ...
# Generating image for seed 50041 (41/119) ...
# Generating image for seed 50042 (42/119) ...
# Generating image for seed 50043 (43/119) ...
# Generating image for seed 50044 (44/119) ...
# Generating image for seed 50045 (45/119) ...
# Generating image for seed 50046 (46/119) ...
# Generating image for seed 50047 (47/119) ...
# Generating image for seed 50048 (48/119) ...
# Generating image for seed 50049 (49/119) ...
# Generating image for seed 50050 (50/119) ...
# Generating image for seed 50051 (51/119) ...
# Generating image for seed 50052 (52/119) ...
# Generating image for seed 50053 (53/119) ...
# Generating image for seed 50054 (54/119) ...
# Generating image for seed 50055 (55/119) ...
# Generating image for seed 50056 (56/119) ...
# Generating image for seed 50057 (57/119) ...
# Generating image for seed 50058 (58/119) ...
# Generating image for seed 50059 (59/119) ...
# Generating image for seed 50060 (60/119) ...
# Generating image for seed 50061 (61/119) ...
# Generating image for seed 50062 (62/119) ...
# Generating image for seed 50063 (63/119) ...
# Generating image for seed 50064 (64/119) ...
# Generating image for seed 50065 (65/119) ...
# Generating image for seed 50066 (66/119) ...
# Generating image for seed 50067 (67/119) ...
# Generating image for seed 50068 (68/119) ...
# Generating image for seed 50069 (69/119) ...
# Generating image for seed 50070 (70/119) ...
# Generating image for seed 50071 (71/119) ...
# Generating image for seed 50072 (72/119) ...
# Generating image for seed 50073 (73/119) ...
# Generating image for seed 50074 (74/119) ...
# Generating image for seed 50075 (75/119) ...
# Generating image for seed 50076 (76/119) ...
# Generating image for seed 50077 (77/119) ...
# Generating image for seed 50078 (78/119) ...
# Generating image for seed 50079 (79/119) ...
# Generating image for seed 50080 (80/119) ...
# Generating image for seed 50081 (81/119) ...
# Generating image for seed 50082 (82/119) ...
# Generating image for seed 50083 (83/119) ...
# Generating image for seed 50084 (84/119) ...
# Generating image for seed 50085 (85/119) ...
# Generating image for seed 50086 (86/119) ...
# Generating image for seed 50087 (87/119) ...
# Generating image for seed 50088 (88/119) ...
# Generating image for seed 50089 (89/119) ...
# Generating image for seed 50090 (90/119) ...
# Generating image for seed 50091 (91/119) ...
# Generating image for seed 50092 (92/119) ...
# Generating image for seed 50093 (93/119) ...
# Generating image for seed 50094 (94/119) ...
# Generating image for seed 50095 (95/119) ...
# Generating image for seed 50096 (96/119) ...
# Generating image for seed 50097 (97/119) ...
# Generating image for seed 50098 (98/119) ...
# Generating image for seed 50099 (99/119) ...
# Generating image for seed 50100 (100/119) ...
# Generating image for seed 50101 (101/119) ...
# Generating image for seed 50102 (102/119) ...
# Generating image for seed 50103 (103/119) ...
# Generating image for seed 50104 (104/119) ...
# Generating image for seed 50105 (105/119) ...
# Generating image for seed 50106 (106/119) ...
# Generating image for seed 50107 (107/119) ...
# Generating image for seed 50108 (108/119) ...
# Generating image for seed 50109 (109/119) ...
# Generating image for seed 50110 (110/119) ...
# Generating image for seed 50111 (111/119) ...
# Generating image for seed 50112 (112/119) ...
# Generating image for seed 50113 (113/119) ...
# Generating image for seed 50114 (114/119) ...
# Generating image for seed 50115 (115/119) ...
# Generating image for seed 50116 (116/119) ...
# Generating image for seed 50117 (117/119) ...
# Generating image for seed 50118 (118/119) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\25_train_stylegan3_make_images_dataset2\fold_5\00000-stylegan3-t-fold_5_minority_256-gpus1-batch8-gamma0.8192\network-snapshot-000160.pkl"...
# Generating image for seed 60000 (0/137) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 60001 (1/137) ...
# Generating image for seed 60002 (2/137) ...
# Generating image for seed 60003 (3/137) ...
# Generating image for seed 60004 (4/137) ...
# Generating image for seed 60005 (5/137) ...
# Generating image for seed 60006 (6/137) ...
# Generating image for seed 60007 (7/137) ...
# Generating image for seed 60008 (8/137) ...
# Generating image for seed 60009 (9/137) ...
# Generating image for seed 60010 (10/137) ...
# Generating image for seed 60011 (11/137) ...
# Generating image for seed 60012 (12/137) ...
# Generating image for seed 60013 (13/137) ...
# Generating image for seed 60014 (14/137) ...
# Generating image for seed 60015 (15/137) ...
# Generating image for seed 60016 (16/137) ...
# Generating image for seed 60017 (17/137) ...
# Generating image for seed 60018 (18/137) ...
# Generating image for seed 60019 (19/137) ...
# Generating image for seed 60020 (20/137) ...
# Generating image for seed 60021 (21/137) ...
# Generating image for seed 60022 (22/137) ...
# Generating image for seed 60023 (23/137) ...
# Generating image for seed 60024 (24/137) ...
# Generating image for seed 60025 (25/137) ...
# Generating image for seed 60026 (26/137) ...
# Generating image for seed 60027 (27/137) ...
# Generating image for seed 60028 (28/137) ...
# Generating image for seed 60029 (29/137) ...
# Generating image for seed 60030 (30/137) ...
# Generating image for seed 60031 (31/137) ...
# Generating image for seed 60032 (32/137) ...
# Generating image for seed 60033 (33/137) ...
# Generating image for seed 60034 (34/137) ...
# Generating image for seed 60035 (35/137) ...
# Generating image for seed 60036 (36/137) ...
# Generating image for seed 60037 (37/137) ...
# Generating image for seed 60038 (38/137) ...
# Generating image for seed 60039 (39/137) ...
# Generating image for seed 60040 (40/137) ...
# Generating image for seed 60041 (41/137) ...
# Generating image for seed 60042 (42/137) ...
# Generating image for seed 60043 (43/137) ...
# Generating image for seed 60044 (44/137) ...
# Generating image for seed 60045 (45/137) ...
# Generating image for seed 60046 (46/137) ...
# Generating image for seed 60047 (47/137) ...
# Generating image for seed 60048 (48/137) ...
# Generating image for seed 60049 (49/137) ...
# Generating image for seed 60050 (50/137) ...
# Generating image for seed 60051 (51/137) ...
# Generating image for seed 60052 (52/137) ...
# Generating image for seed 60053 (53/137) ...
# Generating image for seed 60054 (54/137) ...
# Generating image for seed 60055 (55/137) ...
# Generating image for seed 60056 (56/137) ...
# Generating image for seed 60057 (57/137) ...
# Generating image for seed 60058 (58/137) ...
# Generating image for seed 60059 (59/137) ...
# Generating image for seed 60060 (60/137) ...
# Generating image for seed 60061 (61/137) ...
# Generating image for seed 60062 (62/137) ...
# Generating image for seed 60063 (63/137) ...
# Generating image for seed 60064 (64/137) ...
# Generating image for seed 60065 (65/137) ...
# Generating image for seed 60066 (66/137) ...
# Generating image for seed 60067 (67/137) ...
# Generating image for seed 60068 (68/137) ...
# Generating image for seed 60069 (69/137) ...
# Generating image for seed 60070 (70/137) ...
# Generating image for seed 60071 (71/137) ...
# Generating image for seed 60072 (72/137) ...
# Generating image for seed 60073 (73/137) ...
# Generating image for seed 60074 (74/137) ...
# Generating image for seed 60075 (75/137) ...
# Generating image for seed 60076 (76/137) ...
# Generating image for seed 60077 (77/137) ...
# Generating image for seed 60078 (78/137) ...
# Generating image for seed 60079 (79/137) ...
# Generating image for seed 60080 (80/137) ...
# Generating image for seed 60081 (81/137) ...
# Generating image for seed 60082 (82/137) ...
# Generating image for seed 60083 (83/137) ...
# Generating image for seed 60084 (84/137) ...
# Generating image for seed 60085 (85/137) ...
# Generating image for seed 60086 (86/137) ...
# Generating image for seed 60087 (87/137) ...
# Generating image for seed 60088 (88/137) ...
# Generating image for seed 60089 (89/137) ...
# Generating image for seed 60090 (90/137) ...
# Generating image for seed 60091 (91/137) ...
# Generating image for seed 60092 (92/137) ...
# Generating image for seed 60093 (93/137) ...
# Generating image for seed 60094 (94/137) ...
# Generating image for seed 60095 (95/137) ...
# Generating image for seed 60096 (96/137) ...
# Generating image for seed 60097 (97/137) ...
# Generating image for seed 60098 (98/137) ...
# Generating image for seed 60099 (99/137) ...
# Generating image for seed 60100 (100/137) ...
# Generating image for seed 60101 (101/137) ...
# Generating image for seed 60102 (102/137) ...
# Generating image for seed 60103 (103/137) ...
# Generating image for seed 60104 (104/137) ...
# Generating image for seed 60105 (105/137) ...
# Generating image for seed 60106 (106/137) ...
# Generating image for seed 60107 (107/137) ...
# Generating image for seed 60108 (108/137) ...
# Generating image for seed 60109 (109/137) ...
# Generating image for seed 60110 (110/137) ...
# Generating image for seed 60111 (111/137) ...
# Generating image for seed 60112 (112/137) ...
# Generating image for seed 60113 (113/137) ...
# Generating image for seed 60114 (114/137) ...
# Generating image for seed 60115 (115/137) ...
# Generating image for seed 60116 (116/137) ...
# Generating image for seed 60117 (117/137) ...
# Generating image for seed 60118 (118/137) ...
# Generating image for seed 60119 (119/137) ...
# Generating image for seed 60120 (120/137) ...
# Generating image for seed 60121 (121/137) ...
# Generating image for seed 60122 (122/137) ...
# Generating image for seed 60123 (123/137) ...
# Generating image for seed 60124 (124/137) ...
# Generating image for seed 60125 (125/137) ...
# Generating image for seed 60126 (126/137) ...
# Generating image for seed 60127 (127/137) ...
# Generating image for seed 60128 (128/137) ...
# Generating image for seed 60129 (129/137) ...
# Generating image for seed 60130 (130/137) ...
# Generating image for seed 60131 (131/137) ...
# Generating image for seed 60132 (132/137) ...
# Generating image for seed 60133 (133/137) ...
# Generating image for seed 60134 (134/137) ...
# Generating image for seed 60135 (135/137) ...
# Generating image for seed 60136 (136/137) ...
#   dataset_name         gan_image_id  fold_id  round_id  train_fold_id  \
# 0     dataset2  fold1_seed20000_256        1         1              1
# 1     dataset2  fold1_seed20001_256        1         1              1
# 2     dataset2  fold1_seed20002_256        1         1              1
# 3     dataset2  fold1_seed20003_256        1         1              1
# 4     dataset2  fold1_seed20004_256        1         1              1
# 5     dataset2  fold1_seed20005_256        1         1              1
# 6     dataset2  fold1_seed20006_256        1         1              1
# 7     dataset2  fold1_seed20007_256        1         1              1
# 8     dataset2  fold1_seed20008_256        1         1              1
# 9     dataset2  fold1_seed20009_256        1         1              1
#
#   test_fold_ids  binary_label binary_group   seed  image_size  \
# 0       2,3,4,5             0        cocci  20000         256
# 1       2,3,4,5             0        cocci  20001         256
# 2       2,3,4,5             0        cocci  20002         256
# 3       2,3,4,5             0        cocci  20003         256
# 4       2,3,4,5             0        cocci  20004         256
# 5       2,3,4,5             0        cocci  20005         256
# 6       2,3,4,5             0        cocci  20006         256
# 7       2,3,4,5             0        cocci  20007         256
# 8       2,3,4,5             0        cocci  20008         256
# 9       2,3,4,5             0        cocci  20009         256
#
#                                            file_path  \
# 0  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 1  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 2  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 3  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 4  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 5  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 6  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 7  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 8  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 9  gan_images_256/stylegan3/dataset2/fold_1/seed2...
#
#                                        snapshot_path          source_type
# 0  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 1  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 2  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 3  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 4  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 5  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 6  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 7  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 8  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 9  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated

# %%
# We resize every generated image to the fixed 224x224 CNN input size.
generated_rows_224 = []
for row in generated_rows_256:
    fold_id = int(row["fold_id"])
    source_file = REPO_ROOT / row["file_path"]
    target_dir = GAN_IMAGES_224_DIR / f"fold_{fold_id}"
    target_dir.mkdir(parents=True, exist_ok=True)
    target_file = target_dir / source_file.name

    with Image.open(source_file) as image_handle:
        image = image_handle.convert("RGB")
        resized_image = image.resize((CNN_PATCH_SIZE, CNN_PATCH_SIZE), Image.Resampling.LANCZOS)
        resized_image.save(target_file)

    generated_rows_224.append({
        "dataset_name": row["dataset_name"],
        "gan_image_id": row["gan_image_id"].replace("_256", "_224"),
        "fold_id": row["fold_id"],
        "round_id": row["round_id"],
        "train_fold_id": row["train_fold_id"],
        "test_fold_ids": row["test_fold_ids"],
        "binary_label": row["binary_label"],
        "binary_group": row["binary_group"],
        "seed": row["seed"],
        "image_size": CNN_PATCH_SIZE,
        "file_path": as_repo_relative(REPO_ROOT, target_file),
        "source_file_256": row["file_path"],
        "snapshot_path": row["snapshot_path"],
        "source_type": row["source_type"],
    })

write_csv_rows(MANIFESTS_DIR / "dataset2_stylegan3_generated_manifest_224.csv", generated_rows_224, list(generated_rows_224[0].keys()))

summary = {
    "notebook_tag": NOTEBOOK_TAG,
    "seed": SEED,
    "stylegan_random_seed": STYLEGAN_RANDOM_SEED,
    "gan_patch_size": GAN_PATCH_SIZE,
    "cnn_patch_size": CNN_PATCH_SIZE,
    "gan_batch_size": GAN_BATCH_SIZE,
    "gan_workers": GAN_WORKERS,
    "gan_kimg": GAN_KIMG,
    "gan_mirror": GAN_MIRROR,
    "snap_ticks": SNAP_TICKS,
    "snapshot_selection_kimg": SNAPSHOT_SELECTION_KIMG,
    "ada_target": ADA_TARGET,
    "gan_cfg": GAN_CFG,
    "gan_aug": GAN_AUG,
    "gan_augpipe_reference": GAN_AUGPIPE_REFERENCE,
    "stylegan3_gamma": GAN_GAMMA,
    "kid_metric_name": KID_METRIC_NAME,
    "generated_manifest_256": as_repo_relative(REPO_ROOT, MANIFESTS_DIR / "dataset2_stylegan3_generated_manifest_256.csv"),
    "generated_manifest_224": as_repo_relative(REPO_ROOT, MANIFESTS_DIR / "dataset2_stylegan3_generated_manifest_224.csv"),
}
write_json(NOTEBOOK_RESULTS_DIR / "summary.json", summary)

fold_result_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    generated_count = sum(1 for row in generated_rows_224 if int(row["fold_id"]) == fold_id)
    fold_result_rows.append({
        "fold_id": fold_id,
        "needed_gan_count_224": int(fold_plan["needed_gan_count_224"]),
        "generated_count_224": generated_count,
        "selected_snapshot_kimg": int(kid_lookup[fold_id]["snapshot_kimg"]),
        "selected_kid50k_full": kid_lookup[fold_id]["kid50k_full"],
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "gan_summary_by_fold.csv", fold_result_rows, list(fold_result_rows[0].keys()))
display(pd.DataFrame(fold_result_rows))
display(pd.DataFrame(generated_rows_224[:10]))

# This preview helps us audit that the resized synthetic patches look sensible.
preview_rows = generated_rows_224[:8]
if preview_rows:
    figure_columns = min(4, len(preview_rows))
    figure_rows = math.ceil(len(preview_rows) / figure_columns)
    fig, axes = plt.subplots(figure_rows, figure_columns, figsize=(4 * figure_columns, 4 * figure_rows))
    if not isinstance(axes, (list, tuple)):
        axes = [axes]
    flat_axes = []
    for item in axes:
        if isinstance(item, (list, tuple)):
            flat_axes.extend(item)
        else:
            try:
                flat_axes.extend(item.flatten().tolist())
            except AttributeError:
                flat_axes.append(item)
    for axis, row in zip(flat_axes, preview_rows):
        image_path = REPO_ROOT / row["file_path"]
        with Image.open(image_path) as image_handle:
            axis.imshow(image_handle.convert("RGB"))
        axis.set_title(f"fold {row['fold_id']} | seed {row['seed']}")
        axis.axis("off")
    for axis in flat_axes[len(preview_rows):]:
        axis.axis("off")
    fig.tight_layout()
    fig.savefig(NOTEBOOK_RESULTS_DIR / "generated_preview_224.png", dpi=200)
    plt.show()
print(f"Saved generated 224 manifest to: {MANIFESTS_DIR / 'dataset2_stylegan3_generated_manifest_224.csv'}")
# Out:
#    fold_id  needed_gan_count_224  generated_count_224  selected_snapshot_kimg  \
# 0        1                   110                  110                     200
# 1        2                   149                  149                     160
# 2        3                    90                   90                     160
# 3        4                   119                  119                      80
# 4        5                   137                  137                     160
#
#    selected_kid50k_full
# 0              0.121274
# 1              0.034602
# 2              0.054639
# 3              0.140889
# 4              0.119207
#   dataset_name         gan_image_id  fold_id  round_id  train_fold_id  \
# 0     dataset2  fold1_seed20000_224        1         1              1
# 1     dataset2  fold1_seed20001_224        1         1              1
# 2     dataset2  fold1_seed20002_224        1         1              1
# 3     dataset2  fold1_seed20003_224        1         1              1
# 4     dataset2  fold1_seed20004_224        1         1              1
# 5     dataset2  fold1_seed20005_224        1         1              1
# 6     dataset2  fold1_seed20006_224        1         1              1
# 7     dataset2  fold1_seed20007_224        1         1              1
# 8     dataset2  fold1_seed20008_224        1         1              1
# 9     dataset2  fold1_seed20009_224        1         1              1
#
#   test_fold_ids  binary_label binary_group   seed  image_size  \
# 0       2,3,4,5             0        cocci  20000         224
# 1       2,3,4,5             0        cocci  20001         224
# 2       2,3,4,5             0        cocci  20002         224
# 3       2,3,4,5             0        cocci  20003         224
# 4       2,3,4,5             0        cocci  20004         224
# 5       2,3,4,5             0        cocci  20005         224
# 6       2,3,4,5             0        cocci  20006         224
# 7       2,3,4,5             0        cocci  20007         224
# 8       2,3,4,5             0        cocci  20008         224
# 9       2,3,4,5             0        cocci  20009         224
#
#                                            file_path  \
# 0  gan_images_224/stylegan3/dataset2/fold_1/seed2...
# 1  gan_images_224/stylegan3/dataset2/fold_1/seed2...
# 2  gan_images_224/stylegan3/dataset2/fold_1/seed2...
# 3  gan_images_224/stylegan3/dataset2/fold_1/seed2...
# 4  gan_images_224/stylegan3/dataset2/fold_1/seed2...
# 5  gan_images_224/stylegan3/dataset2/fold_1/seed2...
# 6  gan_images_224/stylegan3/dataset2/fold_1/seed2...
# 7  gan_images_224/stylegan3/dataset2/fold_1/seed2...
# 8  gan_images_224/stylegan3/dataset2/fold_1/seed2...
# 9  gan_images_224/stylegan3/dataset2/fold_1/seed2...
#
#                                      source_file_256  \
# 0  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 1  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 2  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 3  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 4  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 5  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 6  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 7  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 8  gan_images_256/stylegan3/dataset2/fold_1/seed2...
# 9  gan_images_256/stylegan3/dataset2/fold_1/seed2...
#
#                                        snapshot_path          source_type
# 0  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 1  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 2  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 3  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 4  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 5  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 6  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 7  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 8  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# 9  checkpoints/25_train_stylegan3_make_images_dat...  stylegan3_generated
# Saved generated 224 manifest to: C:\Users\FYP2610\Downloads\FYP2\manifests\dataset2_stylegan3_generated_manifest_224.csv
