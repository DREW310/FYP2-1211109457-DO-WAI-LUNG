# %% [markdown]
# # 24 Train StyleGAN3 Make Images DIBaS
#
# This notebook trains one StyleGAN3-T model per training fold, evaluates a fixed sparse set of snapshots, selects the lowest-KID trained snapshot in each fold, and generates the exact minority top-up needed for the second-GAN comparison.

# %% [markdown]
# ## Important Notes
#
# - Open Jupyter from `x64 Native Tools Command Prompt for VS 2022`.
# - Run the notebook itself in the main `fyp2` kernel so the normal notebook packages stay available.
# - Use the `fyp2` environment on the school Windows PC for StyleGAN3 because it matches the RTX 4060 CUDA setup.
# - Put the official NVIDIA StyleGAN3 repository in `third_party/stylegan3` before running this notebook.
# - This notebook keeps the GAN native resolution at `256x256`.
# - Every generated image is resized deterministically to `224x224` before any CNN notebooks use it.
# - Existing StyleGAN2-ADA outputs are not overwritten. StyleGAN3 images and manifests are saved with separate paths and names.
# - Snapshot comparison is fixed to `[40, 80, 120, 160, 200]` kimg so every fold uses the same candidate schedule.

# %%
from pathlib import Path
import csv
import json
import math
import os
import shutil
import subprocess
import sys
import time

import matplotlib.pyplot as plt

import pandas as pd

from IPython.display import display
from PIL import Image

# This helper keeps the notebook easy to run from the repo root or from notebooks/.
def find_repo_root(start_path: Path) -> Path:
    if (start_path / "raw_data").exists():
        return start_path
    if start_path.name == "notebooks" and (start_path.parent / "raw_data").exists():
        return start_path.parent
    raise FileNotFoundError("Could not find the FYP2 repo root.")

REPO_ROOT = find_repo_root(Path.cwd())
MANIFESTS_DIR = REPO_ROOT / "manifests"
RESULTS_DIR = REPO_ROOT / "results"
CHECKPOINTS_DIR = REPO_ROOT / "checkpoints"
GAN_PATCHES_DIR = REPO_ROOT / "gan_patches_256" / "dibas"
GAN_IMAGES_256_DIR = REPO_ROOT / "gan_images_256" / "stylegan3" / "dibas"
GAN_IMAGES_224_DIR = REPO_ROOT / "gan_images_224" / "stylegan3" / "dibas"
THIRD_PARTY_DIR = REPO_ROOT / "third_party"
STYLEGAN_DIR = THIRD_PARTY_DIR / "stylegan3"
NOTEBOOK_TAG = "24_train_stylegan3_make_images_dibas"
NOTEBOOK_RESULTS_DIR = RESULTS_DIR / NOTEBOOK_TAG
NOTEBOOK_CHECKPOINTS_DIR = CHECKPOINTS_DIR / NOTEBOOK_TAG
NOTEBOOK_RESULTS_DIR.mkdir(parents=True, exist_ok=True)
NOTEBOOK_CHECKPOINTS_DIR.mkdir(parents=True, exist_ok=True)
GAN_IMAGES_256_DIR.mkdir(parents=True, exist_ok=True)
GAN_IMAGES_224_DIR.mkdir(parents=True, exist_ok=True)

if not STYLEGAN_DIR.exists():
    raise FileNotFoundError(
        f"Missing StyleGAN3 folder: {STYLEGAN_DIR}. "
        "Clone the official NVIDIA StyleGAN3 repo into third_party/stylegan3 before running this notebook."
    )

SEED = 2026
STYLEGAN_RANDOM_SEED = 0
FOLDS_TO_RUN = [1, 2, 3, 4, 5]
GAN_PATCH_SIZE = 256
CNN_PATCH_SIZE = 224
GAN_BATCH_SIZE = 8
GAN_WORKERS = 3
GAN_KIMG = 200
# StyleGAN3 uses 4 kimg per tick, so snap=10 gives snapshots at 40, 80, 120, 160, and 200 kimg.
# We keep this sparse schedule fixed to reduce runtime and make the selection rule easy to audit.
SNAP_TICKS = 10
SNAPSHOT_SELECTION_KIMG = [40, 80, 120, 160, 200]
GAN_MIRROR = True
ADA_TARGET = 0.6
GAN_CFG = "stylegan3-t"
GAN_AUG = "ada"
GAN_AUGPIPE_REFERENCE = "color"
# StyleGAN3 official train.py does not expose --augpipe.
# The rest of the ADA setup stays aligned with the StyleGAN2-ADA runs.
GAN_GAMMA = 0.8192
KID_METRIC_NAME = "kid50k_full"
GENERATE_START_SEED = 10000
GENERATE_NOISE_MODE = "random"
LONG_COMMAND_NOTEBOOK_MODE = "smart"
KID_OPENMP_DUPLICATE_OK = True
STYLEGAN_WINDOWS_PYTHON = Path(r"C:\Users\FYP2610\anaconda3\envs\fyp2\python.exe")
STYLEGAN_TORCH_CUDA_ARCH_LIST = "8.0+PTX"
STYLEGAN_EXTENSIONS_DIR = CHECKPOINTS_DIR / "torch_extensions_stylegan3_sm80ptx"
STYLEGAN_EXTENSIONS_DIR.mkdir(parents=True, exist_ok=True)

if os.name == "nt":
    PYTHON_EXE = STYLEGAN_WINDOWS_PYTHON
    if not PYTHON_EXE.exists():
        raise FileNotFoundError(
            f"Could not find the StyleGAN Python executable on the Windows machine: {PYTHON_EXE}"
        )
    STYLEGAN_ENV_ROOT = PYTHON_EXE.parent
    CONDA_EXE = STYLEGAN_ENV_ROOT.parent.parent / "Scripts" / "conda.exe"
    if not CONDA_EXE.exists():
        raise FileNotFoundError(
            f"Could not find conda.exe on the Windows machine: {CONDA_EXE}"
        )
else:
    PYTHON_EXE = Path(sys.executable)
    STYLEGAN_ENV_ROOT = None
    CONDA_EXE = None

STYLEGAN_EXTRA_ENV = {
    "TORCH_CUDA_ARCH_LIST": STYLEGAN_TORCH_CUDA_ARCH_LIST,
    "TORCH_EXTENSIONS_DIR": str(STYLEGAN_EXTENSIONS_DIR),
}
if KID_OPENMP_DUPLICATE_OK:
    STYLEGAN_EXTRA_ENV["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# This helper ensures Windows subprocesses really run inside the StyleGAN conda env.
def build_stylegan_command(script_name: str, *script_args: str):
    if os.name == "nt":
        return [
            str(CONDA_EXE),
            "run",
            "--no-capture-output",
            "-p",
            str(STYLEGAN_ENV_ROOT),
            "python",
            script_name,
            *script_args,
        ]
    return [str(PYTHON_EXE), script_name, *script_args]

# %%
# This helper reads a CSV file into a plain list of rows.
def read_csv_rows(csv_path: Path):
    with csv_path.open("r", newline="", encoding="utf-8") as handle:
        return list(csv.DictReader(handle))

# This helper writes a CSV file with a stable header.
def write_csv_rows(csv_path: Path, rows, fieldnames):
    if not rows:
        raise ValueError(f"No rows were provided for {csv_path.name}.")
    csv_path.parent.mkdir(parents=True, exist_ok=True)
    with csv_path.open("w", newline="", encoding="utf-8") as handle:
        writer = csv.DictWriter(handle, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

# This helper writes one small JSON file with clean formatting.
def write_json(json_path: Path, data):
    json_path.parent.mkdir(parents=True, exist_ok=True)
    json_path.write_text(json.dumps(data, indent=2), encoding="utf-8")

# This helper stores paths in repo-relative form so the outputs stay portable.
def as_repo_relative(repo_root: Path, path_value: Path) -> str:
    return path_value.relative_to(repo_root).as_posix()

# This helper decides which command lines matter enough to echo in the notebook.
def should_echo_command_line(line_text: str, line_index: int, notebook_mode: str) -> bool:
    if notebook_mode == "all":
        return True
    if notebook_mode == "quiet":
        return False
    if line_index <= 20:
        return True
    lowered = line_text.lower()
    important_markers = [
        "training for",
        "tick ",
        "sec/kimg",
        "snapshot",
        "saved",
        "kid50k_full",
        "generating image for seed",
        "traceback",
        "runtimeerror",
        "error:",
    ]
    return any(marker in lowered for marker in important_markers)

# This helper runs a subprocess, streams useful lines to the notebook, and saves a log to disk.
def run_command(command_parts, workdir: Path, live_log_path: Path, notebook_mode: str = "smart", extra_env=None):
    live_log_path.parent.mkdir(parents=True, exist_ok=True)
    command_env = os.environ.copy()
    if extra_env is not None:
        command_env.update(extra_env)

    process = subprocess.Popen(
        command_parts,
        cwd=workdir,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        encoding="utf-8",
        errors="replace",
        env=command_env,
    )

    start_time = time.time()
    output_tail = []
    printed_line_count = 0
    suppressed_line_count = 0
    total_line_count = 0

    with live_log_path.open("w", encoding="utf-8") as log_handle:
        for line in process.stdout:
            total_line_count += 1
            output_tail.append(line)
            output_tail = output_tail[-200:]
            log_handle.write(line)
            log_handle.flush()

            line_text = line.rstrip()
            if should_echo_command_line(line_text, total_line_count, notebook_mode):
                print(line_text)
                printed_line_count += 1
            else:
                suppressed_line_count += 1

    returncode = process.wait()
    duration_seconds = round(time.time() - start_time, 2)
    report = {
        "command": " ".join(str(item) for item in command_parts),
        "returncode": returncode,
        "duration_seconds": duration_seconds,
        "printed_line_count": printed_line_count,
        "suppressed_line_count": suppressed_line_count,
        "total_line_count": total_line_count,
        "log_path": as_repo_relative(REPO_ROOT, live_log_path),
        "output_tail": "".join(output_tail),
    }
    return report

# %%
# We load the real patch manifest and compute the exact top-up target for each training fold.
real_patch_rows = read_csv_rows(MANIFESTS_DIR / "patch_manifest_224.csv")
gan_source_rows = read_csv_rows(MANIFESTS_DIR / "gan_patch_manifest_256.csv")
fold_manifest_rows = read_csv_rows(MANIFESTS_DIR / "fold_manifest.csv")

for row in real_patch_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])
for row in gan_source_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])
for row in fold_manifest_rows:
    row["fold_id"] = int(row["fold_id"])
    row["binary_label"] = int(row["binary_label"])

fold_plan_rows = []
for fold_id in FOLDS_TO_RUN:
    train_rows = [row for row in real_patch_rows if int(row["fold_id"]) == fold_id]
    gan_rows = [row for row in gan_source_rows if int(row["fold_id"]) == fold_id]
    train_cocci_count = sum(1 for row in train_rows if int(row["binary_label"]) == 0)
    train_bacilli_count = sum(1 for row in train_rows if int(row["binary_label"]) == 1)
    test_fold_ids = [value for value in FOLDS_TO_RUN if value != fold_id]
    test_fold_text = ",".join(str(value) for value in test_fold_ids)
    if train_cocci_count >= train_bacilli_count:
        raise AssertionError(
            f"Fold {fold_id} no longer has cocci as the minority class. "
            f"cocci={train_cocci_count}, bacilli={train_bacilli_count}"
        )
    needed_gan_count_224 = train_bacilli_count - train_cocci_count
    fold_plan_rows.append({
        "round_id": fold_id,
        "train_fold_id": fold_id,
        "test_fold_ids": test_fold_text,
        "real_train_patch_count_224": len(train_rows),
        "real_cocci_count_224": train_cocci_count,
        "real_bacilli_count_224": train_bacilli_count,
        "needed_gan_count_224": needed_gan_count_224,
        "real_cocci_patch_count_256_for_gan": len(gan_rows),
        "train_raw_sample_count": sum(1 for row in fold_manifest_rows if int(row["fold_id"]) == fold_id),
        "dataset_zip_path": as_repo_relative(REPO_ROOT, NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}" / f"fold_{fold_id}_minority_256.zip"),
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "fold_plan.csv", fold_plan_rows, list(fold_plan_rows[0].keys()))
display(pd.DataFrame(fold_plan_rows))
# Out:
#    round_id  train_fold_id test_fold_ids  real_train_patch_count_224  \
# 0         1              1       2,3,4,5                        1566
# 1         2              2       1,3,4,5                        1566
# 2         3              3       1,2,4,5                        1566
# 3         4              4       1,2,3,5                        1566
# 4         5              5       1,2,3,4                        1566
#
#    real_cocci_count_224  real_bacilli_count_224  needed_gan_count_224  \
# 0                   648                     918                   270
# 1                   648                     918                   270
# 2                   648                     918                   270
# 3                   648                     918                   270
# 4                   648                     918                   270
#
#    real_cocci_patch_count_256_for_gan  train_raw_sample_count  \
# 0                                 480                      29
# 1                                 480                      29
# 2                                 480                      29
# 3                                 480                      29
# 4                                 480                      29
#
#                                     dataset_zip_path
# 0  results/24_train_stylegan3_make_images_dibas/f...
# 1  results/24_train_stylegan3_make_images_dibas/f...
# 2  results/24_train_stylegan3_make_images_dibas/f...
# 3  results/24_train_stylegan3_make_images_dibas/f...
# 4  results/24_train_stylegan3_make_images_dibas/f...

# %%
# We create one StyleGAN zip file per training fold so each GAN only sees same-fold minority data.
dataset_zip_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    source_dir = GAN_PATCHES_DIR / f"fold_{fold_id}"
    if not source_dir.exists():
        raise FileNotFoundError(f"Missing GAN source folder for fold {fold_id}: {source_dir}")

    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    fold_result_dir.mkdir(parents=True, exist_ok=True)
    dataset_zip_path = REPO_ROOT / fold_plan["dataset_zip_path"]
    if dataset_zip_path.exists():
        dataset_zip_path.unlink()

    dataset_tool_log_path = fold_result_dir / "dataset_tool.log"
    report = run_command(
        build_stylegan_command(
            "dataset_tool.py",
            f"--source={source_dir}",
            f"--dest={dataset_zip_path}",
        ),
        STYLEGAN_DIR,
        live_log_path=dataset_tool_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=STYLEGAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "dataset_tool_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"dataset_tool.py failed for fold {fold_id}")

    dataset_zip_rows.append({
        "fold_id": fold_id,
        "source_dir": as_repo_relative(REPO_ROOT, source_dir),
        "dataset_zip_path": as_repo_relative(REPO_ROOT, dataset_zip_path),
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "dataset_zip_manifest.csv", dataset_zip_rows, list(dataset_zip_rows[0].keys()))
display(pd.DataFrame(dataset_zip_rows))
# Out:
#   0%|          | 0/480 [00:00<?, ?it/s]
#   5%|▌         | 25/480 [00:00<00:01, 243.10it/s]
#  11%|█         | 52/480 [00:00<00:01, 256.64it/s]
#  16%|█▋        | 79/480 [00:00<00:01, 260.54it/s]
#  22%|██▏       | 106/480 [00:00<00:01, 261.36it/s]
#  28%|██▊       | 133/480 [00:00<00:01, 261.15it/s]
#  33%|███▎      | 160/480 [00:00<00:01, 260.90it/s]
#  39%|███▉      | 187/480 [00:00<00:01, 260.06it/s]
#  45%|████▍     | 215/480 [00:00<00:01, 263.18it/s]
#  51%|█████     | 243/480 [00:00<00:00, 267.42it/s]
#  56%|█████▋    | 271/480 [00:01<00:00, 268.62it/s]
#  62%|██████▎   | 300/480 [00:01<00:00, 273.66it/s]
#  69%|██████▊   | 329/480 [00:01<00:00, 277.53it/s]
#  75%|███████▍  | 358/480 [00:01<00:00, 280.80it/s]
#  81%|████████  | 387/480 [00:01<00:00, 277.20it/s]
#  86%|████████▋ | 415/480 [00:01<00:00, 277.67it/s]
#  92%|█████████▏| 443/480 [00:01<00:00, 275.01it/s]
#  98%|█████████▊| 471/480 [00:01<00:00, 274.68it/s]
# 100%|██████████| 480/480 [00:01<00:00, 269.88it/s]
#
#   0%|          | 0/480 [00:00<?, ?it/s]
#   5%|▌         | 26/480 [00:00<00:01, 258.12it/s]
#  11%|█         | 53/480 [00:00<00:01, 263.54it/s]
#  17%|█▋        | 81/480 [00:00<00:01, 266.27it/s]
#  22%|██▎       | 108/480 [00:00<00:01, 264.63it/s]
#  28%|██▊       | 135/480 [00:00<00:01, 262.81it/s]
#  34%|███▍      | 162/480 [00:00<00:01, 262.39it/s]
#  39%|███▉      | 189/480 [00:00<00:01, 262.86it/s]
#  45%|████▌     | 216/480 [00:00<00:01, 261.82it/s]
#  51%|█████     | 244/480 [00:00<00:00, 264.17it/s]
#  56%|█████▋    | 271/480 [00:01<00:00, 264.47it/s]
#  62%|██████▏   | 298/480 [00:01<00:00, 259.13it/s]
#  68%|██████▊   | 326/480 [00:01<00:00, 263.59it/s]
#  74%|███████▍  | 355/480 [00:01<00:00, 269.25it/s]
#  80%|████████  | 384/480 [00:01<00:00, 273.27it/s]
#  86%|████████▋ | 414/480 [00:01<00:00, 278.36it/s]
#  92%|█████████▏| 443/480 [00:01<00:00, 281.05it/s]
#  98%|█████████▊| 472/480 [00:01<00:00, 283.36it/s]
# 100%|██████████| 480/480 [00:01<00:00, 270.11it/s]
#
#   0%|          | 0/480 [00:00<?, ?it/s]
#   6%|▌         | 27/480 [00:00<00:01, 262.14it/s]
#  11%|█▏        | 54/480 [00:00<00:01, 260.64it/s]
#  17%|█▋        | 81/480 [00:00<00:01, 262.28it/s]
#  22%|██▎       | 108/480 [00:00<00:01, 265.27it/s]
#  28%|██▊       | 135/480 [00:00<00:01, 265.07it/s]
#  34%|███▍      | 162/480 [00:00<00:01, 262.96it/s]
#  39%|███▉      | 189/480 [00:00<00:01, 263.10it/s]
#  45%|████▌     | 216/480 [00:00<00:01, 262.37it/s]
#  51%|█████     | 243/480 [00:00<00:00, 263.91it/s]
#  56%|█████▋    | 270/480 [00:01<00:00, 263.23it/s]
#  62%|██████▏   | 298/480 [00:01<00:00, 265.08it/s]
#  68%|██████▊   | 326/480 [00:01<00:00, 267.97it/s]
#  74%|███████▍  | 354/480 [00:01<00:00, 269.94it/s]
#  80%|███████▉  | 383/480 [00:01<00:00, 273.46it/s]
#  86%|████████▌ | 411/480 [00:01<00:00, 273.24it/s]
#  91%|█████████▏| 439/480 [00:01<00:00, 272.82it/s]
#  97%|█████████▋| 467/480 [00:01<00:00, 273.72it/s]
# 100%|██████████| 480/480 [00:01<00:00, 268.04it/s]
#
#   0%|          | 0/480 [00:00<?, ?it/s]
#   6%|▌         | 27/480 [00:00<00:01, 261.08it/s]
#  11%|█▏        | 54/480 [00:00<00:01, 265.07it/s]
#  17%|█▋        | 81/480 [00:00<00:01, 266.10it/s]
#  22%|██▎       | 108/480 [00:00<00:01, 266.51it/s]
#  28%|██▊       | 135/480 [00:00<00:01, 266.41it/s]
#  34%|███▍      | 162/480 [00:00<00:01, 265.77it/s]
#  39%|███▉      | 189/480 [00:00<00:01, 264.11it/s]
#  45%|████▌     | 216/480 [00:00<00:01, 263.66it/s]
#  51%|█████     | 243/480 [00:00<00:00, 264.58it/s]
#  56%|█████▋    | 270/480 [00:01<00:00, 260.13it/s]
#  62%|██████▏   | 299/480 [00:01<00:00, 266.63it/s]
#  68%|██████▊   | 327/480 [00:01<00:00, 270.21it/s]
#  74%|███████▍  | 356/480 [00:01<00:00, 274.47it/s]
#  80%|████████  | 384/480 [00:01<00:00, 275.16it/s]
#  86%|████████▌ | 412/480 [00:01<00:00, 275.91it/s]
#  92%|█████████▏| 441/480 [00:01<00:00, 276.97it/s]
#  98%|█████████▊| 469/480 [00:01<00:00, 277.63it/s]
# 100%|██████████| 480/480 [00:01<00:00, 270.15it/s]
#
#   0%|          | 0/480 [00:00<?, ?it/s]
#   5%|▌         | 26/480 [00:00<00:01, 258.29it/s]
#  11%|█         | 53/480 [00:00<00:01, 262.26it/s]
#  17%|█▋        | 80/480 [00:00<00:01, 262.63it/s]
#  22%|██▎       | 108/480 [00:00<00:01, 265.79it/s]
#  28%|██▊       | 135/480 [00:00<00:01, 265.39it/s]
#  34%|███▍      | 162/480 [00:00<00:01, 265.15it/s]
#  40%|███▉      | 190/480 [00:00<00:01, 267.36it/s]
#  45%|████▌     | 217/480 [00:00<00:00, 266.87it/s]
#  51%|█████     | 245/480 [00:00<00:00, 270.14it/s]
#  57%|█████▋    | 274/480 [00:01<00:00, 274.96it/s]
#  63%|██████▎   | 303/480 [00:01<00:00, 277.78it/s]
#  69%|██████▉   | 331/480 [00:01<00:00, 276.56it/s]
#  75%|███████▍  | 359/480 [00:01<00:00, 276.98it/s]
#  81%|████████  | 388/480 [00:01<00:00, 278.37it/s]
#  87%|████████▋ | 416/480 [00:01<00:00, 278.55it/s]
#  93%|█████████▎| 445/480 [00:01<00:00, 278.90it/s]
#  99%|█████████▊| 473/480 [00:01<00:00, 279.23it/s]
# 100%|██████████| 480/480 [00:01<00:00, 273.07it/s]
#    fold_id                    source_dir  \
# 0        1  gan_patches_256/dibas/fold_1
# 1        2  gan_patches_256/dibas/fold_2
# 2        3  gan_patches_256/dibas/fold_3
# 3        4  gan_patches_256/dibas/fold_4
# 4        5  gan_patches_256/dibas/fold_5
#
#                                     dataset_zip_path
# 0  results/24_train_stylegan3_make_images_dibas/f...
# 1  results/24_train_stylegan3_make_images_dibas/f...
# 2  results/24_train_stylegan3_make_images_dibas/f...
# 3  results/24_train_stylegan3_make_images_dibas/f...
# 4  results/24_train_stylegan3_make_images_dibas/f...

# %%
# We train one StyleGAN3-T run per training fold and keep the logs on disk.
training_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    dataset_zip_path = REPO_ROOT / fold_plan["dataset_zip_path"]
    run_parent = NOTEBOOK_CHECKPOINTS_DIR / f"fold_{fold_id}"
    run_parent.mkdir(parents=True, exist_ok=True)
    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    train_log_path = fold_result_dir / "train.log"

    report = run_command(
        build_stylegan_command(
            "train.py",
            f"--outdir={run_parent}",
            "--gpus=1",
            f"--data={dataset_zip_path}",
            f"--cfg={GAN_CFG}",
            f"--gamma={GAN_GAMMA}",
            f"--aug={GAN_AUG}",
            f"--mirror={int(GAN_MIRROR)}",
            f"--batch={GAN_BATCH_SIZE}",
            f"--kimg={GAN_KIMG}",
            f"--snap={SNAP_TICKS}",
            f"--workers={GAN_WORKERS}",
            f"--target={ADA_TARGET}",
            f"--metrics={KID_METRIC_NAME}",
            f"--seed={STYLEGAN_RANDOM_SEED}",
        ),
        STYLEGAN_DIR,
        live_log_path=train_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=STYLEGAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "train_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"StyleGAN3 training failed for fold {fold_id}")

    run_dirs = [path for path in run_parent.iterdir() if path.is_dir()]
    if not run_dirs:
        raise FileNotFoundError(f"No StyleGAN3 run directory was found for fold {fold_id}")
    run_dir = sorted(run_dirs, key=lambda item: item.name)[-1]
    snapshot_paths = sorted(run_dir.glob("network-snapshot-*.pkl"))
    if not snapshot_paths:
        raise FileNotFoundError(f"No snapshots were saved for fold {fold_id}")

    training_rows.append({
        "fold_id": fold_id,
        "run_dir": as_repo_relative(REPO_ROOT, run_dir),
        "latest_snapshot_path": as_repo_relative(REPO_ROOT, snapshot_paths[-1]),
        "train_duration_seconds": report["duration_seconds"],
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "training_run_manifest.csv", training_rows, list(training_rows[0].keys()))
display(pd.DataFrame(training_rows))
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9997227795604651
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "kid50k_full"
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 2m 28s       sec/tick 44.2    sec/kimg 5522.30 maintenance 103.5  cpumem 2.87   gpumem 6.05   reserved 6.80   augment 0.000
# {"results": {"kid50k_full": 0.696605920791626}, "metric": "kid50k_full", "total_time": 1722.8626976013184, "total_time_str": "28m 43s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777390630.0201044}
# tick 1     kimg 4.0      time 44m 44s      sec/tick 790.3   sec/kimg 197.57  maintenance 1746.0 cpumem 3.12   gpumem 5.59   reserved 7.19   augment 0.006
# tick 2     kimg 8.0      time 57m 54s      sec/tick 789.6   sec/kimg 197.41  maintenance 0.1    cpumem 3.04   gpumem 5.59   reserved 7.19   augment 0.011
# tick 3     kimg 12.0     time 1h 11m 04s   sec/tick 790.2   sec/kimg 197.54  maintenance 0.1    cpumem 3.04   gpumem 5.60   reserved 7.19   augment 0.017
# tick 4     kimg 16.0     time 1h 24m 14s   sec/tick 790.0   sec/kimg 197.51  maintenance 0.1    cpumem 3.04   gpumem 5.61   reserved 7.19   augment 0.024
# tick 5     kimg 20.0     time 1h 37m 25s   sec/tick 790.3   sec/kimg 197.57  maintenance 0.3    cpumem 3.04   gpumem 5.61   reserved 7.19   augment 0.030
# tick 6     kimg 24.0     time 1h 50m 35s   sec/tick 790.3   sec/kimg 197.59  maintenance 0.1    cpumem 3.04   gpumem 5.60   reserved 7.19   augment 0.033
# tick 7     kimg 28.0     time 2h 03m 46s   sec/tick 790.3   sec/kimg 197.56  maintenance 0.1    cpumem 3.04   gpumem 5.60   reserved 7.19   augment 0.039
# tick 8     kimg 32.0     time 2h 16m 59s   sec/tick 793.4   sec/kimg 198.35  maintenance 0.1    cpumem 3.04   gpumem 5.61   reserved 7.19   augment 0.044
# tick 9     kimg 36.0     time 2h 30m 10s   sec/tick 790.9   sec/kimg 197.72  maintenance 0.3    cpumem 2.95   gpumem 5.61   reserved 7.19   augment 0.048
# tick 10    kimg 40.0     time 2h 43m 21s   sec/tick 790.1   sec/kimg 197.52  maintenance 0.1    cpumem 2.95   gpumem 5.61   reserved 7.19   augment 0.048
# {"results": {"kid50k_full": 0.23323895037174225}, "metric": "kid50k_full", "total_time": 1776.029886007309, "total_time_str": "29m 36s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777400336.1649065}
# tick 11    kimg 44.0     time 3h 26m 30s   sec/tick 790.4   sec/kimg 197.61  maintenance 1799.2 cpumem 3.05   gpumem 5.60   reserved 7.19   augment 0.045
# tick 12    kimg 48.0     time 3h 39m 41s   sec/tick 790.2   sec/kimg 197.56  maintenance 0.1    cpumem 3.05   gpumem 5.63   reserved 7.19   augment 0.042
# tick 13    kimg 52.0     time 3h 52m 51s   sec/tick 790.3   sec/kimg 197.58  maintenance 0.3    cpumem 2.95   gpumem 5.61   reserved 7.19   augment 0.041
# tick 14    kimg 56.0     time 4h 06m 02s   sec/tick 790.5   sec/kimg 197.63  maintenance 0.1    cpumem 2.95   gpumem 5.60   reserved 7.19   augment 0.040
# tick 15    kimg 60.0     time 4h 19m 12s   sec/tick 790.2   sec/kimg 197.55  maintenance 0.1    cpumem 2.95   gpumem 5.61   reserved 7.19   augment 0.040
# tick 16    kimg 64.0     time 4h 32m 23s   sec/tick 790.6   sec/kimg 197.64  maintenance 0.1    cpumem 2.95   gpumem 5.61   reserved 7.19   augment 0.040
# tick 17    kimg 68.0     time 4h 45m 33s   sec/tick 789.8   sec/kimg 197.44  maintenance 0.0    cpumem 2.95   gpumem 5.60   reserved 7.19   augment 0.041
# tick 18    kimg 72.0     time 4h 58m 43s   sec/tick 790.4   sec/kimg 197.60  maintenance 0.1    cpumem 2.95   gpumem 5.60   reserved 7.19   augment 0.040
# tick 19    kimg 76.0     time 5h 11m 54s   sec/tick 790.5   sec/kimg 197.63  maintenance 0.0    cpumem 2.95   gpumem 5.60   reserved 7.19   augment 0.041
# tick 20    kimg 80.0     time 5h 25m 05s   sec/tick 790.7   sec/kimg 197.68  maintenance 0.1    cpumem 2.95   gpumem 5.61   reserved 7.19   augment 0.042
# {"results": {"kid50k_full": 0.1519930213689804}, "metric": "kid50k_full", "total_time": 1776.0600371360779, "total_time_str": "29m 36s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777410045.4118123}
# tick 21    kimg 84.0     time 6h 08m 20s   sec/tick 790.9   sec/kimg 197.72  maintenance 1804.4 cpumem 3.05   gpumem 5.63   reserved 7.20   augment 0.041
# tick 22    kimg 88.0     time 6h 21m 31s   sec/tick 790.6   sec/kimg 197.66  maintenance 0.1    cpumem 3.05   gpumem 5.60   reserved 7.20   augment 0.041
# tick 23    kimg 92.0     time 6h 34m 41s   sec/tick 790.2   sec/kimg 197.56  maintenance 0.1    cpumem 2.95   gpumem 5.60   reserved 7.20   augment 0.040
# tick 24    kimg 96.0     time 6h 47m 52s   sec/tick 790.7   sec/kimg 197.69  maintenance 0.1    cpumem 2.95   gpumem 5.60   reserved 7.20   augment 0.041
# tick 25    kimg 100.0    time 7h 01m 03s   sec/tick 791.0   sec/kimg 197.74  maintenance 0.3    cpumem 2.95   gpumem 5.61   reserved 7.20   augment 0.041
# tick 26    kimg 104.0    time 7h 14m 14s   sec/tick 790.8   sec/kimg 197.71  maintenance 0.0    cpumem 2.95   gpumem 5.61   reserved 7.20   augment 0.042
# tick 27    kimg 108.0    time 7h 27m 25s   sec/tick 790.4   sec/kimg 197.61  maintenance 0.1    cpumem 2.95   gpumem 5.62   reserved 7.20   augment 0.043
# tick 28    kimg 112.0    time 7h 40m 36s   sec/tick 791.1   sec/kimg 197.76  maintenance 0.1    cpumem 2.95   gpumem 5.61   reserved 7.20   augment 0.045
# tick 29    kimg 116.0    time 7h 53m 47s   sec/tick 791.0   sec/kimg 197.75  maintenance 0.3    cpumem 2.95   gpumem 5.60   reserved 7.20   augment 0.045
# tick 30    kimg 120.0    time 8h 06m 58s   sec/tick 790.5   sec/kimg 197.63  maintenance 0.1    cpumem 2.95   gpumem 5.63   reserved 7.20   augment 0.045
# {"results": {"kid50k_full": 0.12100671231746674}, "metric": "kid50k_full", "total_time": 1775.6508107185364, "total_time_str": "29m 36s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777419763.4948254}
# tick 31    kimg 124.0    time 8h 50m 18s   sec/tick 791.0   sec/kimg 197.75  maintenance 1809.3 cpumem 2.93   gpumem 5.62   reserved 7.20   augment 0.044
# tick 32    kimg 128.0    time 9h 03m 29s   sec/tick 790.6   sec/kimg 197.65  maintenance 0.1    cpumem 2.93   gpumem 5.61   reserved 7.20   augment 0.044
# tick 33    kimg 132.0    time 9h 16m 40s   sec/tick 790.6   sec/kimg 197.64  maintenance 0.3    cpumem 2.83   gpumem 5.62   reserved 7.20   augment 0.043
# tick 34    kimg 136.0    time 9h 29m 51s   sec/tick 790.9   sec/kimg 197.72  maintenance 0.1    cpumem 2.83   gpumem 5.61   reserved 7.20   augment 0.044
# tick 35    kimg 140.0    time 9h 43m 01s   sec/tick 790.5   sec/kimg 197.63  maintenance 0.1    cpumem 2.83   gpumem 5.67   reserved 7.20   augment 0.043
# tick 36    kimg 144.0    time 9h 56m 12s   sec/tick 790.5   sec/kimg 197.63  maintenance 0.1    cpumem 2.83   gpumem 5.62   reserved 7.20   augment 0.043
# tick 37    kimg 148.0    time 10h 09m 23s  sec/tick 790.2   sec/kimg 197.55  maintenance 0.3    cpumem 2.83   gpumem 5.61   reserved 7.20   augment 0.044
# tick 38    kimg 152.0    time 10h 22m 33s  sec/tick 790.5   sec/kimg 197.63  maintenance 0.1    cpumem 2.83   gpumem 5.61   reserved 7.20   augment 0.045
# tick 39    kimg 156.0    time 10h 35m 44s  sec/tick 790.2   sec/kimg 197.54  maintenance 0.1    cpumem 2.83   gpumem 5.61   reserved 7.20   augment 0.044
# tick 40    kimg 160.0    time 10h 48m 54s  sec/tick 790.4   sec/kimg 197.60  maintenance 0.1    cpumem 2.83   gpumem 5.61   reserved 7.20   augment 0.043
# {"results": {"kid50k_full": 0.0873178094625473}, "metric": "kid50k_full", "total_time": 1774.621619462967, "total_time_str": "29m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777429481.0905519}
# tick 41    kimg 164.0    time 11h 32m 15s  sec/tick 790.1   sec/kimg 197.51  maintenance 1810.7 cpumem 2.92   gpumem 5.61   reserved 7.20   augment 0.045
# tick 42    kimg 168.0    time 11h 45m 25s  sec/tick 790.3   sec/kimg 197.58  maintenance 0.1    cpumem 2.92   gpumem 5.61   reserved 7.20   augment 0.047
# tick 43    kimg 172.0    time 11h 58m 36s  sec/tick 790.5   sec/kimg 197.62  maintenance 0.1    cpumem 2.82   gpumem 5.61   reserved 7.20   augment 0.049
# tick 44    kimg 176.0    time 12h 11m 47s  sec/tick 790.7   sec/kimg 197.68  maintenance 0.1    cpumem 2.82   gpumem 5.61   reserved 7.20   augment 0.050
# tick 45    kimg 180.0    time 12h 24m 58s  sec/tick 790.5   sec/kimg 197.63  maintenance 0.3    cpumem 2.82   gpumem 5.61   reserved 7.20   augment 0.051
# tick 46    kimg 184.0    time 12h 38m 08s  sec/tick 790.8   sec/kimg 197.70  maintenance 0.1    cpumem 2.82   gpumem 5.62   reserved 7.20   augment 0.052
# tick 47    kimg 188.0    time 12h 51m 19s  sec/tick 790.4   sec/kimg 197.61  maintenance 0.1    cpumem 2.82   gpumem 5.62   reserved 7.20   augment 0.052
# tick 48    kimg 192.0    time 13h 04m 30s  sec/tick 790.5   sec/kimg 197.63  maintenance 0.1    cpumem 2.82   gpumem 5.61   reserved 7.20   augment 0.054
# tick 49    kimg 196.0    time 13h 17m 40s  sec/tick 789.5   sec/kimg 197.38  maintenance 0.3    cpumem 2.19   gpumem 5.61   reserved 7.20   augment 0.054
# tick 50    kimg 200.0    time 13h 30m 48s  sec/tick 788.8   sec/kimg 197.60  maintenance 0.1    cpumem 2.19   gpumem 5.61   reserved 7.20   augment 0.055
# {"results": {"kid50k_full": 0.07678847759962082}, "metric": "kid50k_full", "total_time": 1774.584861278534, "total_time_str": "29m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777439195.4384718}
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9997227795604651
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "kid50k_full"
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 2m 27s       sec/tick 44.9    sec/kimg 5614.02 maintenance 102.4  cpumem 2.87   gpumem 6.01   reserved 6.79   augment 0.000
# {"results": {"kid50k_full": 0.6680581569671631}, "metric": "kid50k_full", "total_time": 1730.2581768035889, "total_time_str": "28m 50s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777441101.5210888}
# tick 1     kimg 4.0      time 45m 05s      sec/tick 804.0   sec/kimg 200.99  maintenance 1753.6 cpumem 3.35   gpumem 5.60   reserved 7.26   augment 0.005
# tick 2     kimg 8.0      time 58m 29s      sec/tick 803.9   sec/kimg 200.98  maintenance 0.1    cpumem 3.27   gpumem 5.60   reserved 7.26   augment 0.010
# tick 3     kimg 12.0     time 1h 12m 00s   sec/tick 811.3   sec/kimg 202.84  maintenance 0.1    cpumem 3.27   gpumem 5.61   reserved 7.26   augment 0.016
# tick 4     kimg 16.0     time 1h 25m 25s   sec/tick 804.2   sec/kimg 201.05  maintenance 0.1    cpumem 3.27   gpumem 5.61   reserved 7.26   augment 0.022
# tick 5     kimg 20.0     time 1h 38m 49s   sec/tick 803.9   sec/kimg 200.97  maintenance 0.3    cpumem 3.27   gpumem 5.62   reserved 7.26   augment 0.027
# tick 6     kimg 24.0     time 1h 52m 13s   sec/tick 804.0   sec/kimg 200.99  maintenance 0.1    cpumem 3.27   gpumem 5.60   reserved 7.26   augment 0.033
# tick 7     kimg 28.0     time 2h 05m 37s   sec/tick 803.5   sec/kimg 200.88  maintenance 0.1    cpumem 3.27   gpumem 5.60   reserved 7.26   augment 0.038
# tick 8     kimg 32.0     time 2h 19m 01s   sec/tick 804.0   sec/kimg 201.00  maintenance 0.1    cpumem 1.31   gpumem 5.62   reserved 7.26   augment 0.042
# tick 9     kimg 36.0     time 2h 32m 25s   sec/tick 803.9   sec/kimg 200.96  maintenance 0.3    cpumem 0.97   gpumem 5.61   reserved 7.26   augment 0.046
# tick 10    kimg 40.0     time 2h 45m 49s   sec/tick 803.7   sec/kimg 200.92  maintenance 0.1    cpumem 0.98   gpumem 5.61   reserved 7.26   augment 0.050
# {"results": {"kid50k_full": 0.3226886987686157}, "metric": "kid50k_full", "total_time": 1795.004822731018, "total_time_str": "29m 55s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777450968.4997406}
# tick 11    kimg 44.0     time 3h 29m 53s   sec/tick 824.9   sec/kimg 206.23  maintenance 1819.2 cpumem 1.03   gpumem 5.63   reserved 7.26   augment 0.052
# tick 12    kimg 48.0     time 3h 43m 38s   sec/tick 824.9   sec/kimg 206.21  maintenance 0.1    cpumem 0.67   gpumem 5.63   reserved 7.26   augment 0.055
# tick 13    kimg 52.0     time 3h 57m 23s   sec/tick 824.9   sec/kimg 206.21  maintenance 0.3    cpumem 0.67   gpumem 5.63   reserved 7.26   augment 0.055
# tick 14    kimg 56.0     time 4h 11m 08s   sec/tick 824.9   sec/kimg 206.23  maintenance 0.1    cpumem 0.26   gpumem 5.60   reserved 7.26   augment 0.054
# tick 15    kimg 60.0     time 4h 25m 08s   sec/tick 839.8   sec/kimg 209.95  maintenance 0.1    cpumem 0.25   gpumem 5.63   reserved 7.26   augment 0.054
# tick 16    kimg 64.0     time 4h 38m 58s   sec/tick 830.0   sec/kimg 207.50  maintenance 0.1    cpumem 0.25   gpumem 5.61   reserved 7.26   augment 0.053
# tick 17    kimg 68.0     time 4h 52m 46s   sec/tick 828.0   sec/kimg 207.01  maintenance 0.3    cpumem 0.25   gpumem 5.61   reserved 7.26   augment 0.052
# tick 18    kimg 72.0     time 5h 06m 27s   sec/tick 820.9   sec/kimg 205.22  maintenance 0.1    cpumem 0.25   gpumem 5.62   reserved 7.26   augment 0.052
# tick 19    kimg 76.0     time 5h 20m 08s   sec/tick 820.8   sec/kimg 205.19  maintenance 0.1    cpumem 0.25   gpumem 5.61   reserved 7.26   augment 0.053
# tick 20    kimg 80.0     time 5h 33m 49s   sec/tick 821.0   sec/kimg 205.26  maintenance 0.1    cpumem 0.25   gpumem 5.61   reserved 7.26   augment 0.055
# {"results": {"kid50k_full": 0.18418382108211517}, "metric": "kid50k_full", "total_time": 1773.9840683937073, "total_time_str": "29m 34s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777461032.174582}
# tick 21    kimg 84.0     time 6h 17m 33s   sec/tick 821.4   sec/kimg 205.35  maintenance 1802.1 cpumem 1.28   gpumem 5.63   reserved 7.26   augment 0.056
# tick 22    kimg 88.0     time 6h 31m 14s   sec/tick 820.7   sec/kimg 205.19  maintenance 0.1    cpumem 1.28   gpumem 5.62   reserved 7.26   augment 0.057
# tick 23    kimg 92.0     time 6h 44m 55s   sec/tick 821.2   sec/kimg 205.29  maintenance 0.1    cpumem 1.18   gpumem 5.62   reserved 7.26   augment 0.057
# tick 24    kimg 96.0     time 6h 58m 37s   sec/tick 821.5   sec/kimg 205.37  maintenance 0.1    cpumem 1.18   gpumem 5.62   reserved 7.26   augment 0.058
# tick 25    kimg 100.0    time 7h 12m 18s   sec/tick 821.2   sec/kimg 205.31  maintenance 0.3    cpumem 1.18   gpumem 5.62   reserved 7.26   augment 0.058
# tick 26    kimg 104.0    time 7h 25m 59s   sec/tick 820.9   sec/kimg 205.23  maintenance 0.1    cpumem 1.18   gpumem 5.62   reserved 7.26   augment 0.060
# tick 27    kimg 108.0    time 7h 39m 41s   sec/tick 821.1   sec/kimg 205.28  maintenance 0.1    cpumem 1.18   gpumem 5.62   reserved 7.26   augment 0.061
# tick 28    kimg 112.0    time 7h 53m 22s   sec/tick 821.3   sec/kimg 205.32  maintenance 0.1    cpumem 1.18   gpumem 5.62   reserved 7.26   augment 0.061
# tick 29    kimg 116.0    time 8h 07m 03s   sec/tick 821.1   sec/kimg 205.27  maintenance 0.3    cpumem 1.18   gpumem 5.62   reserved 7.26   augment 0.061
# tick 30    kimg 120.0    time 8h 20m 45s   sec/tick 821.3   sec/kimg 205.33  maintenance 0.1    cpumem 1.18   gpumem 5.63   reserved 7.26   augment 0.059
# {"results": {"kid50k_full": 0.08131185919046402}, "metric": "kid50k_full", "total_time": 1773.5508160591125, "total_time_str": "29m 34s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777471053.9946275}
# tick 31    kimg 124.0    time 9h 04m 35s   sec/tick 821.3   sec/kimg 205.32  maintenance 1808.6 cpumem 1.27   gpumem 5.62   reserved 7.26   augment 0.059
# tick 32    kimg 128.0    time 9h 18m 16s   sec/tick 821.5   sec/kimg 205.38  maintenance 0.1    cpumem 1.27   gpumem 5.62   reserved 7.26   augment 0.058
# tick 33    kimg 132.0    time 9h 31m 58s   sec/tick 821.3   sec/kimg 205.32  maintenance 0.3    cpumem 1.17   gpumem 5.62   reserved 7.26   augment 0.057
# tick 34    kimg 136.0    time 9h 45m 40s   sec/tick 821.6   sec/kimg 205.40  maintenance 0.1    cpumem 1.17   gpumem 5.61   reserved 7.26   augment 0.056
# tick 35    kimg 140.0    time 9h 59m 33s   sec/tick 833.6   sec/kimg 208.39  maintenance 0.1    cpumem 1.17   gpumem 5.67   reserved 7.26   augment 0.057
# tick 36    kimg 144.0    time 10h 13m 16s  sec/tick 822.0   sec/kimg 205.50  maintenance 0.1    cpumem 1.17   gpumem 5.63   reserved 7.26   augment 0.058
# tick 37    kimg 148.0    time 10h 26m 58s  sec/tick 822.1   sec/kimg 205.54  maintenance 0.3    cpumem 1.17   gpumem 5.61   reserved 7.26   augment 0.059
# tick 38    kimg 152.0    time 10h 40m 40s  sec/tick 822.1   sec/kimg 205.52  maintenance 0.1    cpumem 1.17   gpumem 5.63   reserved 7.26   augment 0.059
# tick 39    kimg 156.0    time 10h 54m 23s  sec/tick 822.2   sec/kimg 205.56  maintenance 0.1    cpumem 1.17   gpumem 5.62   reserved 7.26   augment 0.061
# tick 40    kimg 160.0    time 11h 08m 05s  sec/tick 822.1   sec/kimg 205.51  maintenance 0.1    cpumem 1.17   gpumem 5.63   reserved 7.26   augment 0.061
# {"results": {"kid50k_full": 0.0866679921746254}, "metric": "kid50k_full", "total_time": 1775.607978105545, "total_time_str": "29m 36s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777481097.4016337}
# tick 41    kimg 164.0    time 11h 51m 59s  sec/tick 822.5   sec/kimg 205.63  maintenance 1812.1 cpumem 1.28   gpumem 5.62   reserved 7.26   augment 0.061
# tick 42    kimg 168.0    time 12h 05m 42s  sec/tick 822.3   sec/kimg 205.57  maintenance 0.1    cpumem 1.28   gpumem 5.64   reserved 7.26   augment 0.063
# tick 43    kimg 172.0    time 12h 19m 24s  sec/tick 821.9   sec/kimg 205.48  maintenance 0.1    cpumem 1.17   gpumem 5.63   reserved 7.26   augment 0.063
# tick 44    kimg 176.0    time 12h 33m 21s  sec/tick 836.8   sec/kimg 209.21  maintenance 0.1    cpumem 1.17   gpumem 5.62   reserved 7.26   augment 0.065
# tick 45    kimg 180.0    time 12h 47m 02s  sec/tick 821.3   sec/kimg 205.33  maintenance 0.3    cpumem 1.17   gpumem 5.62   reserved 7.26   augment 0.067
# tick 46    kimg 184.0    time 13h 00m 44s  sec/tick 821.3   sec/kimg 205.32  maintenance 0.1    cpumem 1.17   gpumem 5.62   reserved 7.26   augment 0.068
# tick 47    kimg 188.0    time 13h 14m 25s  sec/tick 821.3   sec/kimg 205.32  maintenance 0.1    cpumem 1.17   gpumem 5.62   reserved 7.26   augment 0.068
# tick 48    kimg 192.0    time 13h 28m 07s  sec/tick 821.5   sec/kimg 205.37  maintenance 0.1    cpumem 1.17   gpumem 5.61   reserved 7.26   augment 0.069
# tick 49    kimg 196.0    time 13h 41m 48s  sec/tick 821.3   sec/kimg 205.32  maintenance 0.3    cpumem 1.17   gpumem 5.62   reserved 7.26   augment 0.070
# tick 50    kimg 200.0    time 13h 55m 29s  sec/tick 820.4   sec/kimg 205.52  maintenance 0.1    cpumem 1.17   gpumem 5.62   reserved 7.26   augment 0.072
# {"results": {"kid50k_full": 0.05289451777935028}, "metric": "kid50k_full", "total_time": 1775.300145149231, "total_time_str": "29m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777491140.7931232}
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9997227795604651
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "kid50k_full"
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 2m 31s       sec/tick 46.0    sec/kimg 5750.29 maintenance 104.6  cpumem 2.87   gpumem 6.01   reserved 6.79   augment 0.000
# {"results": {"kid50k_full": 0.688776433467865}, "metric": "kid50k_full", "total_time": 1730.696664094925, "total_time_str": "28m 51s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777493051.9643302}
# tick 1     kimg 4.0      time 45m 39s      sec/tick 834.7   sec/kimg 208.69  maintenance 1754.0 cpumem 3.72   gpumem 5.59   reserved 7.53   augment 0.006
# tick 2     kimg 8.0      time 59m 34s      sec/tick 834.7   sec/kimg 208.68  maintenance 0.1    cpumem 3.64   gpumem 5.60   reserved 7.53   augment 0.011
# tick 3     kimg 12.0     time 1h 13m 29s   sec/tick 835.0   sec/kimg 208.74  maintenance 0.1    cpumem 3.64   gpumem 5.60   reserved 7.53   augment 0.015
# tick 4     kimg 16.0     time 1h 27m 25s   sec/tick 835.2   sec/kimg 208.80  maintenance 0.1    cpumem 3.64   gpumem 5.61   reserved 7.53   augment 0.022
# tick 5     kimg 20.0     time 1h 41m 20s   sec/tick 835.2   sec/kimg 208.79  maintenance 0.3    cpumem 3.64   gpumem 5.62   reserved 7.53   augment 0.028
# tick 6     kimg 24.0     time 1h 55m 15s   sec/tick 835.0   sec/kimg 208.76  maintenance 0.1    cpumem 3.64   gpumem 5.60   reserved 7.53   augment 0.036
# tick 7     kimg 28.0     time 2h 09m 10s   sec/tick 834.7   sec/kimg 208.68  maintenance 0.1    cpumem 3.64   gpumem 5.60   reserved 7.53   augment 0.042
# tick 8     kimg 32.0     time 2h 23m 06s   sec/tick 835.2   sec/kimg 208.80  maintenance 0.1    cpumem 3.64   gpumem 5.62   reserved 7.53   augment 0.046
# tick 9     kimg 36.0     time 2h 37m 01s   sec/tick 835.1   sec/kimg 208.78  maintenance 0.3    cpumem 3.64   gpumem 5.61   reserved 7.53   augment 0.051
# tick 10    kimg 40.0     time 2h 50m 56s   sec/tick 835.2   sec/kimg 208.81  maintenance 0.1    cpumem 3.64   gpumem 5.61   reserved 7.53   augment 0.054
# {"results": {"kid50k_full": 0.34002792835235596}, "metric": "kid50k_full", "total_time": 1777.258677482605, "total_time_str": "29m 37s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777503203.628932}
# tick 11    kimg 44.0     time 3h 34m 52s   sec/tick 835.3   sec/kimg 208.82  maintenance 1800.0 cpumem 3.75   gpumem 5.62   reserved 7.53   augment 0.054
# tick 12    kimg 48.0     time 3h 48m 47s   sec/tick 835.2   sec/kimg 208.80  maintenance 0.1    cpumem 3.75   gpumem 5.63   reserved 7.53   augment 0.052
# tick 13    kimg 52.0     time 4h 02m 42s   sec/tick 835.1   sec/kimg 208.78  maintenance 0.3    cpumem 3.64   gpumem 5.62   reserved 7.53   augment 0.050
# tick 14    kimg 56.0     time 4h 16m 38s   sec/tick 835.1   sec/kimg 208.78  maintenance 0.1    cpumem 3.64   gpumem 5.60   reserved 7.53   augment 0.048
# tick 15    kimg 60.0     time 4h 30m 33s   sec/tick 835.1   sec/kimg 208.77  maintenance 0.1    cpumem 3.64   gpumem 5.61   reserved 7.53   augment 0.047
# tick 16    kimg 64.0     time 4h 44m 28s   sec/tick 835.4   sec/kimg 208.85  maintenance 0.1    cpumem 3.64   gpumem 5.61   reserved 7.53   augment 0.046
# tick 17    kimg 68.0     time 4h 58m 23s   sec/tick 834.7   sec/kimg 208.66  maintenance 0.3    cpumem 3.64   gpumem 5.60   reserved 7.53   augment 0.043
# tick 18    kimg 72.0     time 5h 12m 18s   sec/tick 834.7   sec/kimg 208.68  maintenance 0.1    cpumem 3.64   gpumem 5.60   reserved 7.53   augment 0.040
# tick 19    kimg 76.0     time 5h 26m 13s   sec/tick 834.7   sec/kimg 208.67  maintenance 0.1    cpumem 3.64   gpumem 5.60   reserved 7.53   augment 0.038
# tick 20    kimg 80.0     time 5h 40m 08s   sec/tick 835.2   sec/kimg 208.80  maintenance 0.1    cpumem 3.64   gpumem 5.61   reserved 7.53   augment 0.036
# {"results": {"kid50k_full": 0.12689541280269623}, "metric": "kid50k_full", "total_time": 1775.4059796333313, "total_time_str": "29m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777513358.4167774}
# tick 21    kimg 84.0     time 6h 24m 06s   sec/tick 835.1   sec/kimg 208.77  maintenance 1802.8 cpumem 3.77   gpumem 5.63   reserved 7.53   augment 0.036
# tick 22    kimg 88.0     time 6h 38m 01s   sec/tick 834.8   sec/kimg 208.70  maintenance 0.1    cpumem 3.77   gpumem 5.60   reserved 7.53   augment 0.036
# tick 23    kimg 92.0     time 6h 51m 57s   sec/tick 835.3   sec/kimg 208.82  maintenance 0.1    cpumem 3.64   gpumem 5.60   reserved 7.53   augment 0.035
# tick 24    kimg 96.0     time 7h 05m 52s   sec/tick 834.9   sec/kimg 208.74  maintenance 0.1    cpumem 3.64   gpumem 5.60   reserved 7.53   augment 0.036
# tick 25    kimg 100.0    time 7h 19m 47s   sec/tick 835.1   sec/kimg 208.77  maintenance 0.3    cpumem 3.64   gpumem 5.61   reserved 7.53   augment 0.038
# tick 26    kimg 104.0    time 7h 33m 42s   sec/tick 835.0   sec/kimg 208.76  maintenance 0.1    cpumem 3.64   gpumem 5.61   reserved 7.53   augment 0.039
# tick 27    kimg 108.0    time 7h 47m 37s   sec/tick 835.0   sec/kimg 208.76  maintenance 0.1    cpumem 3.64   gpumem 5.62   reserved 7.53   augment 0.039
# tick 28    kimg 112.0    time 8h 01m 33s   sec/tick 835.2   sec/kimg 208.81  maintenance 0.1    cpumem 3.64   gpumem 5.61   reserved 7.53   augment 0.041
# tick 29    kimg 116.0    time 8h 15m 28s   sec/tick 835.2   sec/kimg 208.80  maintenance 0.3    cpumem 3.56   gpumem 5.60   reserved 7.53   augment 0.042
# tick 30    kimg 120.0    time 8h 29m 23s   sec/tick 834.9   sec/kimg 208.72  maintenance 0.1    cpumem 3.56   gpumem 5.63   reserved 7.53   augment 0.044
# {"results": {"kid50k_full": 0.06319601833820343}, "metric": "kid50k_full", "total_time": 1775.1676964759827, "total_time_str": "29m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777523513.8796241}
# tick 31    kimg 124.0    time 9h 13m 22s   sec/tick 835.4   sec/kimg 208.84  maintenance 1803.4 cpumem 3.58   gpumem 5.62   reserved 7.53   augment 0.044
# tick 32    kimg 128.0    time 9h 27m 17s   sec/tick 835.0   sec/kimg 208.75  maintenance 0.1    cpumem 3.58   gpumem 5.60   reserved 7.53   augment 0.046
# tick 33    kimg 132.0    time 9h 41m 12s   sec/tick 835.0   sec/kimg 208.74  maintenance 0.3    cpumem 3.48   gpumem 5.62   reserved 7.53   augment 0.047
# tick 34    kimg 136.0    time 9h 55m 07s   sec/tick 834.8   sec/kimg 208.70  maintenance 0.1    cpumem 3.48   gpumem 5.61   reserved 7.53   augment 0.048
# tick 35    kimg 140.0    time 10h 09m 02s  sec/tick 834.7   sec/kimg 208.69  maintenance 0.1    cpumem 3.48   gpumem 5.67   reserved 7.53   augment 0.050
# tick 36    kimg 144.0    time 10h 22m 57s  sec/tick 835.2   sec/kimg 208.81  maintenance 0.1    cpumem 3.48   gpumem 5.63   reserved 7.53   augment 0.052
# tick 37    kimg 148.0    time 10h 36m 53s  sec/tick 834.9   sec/kimg 208.72  maintenance 0.3    cpumem 3.48   gpumem 5.61   reserved 7.53   augment 0.053
# tick 38    kimg 152.0    time 10h 50m 48s  sec/tick 835.1   sec/kimg 208.79  maintenance 0.1    cpumem 3.48   gpumem 5.62   reserved 7.53   augment 0.055
# tick 39    kimg 156.0    time 11h 04m 43s  sec/tick 835.0   sec/kimg 208.74  maintenance 0.1    cpumem 3.48   gpumem 5.61   reserved 7.53   augment 0.055
# tick 40    kimg 160.0    time 11h 18m 38s  sec/tick 835.1   sec/kimg 208.78  maintenance 0.1    cpumem 3.48   gpumem 5.63   reserved 7.53   augment 0.057
# {"results": {"kid50k_full": 0.08877114951610565}, "metric": "kid50k_full", "total_time": 1784.6817927360535, "total_time_str": "29m 45s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777533684.4328315}
# tick 41    kimg 164.0    time 12h 02m 52s  sec/tick 834.8   sec/kimg 208.69  maintenance 1818.8 cpumem 2.11   gpumem 5.61   reserved 7.53   augment 0.059
# tick 42    kimg 168.0    time 12h 16m 46s  sec/tick 833.9   sec/kimg 208.48  maintenance 0.1    cpumem 2.11   gpumem 5.64   reserved 7.53   augment 0.060
# tick 43    kimg 172.0    time 12h 30m 42s  sec/tick 835.5   sec/kimg 208.87  maintenance 0.1    cpumem 2.01   gpumem 5.63   reserved 7.53   augment 0.062
# tick 44    kimg 176.0    time 12h 44m 37s  sec/tick 835.5   sec/kimg 208.88  maintenance 0.1    cpumem 2.01   gpumem 5.61   reserved 7.53   augment 0.064
# tick 45    kimg 180.0    time 12h 58m 33s  sec/tick 835.4   sec/kimg 208.85  maintenance 0.3    cpumem 2.01   gpumem 5.62   reserved 7.53   augment 0.065
# tick 46    kimg 184.0    time 13h 12m 28s  sec/tick 835.4   sec/kimg 208.84  maintenance 0.1    cpumem 2.01   gpumem 5.62   reserved 7.53   augment 0.067
# tick 47    kimg 188.0    time 13h 26m 24s  sec/tick 835.6   sec/kimg 208.89  maintenance 0.1    cpumem 2.01   gpumem 5.61   reserved 7.53   augment 0.069
# tick 48    kimg 192.0    time 13h 40m 20s  sec/tick 835.7   sec/kimg 208.92  maintenance 0.1    cpumem 2.01   gpumem 5.62   reserved 7.53   augment 0.070
# tick 49    kimg 196.0    time 13h 54m 16s  sec/tick 835.4   sec/kimg 208.84  maintenance 0.3    cpumem 2.01   gpumem 5.61   reserved 7.53   augment 0.073
# tick 50    kimg 200.0    time 14h 08m 10s  sec/tick 834.0   sec/kimg 208.93  maintenance 0.1    cpumem 2.01   gpumem 5.62   reserved 7.53   augment 0.076
# {"results": {"kid50k_full": 0.10575368255376816}, "metric": "kid50k_full", "total_time": 1775.2660796642303, "total_time_str": "29m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777543847.534484}
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9997227795604651
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "kid50k_full"
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 2m 28s       sec/tick 45.1    sec/kimg 5643.63 maintenance 102.7  cpumem 2.87   gpumem 6.01   reserved 6.79   augment 0.000
# {"results": {"kid50k_full": 0.6777661442756653}, "metric": "kid50k_full", "total_time": 1730.9012598991394, "total_time_str": "28m 51s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777545755.3518066}
# tick 1     kimg 4.0      time 45m 15s      sec/tick 812.8   sec/kimg 203.21  maintenance 1754.2 cpumem 3.49   gpumem 5.59   reserved 7.29   augment 0.006
# tick 2     kimg 8.0      time 58m 47s      sec/tick 812.5   sec/kimg 203.12  maintenance 0.1    cpumem 3.41   gpumem 5.60   reserved 7.29   augment 0.010
# tick 3     kimg 12.0     time 1h 12m 20s   sec/tick 812.5   sec/kimg 203.14  maintenance 0.1    cpumem 3.41   gpumem 5.60   reserved 7.29   augment 0.015
# tick 4     kimg 16.0     time 1h 25m 53s   sec/tick 812.8   sec/kimg 203.20  maintenance 0.1    cpumem 3.41   gpumem 5.61   reserved 7.29   augment 0.022
# tick 5     kimg 20.0     time 1h 39m 26s   sec/tick 812.5   sec/kimg 203.11  maintenance 0.3    cpumem 3.41   gpumem 5.61   reserved 7.29   augment 0.029
# tick 6     kimg 24.0     time 1h 52m 58s   sec/tick 812.6   sec/kimg 203.14  maintenance 0.1    cpumem 3.41   gpumem 5.60   reserved 7.29   augment 0.033
# tick 7     kimg 28.0     time 2h 06m 32s   sec/tick 812.9   sec/kimg 203.22  maintenance 0.1    cpumem 3.41   gpumem 5.60   reserved 7.29   augment 0.035
# tick 8     kimg 32.0     time 2h 20m 14s   sec/tick 822.6   sec/kimg 205.65  maintenance 0.1    cpumem 3.41   gpumem 5.61   reserved 7.29   augment 0.039
# tick 9     kimg 36.0     time 2h 33m 47s   sec/tick 812.1   sec/kimg 203.02  maintenance 0.3    cpumem 3.41   gpumem 5.60   reserved 7.29   augment 0.044
# tick 10    kimg 40.0     time 2h 47m 19s   sec/tick 812.4   sec/kimg 203.10  maintenance 0.1    cpumem 3.41   gpumem 5.61   reserved 7.29   augment 0.049
# {"results": {"kid50k_full": 0.45298272371292114}, "metric": "kid50k_full", "total_time": 1767.8450508117676, "total_time_str": "29m 28s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777555688.2651224}
# tick 11    kimg 44.0     time 3h 30m 48s   sec/tick 813.0   sec/kimg 203.26  maintenance 1795.8 cpumem 3.53   gpumem 5.60   reserved 7.29   augment 0.048
# tick 12    kimg 48.0     time 3h 44m 21s   sec/tick 812.9   sec/kimg 203.22  maintenance 0.1    cpumem 3.53   gpumem 5.63   reserved 7.29   augment 0.044
# tick 13    kimg 52.0     time 3h 57m 54s   sec/tick 812.7   sec/kimg 203.17  maintenance 0.3    cpumem 3.43   gpumem 5.62   reserved 7.29   augment 0.041
# tick 14    kimg 56.0     time 4h 11m 27s   sec/tick 813.0   sec/kimg 203.24  maintenance 0.1    cpumem 3.43   gpumem 5.60   reserved 7.29   augment 0.039
# tick 15    kimg 60.0     time 4h 25m 00s   sec/tick 813.0   sec/kimg 203.25  maintenance 0.1    cpumem 3.43   gpumem 5.61   reserved 7.29   augment 0.039
# tick 16    kimg 64.0     time 4h 38m 34s   sec/tick 813.4   sec/kimg 203.35  maintenance 0.1    cpumem 3.43   gpumem 5.61   reserved 7.29   augment 0.038
# tick 17    kimg 68.0     time 4h 52m 08s   sec/tick 813.7   sec/kimg 203.41  maintenance 0.3    cpumem 3.43   gpumem 5.60   reserved 7.29   augment 0.037
# tick 18    kimg 72.0     time 5h 05m 41s   sec/tick 813.7   sec/kimg 203.42  maintenance 0.1    cpumem 3.43   gpumem 5.60   reserved 7.29   augment 0.036
# tick 19    kimg 76.0     time 5h 19m 16s   sec/tick 814.0   sec/kimg 203.50  maintenance 0.1    cpumem 3.43   gpumem 5.60   reserved 7.29   augment 0.034
# tick 20    kimg 80.0     time 5h 32m 50s   sec/tick 813.9   sec/kimg 203.47  maintenance 0.1    cpumem 3.43   gpumem 5.61   reserved 7.29   augment 0.033
# {"results": {"kid50k_full": 0.15688319504261017}, "metric": "kid50k_full", "total_time": 1777.1345565319061, "total_time_str": "29m 37s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777565628.282091}
# tick 21    kimg 84.0     time 6h 16m 29s   sec/tick 813.9   sec/kimg 203.48  maintenance 1805.3 cpumem 3.13   gpumem 5.63   reserved 7.29   augment 0.032
# tick 22    kimg 88.0     time 6h 30m 03s   sec/tick 814.1   sec/kimg 203.52  maintenance 0.1    cpumem 3.13   gpumem 5.60   reserved 7.29   augment 0.030
# tick 23    kimg 92.0     time 6h 43m 37s   sec/tick 813.6   sec/kimg 203.40  maintenance 0.1    cpumem 3.03   gpumem 5.61   reserved 7.29   augment 0.029
# tick 24    kimg 96.0     time 6h 57m 11s   sec/tick 814.3   sec/kimg 203.56  maintenance 0.1    cpumem 3.03   gpumem 5.60   reserved 7.29   augment 0.029
# tick 25    kimg 100.0    time 7h 10m 45s   sec/tick 813.9   sec/kimg 203.46  maintenance 0.3    cpumem 3.03   gpumem 5.61   reserved 7.29   augment 0.030
# tick 26    kimg 104.0    time 7h 24m 19s   sec/tick 813.8   sec/kimg 203.46  maintenance 0.1    cpumem 3.03   gpumem 5.61   reserved 7.29   augment 0.030
# tick 27    kimg 108.0    time 7h 37m 53s   sec/tick 814.0   sec/kimg 203.49  maintenance 0.1    cpumem 3.03   gpumem 5.62   reserved 7.29   augment 0.031
# tick 28    kimg 112.0    time 7h 51m 27s   sec/tick 813.8   sec/kimg 203.45  maintenance 0.1    cpumem 3.03   gpumem 5.61   reserved 7.29   augment 0.032
# tick 29    kimg 116.0    time 8h 05m 09s   sec/tick 821.2   sec/kimg 205.29  maintenance 0.3    cpumem 2.27   gpumem 5.60   reserved 7.29   augment 0.033
# tick 30    kimg 120.0    time 8h 18m 43s   sec/tick 814.0   sec/kimg 203.50  maintenance 0.1    cpumem 1.92   gpumem 5.63   reserved 7.29   augment 0.034
# {"results": {"kid50k_full": 0.07211332768201828}, "metric": "kid50k_full", "total_time": 1770.762395143509, "total_time_str": "29m 31s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777575579.6271188}
# tick 31    kimg 124.0    time 9h 02m 21s   sec/tick 814.5   sec/kimg 203.63  maintenance 1803.3 cpumem 2.01   gpumem 5.62   reserved 7.29   augment 0.035
# tick 32    kimg 128.0    time 9h 15m 55s   sec/tick 814.5   sec/kimg 203.63  maintenance 0.1    cpumem 2.01   gpumem 5.60   reserved 7.29   augment 0.037
# tick 33    kimg 132.0    time 9h 29m 30s   sec/tick 814.1   sec/kimg 203.52  maintenance 0.3    cpumem 1.90   gpumem 5.61   reserved 7.29   augment 0.038
# tick 34    kimg 136.0    time 9h 43m 04s   sec/tick 813.6   sec/kimg 203.41  maintenance 0.1    cpumem 1.90   gpumem 5.61   reserved 7.29   augment 0.039
# tick 35    kimg 140.0    time 9h 56m 37s   sec/tick 813.8   sec/kimg 203.44  maintenance 0.1    cpumem 1.90   gpumem 5.67   reserved 7.29   augment 0.041
# tick 36    kimg 144.0    time 10h 10m 12s  sec/tick 814.3   sec/kimg 203.58  maintenance 0.1    cpumem 1.90   gpumem 5.62   reserved 7.29   augment 0.041
# tick 37    kimg 148.0    time 10h 23m 46s  sec/tick 814.2   sec/kimg 203.55  maintenance 0.3    cpumem 1.90   gpumem 5.61   reserved 7.29   augment 0.042
# tick 38    kimg 152.0    time 10h 37m 21s  sec/tick 814.0   sec/kimg 203.51  maintenance 0.1    cpumem 1.90   gpumem 5.61   reserved 7.29   augment 0.044
# tick 39    kimg 156.0    time 10h 50m 55s  sec/tick 814.1   sec/kimg 203.51  maintenance 0.1    cpumem 1.90   gpumem 5.61   reserved 7.29   augment 0.046
# tick 40    kimg 160.0    time 11h 04m 29s  sec/tick 814.1   sec/kimg 203.53  maintenance 0.1    cpumem 1.72   gpumem 5.61   reserved 7.29   augment 0.047
# {"results": {"kid50k_full": 0.04195613041520119}, "metric": "kid50k_full", "total_time": 1771.308361530304, "total_time_str": "29m 31s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777585520.9669116}
# tick 41    kimg 164.0    time 11h 48m 01s  sec/tick 813.7   sec/kimg 203.42  maintenance 1798.6 cpumem 1.84   gpumem 5.61   reserved 7.29   augment 0.049
# tick 42    kimg 168.0    time 12h 01m 35s  sec/tick 814.0   sec/kimg 203.50  maintenance 0.1    cpumem 1.84   gpumem 5.61   reserved 7.29   augment 0.051
# tick 43    kimg 172.0    time 12h 15m 09s  sec/tick 813.8   sec/kimg 203.45  maintenance 0.1    cpumem 1.74   gpumem 5.63   reserved 7.29   augment 0.053
# tick 44    kimg 176.0    time 12h 28m 44s  sec/tick 814.2   sec/kimg 203.55  maintenance 0.1    cpumem 1.74   gpumem 5.61   reserved 7.29   augment 0.054
# tick 45    kimg 180.0    time 12h 42m 18s  sec/tick 813.9   sec/kimg 203.47  maintenance 0.3    cpumem 1.74   gpumem 5.61   reserved 7.29   augment 0.056
# tick 46    kimg 184.0    time 12h 55m 52s  sec/tick 814.2   sec/kimg 203.56  maintenance 0.1    cpumem 1.74   gpumem 5.62   reserved 7.29   augment 0.058
# tick 47    kimg 188.0    time 13h 09m 26s  sec/tick 814.1   sec/kimg 203.53  maintenance 0.1    cpumem 1.74   gpumem 5.61   reserved 7.29   augment 0.062
# tick 48    kimg 192.0    time 13h 23m 00s  sec/tick 813.8   sec/kimg 203.45  maintenance 0.1    cpumem 1.74   gpumem 5.61   reserved 7.29   augment 0.065
# tick 49    kimg 196.0    time 13h 36m 34s  sec/tick 813.8   sec/kimg 203.45  maintenance 0.3    cpumem 1.74   gpumem 5.61   reserved 7.29   augment 0.067
# tick 50    kimg 200.0    time 13h 50m 07s  sec/tick 812.7   sec/kimg 203.58  maintenance 0.1    cpumem 1.74   gpumem 5.62   reserved 7.29   augment 0.069
# {"results": {"kid50k_full": 0.09797178208827972}, "metric": "kid50k_full", "total_time": 1771.0948419570923, "total_time_str": "29m 31s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777595467.8765025}
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9997227795604651
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "kid50k_full"
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
# Training for 200 kimg...
# tick 0     kimg 0.0      time 2m 29s       sec/tick 45.3    sec/kimg 5661.74 maintenance 103.4  cpumem 2.87   gpumem 6.01   reserved 6.79   augment 0.000
# {"results": {"kid50k_full": 0.6521922945976257}, "metric": "kid50k_full", "total_time": 1731.4521191120148, "total_time_str": "28m 51s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1777597376.7742517}
# tick 1     kimg 4.0      time 45m 11s      sec/tick 808.0   sec/kimg 202.00  maintenance 1754.8 cpumem 3.53   gpumem 5.59   reserved 7.29   augment 0.006
# tick 2     kimg 8.0      time 58m 40s      sec/tick 808.1   sec/kimg 202.04  maintenance 0.1    cpumem 3.45   gpumem 5.60   reserved 7.29   augment 0.013
# tick 3     kimg 12.0     time 1h 12m 08s   sec/tick 808.3   sec/kimg 202.08  maintenance 0.1    cpumem 3.45   gpumem 5.60   reserved 7.29   augment 0.017
# tick 4     kimg 16.0     time 1h 25m 36s   sec/tick 808.2   sec/kimg 202.04  maintenance 0.1    cpumem 3.45   gpumem 5.61   reserved 7.29   augment 0.024
# tick 5     kimg 20.0     time 1h 39m 05s   sec/tick 808.6   sec/kimg 202.14  maintenance 0.3    cpumem 3.45   gpumem 5.61   reserved 7.29   augment 0.027
# tick 6     kimg 24.0     time 1h 52m 34s   sec/tick 808.7   sec/kimg 202.18  maintenance 0.1    cpumem 3.45   gpumem 5.60   reserved 7.29   augment 0.032
# tick 7     kimg 28.0     time 2h 06m 03s   sec/tick 808.6   sec/kimg 202.14  maintenance 0.1    cpumem 3.45   gpumem 5.60   reserved 7.29   augment 0.034
# tick 8     kimg 32.0     time 2h 19m 31s   sec/tick 808.2   sec/kimg 202.04  maintenance 0.1    cpumem 3.45   gpumem 5.61   reserved 7.29   augment 0.038
# tick 9     kimg 36.0     time 2h 33m 00s   sec/tick 808.2   sec/kimg 202.05  maintenance 0.3    cpumem 3.45   gpumem 5.60   reserved 7.29   augment 0.044
# tick 10    kimg 40.0     time 2h 46m 28s   sec/tick 808.4   sec/kimg 202.10  maintenance 0.1    cpumem 3.45   gpumem 5.61   reserved 7.29   augment 0.046
# {"results": {"kid50k_full": 0.3965625762939453}, "metric": "kid50k_full", "total_time": 1714.8451809883118, "total_time_str": "28m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1777607201.1687639}
# tick 11    kimg 44.0     time 3h 28m 56s   sec/tick 808.4   sec/kimg 202.11  maintenance 1739.6 cpumem 3.57   gpumem 5.61   reserved 7.29   augment 0.050
# tick 12    kimg 48.0     time 3h 42m 25s   sec/tick 808.4   sec/kimg 202.10  maintenance 0.1    cpumem 3.57   gpumem 5.63   reserved 7.29   augment 0.050
# tick 13    kimg 52.0     time 3h 55m 53s   sec/tick 808.3   sec/kimg 202.07  maintenance 0.3    cpumem 3.47   gpumem 5.62   reserved 7.29   augment 0.050
# tick 14    kimg 56.0     time 4h 09m 24s   sec/tick 810.9   sec/kimg 202.72  maintenance 0.1    cpumem 3.47   gpumem 5.60   reserved 7.29   augment 0.047
# tick 15    kimg 60.0     time 4h 22m 52s   sec/tick 808.0   sec/kimg 202.00  maintenance 0.1    cpumem 3.47   gpumem 5.61   reserved 7.29   augment 0.046
# tick 16    kimg 64.0     time 4h 36m 21s   sec/tick 808.0   sec/kimg 201.99  maintenance 0.1    cpumem 3.47   gpumem 5.61   reserved 7.29   augment 0.047
# tick 17    kimg 68.0     time 4h 49m 49s   sec/tick 807.9   sec/kimg 201.97  maintenance 0.3    cpumem 3.47   gpumem 5.60   reserved 7.29   augment 0.049
# tick 18    kimg 72.0     time 5h 03m 16s   sec/tick 807.3   sec/kimg 201.83  maintenance 0.1    cpumem 3.47   gpumem 5.61   reserved 7.29   augment 0.053
# tick 19    kimg 76.0     time 5h 16m 45s   sec/tick 808.9   sec/kimg 202.22  maintenance 0.1    cpumem 3.47   gpumem 5.61   reserved 7.29   augment 0.055
# tick 20    kimg 80.0     time 5h 30m 14s   sec/tick 809.1   sec/kimg 202.27  maintenance 0.1    cpumem 3.47   gpumem 5.61   reserved 7.29   augment 0.057
# {"results": {"kid50k_full": 0.17623136937618256}, "metric": "kid50k_full", "total_time": 1715.1690533161163, "total_time_str": "28m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1777617027.6646533}
# tick 21    kimg 84.0     time 6h 12m 43s   sec/tick 808.9   sec/kimg 202.23  maintenance 1739.9 cpumem 3.56   gpumem 5.63   reserved 7.29   augment 0.057
# tick 22    kimg 88.0     time 6h 26m 12s   sec/tick 808.8   sec/kimg 202.20  maintenance 0.1    cpumem 3.56   gpumem 5.62   reserved 7.29   augment 0.057
# tick 23    kimg 92.0     time 6h 39m 41s   sec/tick 809.1   sec/kimg 202.27  maintenance 0.1    cpumem 3.46   gpumem 5.62   reserved 7.29   augment 0.057
# tick 24    kimg 96.0     time 6h 53m 11s   sec/tick 809.2   sec/kimg 202.29  maintenance 0.1    cpumem 3.46   gpumem 5.62   reserved 7.29   augment 0.057
# tick 25    kimg 100.0    time 7h 06m 40s   sec/tick 809.0   sec/kimg 202.26  maintenance 0.3    cpumem 3.46   gpumem 5.62   reserved 7.29   augment 0.057
# tick 26    kimg 104.0    time 7h 20m 09s   sec/tick 808.9   sec/kimg 202.22  maintenance 0.1    cpumem 3.46   gpumem 5.62   reserved 7.29   augment 0.057
# tick 27    kimg 108.0    time 7h 33m 38s   sec/tick 809.2   sec/kimg 202.29  maintenance 0.1    cpumem 3.46   gpumem 5.63   reserved 7.29   augment 0.055
# tick 28    kimg 112.0    time 7h 47m 08s   sec/tick 809.1   sec/kimg 202.29  maintenance 0.1    cpumem 3.31   gpumem 5.62   reserved 7.29   augment 0.054
# tick 29    kimg 116.0    time 8h 00m 37s   sec/tick 808.9   sec/kimg 202.22  maintenance 0.3    cpumem 3.31   gpumem 5.62   reserved 7.29   augment 0.053
# tick 30    kimg 120.0    time 8h 14m 06s   sec/tick 809.2   sec/kimg 202.30  maintenance 0.1    cpumem 3.31   gpumem 5.63   reserved 7.29   augment 0.052
# {"results": {"kid50k_full": 0.07399650663137436}, "metric": "kid50k_full", "total_time": 1714.420146226883, "total_time_str": "28m 34s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1777626869.109483}
# tick 31    kimg 124.0    time 8h 56m 45s   sec/tick 809.4   sec/kimg 202.34  maintenance 1749.6 cpumem 3.39   gpumem 5.62   reserved 7.29   augment 0.050
# tick 32    kimg 128.0    time 9h 10m 14s   sec/tick 809.1   sec/kimg 202.27  maintenance 0.1    cpumem 3.39   gpumem 5.61   reserved 7.29   augment 0.048
# tick 33    kimg 132.0    time 9h 23m 44s   sec/tick 809.1   sec/kimg 202.27  maintenance 0.3    cpumem 3.29   gpumem 5.62   reserved 7.29   augment 0.047
# tick 34    kimg 136.0    time 9h 37m 13s   sec/tick 809.1   sec/kimg 202.28  maintenance 0.1    cpumem 3.29   gpumem 5.61   reserved 7.29   augment 0.048
# tick 35    kimg 140.0    time 9h 50m 42s   sec/tick 808.8   sec/kimg 202.19  maintenance 0.1    cpumem 3.29   gpumem 5.67   reserved 7.29   augment 0.049
# tick 36    kimg 144.0    time 10h 04m 11s  sec/tick 809.2   sec/kimg 202.30  maintenance 0.1    cpumem 3.29   gpumem 5.62   reserved 7.29   augment 0.049
# tick 37    kimg 148.0    time 10h 17m 41s  sec/tick 809.1   sec/kimg 202.28  maintenance 0.3    cpumem 3.29   gpumem 5.61   reserved 7.29   augment 0.047
# tick 38    kimg 152.0    time 10h 31m 10s  sec/tick 809.1   sec/kimg 202.27  maintenance 0.1    cpumem 3.29   gpumem 5.63   reserved 7.29   augment 0.047
# tick 39    kimg 156.0    time 10h 44m 39s  sec/tick 809.3   sec/kimg 202.33  maintenance 0.1    cpumem 3.29   gpumem 5.61   reserved 7.29   augment 0.047
# tick 40    kimg 160.0    time 10h 58m 09s  sec/tick 809.6   sec/kimg 202.39  maintenance 0.1    cpumem 3.29   gpumem 5.61   reserved 7.29   augment 0.045
# {"results": {"kid50k_full": 0.073210209608078}, "metric": "kid50k_full", "total_time": 1713.9329860210419, "total_time_str": "28m 34s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1777636711.3794057}
# tick 41    kimg 164.0    time 11h 40m 47s  sec/tick 809.4   sec/kimg 202.35  maintenance 1749.1 cpumem 3.28   gpumem 5.61   reserved 7.29   augment 0.045
# tick 42    kimg 168.0    time 11h 54m 17s  sec/tick 809.3   sec/kimg 202.33  maintenance 0.1    cpumem 3.28   gpumem 5.61   reserved 7.29   augment 0.044
# tick 43    kimg 172.0    time 12h 07m 47s  sec/tick 809.6   sec/kimg 202.41  maintenance 0.1    cpumem 3.18   gpumem 5.61   reserved 7.29   augment 0.045
# tick 44    kimg 176.0    time 12h 21m 16s  sec/tick 809.3   sec/kimg 202.32  maintenance 0.1    cpumem 3.18   gpumem 5.61   reserved 7.29   augment 0.045
# tick 45    kimg 180.0    time 12h 34m 45s  sec/tick 809.0   sec/kimg 202.26  maintenance 0.3    cpumem 3.18   gpumem 5.61   reserved 7.29   augment 0.046
# tick 46    kimg 184.0    time 12h 48m 15s  sec/tick 809.0   sec/kimg 202.25  maintenance 0.1    cpumem 3.18   gpumem 5.61   reserved 7.29   augment 0.046
# tick 47    kimg 188.0    time 13h 01m 51s  sec/tick 815.9   sec/kimg 203.98  maintenance 0.1    cpumem 2.21   gpumem 5.61   reserved 7.29   augment 0.047
# tick 48    kimg 192.0    time 13h 15m 20s  sec/tick 809.5   sec/kimg 202.37  maintenance 0.1    cpumem 2.21   gpumem 5.61   reserved 7.29   augment 0.048
# tick 49    kimg 196.0    time 13h 28m 50s  sec/tick 809.3   sec/kimg 202.33  maintenance 0.3    cpumem 2.21   gpumem 5.61   reserved 7.29   augment 0.050
# tick 50    kimg 200.0    time 13h 42m 17s  sec/tick 807.4   sec/kimg 202.25  maintenance 0.1    cpumem 2.21   gpumem 5.61   reserved 7.29   augment 0.052
# {"results": {"kid50k_full": 0.10232876986265182}, "metric": "kid50k_full", "total_time": 1714.6049704551697, "total_time_str": "28m 35s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1777646560.9598527}
#    fold_id                                            run_dir  \
# 0        1  checkpoints/24_train_stylegan3_make_images_dib...
# 1        2  checkpoints/24_train_stylegan3_make_images_dib...
# 2        3  checkpoints/24_train_stylegan3_make_images_dib...
# 3        4  checkpoints/24_train_stylegan3_make_images_dib...
# 4        5  checkpoints/24_train_stylegan3_make_images_dib...
#
#                                 latest_snapshot_path  train_duration_seconds
# 0  checkpoints/24_train_stylegan3_make_images_dib...                50463.62
# 1  checkpoints/24_train_stylegan3_make_images_dib...                51946.67
# 2  checkpoints/24_train_stylegan3_make_images_dib...                52705.73
# 3  checkpoints/24_train_stylegan3_make_images_dib...                51620.35
# 4  checkpoints/24_train_stylegan3_make_images_dib...                51092.95

# %%
# We read the online KID results from training and select the lowest-KID snapshot per fold.
kid_snapshot_rows = []
kid_rows = []
training_lookup = {int(row["fold_id"]): row for row in training_rows}

def parse_snapshot_kimg(snapshot_path: Path) -> int:
    return int(snapshot_path.stem.replace("network-snapshot-", ""))

def read_kid_values_by_snapshot(run_dir: Path):
    metric_file = run_dir / f"metric-{KID_METRIC_NAME}.jsonl"
    if not metric_file.exists():
        raise FileNotFoundError(f"Missing metric log: {metric_file}")

    kid_values = {}
    lines = [line for line in metric_file.read_text(encoding="utf-8").splitlines() if line.strip()]
    for line in lines:
        record = json.loads(line)
        if "results" not in record or "snapshot_pkl" not in record:
            continue
        kid_value = record["results"].get(KID_METRIC_NAME)
        if kid_value is None:
            continue
        kid_values[record["snapshot_pkl"]] = kid_value
    return kid_values

for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    run_dir = REPO_ROOT / training_lookup[fold_id]["run_dir"]
    candidate_snapshot_kimg = set(SNAPSHOT_SELECTION_KIMG)
    snapshot_paths = [
        path for path in sorted(run_dir.glob("network-snapshot-*.pkl"))
        if parse_snapshot_kimg(path) in candidate_snapshot_kimg
    ]
    if not snapshot_paths:
        raise FileNotFoundError(
            f"No snapshots from {SNAPSHOT_SELECTION_KIMG} kimg were found for fold {fold_id}"
        )
    kid_values = read_kid_values_by_snapshot(run_dir)

    fold_snapshot_rows = []
    for snapshot_path in snapshot_paths:
        kid_value = kid_values.get(snapshot_path.name)
        if kid_value is None:
            raise ValueError(
                f"No online KID value was found for fold {fold_id} at {snapshot_path.name}"
            )

        fold_snapshot_rows.append({
            "fold_id": fold_id,
            "snapshot_path": as_repo_relative(REPO_ROOT, snapshot_path),
            "snapshot_kimg": parse_snapshot_kimg(snapshot_path),
            "kid50k_full": kid_value,
        })

    kid_snapshot_rows.extend(fold_snapshot_rows)
    best_row = sorted(fold_snapshot_rows, key=lambda row: (row["kid50k_full"], row["snapshot_kimg"]))[0]
    kid_rows.append(best_row)

write_csv_rows(NOTEBOOK_RESULTS_DIR / "kid_snapshot_results.csv", kid_snapshot_rows, list(kid_snapshot_rows[0].keys()))
write_csv_rows(NOTEBOOK_RESULTS_DIR / "kid_results.csv", kid_rows, list(kid_rows[0].keys()))
kid_snapshot_df = pd.DataFrame(kid_snapshot_rows)
kid_df = pd.DataFrame(kid_rows)
display(kid_snapshot_df)
display(kid_df)

# This figure shows how KID moved across saved snapshots inside each fold.
fig, axis = plt.subplots(figsize=(9, 5))
for fold_id in sorted(kid_snapshot_df["fold_id"].unique()):
    current = kid_snapshot_df[kid_snapshot_df["fold_id"] == fold_id].sort_values("snapshot_kimg")
    axis.plot(current["snapshot_kimg"], current["kid50k_full"], marker="o", label=f"fold {fold_id}")
axis.set_xlabel("Snapshot kimg")
axis.set_ylabel("KID (lower is better)")
axis.set_title("KID progress by fold")
axis.legend()
fig.tight_layout()
fig.savefig(NOTEBOOK_RESULTS_DIR / "kid_progress_by_fold.png", dpi=200)
plt.show()
# Out:
#     fold_id                                      snapshot_path  snapshot_kimg  \
# 0         1  checkpoints/24_train_stylegan3_make_images_dib...             40
# 1         1  checkpoints/24_train_stylegan3_make_images_dib...             80
# 2         1  checkpoints/24_train_stylegan3_make_images_dib...            120
# 3         1  checkpoints/24_train_stylegan3_make_images_dib...            160
# 4         1  checkpoints/24_train_stylegan3_make_images_dib...            200
# 5         2  checkpoints/24_train_stylegan3_make_images_dib...             40
# 6         2  checkpoints/24_train_stylegan3_make_images_dib...             80
# 7         2  checkpoints/24_train_stylegan3_make_images_dib...            120
# 8         2  checkpoints/24_train_stylegan3_make_images_dib...            160
# 9         2  checkpoints/24_train_stylegan3_make_images_dib...            200
# 10        3  checkpoints/24_train_stylegan3_make_images_dib...             40
# 11        3  checkpoints/24_train_stylegan3_make_images_dib...             80
# 12        3  checkpoints/24_train_stylegan3_make_images_dib...            120
# 13        3  checkpoints/24_train_stylegan3_make_images_dib...            160
# 14        3  checkpoints/24_train_stylegan3_make_images_dib...            200
# 15        4  checkpoints/24_train_stylegan3_make_images_dib...             40
# 16        4  checkpoints/24_train_stylegan3_make_images_dib...             80
# 17        4  checkpoints/24_train_stylegan3_make_images_dib...            120
# 18        4  checkpoints/24_train_stylegan3_make_images_dib...            160
# 19        4  checkpoints/24_train_stylegan3_make_images_dib...            200
# 20        5  checkpoints/24_train_stylegan3_make_images_dib...             40
# 21        5  checkpoints/24_train_stylegan3_make_images_dib...             80
# 22        5  checkpoints/24_train_stylegan3_make_images_dib...            120
# 23        5  checkpoints/24_train_stylegan3_make_images_dib...            160
# 24        5  checkpoints/24_train_stylegan3_make_images_dib...            200
#
#     kid50k_full
# 0      0.233239
# 1      0.151993
# 2      0.121007
# 3      0.087318
# 4      0.076788
# 5      0.322689
# 6      0.184184
# 7      0.081312
# 8      0.086668
# 9      0.052895
# 10     0.340028
# 11     0.126895
# 12     0.063196
# 13     0.088771
# 14     0.105754
# 15     0.452983
# 16     0.156883
# 17     0.072113
# 18     0.041956
# 19     0.097972
# 20     0.396563
# 21     0.176231
# 22     0.073997
# 23     0.073210
# 24     0.102329
#    fold_id                                      snapshot_path  snapshot_kimg  \
# 0        1  checkpoints/24_train_stylegan3_make_images_dib...            200
# 1        2  checkpoints/24_train_stylegan3_make_images_dib...            200
# 2        3  checkpoints/24_train_stylegan3_make_images_dib...            120
# 3        4  checkpoints/24_train_stylegan3_make_images_dib...            160
# 4        5  checkpoints/24_train_stylegan3_make_images_dib...            160
#
#    kid50k_full
# 0     0.076788
# 1     0.052895
# 2     0.063196
# 3     0.041956
# 4     0.073210

# %%
# We generate exactly the number of synthetic minority images needed to balance each training fold.
kid_lookup = {int(row["fold_id"]): row for row in kid_rows}
generated_rows_256 = []

for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    snapshot_path = REPO_ROOT / kid_lookup[fold_id]["snapshot_path"]
    generated_256_dir = GAN_IMAGES_256_DIR / f"fold_{fold_id}"
    if generated_256_dir.exists():
        shutil.rmtree(generated_256_dir)
    generated_256_dir.mkdir(parents=True, exist_ok=True)

    needed_count = int(fold_plan["needed_gan_count_224"])
    start_seed = GENERATE_START_SEED + (fold_id * 10000)
    end_seed = start_seed + needed_count - 1
    seed_text = f"{start_seed}-{end_seed}"
    fold_result_dir = NOTEBOOK_RESULTS_DIR / f"fold_{fold_id}"
    generate_log_path = fold_result_dir / "generate.log"

    report = run_command(
        build_stylegan_command(
            "gen_images.py",
            f"--network={snapshot_path}",
            f"--outdir={generated_256_dir}",
            f"--seeds={seed_text}",
            f"--noise-mode={GENERATE_NOISE_MODE}",
            "--trunc=1",
        ),
        STYLEGAN_DIR,
        live_log_path=generate_log_path,
        notebook_mode=LONG_COMMAND_NOTEBOOK_MODE,
        extra_env=STYLEGAN_EXTRA_ENV,
    )
    write_json(fold_result_dir / "generate_report.json", report)
    if report["returncode"] != 0:
        raise RuntimeError(f"StyleGAN3 generation failed for fold {fold_id}")

    generated_files = sorted(generated_256_dir.glob("seed*.png"))
    if len(generated_files) != needed_count:
        raise AssertionError(
            f"Fold {fold_id} should have {needed_count} generated 256 images, but found {len(generated_files)}."
        )

    for generated_file in generated_files:
        seed_value = int(generated_file.stem.replace("seed", ""))
        test_fold_ids = [value for value in FOLDS_TO_RUN if value != fold_id]
        test_fold_text = ",".join(str(value) for value in test_fold_ids)
        generated_rows_256.append({
            "dataset_name": "dibas",
            "gan_image_id": f"fold{fold_id}_seed{seed_value}_256",
            "fold_id": fold_id,
            "round_id": fold_id,
            "train_fold_id": fold_id,
            "test_fold_ids": test_fold_text,
            "binary_label": 0,
            "binary_group": "cocci",
            "seed": seed_value,
            "image_size": GAN_PATCH_SIZE,
            "file_path": as_repo_relative(REPO_ROOT, generated_file),
            "snapshot_path": as_repo_relative(REPO_ROOT, snapshot_path),
            "source_type": "stylegan3_generated",
        })

write_csv_rows(MANIFESTS_DIR / "stylegan3_generated_manifest_256.csv", generated_rows_256, list(generated_rows_256[0].keys()))
display(pd.DataFrame(generated_rows_256[:10]))
# Out:
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\24_train_stylegan3_make_images_dibas\fold_1\00000-stylegan3-t-fold_1_minority_256-gpus1-batch8-gamma0.8192\network-snapshot-000200.pkl"...
# Generating image for seed 20000 (0/270) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 20001 (1/270) ...
# Generating image for seed 20002 (2/270) ...
# Generating image for seed 20003 (3/270) ...
# Generating image for seed 20004 (4/270) ...
# Generating image for seed 20005 (5/270) ...
# Generating image for seed 20006 (6/270) ...
# Generating image for seed 20007 (7/270) ...
# Generating image for seed 20008 (8/270) ...
# Generating image for seed 20009 (9/270) ...
# Generating image for seed 20010 (10/270) ...
# Generating image for seed 20011 (11/270) ...
# Generating image for seed 20012 (12/270) ...
# Generating image for seed 20013 (13/270) ...
# Generating image for seed 20014 (14/270) ...
# Generating image for seed 20015 (15/270) ...
# Generating image for seed 20016 (16/270) ...
# Generating image for seed 20017 (17/270) ...
# Generating image for seed 20018 (18/270) ...
# Generating image for seed 20019 (19/270) ...
# Generating image for seed 20020 (20/270) ...
# Generating image for seed 20021 (21/270) ...
# Generating image for seed 20022 (22/270) ...
# Generating image for seed 20023 (23/270) ...
# Generating image for seed 20024 (24/270) ...
# Generating image for seed 20025 (25/270) ...
# Generating image for seed 20026 (26/270) ...
# Generating image for seed 20027 (27/270) ...
# Generating image for seed 20028 (28/270) ...
# Generating image for seed 20029 (29/270) ...
# Generating image for seed 20030 (30/270) ...
# Generating image for seed 20031 (31/270) ...
# Generating image for seed 20032 (32/270) ...
# Generating image for seed 20033 (33/270) ...
# Generating image for seed 20034 (34/270) ...
# Generating image for seed 20035 (35/270) ...
# Generating image for seed 20036 (36/270) ...
# Generating image for seed 20037 (37/270) ...
# Generating image for seed 20038 (38/270) ...
# Generating image for seed 20039 (39/270) ...
# Generating image for seed 20040 (40/270) ...
# Generating image for seed 20041 (41/270) ...
# Generating image for seed 20042 (42/270) ...
# Generating image for seed 20043 (43/270) ...
# Generating image for seed 20044 (44/270) ...
# Generating image for seed 20045 (45/270) ...
# Generating image for seed 20046 (46/270) ...
# Generating image for seed 20047 (47/270) ...
# Generating image for seed 20048 (48/270) ...
# Generating image for seed 20049 (49/270) ...
# Generating image for seed 20050 (50/270) ...
# Generating image for seed 20051 (51/270) ...
# Generating image for seed 20052 (52/270) ...
# Generating image for seed 20053 (53/270) ...
# Generating image for seed 20054 (54/270) ...
# Generating image for seed 20055 (55/270) ...
# Generating image for seed 20056 (56/270) ...
# Generating image for seed 20057 (57/270) ...
# Generating image for seed 20058 (58/270) ...
# Generating image for seed 20059 (59/270) ...
# Generating image for seed 20060 (60/270) ...
# Generating image for seed 20061 (61/270) ...
# Generating image for seed 20062 (62/270) ...
# Generating image for seed 20063 (63/270) ...
# Generating image for seed 20064 (64/270) ...
# Generating image for seed 20065 (65/270) ...
# Generating image for seed 20066 (66/270) ...
# Generating image for seed 20067 (67/270) ...
# Generating image for seed 20068 (68/270) ...
# Generating image for seed 20069 (69/270) ...
# Generating image for seed 20070 (70/270) ...
# Generating image for seed 20071 (71/270) ...
# Generating image for seed 20072 (72/270) ...
# Generating image for seed 20073 (73/270) ...
# Generating image for seed 20074 (74/270) ...
# Generating image for seed 20075 (75/270) ...
# Generating image for seed 20076 (76/270) ...
# Generating image for seed 20077 (77/270) ...
# Generating image for seed 20078 (78/270) ...
# Generating image for seed 20079 (79/270) ...
# Generating image for seed 20080 (80/270) ...
# Generating image for seed 20081 (81/270) ...
# Generating image for seed 20082 (82/270) ...
# Generating image for seed 20083 (83/270) ...
# Generating image for seed 20084 (84/270) ...
# Generating image for seed 20085 (85/270) ...
# Generating image for seed 20086 (86/270) ...
# Generating image for seed 20087 (87/270) ...
# Generating image for seed 20088 (88/270) ...
# Generating image for seed 20089 (89/270) ...
# Generating image for seed 20090 (90/270) ...
# Generating image for seed 20091 (91/270) ...
# Generating image for seed 20092 (92/270) ...
# Generating image for seed 20093 (93/270) ...
# Generating image for seed 20094 (94/270) ...
# Generating image for seed 20095 (95/270) ...
# Generating image for seed 20096 (96/270) ...
# Generating image for seed 20097 (97/270) ...
# Generating image for seed 20098 (98/270) ...
# Generating image for seed 20099 (99/270) ...
# Generating image for seed 20100 (100/270) ...
# Generating image for seed 20101 (101/270) ...
# Generating image for seed 20102 (102/270) ...
# Generating image for seed 20103 (103/270) ...
# Generating image for seed 20104 (104/270) ...
# Generating image for seed 20105 (105/270) ...
# Generating image for seed 20106 (106/270) ...
# Generating image for seed 20107 (107/270) ...
# Generating image for seed 20108 (108/270) ...
# Generating image for seed 20109 (109/270) ...
# Generating image for seed 20110 (110/270) ...
# Generating image for seed 20111 (111/270) ...
# Generating image for seed 20112 (112/270) ...
# Generating image for seed 20113 (113/270) ...
# Generating image for seed 20114 (114/270) ...
# Generating image for seed 20115 (115/270) ...
# Generating image for seed 20116 (116/270) ...
# Generating image for seed 20117 (117/270) ...
# Generating image for seed 20118 (118/270) ...
# Generating image for seed 20119 (119/270) ...
# Generating image for seed 20120 (120/270) ...
# Generating image for seed 20121 (121/270) ...
# Generating image for seed 20122 (122/270) ...
# Generating image for seed 20123 (123/270) ...
# Generating image for seed 20124 (124/270) ...
# Generating image for seed 20125 (125/270) ...
# Generating image for seed 20126 (126/270) ...
# Generating image for seed 20127 (127/270) ...
# Generating image for seed 20128 (128/270) ...
# Generating image for seed 20129 (129/270) ...
# Generating image for seed 20130 (130/270) ...
# Generating image for seed 20131 (131/270) ...
# Generating image for seed 20132 (132/270) ...
# Generating image for seed 20133 (133/270) ...
# Generating image for seed 20134 (134/270) ...
# Generating image for seed 20135 (135/270) ...
# Generating image for seed 20136 (136/270) ...
# Generating image for seed 20137 (137/270) ...
# Generating image for seed 20138 (138/270) ...
# Generating image for seed 20139 (139/270) ...
# Generating image for seed 20140 (140/270) ...
# Generating image for seed 20141 (141/270) ...
# Generating image for seed 20142 (142/270) ...
# Generating image for seed 20143 (143/270) ...
# Generating image for seed 20144 (144/270) ...
# Generating image for seed 20145 (145/270) ...
# Generating image for seed 20146 (146/270) ...
# Generating image for seed 20147 (147/270) ...
# Generating image for seed 20148 (148/270) ...
# Generating image for seed 20149 (149/270) ...
# Generating image for seed 20150 (150/270) ...
# Generating image for seed 20151 (151/270) ...
# Generating image for seed 20152 (152/270) ...
# Generating image for seed 20153 (153/270) ...
# Generating image for seed 20154 (154/270) ...
# Generating image for seed 20155 (155/270) ...
# Generating image for seed 20156 (156/270) ...
# Generating image for seed 20157 (157/270) ...
# Generating image for seed 20158 (158/270) ...
# Generating image for seed 20159 (159/270) ...
# Generating image for seed 20160 (160/270) ...
# Generating image for seed 20161 (161/270) ...
# Generating image for seed 20162 (162/270) ...
# Generating image for seed 20163 (163/270) ...
# Generating image for seed 20164 (164/270) ...
# Generating image for seed 20165 (165/270) ...
# Generating image for seed 20166 (166/270) ...
# Generating image for seed 20167 (167/270) ...
# Generating image for seed 20168 (168/270) ...
# Generating image for seed 20169 (169/270) ...
# Generating image for seed 20170 (170/270) ...
# Generating image for seed 20171 (171/270) ...
# Generating image for seed 20172 (172/270) ...
# Generating image for seed 20173 (173/270) ...
# Generating image for seed 20174 (174/270) ...
# Generating image for seed 20175 (175/270) ...
# Generating image for seed 20176 (176/270) ...
# Generating image for seed 20177 (177/270) ...
# Generating image for seed 20178 (178/270) ...
# Generating image for seed 20179 (179/270) ...
# Generating image for seed 20180 (180/270) ...
# Generating image for seed 20181 (181/270) ...
# Generating image for seed 20182 (182/270) ...
# Generating image for seed 20183 (183/270) ...
# Generating image for seed 20184 (184/270) ...
# Generating image for seed 20185 (185/270) ...
# Generating image for seed 20186 (186/270) ...
# Generating image for seed 20187 (187/270) ...
# Generating image for seed 20188 (188/270) ...
# Generating image for seed 20189 (189/270) ...
# Generating image for seed 20190 (190/270) ...
# Generating image for seed 20191 (191/270) ...
# Generating image for seed 20192 (192/270) ...
# Generating image for seed 20193 (193/270) ...
# Generating image for seed 20194 (194/270) ...
# Generating image for seed 20195 (195/270) ...
# Generating image for seed 20196 (196/270) ...
# Generating image for seed 20197 (197/270) ...
# Generating image for seed 20198 (198/270) ...
# Generating image for seed 20199 (199/270) ...
# Generating image for seed 20200 (200/270) ...
# Generating image for seed 20201 (201/270) ...
# Generating image for seed 20202 (202/270) ...
# Generating image for seed 20203 (203/270) ...
# Generating image for seed 20204 (204/270) ...
# Generating image for seed 20205 (205/270) ...
# Generating image for seed 20206 (206/270) ...
# Generating image for seed 20207 (207/270) ...
# Generating image for seed 20208 (208/270) ...
# Generating image for seed 20209 (209/270) ...
# Generating image for seed 20210 (210/270) ...
# Generating image for seed 20211 (211/270) ...
# Generating image for seed 20212 (212/270) ...
# Generating image for seed 20213 (213/270) ...
# Generating image for seed 20214 (214/270) ...
# Generating image for seed 20215 (215/270) ...
# Generating image for seed 20216 (216/270) ...
# Generating image for seed 20217 (217/270) ...
# Generating image for seed 20218 (218/270) ...
# Generating image for seed 20219 (219/270) ...
# Generating image for seed 20220 (220/270) ...
# Generating image for seed 20221 (221/270) ...
# Generating image for seed 20222 (222/270) ...
# Generating image for seed 20223 (223/270) ...
# Generating image for seed 20224 (224/270) ...
# Generating image for seed 20225 (225/270) ...
# Generating image for seed 20226 (226/270) ...
# Generating image for seed 20227 (227/270) ...
# Generating image for seed 20228 (228/270) ...
# Generating image for seed 20229 (229/270) ...
# Generating image for seed 20230 (230/270) ...
# Generating image for seed 20231 (231/270) ...
# Generating image for seed 20232 (232/270) ...
# Generating image for seed 20233 (233/270) ...
# Generating image for seed 20234 (234/270) ...
# Generating image for seed 20235 (235/270) ...
# Generating image for seed 20236 (236/270) ...
# Generating image for seed 20237 (237/270) ...
# Generating image for seed 20238 (238/270) ...
# Generating image for seed 20239 (239/270) ...
# Generating image for seed 20240 (240/270) ...
# Generating image for seed 20241 (241/270) ...
# Generating image for seed 20242 (242/270) ...
# Generating image for seed 20243 (243/270) ...
# Generating image for seed 20244 (244/270) ...
# Generating image for seed 20245 (245/270) ...
# Generating image for seed 20246 (246/270) ...
# Generating image for seed 20247 (247/270) ...
# Generating image for seed 20248 (248/270) ...
# Generating image for seed 20249 (249/270) ...
# Generating image for seed 20250 (250/270) ...
# Generating image for seed 20251 (251/270) ...
# Generating image for seed 20252 (252/270) ...
# Generating image for seed 20253 (253/270) ...
# Generating image for seed 20254 (254/270) ...
# Generating image for seed 20255 (255/270) ...
# Generating image for seed 20256 (256/270) ...
# Generating image for seed 20257 (257/270) ...
# Generating image for seed 20258 (258/270) ...
# Generating image for seed 20259 (259/270) ...
# Generating image for seed 20260 (260/270) ...
# Generating image for seed 20261 (261/270) ...
# Generating image for seed 20262 (262/270) ...
# Generating image for seed 20263 (263/270) ...
# Generating image for seed 20264 (264/270) ...
# Generating image for seed 20265 (265/270) ...
# Generating image for seed 20266 (266/270) ...
# Generating image for seed 20267 (267/270) ...
# Generating image for seed 20268 (268/270) ...
# Generating image for seed 20269 (269/270) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\24_train_stylegan3_make_images_dibas\fold_2\00000-stylegan3-t-fold_2_minority_256-gpus1-batch8-gamma0.8192\network-snapshot-000200.pkl"...
# Generating image for seed 30000 (0/270) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 30001 (1/270) ...
# Generating image for seed 30002 (2/270) ...
# Generating image for seed 30003 (3/270) ...
# Generating image for seed 30004 (4/270) ...
# Generating image for seed 30005 (5/270) ...
# Generating image for seed 30006 (6/270) ...
# Generating image for seed 30007 (7/270) ...
# Generating image for seed 30008 (8/270) ...
# Generating image for seed 30009 (9/270) ...
# Generating image for seed 30010 (10/270) ...
# Generating image for seed 30011 (11/270) ...
# Generating image for seed 30012 (12/270) ...
# Generating image for seed 30013 (13/270) ...
# Generating image for seed 30014 (14/270) ...
# Generating image for seed 30015 (15/270) ...
# Generating image for seed 30016 (16/270) ...
# Generating image for seed 30017 (17/270) ...
# Generating image for seed 30018 (18/270) ...
# Generating image for seed 30019 (19/270) ...
# Generating image for seed 30020 (20/270) ...
# Generating image for seed 30021 (21/270) ...
# Generating image for seed 30022 (22/270) ...
# Generating image for seed 30023 (23/270) ...
# Generating image for seed 30024 (24/270) ...
# Generating image for seed 30025 (25/270) ...
# Generating image for seed 30026 (26/270) ...
# Generating image for seed 30027 (27/270) ...
# Generating image for seed 30028 (28/270) ...
# Generating image for seed 30029 (29/270) ...
# Generating image for seed 30030 (30/270) ...
# Generating image for seed 30031 (31/270) ...
# Generating image for seed 30032 (32/270) ...
# Generating image for seed 30033 (33/270) ...
# Generating image for seed 30034 (34/270) ...
# Generating image for seed 30035 (35/270) ...
# Generating image for seed 30036 (36/270) ...
# Generating image for seed 30037 (37/270) ...
# Generating image for seed 30038 (38/270) ...
# Generating image for seed 30039 (39/270) ...
# Generating image for seed 30040 (40/270) ...
# Generating image for seed 30041 (41/270) ...
# Generating image for seed 30042 (42/270) ...
# Generating image for seed 30043 (43/270) ...
# Generating image for seed 30044 (44/270) ...
# Generating image for seed 30045 (45/270) ...
# Generating image for seed 30046 (46/270) ...
# Generating image for seed 30047 (47/270) ...
# Generating image for seed 30048 (48/270) ...
# Generating image for seed 30049 (49/270) ...
# Generating image for seed 30050 (50/270) ...
# Generating image for seed 30051 (51/270) ...
# Generating image for seed 30052 (52/270) ...
# Generating image for seed 30053 (53/270) ...
# Generating image for seed 30054 (54/270) ...
# Generating image for seed 30055 (55/270) ...
# Generating image for seed 30056 (56/270) ...
# Generating image for seed 30057 (57/270) ...
# Generating image for seed 30058 (58/270) ...
# Generating image for seed 30059 (59/270) ...
# Generating image for seed 30060 (60/270) ...
# Generating image for seed 30061 (61/270) ...
# Generating image for seed 30062 (62/270) ...
# Generating image for seed 30063 (63/270) ...
# Generating image for seed 30064 (64/270) ...
# Generating image for seed 30065 (65/270) ...
# Generating image for seed 30066 (66/270) ...
# Generating image for seed 30067 (67/270) ...
# Generating image for seed 30068 (68/270) ...
# Generating image for seed 30069 (69/270) ...
# Generating image for seed 30070 (70/270) ...
# Generating image for seed 30071 (71/270) ...
# Generating image for seed 30072 (72/270) ...
# Generating image for seed 30073 (73/270) ...
# Generating image for seed 30074 (74/270) ...
# Generating image for seed 30075 (75/270) ...
# Generating image for seed 30076 (76/270) ...
# Generating image for seed 30077 (77/270) ...
# Generating image for seed 30078 (78/270) ...
# Generating image for seed 30079 (79/270) ...
# Generating image for seed 30080 (80/270) ...
# Generating image for seed 30081 (81/270) ...
# Generating image for seed 30082 (82/270) ...
# Generating image for seed 30083 (83/270) ...
# Generating image for seed 30084 (84/270) ...
# Generating image for seed 30085 (85/270) ...
# Generating image for seed 30086 (86/270) ...
# Generating image for seed 30087 (87/270) ...
# Generating image for seed 30088 (88/270) ...
# Generating image for seed 30089 (89/270) ...
# Generating image for seed 30090 (90/270) ...
# Generating image for seed 30091 (91/270) ...
# Generating image for seed 30092 (92/270) ...
# Generating image for seed 30093 (93/270) ...
# Generating image for seed 30094 (94/270) ...
# Generating image for seed 30095 (95/270) ...
# Generating image for seed 30096 (96/270) ...
# Generating image for seed 30097 (97/270) ...
# Generating image for seed 30098 (98/270) ...
# Generating image for seed 30099 (99/270) ...
# Generating image for seed 30100 (100/270) ...
# Generating image for seed 30101 (101/270) ...
# Generating image for seed 30102 (102/270) ...
# Generating image for seed 30103 (103/270) ...
# Generating image for seed 30104 (104/270) ...
# Generating image for seed 30105 (105/270) ...
# Generating image for seed 30106 (106/270) ...
# Generating image for seed 30107 (107/270) ...
# Generating image for seed 30108 (108/270) ...
# Generating image for seed 30109 (109/270) ...
# Generating image for seed 30110 (110/270) ...
# Generating image for seed 30111 (111/270) ...
# Generating image for seed 30112 (112/270) ...
# Generating image for seed 30113 (113/270) ...
# Generating image for seed 30114 (114/270) ...
# Generating image for seed 30115 (115/270) ...
# Generating image for seed 30116 (116/270) ...
# Generating image for seed 30117 (117/270) ...
# Generating image for seed 30118 (118/270) ...
# Generating image for seed 30119 (119/270) ...
# Generating image for seed 30120 (120/270) ...
# Generating image for seed 30121 (121/270) ...
# Generating image for seed 30122 (122/270) ...
# Generating image for seed 30123 (123/270) ...
# Generating image for seed 30124 (124/270) ...
# Generating image for seed 30125 (125/270) ...
# Generating image for seed 30126 (126/270) ...
# Generating image for seed 30127 (127/270) ...
# Generating image for seed 30128 (128/270) ...
# Generating image for seed 30129 (129/270) ...
# Generating image for seed 30130 (130/270) ...
# Generating image for seed 30131 (131/270) ...
# Generating image for seed 30132 (132/270) ...
# Generating image for seed 30133 (133/270) ...
# Generating image for seed 30134 (134/270) ...
# Generating image for seed 30135 (135/270) ...
# Generating image for seed 30136 (136/270) ...
# Generating image for seed 30137 (137/270) ...
# Generating image for seed 30138 (138/270) ...
# Generating image for seed 30139 (139/270) ...
# Generating image for seed 30140 (140/270) ...
# Generating image for seed 30141 (141/270) ...
# Generating image for seed 30142 (142/270) ...
# Generating image for seed 30143 (143/270) ...
# Generating image for seed 30144 (144/270) ...
# Generating image for seed 30145 (145/270) ...
# Generating image for seed 30146 (146/270) ...
# Generating image for seed 30147 (147/270) ...
# Generating image for seed 30148 (148/270) ...
# Generating image for seed 30149 (149/270) ...
# Generating image for seed 30150 (150/270) ...
# Generating image for seed 30151 (151/270) ...
# Generating image for seed 30152 (152/270) ...
# Generating image for seed 30153 (153/270) ...
# Generating image for seed 30154 (154/270) ...
# Generating image for seed 30155 (155/270) ...
# Generating image for seed 30156 (156/270) ...
# Generating image for seed 30157 (157/270) ...
# Generating image for seed 30158 (158/270) ...
# Generating image for seed 30159 (159/270) ...
# Generating image for seed 30160 (160/270) ...
# Generating image for seed 30161 (161/270) ...
# Generating image for seed 30162 (162/270) ...
# Generating image for seed 30163 (163/270) ...
# Generating image for seed 30164 (164/270) ...
# Generating image for seed 30165 (165/270) ...
# Generating image for seed 30166 (166/270) ...
# Generating image for seed 30167 (167/270) ...
# Generating image for seed 30168 (168/270) ...
# Generating image for seed 30169 (169/270) ...
# Generating image for seed 30170 (170/270) ...
# Generating image for seed 30171 (171/270) ...
# Generating image for seed 30172 (172/270) ...
# Generating image for seed 30173 (173/270) ...
# Generating image for seed 30174 (174/270) ...
# Generating image for seed 30175 (175/270) ...
# Generating image for seed 30176 (176/270) ...
# Generating image for seed 30177 (177/270) ...
# Generating image for seed 30178 (178/270) ...
# Generating image for seed 30179 (179/270) ...
# Generating image for seed 30180 (180/270) ...
# Generating image for seed 30181 (181/270) ...
# Generating image for seed 30182 (182/270) ...
# Generating image for seed 30183 (183/270) ...
# Generating image for seed 30184 (184/270) ...
# Generating image for seed 30185 (185/270) ...
# Generating image for seed 30186 (186/270) ...
# Generating image for seed 30187 (187/270) ...
# Generating image for seed 30188 (188/270) ...
# Generating image for seed 30189 (189/270) ...
# Generating image for seed 30190 (190/270) ...
# Generating image for seed 30191 (191/270) ...
# Generating image for seed 30192 (192/270) ...
# Generating image for seed 30193 (193/270) ...
# Generating image for seed 30194 (194/270) ...
# Generating image for seed 30195 (195/270) ...
# Generating image for seed 30196 (196/270) ...
# Generating image for seed 30197 (197/270) ...
# Generating image for seed 30198 (198/270) ...
# Generating image for seed 30199 (199/270) ...
# Generating image for seed 30200 (200/270) ...
# Generating image for seed 30201 (201/270) ...
# Generating image for seed 30202 (202/270) ...
# Generating image for seed 30203 (203/270) ...
# Generating image for seed 30204 (204/270) ...
# Generating image for seed 30205 (205/270) ...
# Generating image for seed 30206 (206/270) ...
# Generating image for seed 30207 (207/270) ...
# Generating image for seed 30208 (208/270) ...
# Generating image for seed 30209 (209/270) ...
# Generating image for seed 30210 (210/270) ...
# Generating image for seed 30211 (211/270) ...
# Generating image for seed 30212 (212/270) ...
# Generating image for seed 30213 (213/270) ...
# Generating image for seed 30214 (214/270) ...
# Generating image for seed 30215 (215/270) ...
# Generating image for seed 30216 (216/270) ...
# Generating image for seed 30217 (217/270) ...
# Generating image for seed 30218 (218/270) ...
# Generating image for seed 30219 (219/270) ...
# Generating image for seed 30220 (220/270) ...
# Generating image for seed 30221 (221/270) ...
# Generating image for seed 30222 (222/270) ...
# Generating image for seed 30223 (223/270) ...
# Generating image for seed 30224 (224/270) ...
# Generating image for seed 30225 (225/270) ...
# Generating image for seed 30226 (226/270) ...
# Generating image for seed 30227 (227/270) ...
# Generating image for seed 30228 (228/270) ...
# Generating image for seed 30229 (229/270) ...
# Generating image for seed 30230 (230/270) ...
# Generating image for seed 30231 (231/270) ...
# Generating image for seed 30232 (232/270) ...
# Generating image for seed 30233 (233/270) ...
# Generating image for seed 30234 (234/270) ...
# Generating image for seed 30235 (235/270) ...
# Generating image for seed 30236 (236/270) ...
# Generating image for seed 30237 (237/270) ...
# Generating image for seed 30238 (238/270) ...
# Generating image for seed 30239 (239/270) ...
# Generating image for seed 30240 (240/270) ...
# Generating image for seed 30241 (241/270) ...
# Generating image for seed 30242 (242/270) ...
# Generating image for seed 30243 (243/270) ...
# Generating image for seed 30244 (244/270) ...
# Generating image for seed 30245 (245/270) ...
# Generating image for seed 30246 (246/270) ...
# Generating image for seed 30247 (247/270) ...
# Generating image for seed 30248 (248/270) ...
# Generating image for seed 30249 (249/270) ...
# Generating image for seed 30250 (250/270) ...
# Generating image for seed 30251 (251/270) ...
# Generating image for seed 30252 (252/270) ...
# Generating image for seed 30253 (253/270) ...
# Generating image for seed 30254 (254/270) ...
# Generating image for seed 30255 (255/270) ...
# Generating image for seed 30256 (256/270) ...
# Generating image for seed 30257 (257/270) ...
# Generating image for seed 30258 (258/270) ...
# Generating image for seed 30259 (259/270) ...
# Generating image for seed 30260 (260/270) ...
# Generating image for seed 30261 (261/270) ...
# Generating image for seed 30262 (262/270) ...
# Generating image for seed 30263 (263/270) ...
# Generating image for seed 30264 (264/270) ...
# Generating image for seed 30265 (265/270) ...
# Generating image for seed 30266 (266/270) ...
# Generating image for seed 30267 (267/270) ...
# Generating image for seed 30268 (268/270) ...
# Generating image for seed 30269 (269/270) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\24_train_stylegan3_make_images_dibas\fold_3\00000-stylegan3-t-fold_3_minority_256-gpus1-batch8-gamma0.8192\network-snapshot-000120.pkl"...
# Generating image for seed 40000 (0/270) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 40001 (1/270) ...
# Generating image for seed 40002 (2/270) ...
# Generating image for seed 40003 (3/270) ...
# Generating image for seed 40004 (4/270) ...
# Generating image for seed 40005 (5/270) ...
# Generating image for seed 40006 (6/270) ...
# Generating image for seed 40007 (7/270) ...
# Generating image for seed 40008 (8/270) ...
# Generating image for seed 40009 (9/270) ...
# Generating image for seed 40010 (10/270) ...
# Generating image for seed 40011 (11/270) ...
# Generating image for seed 40012 (12/270) ...
# Generating image for seed 40013 (13/270) ...
# Generating image for seed 40014 (14/270) ...
# Generating image for seed 40015 (15/270) ...
# Generating image for seed 40016 (16/270) ...
# Generating image for seed 40017 (17/270) ...
# Generating image for seed 40018 (18/270) ...
# Generating image for seed 40019 (19/270) ...
# Generating image for seed 40020 (20/270) ...
# Generating image for seed 40021 (21/270) ...
# Generating image for seed 40022 (22/270) ...
# Generating image for seed 40023 (23/270) ...
# Generating image for seed 40024 (24/270) ...
# Generating image for seed 40025 (25/270) ...
# Generating image for seed 40026 (26/270) ...
# Generating image for seed 40027 (27/270) ...
# Generating image for seed 40028 (28/270) ...
# Generating image for seed 40029 (29/270) ...
# Generating image for seed 40030 (30/270) ...
# Generating image for seed 40031 (31/270) ...
# Generating image for seed 40032 (32/270) ...
# Generating image for seed 40033 (33/270) ...
# Generating image for seed 40034 (34/270) ...
# Generating image for seed 40035 (35/270) ...
# Generating image for seed 40036 (36/270) ...
# Generating image for seed 40037 (37/270) ...
# Generating image for seed 40038 (38/270) ...
# Generating image for seed 40039 (39/270) ...
# Generating image for seed 40040 (40/270) ...
# Generating image for seed 40041 (41/270) ...
# Generating image for seed 40042 (42/270) ...
# Generating image for seed 40043 (43/270) ...
# Generating image for seed 40044 (44/270) ...
# Generating image for seed 40045 (45/270) ...
# Generating image for seed 40046 (46/270) ...
# Generating image for seed 40047 (47/270) ...
# Generating image for seed 40048 (48/270) ...
# Generating image for seed 40049 (49/270) ...
# Generating image for seed 40050 (50/270) ...
# Generating image for seed 40051 (51/270) ...
# Generating image for seed 40052 (52/270) ...
# Generating image for seed 40053 (53/270) ...
# Generating image for seed 40054 (54/270) ...
# Generating image for seed 40055 (55/270) ...
# Generating image for seed 40056 (56/270) ...
# Generating image for seed 40057 (57/270) ...
# Generating image for seed 40058 (58/270) ...
# Generating image for seed 40059 (59/270) ...
# Generating image for seed 40060 (60/270) ...
# Generating image for seed 40061 (61/270) ...
# Generating image for seed 40062 (62/270) ...
# Generating image for seed 40063 (63/270) ...
# Generating image for seed 40064 (64/270) ...
# Generating image for seed 40065 (65/270) ...
# Generating image for seed 40066 (66/270) ...
# Generating image for seed 40067 (67/270) ...
# Generating image for seed 40068 (68/270) ...
# Generating image for seed 40069 (69/270) ...
# Generating image for seed 40070 (70/270) ...
# Generating image for seed 40071 (71/270) ...
# Generating image for seed 40072 (72/270) ...
# Generating image for seed 40073 (73/270) ...
# Generating image for seed 40074 (74/270) ...
# Generating image for seed 40075 (75/270) ...
# Generating image for seed 40076 (76/270) ...
# Generating image for seed 40077 (77/270) ...
# Generating image for seed 40078 (78/270) ...
# Generating image for seed 40079 (79/270) ...
# Generating image for seed 40080 (80/270) ...
# Generating image for seed 40081 (81/270) ...
# Generating image for seed 40082 (82/270) ...
# Generating image for seed 40083 (83/270) ...
# Generating image for seed 40084 (84/270) ...
# Generating image for seed 40085 (85/270) ...
# Generating image for seed 40086 (86/270) ...
# Generating image for seed 40087 (87/270) ...
# Generating image for seed 40088 (88/270) ...
# Generating image for seed 40089 (89/270) ...
# Generating image for seed 40090 (90/270) ...
# Generating image for seed 40091 (91/270) ...
# Generating image for seed 40092 (92/270) ...
# Generating image for seed 40093 (93/270) ...
# Generating image for seed 40094 (94/270) ...
# Generating image for seed 40095 (95/270) ...
# Generating image for seed 40096 (96/270) ...
# Generating image for seed 40097 (97/270) ...
# Generating image for seed 40098 (98/270) ...
# Generating image for seed 40099 (99/270) ...
# Generating image for seed 40100 (100/270) ...
# Generating image for seed 40101 (101/270) ...
# Generating image for seed 40102 (102/270) ...
# Generating image for seed 40103 (103/270) ...
# Generating image for seed 40104 (104/270) ...
# Generating image for seed 40105 (105/270) ...
# Generating image for seed 40106 (106/270) ...
# Generating image for seed 40107 (107/270) ...
# Generating image for seed 40108 (108/270) ...
# Generating image for seed 40109 (109/270) ...
# Generating image for seed 40110 (110/270) ...
# Generating image for seed 40111 (111/270) ...
# Generating image for seed 40112 (112/270) ...
# Generating image for seed 40113 (113/270) ...
# Generating image for seed 40114 (114/270) ...
# Generating image for seed 40115 (115/270) ...
# Generating image for seed 40116 (116/270) ...
# Generating image for seed 40117 (117/270) ...
# Generating image for seed 40118 (118/270) ...
# Generating image for seed 40119 (119/270) ...
# Generating image for seed 40120 (120/270) ...
# Generating image for seed 40121 (121/270) ...
# Generating image for seed 40122 (122/270) ...
# Generating image for seed 40123 (123/270) ...
# Generating image for seed 40124 (124/270) ...
# Generating image for seed 40125 (125/270) ...
# Generating image for seed 40126 (126/270) ...
# Generating image for seed 40127 (127/270) ...
# Generating image for seed 40128 (128/270) ...
# Generating image for seed 40129 (129/270) ...
# Generating image for seed 40130 (130/270) ...
# Generating image for seed 40131 (131/270) ...
# Generating image for seed 40132 (132/270) ...
# Generating image for seed 40133 (133/270) ...
# Generating image for seed 40134 (134/270) ...
# Generating image for seed 40135 (135/270) ...
# Generating image for seed 40136 (136/270) ...
# Generating image for seed 40137 (137/270) ...
# Generating image for seed 40138 (138/270) ...
# Generating image for seed 40139 (139/270) ...
# Generating image for seed 40140 (140/270) ...
# Generating image for seed 40141 (141/270) ...
# Generating image for seed 40142 (142/270) ...
# Generating image for seed 40143 (143/270) ...
# Generating image for seed 40144 (144/270) ...
# Generating image for seed 40145 (145/270) ...
# Generating image for seed 40146 (146/270) ...
# Generating image for seed 40147 (147/270) ...
# Generating image for seed 40148 (148/270) ...
# Generating image for seed 40149 (149/270) ...
# Generating image for seed 40150 (150/270) ...
# Generating image for seed 40151 (151/270) ...
# Generating image for seed 40152 (152/270) ...
# Generating image for seed 40153 (153/270) ...
# Generating image for seed 40154 (154/270) ...
# Generating image for seed 40155 (155/270) ...
# Generating image for seed 40156 (156/270) ...
# Generating image for seed 40157 (157/270) ...
# Generating image for seed 40158 (158/270) ...
# Generating image for seed 40159 (159/270) ...
# Generating image for seed 40160 (160/270) ...
# Generating image for seed 40161 (161/270) ...
# Generating image for seed 40162 (162/270) ...
# Generating image for seed 40163 (163/270) ...
# Generating image for seed 40164 (164/270) ...
# Generating image for seed 40165 (165/270) ...
# Generating image for seed 40166 (166/270) ...
# Generating image for seed 40167 (167/270) ...
# Generating image for seed 40168 (168/270) ...
# Generating image for seed 40169 (169/270) ...
# Generating image for seed 40170 (170/270) ...
# Generating image for seed 40171 (171/270) ...
# Generating image for seed 40172 (172/270) ...
# Generating image for seed 40173 (173/270) ...
# Generating image for seed 40174 (174/270) ...
# Generating image for seed 40175 (175/270) ...
# Generating image for seed 40176 (176/270) ...
# Generating image for seed 40177 (177/270) ...
# Generating image for seed 40178 (178/270) ...
# Generating image for seed 40179 (179/270) ...
# Generating image for seed 40180 (180/270) ...
# Generating image for seed 40181 (181/270) ...
# Generating image for seed 40182 (182/270) ...
# Generating image for seed 40183 (183/270) ...
# Generating image for seed 40184 (184/270) ...
# Generating image for seed 40185 (185/270) ...
# Generating image for seed 40186 (186/270) ...
# Generating image for seed 40187 (187/270) ...
# Generating image for seed 40188 (188/270) ...
# Generating image for seed 40189 (189/270) ...
# Generating image for seed 40190 (190/270) ...
# Generating image for seed 40191 (191/270) ...
# Generating image for seed 40192 (192/270) ...
# Generating image for seed 40193 (193/270) ...
# Generating image for seed 40194 (194/270) ...
# Generating image for seed 40195 (195/270) ...
# Generating image for seed 40196 (196/270) ...
# Generating image for seed 40197 (197/270) ...
# Generating image for seed 40198 (198/270) ...
# Generating image for seed 40199 (199/270) ...
# Generating image for seed 40200 (200/270) ...
# Generating image for seed 40201 (201/270) ...
# Generating image for seed 40202 (202/270) ...
# Generating image for seed 40203 (203/270) ...
# Generating image for seed 40204 (204/270) ...
# Generating image for seed 40205 (205/270) ...
# Generating image for seed 40206 (206/270) ...
# Generating image for seed 40207 (207/270) ...
# Generating image for seed 40208 (208/270) ...
# Generating image for seed 40209 (209/270) ...
# Generating image for seed 40210 (210/270) ...
# Generating image for seed 40211 (211/270) ...
# Generating image for seed 40212 (212/270) ...
# Generating image for seed 40213 (213/270) ...
# Generating image for seed 40214 (214/270) ...
# Generating image for seed 40215 (215/270) ...
# Generating image for seed 40216 (216/270) ...
# Generating image for seed 40217 (217/270) ...
# Generating image for seed 40218 (218/270) ...
# Generating image for seed 40219 (219/270) ...
# Generating image for seed 40220 (220/270) ...
# Generating image for seed 40221 (221/270) ...
# Generating image for seed 40222 (222/270) ...
# Generating image for seed 40223 (223/270) ...
# Generating image for seed 40224 (224/270) ...
# Generating image for seed 40225 (225/270) ...
# Generating image for seed 40226 (226/270) ...
# Generating image for seed 40227 (227/270) ...
# Generating image for seed 40228 (228/270) ...
# Generating image for seed 40229 (229/270) ...
# Generating image for seed 40230 (230/270) ...
# Generating image for seed 40231 (231/270) ...
# Generating image for seed 40232 (232/270) ...
# Generating image for seed 40233 (233/270) ...
# Generating image for seed 40234 (234/270) ...
# Generating image for seed 40235 (235/270) ...
# Generating image for seed 40236 (236/270) ...
# Generating image for seed 40237 (237/270) ...
# Generating image for seed 40238 (238/270) ...
# Generating image for seed 40239 (239/270) ...
# Generating image for seed 40240 (240/270) ...
# Generating image for seed 40241 (241/270) ...
# Generating image for seed 40242 (242/270) ...
# Generating image for seed 40243 (243/270) ...
# Generating image for seed 40244 (244/270) ...
# Generating image for seed 40245 (245/270) ...
# Generating image for seed 40246 (246/270) ...
# Generating image for seed 40247 (247/270) ...
# Generating image for seed 40248 (248/270) ...
# Generating image for seed 40249 (249/270) ...
# Generating image for seed 40250 (250/270) ...
# Generating image for seed 40251 (251/270) ...
# Generating image for seed 40252 (252/270) ...
# Generating image for seed 40253 (253/270) ...
# Generating image for seed 40254 (254/270) ...
# Generating image for seed 40255 (255/270) ...
# Generating image for seed 40256 (256/270) ...
# Generating image for seed 40257 (257/270) ...
# Generating image for seed 40258 (258/270) ...
# Generating image for seed 40259 (259/270) ...
# Generating image for seed 40260 (260/270) ...
# Generating image for seed 40261 (261/270) ...
# Generating image for seed 40262 (262/270) ...
# Generating image for seed 40263 (263/270) ...
# Generating image for seed 40264 (264/270) ...
# Generating image for seed 40265 (265/270) ...
# Generating image for seed 40266 (266/270) ...
# Generating image for seed 40267 (267/270) ...
# Generating image for seed 40268 (268/270) ...
# Generating image for seed 40269 (269/270) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\24_train_stylegan3_make_images_dibas\fold_4\00000-stylegan3-t-fold_4_minority_256-gpus1-batch8-gamma0.8192\network-snapshot-000160.pkl"...
# Generating image for seed 50000 (0/270) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 50001 (1/270) ...
# Generating image for seed 50002 (2/270) ...
# Generating image for seed 50003 (3/270) ...
# Generating image for seed 50004 (4/270) ...
# Generating image for seed 50005 (5/270) ...
# Generating image for seed 50006 (6/270) ...
# Generating image for seed 50007 (7/270) ...
# Generating image for seed 50008 (8/270) ...
# Generating image for seed 50009 (9/270) ...
# Generating image for seed 50010 (10/270) ...
# Generating image for seed 50011 (11/270) ...
# Generating image for seed 50012 (12/270) ...
# Generating image for seed 50013 (13/270) ...
# Generating image for seed 50014 (14/270) ...
# Generating image for seed 50015 (15/270) ...
# Generating image for seed 50016 (16/270) ...
# Generating image for seed 50017 (17/270) ...
# Generating image for seed 50018 (18/270) ...
# Generating image for seed 50019 (19/270) ...
# Generating image for seed 50020 (20/270) ...
# Generating image for seed 50021 (21/270) ...
# Generating image for seed 50022 (22/270) ...
# Generating image for seed 50023 (23/270) ...
# Generating image for seed 50024 (24/270) ...
# Generating image for seed 50025 (25/270) ...
# Generating image for seed 50026 (26/270) ...
# Generating image for seed 50027 (27/270) ...
# Generating image for seed 50028 (28/270) ...
# Generating image for seed 50029 (29/270) ...
# Generating image for seed 50030 (30/270) ...
# Generating image for seed 50031 (31/270) ...
# Generating image for seed 50032 (32/270) ...
# Generating image for seed 50033 (33/270) ...
# Generating image for seed 50034 (34/270) ...
# Generating image for seed 50035 (35/270) ...
# Generating image for seed 50036 (36/270) ...
# Generating image for seed 50037 (37/270) ...
# Generating image for seed 50038 (38/270) ...
# Generating image for seed 50039 (39/270) ...
# Generating image for seed 50040 (40/270) ...
# Generating image for seed 50041 (41/270) ...
# Generating image for seed 50042 (42/270) ...
# Generating image for seed 50043 (43/270) ...
# Generating image for seed 50044 (44/270) ...
# Generating image for seed 50045 (45/270) ...
# Generating image for seed 50046 (46/270) ...
# Generating image for seed 50047 (47/270) ...
# Generating image for seed 50048 (48/270) ...
# Generating image for seed 50049 (49/270) ...
# Generating image for seed 50050 (50/270) ...
# Generating image for seed 50051 (51/270) ...
# Generating image for seed 50052 (52/270) ...
# Generating image for seed 50053 (53/270) ...
# Generating image for seed 50054 (54/270) ...
# Generating image for seed 50055 (55/270) ...
# Generating image for seed 50056 (56/270) ...
# Generating image for seed 50057 (57/270) ...
# Generating image for seed 50058 (58/270) ...
# Generating image for seed 50059 (59/270) ...
# Generating image for seed 50060 (60/270) ...
# Generating image for seed 50061 (61/270) ...
# Generating image for seed 50062 (62/270) ...
# Generating image for seed 50063 (63/270) ...
# Generating image for seed 50064 (64/270) ...
# Generating image for seed 50065 (65/270) ...
# Generating image for seed 50066 (66/270) ...
# Generating image for seed 50067 (67/270) ...
# Generating image for seed 50068 (68/270) ...
# Generating image for seed 50069 (69/270) ...
# Generating image for seed 50070 (70/270) ...
# Generating image for seed 50071 (71/270) ...
# Generating image for seed 50072 (72/270) ...
# Generating image for seed 50073 (73/270) ...
# Generating image for seed 50074 (74/270) ...
# Generating image for seed 50075 (75/270) ...
# Generating image for seed 50076 (76/270) ...
# Generating image for seed 50077 (77/270) ...
# Generating image for seed 50078 (78/270) ...
# Generating image for seed 50079 (79/270) ...
# Generating image for seed 50080 (80/270) ...
# Generating image for seed 50081 (81/270) ...
# Generating image for seed 50082 (82/270) ...
# Generating image for seed 50083 (83/270) ...
# Generating image for seed 50084 (84/270) ...
# Generating image for seed 50085 (85/270) ...
# Generating image for seed 50086 (86/270) ...
# Generating image for seed 50087 (87/270) ...
# Generating image for seed 50088 (88/270) ...
# Generating image for seed 50089 (89/270) ...
# Generating image for seed 50090 (90/270) ...
# Generating image for seed 50091 (91/270) ...
# Generating image for seed 50092 (92/270) ...
# Generating image for seed 50093 (93/270) ...
# Generating image for seed 50094 (94/270) ...
# Generating image for seed 50095 (95/270) ...
# Generating image for seed 50096 (96/270) ...
# Generating image for seed 50097 (97/270) ...
# Generating image for seed 50098 (98/270) ...
# Generating image for seed 50099 (99/270) ...
# Generating image for seed 50100 (100/270) ...
# Generating image for seed 50101 (101/270) ...
# Generating image for seed 50102 (102/270) ...
# Generating image for seed 50103 (103/270) ...
# Generating image for seed 50104 (104/270) ...
# Generating image for seed 50105 (105/270) ...
# Generating image for seed 50106 (106/270) ...
# Generating image for seed 50107 (107/270) ...
# Generating image for seed 50108 (108/270) ...
# Generating image for seed 50109 (109/270) ...
# Generating image for seed 50110 (110/270) ...
# Generating image for seed 50111 (111/270) ...
# Generating image for seed 50112 (112/270) ...
# Generating image for seed 50113 (113/270) ...
# Generating image for seed 50114 (114/270) ...
# Generating image for seed 50115 (115/270) ...
# Generating image for seed 50116 (116/270) ...
# Generating image for seed 50117 (117/270) ...
# Generating image for seed 50118 (118/270) ...
# Generating image for seed 50119 (119/270) ...
# Generating image for seed 50120 (120/270) ...
# Generating image for seed 50121 (121/270) ...
# Generating image for seed 50122 (122/270) ...
# Generating image for seed 50123 (123/270) ...
# Generating image for seed 50124 (124/270) ...
# Generating image for seed 50125 (125/270) ...
# Generating image for seed 50126 (126/270) ...
# Generating image for seed 50127 (127/270) ...
# Generating image for seed 50128 (128/270) ...
# Generating image for seed 50129 (129/270) ...
# Generating image for seed 50130 (130/270) ...
# Generating image for seed 50131 (131/270) ...
# Generating image for seed 50132 (132/270) ...
# Generating image for seed 50133 (133/270) ...
# Generating image for seed 50134 (134/270) ...
# Generating image for seed 50135 (135/270) ...
# Generating image for seed 50136 (136/270) ...
# Generating image for seed 50137 (137/270) ...
# Generating image for seed 50138 (138/270) ...
# Generating image for seed 50139 (139/270) ...
# Generating image for seed 50140 (140/270) ...
# Generating image for seed 50141 (141/270) ...
# Generating image for seed 50142 (142/270) ...
# Generating image for seed 50143 (143/270) ...
# Generating image for seed 50144 (144/270) ...
# Generating image for seed 50145 (145/270) ...
# Generating image for seed 50146 (146/270) ...
# Generating image for seed 50147 (147/270) ...
# Generating image for seed 50148 (148/270) ...
# Generating image for seed 50149 (149/270) ...
# Generating image for seed 50150 (150/270) ...
# Generating image for seed 50151 (151/270) ...
# Generating image for seed 50152 (152/270) ...
# Generating image for seed 50153 (153/270) ...
# Generating image for seed 50154 (154/270) ...
# Generating image for seed 50155 (155/270) ...
# Generating image for seed 50156 (156/270) ...
# Generating image for seed 50157 (157/270) ...
# Generating image for seed 50158 (158/270) ...
# Generating image for seed 50159 (159/270) ...
# Generating image for seed 50160 (160/270) ...
# Generating image for seed 50161 (161/270) ...
# Generating image for seed 50162 (162/270) ...
# Generating image for seed 50163 (163/270) ...
# Generating image for seed 50164 (164/270) ...
# Generating image for seed 50165 (165/270) ...
# Generating image for seed 50166 (166/270) ...
# Generating image for seed 50167 (167/270) ...
# Generating image for seed 50168 (168/270) ...
# Generating image for seed 50169 (169/270) ...
# Generating image for seed 50170 (170/270) ...
# Generating image for seed 50171 (171/270) ...
# Generating image for seed 50172 (172/270) ...
# Generating image for seed 50173 (173/270) ...
# Generating image for seed 50174 (174/270) ...
# Generating image for seed 50175 (175/270) ...
# Generating image for seed 50176 (176/270) ...
# Generating image for seed 50177 (177/270) ...
# Generating image for seed 50178 (178/270) ...
# Generating image for seed 50179 (179/270) ...
# Generating image for seed 50180 (180/270) ...
# Generating image for seed 50181 (181/270) ...
# Generating image for seed 50182 (182/270) ...
# Generating image for seed 50183 (183/270) ...
# Generating image for seed 50184 (184/270) ...
# Generating image for seed 50185 (185/270) ...
# Generating image for seed 50186 (186/270) ...
# Generating image for seed 50187 (187/270) ...
# Generating image for seed 50188 (188/270) ...
# Generating image for seed 50189 (189/270) ...
# Generating image for seed 50190 (190/270) ...
# Generating image for seed 50191 (191/270) ...
# Generating image for seed 50192 (192/270) ...
# Generating image for seed 50193 (193/270) ...
# Generating image for seed 50194 (194/270) ...
# Generating image for seed 50195 (195/270) ...
# Generating image for seed 50196 (196/270) ...
# Generating image for seed 50197 (197/270) ...
# Generating image for seed 50198 (198/270) ...
# Generating image for seed 50199 (199/270) ...
# Generating image for seed 50200 (200/270) ...
# Generating image for seed 50201 (201/270) ...
# Generating image for seed 50202 (202/270) ...
# Generating image for seed 50203 (203/270) ...
# Generating image for seed 50204 (204/270) ...
# Generating image for seed 50205 (205/270) ...
# Generating image for seed 50206 (206/270) ...
# Generating image for seed 50207 (207/270) ...
# Generating image for seed 50208 (208/270) ...
# Generating image for seed 50209 (209/270) ...
# Generating image for seed 50210 (210/270) ...
# Generating image for seed 50211 (211/270) ...
# Generating image for seed 50212 (212/270) ...
# Generating image for seed 50213 (213/270) ...
# Generating image for seed 50214 (214/270) ...
# ...
# Generating image for seed 50262 (262/270) ...
# Generating image for seed 50263 (263/270) ...
# Generating image for seed 50264 (264/270) ...
# Generating image for seed 50265 (265/270) ...
# Generating image for seed 50266 (266/270) ...
# Generating image for seed 50267 (267/270) ...
# Generating image for seed 50268 (268/270) ...
# Generating image for seed 50269 (269/270) ...
# Loading networks from "C:\Users\FYP2610\Downloads\FYP2\checkpoints\24_train_stylegan3_make_images_dibas\fold_5\00000-stylegan3-t-fold_5_minority_256-gpus1-batch8-gamma0.8192\network-snapshot-000160.pkl"...
# Generating image for seed 60000 (0/270) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 60001 (1/270) ...
# Generating image for seed 60002 (2/270) ...
# Generating image for seed 60003 (3/270) ...
# Generating image for seed 60004 (4/270) ...
# Generating image for seed 60005 (5/270) ...
# Generating image for seed 60006 (6/270) ...
# Generating image for seed 60007 (7/270) ...
# Generating image for seed 60008 (8/270) ...
# Generating image for seed 60009 (9/270) ...
# Generating image for seed 60010 (10/270) ...
# Generating image for seed 60011 (11/270) ...
# Generating image for seed 60012 (12/270) ...
# Generating image for seed 60013 (13/270) ...
# Generating image for seed 60014 (14/270) ...
# Generating image for seed 60015 (15/270) ...
# Generating image for seed 60016 (16/270) ...
# Generating image for seed 60017 (17/270) ...
# Generating image for seed 60018 (18/270) ...
# Generating image for seed 60019 (19/270) ...
# Generating image for seed 60020 (20/270) ...
# Generating image for seed 60021 (21/270) ...
# Generating image for seed 60022 (22/270) ...
# Generating image for seed 60023 (23/270) ...
# Generating image for seed 60024 (24/270) ...
# Generating image for seed 60025 (25/270) ...
# Generating image for seed 60026 (26/270) ...
# Generating image for seed 60027 (27/270) ...
# Generating image for seed 60028 (28/270) ...
# Generating image for seed 60029 (29/270) ...
# Generating image for seed 60030 (30/270) ...
# Generating image for seed 60031 (31/270) ...
# Generating image for seed 60032 (32/270) ...
# Generating image for seed 60033 (33/270) ...
# Generating image for seed 60034 (34/270) ...
# Generating image for seed 60035 (35/270) ...
# Generating image for seed 60036 (36/270) ...
# Generating image for seed 60037 (37/270) ...
# Generating image for seed 60038 (38/270) ...
# Generating image for seed 60039 (39/270) ...
# Generating image for seed 60040 (40/270) ...
# Generating image for seed 60041 (41/270) ...
# Generating image for seed 60042 (42/270) ...
# Generating image for seed 60043 (43/270) ...
# Generating image for seed 60044 (44/270) ...
# Generating image for seed 60045 (45/270) ...
# Generating image for seed 60046 (46/270) ...
# Generating image for seed 60047 (47/270) ...
# Generating image for seed 60048 (48/270) ...
# Generating image for seed 60049 (49/270) ...
# Generating image for seed 60050 (50/270) ...
# Generating image for seed 60051 (51/270) ...
# Generating image for seed 60052 (52/270) ...
# Generating image for seed 60053 (53/270) ...
# Generating image for seed 60054 (54/270) ...
# Generating image for seed 60055 (55/270) ...
# Generating image for seed 60056 (56/270) ...
# Generating image for seed 60057 (57/270) ...
# Generating image for seed 60058 (58/270) ...
# Generating image for seed 60059 (59/270) ...
# Generating image for seed 60060 (60/270) ...
# Generating image for seed 60061 (61/270) ...
# Generating image for seed 60062 (62/270) ...
# Generating image for seed 60063 (63/270) ...
# Generating image for seed 60064 (64/270) ...
# Generating image for seed 60065 (65/270) ...
# Generating image for seed 60066 (66/270) ...
# Generating image for seed 60067 (67/270) ...
# Generating image for seed 60068 (68/270) ...
# Generating image for seed 60069 (69/270) ...
# Generating image for seed 60070 (70/270) ...
# Generating image for seed 60071 (71/270) ...
# Generating image for seed 60072 (72/270) ...
# Generating image for seed 60073 (73/270) ...
# Generating image for seed 60074 (74/270) ...
# Generating image for seed 60075 (75/270) ...
# Generating image for seed 60076 (76/270) ...
# Generating image for seed 60077 (77/270) ...
# Generating image for seed 60078 (78/270) ...
# Generating image for seed 60079 (79/270) ...
# Generating image for seed 60080 (80/270) ...
# Generating image for seed 60081 (81/270) ...
# Generating image for seed 60082 (82/270) ...
# Generating image for seed 60083 (83/270) ...
# Generating image for seed 60084 (84/270) ...
# Generating image for seed 60085 (85/270) ...
# Generating image for seed 60086 (86/270) ...
# Generating image for seed 60087 (87/270) ...
# Generating image for seed 60088 (88/270) ...
# Generating image for seed 60089 (89/270) ...
# Generating image for seed 60090 (90/270) ...
# Generating image for seed 60091 (91/270) ...
# Generating image for seed 60092 (92/270) ...
# Generating image for seed 60093 (93/270) ...
# Generating image for seed 60094 (94/270) ...
# Generating image for seed 60095 (95/270) ...
# Generating image for seed 60096 (96/270) ...
# Generating image for seed 60097 (97/270) ...
# Generating image for seed 60098 (98/270) ...
# Generating image for seed 60099 (99/270) ...
# Generating image for seed 60100 (100/270) ...
# Generating image for seed 60101 (101/270) ...
# Generating image for seed 60102 (102/270) ...
# Generating image for seed 60103 (103/270) ...
# Generating image for seed 60104 (104/270) ...
# Generating image for seed 60105 (105/270) ...
# Generating image for seed 60106 (106/270) ...
# Generating image for seed 60107 (107/270) ...
# Generating image for seed 60108 (108/270) ...
# Generating image for seed 60109 (109/270) ...
# Generating image for seed 60110 (110/270) ...
# Generating image for seed 60111 (111/270) ...
# Generating image for seed 60112 (112/270) ...
# Generating image for seed 60113 (113/270) ...
# Generating image for seed 60114 (114/270) ...
# Generating image for seed 60115 (115/270) ...
# Generating image for seed 60116 (116/270) ...
# Generating image for seed 60117 (117/270) ...
# Generating image for seed 60118 (118/270) ...
# Generating image for seed 60119 (119/270) ...
# Generating image for seed 60120 (120/270) ...
# Generating image for seed 60121 (121/270) ...
# Generating image for seed 60122 (122/270) ...
# Generating image for seed 60123 (123/270) ...
# Generating image for seed 60124 (124/270) ...
# Generating image for seed 60125 (125/270) ...
# Generating image for seed 60126 (126/270) ...
# Generating image for seed 60127 (127/270) ...
# Generating image for seed 60128 (128/270) ...
# Generating image for seed 60129 (129/270) ...
# Generating image for seed 60130 (130/270) ...
# Generating image for seed 60131 (131/270) ...
# Generating image for seed 60132 (132/270) ...
# Generating image for seed 60133 (133/270) ...
# Generating image for seed 60134 (134/270) ...
# Generating image for seed 60135 (135/270) ...
# Generating image for seed 60136 (136/270) ...
# Generating image for seed 60137 (137/270) ...
# Generating image for seed 60138 (138/270) ...
# Generating image for seed 60139 (139/270) ...
# Generating image for seed 60140 (140/270) ...
# Generating image for seed 60141 (141/270) ...
# Generating image for seed 60142 (142/270) ...
# Generating image for seed 60143 (143/270) ...
# Generating image for seed 60144 (144/270) ...
# Generating image for seed 60145 (145/270) ...
# Generating image for seed 60146 (146/270) ...
# Generating image for seed 60147 (147/270) ...
# Generating image for seed 60148 (148/270) ...
# Generating image for seed 60149 (149/270) ...
# Generating image for seed 60150 (150/270) ...
# Generating image for seed 60151 (151/270) ...
# Generating image for seed 60152 (152/270) ...
# Generating image for seed 60153 (153/270) ...
# Generating image for seed 60154 (154/270) ...
# Generating image for seed 60155 (155/270) ...
# Generating image for seed 60156 (156/270) ...
# Generating image for seed 60157 (157/270) ...
# Generating image for seed 60158 (158/270) ...
# Generating image for seed 60159 (159/270) ...
# Generating image for seed 60160 (160/270) ...
# Generating image for seed 60161 (161/270) ...
# Generating image for seed 60162 (162/270) ...
# Generating image for seed 60163 (163/270) ...
# Generating image for seed 60164 (164/270) ...
# Generating image for seed 60165 (165/270) ...
# Generating image for seed 60166 (166/270) ...
# Generating image for seed 60167 (167/270) ...
# Generating image for seed 60168 (168/270) ...
# Generating image for seed 60169 (169/270) ...
# Generating image for seed 60170 (170/270) ...
# Generating image for seed 60171 (171/270) ...
# Generating image for seed 60172 (172/270) ...
# Generating image for seed 60173 (173/270) ...
# Generating image for seed 60174 (174/270) ...
# Generating image for seed 60175 (175/270) ...
# Generating image for seed 60176 (176/270) ...
# Generating image for seed 60177 (177/270) ...
# Generating image for seed 60178 (178/270) ...
# Generating image for seed 60179 (179/270) ...
# Generating image for seed 60180 (180/270) ...
# Generating image for seed 60181 (181/270) ...
# Generating image for seed 60182 (182/270) ...
# Generating image for seed 60183 (183/270) ...
# Generating image for seed 60184 (184/270) ...
# Generating image for seed 60185 (185/270) ...
# Generating image for seed 60186 (186/270) ...
# Generating image for seed 60187 (187/270) ...
# Generating image for seed 60188 (188/270) ...
# Generating image for seed 60189 (189/270) ...
# Generating image for seed 60190 (190/270) ...
# Generating image for seed 60191 (191/270) ...
# Generating image for seed 60192 (192/270) ...
# Generating image for seed 60193 (193/270) ...
# Generating image for seed 60194 (194/270) ...
# Generating image for seed 60195 (195/270) ...
# Generating image for seed 60196 (196/270) ...
# Generating image for seed 60197 (197/270) ...
# Generating image for seed 60198 (198/270) ...
# Generating image for seed 60199 (199/270) ...
# Generating image for seed 60200 (200/270) ...
# Generating image for seed 60201 (201/270) ...
# Generating image for seed 60202 (202/270) ...
# Generating image for seed 60203 (203/270) ...
# Generating image for seed 60204 (204/270) ...
# Generating image for seed 60205 (205/270) ...
# Generating image for seed 60206 (206/270) ...
# Generating image for seed 60207 (207/270) ...
# Generating image for seed 60208 (208/270) ...
# Generating image for seed 60209 (209/270) ...
# Generating image for seed 60210 (210/270) ...
# Generating image for seed 60211 (211/270) ...
# Generating image for seed 60212 (212/270) ...
# Generating image for seed 60213 (213/270) ...
# Generating image for seed 60214 (214/270) ...
# Generating image for seed 60215 (215/270) ...
# Generating image for seed 60216 (216/270) ...
# Generating image for seed 60217 (217/270) ...
# Generating image for seed 60218 (218/270) ...
# Generating image for seed 60219 (219/270) ...
# Generating image for seed 60220 (220/270) ...
# Generating image for seed 60221 (221/270) ...
# Generating image for seed 60222 (222/270) ...
# Generating image for seed 60223 (223/270) ...
# Generating image for seed 60224 (224/270) ...
# Generating image for seed 60225 (225/270) ...
# Generating image for seed 60226 (226/270) ...
# Generating image for seed 60227 (227/270) ...
# Generating image for seed 60228 (228/270) ...
# Generating image for seed 60229 (229/270) ...
# Generating image for seed 60230 (230/270) ...
# Generating image for seed 60231 (231/270) ...
# Generating image for seed 60232 (232/270) ...
# Generating image for seed 60233 (233/270) ...
# Generating image for seed 60234 (234/270) ...
# Generating image for seed 60235 (235/270) ...
# Generating image for seed 60236 (236/270) ...
# Generating image for seed 60237 (237/270) ...
# Generating image for seed 60238 (238/270) ...
# Generating image for seed 60239 (239/270) ...
# Generating image for seed 60240 (240/270) ...
# Generating image for seed 60241 (241/270) ...
# Generating image for seed 60242 (242/270) ...
# Generating image for seed 60243 (243/270) ...
# Generating image for seed 60244 (244/270) ...
# Generating image for seed 60245 (245/270) ...
# Generating image for seed 60246 (246/270) ...
# Generating image for seed 60247 (247/270) ...
# Generating image for seed 60248 (248/270) ...
# Generating image for seed 60249 (249/270) ...
# Generating image for seed 60250 (250/270) ...
# Generating image for seed 60251 (251/270) ...
# Generating image for seed 60252 (252/270) ...
# Generating image for seed 60253 (253/270) ...
# Generating image for seed 60254 (254/270) ...
# Generating image for seed 60255 (255/270) ...
# Generating image for seed 60256 (256/270) ...
# Generating image for seed 60257 (257/270) ...
# Generating image for seed 60258 (258/270) ...
# Generating image for seed 60259 (259/270) ...
# Generating image for seed 60260 (260/270) ...
# Generating image for seed 60261 (261/270) ...
# Generating image for seed 60262 (262/270) ...
# Generating image for seed 60263 (263/270) ...
# Generating image for seed 60264 (264/270) ...
# Generating image for seed 60265 (265/270) ...
# Generating image for seed 60266 (266/270) ...
# Generating image for seed 60267 (267/270) ...
# Generating image for seed 60268 (268/270) ...
# Generating image for seed 60269 (269/270) ...
#   dataset_name         gan_image_id  fold_id  round_id  train_fold_id  \
# 0        dibas  fold1_seed20000_256        1         1              1
# 1        dibas  fold1_seed20001_256        1         1              1
# 2        dibas  fold1_seed20002_256        1         1              1
# 3        dibas  fold1_seed20003_256        1         1              1
# 4        dibas  fold1_seed20004_256        1         1              1
# 5        dibas  fold1_seed20005_256        1         1              1
# 6        dibas  fold1_seed20006_256        1         1              1
# 7        dibas  fold1_seed20007_256        1         1              1
# 8        dibas  fold1_seed20008_256        1         1              1
# 9        dibas  fold1_seed20009_256        1         1              1
#
#   test_fold_ids  binary_label binary_group   seed  image_size  \
# 0       2,3,4,5             0        cocci  20000         256
# 1       2,3,4,5             0        cocci  20001         256
# 2       2,3,4,5             0        cocci  20002         256
# 3       2,3,4,5             0        cocci  20003         256
# 4       2,3,4,5             0        cocci  20004         256
# 5       2,3,4,5             0        cocci  20005         256
# 6       2,3,4,5             0        cocci  20006         256
# 7       2,3,4,5             0        cocci  20007         256
# 8       2,3,4,5             0        cocci  20008         256
# 9       2,3,4,5             0        cocci  20009         256
#
#                                            file_path  \
# 0  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 1  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 2  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 3  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 4  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 5  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 6  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 7  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 8  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 9  gan_images_256/stylegan3/dibas/fold_1/seed2000...
#
#                                        snapshot_path          source_type
# 0  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 1  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 2  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 3  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 4  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 5  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 6  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 7  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 8  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 9  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated

# %%
# We resize every generated image to the fixed 224x224 CNN input size.
generated_rows_224 = []
for row in generated_rows_256:
    fold_id = int(row["fold_id"])
    source_file = REPO_ROOT / row["file_path"]
    target_dir = GAN_IMAGES_224_DIR / f"fold_{fold_id}"
    target_dir.mkdir(parents=True, exist_ok=True)
    target_file = target_dir / source_file.name

    with Image.open(source_file) as image_handle:
        image = image_handle.convert("RGB")
        resized_image = image.resize((CNN_PATCH_SIZE, CNN_PATCH_SIZE), Image.Resampling.LANCZOS)
        resized_image.save(target_file)

    generated_rows_224.append({
        "dataset_name": row["dataset_name"],
        "gan_image_id": row["gan_image_id"].replace("_256", "_224"),
        "fold_id": row["fold_id"],
        "round_id": row["round_id"],
        "train_fold_id": row["train_fold_id"],
        "test_fold_ids": row["test_fold_ids"],
        "binary_label": row["binary_label"],
        "binary_group": row["binary_group"],
        "seed": row["seed"],
        "image_size": CNN_PATCH_SIZE,
        "file_path": as_repo_relative(REPO_ROOT, target_file),
        "source_file_256": row["file_path"],
        "snapshot_path": row["snapshot_path"],
        "source_type": row["source_type"],
    })

write_csv_rows(MANIFESTS_DIR / "stylegan3_generated_manifest_224.csv", generated_rows_224, list(generated_rows_224[0].keys()))

summary = {
    "notebook_tag": NOTEBOOK_TAG,
    "seed": SEED,
    "stylegan_random_seed": STYLEGAN_RANDOM_SEED,
    "gan_patch_size": GAN_PATCH_SIZE,
    "cnn_patch_size": CNN_PATCH_SIZE,
    "gan_batch_size": GAN_BATCH_SIZE,
    "gan_workers": GAN_WORKERS,
    "gan_kimg": GAN_KIMG,
    "gan_mirror": GAN_MIRROR,
    "snap_ticks": SNAP_TICKS,
    "snapshot_selection_kimg": SNAPSHOT_SELECTION_KIMG,
    "ada_target": ADA_TARGET,
    "gan_cfg": GAN_CFG,
    "gan_aug": GAN_AUG,
    "gan_augpipe_reference": GAN_AUGPIPE_REFERENCE,
    "stylegan3_gamma": GAN_GAMMA,
    "kid_metric_name": KID_METRIC_NAME,
    "generated_manifest_256": as_repo_relative(REPO_ROOT, MANIFESTS_DIR / "stylegan3_generated_manifest_256.csv"),
    "generated_manifest_224": as_repo_relative(REPO_ROOT, MANIFESTS_DIR / "stylegan3_generated_manifest_224.csv"),
}
write_json(NOTEBOOK_RESULTS_DIR / "summary.json", summary)

fold_result_rows = []
for fold_plan in fold_plan_rows:
    fold_id = int(fold_plan["train_fold_id"])
    generated_count = sum(1 for row in generated_rows_224 if int(row["fold_id"]) == fold_id)
    fold_result_rows.append({
        "fold_id": fold_id,
        "needed_gan_count_224": int(fold_plan["needed_gan_count_224"]),
        "generated_count_224": generated_count,
        "selected_snapshot_kimg": int(kid_lookup[fold_id]["snapshot_kimg"]),
        "selected_kid50k_full": kid_lookup[fold_id]["kid50k_full"],
    })

write_csv_rows(NOTEBOOK_RESULTS_DIR / "gan_summary_by_fold.csv", fold_result_rows, list(fold_result_rows[0].keys()))
display(pd.DataFrame(fold_result_rows))
display(pd.DataFrame(generated_rows_224[:10]))

# This preview helps us audit that the resized synthetic patches look sensible.
preview_rows = generated_rows_224[:8]
if preview_rows:
    figure_columns = min(4, len(preview_rows))
    figure_rows = math.ceil(len(preview_rows) / figure_columns)
    fig, axes = plt.subplots(figure_rows, figure_columns, figsize=(4 * figure_columns, 4 * figure_rows))
    if not isinstance(axes, (list, tuple)):
        axes = [axes]
    flat_axes = []
    for item in axes:
        if isinstance(item, (list, tuple)):
            flat_axes.extend(item)
        else:
            try:
                flat_axes.extend(item.flatten().tolist())
            except AttributeError:
                flat_axes.append(item)
    for axis, row in zip(flat_axes, preview_rows):
        image_path = REPO_ROOT / row["file_path"]
        with Image.open(image_path) as image_handle:
            axis.imshow(image_handle.convert("RGB"))
        axis.set_title(f"fold {row['fold_id']} | seed {row['seed']}")
        axis.axis("off")
    for axis in flat_axes[len(preview_rows):]:
        axis.axis("off")
    fig.tight_layout()
    fig.savefig(NOTEBOOK_RESULTS_DIR / "generated_preview_224.png", dpi=200)
    plt.show()
print(f"Saved generated 224 manifest to: {MANIFESTS_DIR / 'stylegan3_generated_manifest_224.csv'}")
# Out:
#    fold_id  needed_gan_count_224  generated_count_224  selected_snapshot_kimg  \
# 0        1                   270                  270                     200
# 1        2                   270                  270                     200
# 2        3                   270                  270                     120
# 3        4                   270                  270                     160
# 4        5                   270                  270                     160
#
#    selected_kid50k_full
# 0              0.076788
# 1              0.052895
# 2              0.063196
# 3              0.041956
# 4              0.073210
#   dataset_name         gan_image_id  fold_id  round_id  train_fold_id  \
# 0        dibas  fold1_seed20000_224        1         1              1
# 1        dibas  fold1_seed20001_224        1         1              1
# 2        dibas  fold1_seed20002_224        1         1              1
# 3        dibas  fold1_seed20003_224        1         1              1
# 4        dibas  fold1_seed20004_224        1         1              1
# 5        dibas  fold1_seed20005_224        1         1              1
# 6        dibas  fold1_seed20006_224        1         1              1
# 7        dibas  fold1_seed20007_224        1         1              1
# 8        dibas  fold1_seed20008_224        1         1              1
# 9        dibas  fold1_seed20009_224        1         1              1
#
#   test_fold_ids  binary_label binary_group   seed  image_size  \
# 0       2,3,4,5             0        cocci  20000         224
# 1       2,3,4,5             0        cocci  20001         224
# 2       2,3,4,5             0        cocci  20002         224
# 3       2,3,4,5             0        cocci  20003         224
# 4       2,3,4,5             0        cocci  20004         224
# 5       2,3,4,5             0        cocci  20005         224
# 6       2,3,4,5             0        cocci  20006         224
# 7       2,3,4,5             0        cocci  20007         224
# 8       2,3,4,5             0        cocci  20008         224
# 9       2,3,4,5             0        cocci  20009         224
#
#                                            file_path  \
# 0  gan_images_224/stylegan3/dibas/fold_1/seed2000...
# 1  gan_images_224/stylegan3/dibas/fold_1/seed2000...
# 2  gan_images_224/stylegan3/dibas/fold_1/seed2000...
# 3  gan_images_224/stylegan3/dibas/fold_1/seed2000...
# 4  gan_images_224/stylegan3/dibas/fold_1/seed2000...
# 5  gan_images_224/stylegan3/dibas/fold_1/seed2000...
# 6  gan_images_224/stylegan3/dibas/fold_1/seed2000...
# 7  gan_images_224/stylegan3/dibas/fold_1/seed2000...
# 8  gan_images_224/stylegan3/dibas/fold_1/seed2000...
# 9  gan_images_224/stylegan3/dibas/fold_1/seed2000...
#
#                                      source_file_256  \
# 0  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 1  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 2  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 3  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 4  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 5  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 6  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 7  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 8  gan_images_256/stylegan3/dibas/fold_1/seed2000...
# 9  gan_images_256/stylegan3/dibas/fold_1/seed2000...
#
#                                        snapshot_path          source_type
# 0  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 1  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 2  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 3  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 4  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 5  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 6  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 7  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 8  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# 9  checkpoints/24_train_stylegan3_make_images_dib...  stylegan3_generated
# Saved generated 224 manifest to: C:\Users\FYP2610\Downloads\FYP2\manifests\stylegan3_generated_manifest_224.csv
